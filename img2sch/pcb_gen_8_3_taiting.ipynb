# %% [markdown]
# # Library

# %%
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt
import pprint
import numpy as np
from matplotlib.patches import Rectangle, Circle,Polygon
from itertools import permutations
from IPython.display import display, clear_output
import time
import math
import heapq
from lxml import etree

# %% [markdown]
# # Layout (.brd) Extract Function

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
csv_path = "/Users/linkaiyuan/文件/PSU/eagle_stats.csv"
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip()  # Strip spaces

# List of fields to plot
fields = [
    'Num Components',
    'Num Nets',
    'Num Pads',
    'Num Layers',
    'Num of total pins',
    'Width',
    'Height'
]

# Convert all to numeric (in case of object dtype)
for field in fields:
    df[field] = pd.to_numeric(df[field], errors='coerce')

# Plot and save each field
for field in fields:
    df_sorted = df.sort_values(by=field, ascending=False).reset_index(drop=True)
    
    plt.figure(figsize=(10, 5))
    plt.bar(range(len(df_sorted)), df_sorted[field])
    plt.title(f"{field} per Board")
    plt.xlabel("Board Index")
    plt.ylabel(field)
    plt.tight_layout()

    # Save to PNG
    safe_field_name = field.replace(" ", "_").lower()
    save_path = f"{safe_field_name}_per_board.png"
    plt.savefig(save_path, dpi=300)
    plt.close()
    print(f"Saved plot: {save_path}")
# Out:
# Saved plot: num_components_per_board.png
# Saved plot: num_nets_per_board.png
# Saved plot: num_pads_per_board.png
# Saved plot: num_layers_per_board.png
# Saved plot: num_of_total_pins_per_board.png
# Saved plot: width_per_board.png
# Saved plot: height_per_board.png

# %%
# Convert XML to dict
def xml_to_dict(element):
    """
    Recursively converts an XML element and its children into a dictionary.
    """
    # Convert attributes and text of the element to a dictionary
    result = {element.tag: {} if element.attrib else None}

    # Add element attributes to the dictionary
    if element.attrib:
        result[element.tag].update((key, value) for key, value in element.attrib.items())

    # Add element text to the dictionary if it exists
    if element.text and element.text.strip():
        text = element.text.strip()
        if result[element.tag]:
            result[element.tag]['text'] = text
        else:
            result[element.tag] = text

    # Convert child elements
    children = list(element)
    if children:
        child_dict = {}
        for child in children:
            child_result = xml_to_dict(child)
            if child.tag in child_dict:
                if isinstance(child_dict[child.tag], list):
                    child_dict[child.tag].append(child_result[child.tag])
                else:
                    child_dict[child.tag] = [child_dict[child.tag], child_result[child.tag]]
            else:
                child_dict.update(child_result)
        if result[element.tag]:
            result[element.tag].update(child_dict)
        else:
            result[element.tag] = child_dict

    return result

# Output elements from a file according the path
def get_elements(file,root):
    list_elements = []
    for elements in file.getroot().findall(root):
        for element in elements:
            list_elements.append(element)
    return list_elements

# print list of elements attribute
def print_elements(list_elements):
    for element in list_elements:
        print(element,element.attrib.items())

# Output list of elements according the tag name
def get_tag_name(list_elements,tag_name):
    return [elem for elem in list_elements if elem.tag == tag_name]

# Output wire from an element
def get_wire(wire):
    return [[float(wire.get('x1')),float(wire.get('y1'))],[float(wire.get('x2')),float(wire.get('y2'))]]
    # return [[float(wire.get('x1')),float(wire.get('x2'))],[float(wire.get('y1')),float(wire.get('y2'))]]

# Output wires from list of  element
def get_wires(elements):
    wires =[]
    for element in elements:
        wire = get_wire(element)
        wires.append(wire)
    return wires

# Output smd of an element
def get_smd(ICsmd):
    smd_names = []
    # print('HWE',ICsmd)
    if isinstance(ICsmd, list):
        for smd in ICsmd:
            # print('HWE',smd.keys())
            x = float(smd.get('x'))
            y = float(smd.get('y'))
            tmp_smd = {}
            tmp_smd['name'] = smd.get('name')
            tmp_smd['pos'] = [x,y]
            tmp_smd['wid_len'] = [float(smd.get('dx')),float(smd.get('dy'))]
            tmp_smd['rot'] = 'R0'
            if 'rot' in smd.keys():
                tmp_smd['rot'] = smd.get('rot')
                if tmp_smd['rot'].upper().startswith('M'):
                    tmp_smd['is_mirror'] = True
                else:
                    tmp_smd['is_mirror'] = False
            smd_names.append(tmp_smd)
            
    else:
        x = float(ICsmd.get('x'))
        y = float(ICsmd.get('y'))
        tmp_smd = {}
        tmp_smd['name'] = ICsmd.get('name')
        tmp_smd['pos'] = [x, y]
        tmp_smd['wid_len'] = [float(ICsmd.get('dx')), float(ICsmd.get('dy'))]
        tmp_smd['rot'] = 'R0'
        if 'rot' in ICsmd.keys():
            tmp_smd['rot'] = ICsmd.get('rot')
            if tmp_smd['rot'].upper().startswith('M'):
                tmp_smd['is_mirror'] = True
            else:
                tmp_smd['is_mirror'] = False
        smd_names.append(tmp_smd)
    return smd_names


def get_pad(ICpad):
    # print(ICpad)
    pads= []
    # print('HWE',ICpad)
    if isinstance(ICpad, list):
        for pad in ICpad:
            # print('HWE',smd.keys())
            x = float(pad.get('x'))
            y = float(pad.get('y'))
            tmp_pad = {}
            tmp_pad['name'] = pad.get('name')
            tmp_pad['pos'] = [x,y]
            tmp_pad['drill'] = pad.get('drill')
            tmp_pad['diameter'] = pad.get('diameter')
            pads.append(tmp_pad)
            
    else:
        x = float(ICpad.get('x'))
        y = float(ICpad.get('y'))
        tmp_pad = {}
        tmp_pad['name'] = ICpad.get('name')
        tmp_pad['pos'] = [x, y]
        tmp_pad['drill'] = ICpad.get('drill')
        tmp_pad['diameter'] = ICpad.get('diameter')

        pads.append(tmp_pad)
    return pads

def get_one_ic(pack,library_name):
    IC = {}
    IC['name'] = pack['name']
    IC['library'] = library_name


    if 'wire' in pack.keys():
        IC['wire'] = get_wires(pack['wire'])
    else:
        IC['wire'] = []

    if 'smd' in pack.keys():
        smd = pack['smd']
        # print(smd)
        IC['smd'] = get_smd(smd)
    else:
        IC['smd'] = []
    
    if 'pad' in pack.keys():
        pad = pack['pad']
        IC['pad'] = get_pad(pad)
    else:
        IC['pad'] = []


    return IC

# Output library from libraries
def get_IC_info(list_library):
    ICs = []
    for library in list_library:
        if isinstance(library['packages']['package'], list):
            for pack in library['packages']['package']:
                # print(pack['name'],library['name'] ,pack.keys())
                ICs.append(get_one_ic(pack, library['name']))
        else:
            # print(library['packages']['package']['name'],library['name'],library['packages']['package'].keys())
            # print(library['packages']['package']['smd'])
            ICs.append(get_one_ic(library['packages']['package'],library['name']))

    return ICs

# Output element information
def get_element_info(list_element):
    elements = []
    for ele in list_element:
        element = {}

        element['name'] = ele['name']
        element['pos'] = [ele['x'],ele['y']]
        element['package'] = ele['package']
        if 'rot' in ele.keys():
            element['rot'] = ele['rot']
            if element['rot'].upper().startswith('M'):
                element['is_mirror'] = True
            else:
                element['is_mirror'] = False
        else:
            element['rot'] = 'R0'
        elements.append(element)

    return elements

# Output position of contactref
def generate_wire_terminal(connection_point, elements, ic_library):
    element_map = {el['name']: el for el in elements}
    
    def get_position(element, pad_name):
        element_pos = [float(coord) for coord in element['pos']]
        rotation = int(element.get('rot', 'R0')[1:]) if element.get('rot', '').startswith('R') else 0
        is_mirror = True if element.get('rot', '').startswith('M') else False
        ic = next((ic for ic in ic_library if ic['name'] == element['package']), None)
        
        if ic:
            pad = next((smd for smd in ic.get('smd', []) if smd['name'] == pad_name), None)
            if pad:
                rotated_pad = rotate_point(pad['pos'], [0, 0], rotation)
                if is_mirror:
                    rotated_pad[0] = -rotated_pad[0]
                return [
                    element_pos[0] + rotated_pad[0],
                    element_pos[1] + rotated_pad[1]
                ]
        return element_pos  # If no pad is found, return the element position itself
    
    # Extract the element and pad from the input
    element_name = connection_point['ele']
    pad_name = connection_point['pad']
    
    # Get the corresponding element from the elements list
    element = element_map[element_name]
    
    # Calculate the position of the pad
    position = get_position(element, pad_name)
    
    return position

# Output contactref from signals
def get_contactref(list_contactref,elements,ic_library):
    contactrefs = []
    
    if  isinstance(list_contactref, list):
        for contact in list_contactref:
            # print("contact:",contact)
            contactref = {}
            contactref['ele'] = contact['element']
            contactref['pad'] = contact['pad']
            contactref['pos'] = generate_wire_terminal( {'ele': contact['element'], 'pad': contact['pad']}, elements, ic_library)
            contactrefs.append(contactref)
    else:
        # print("contact2:",list_contactref)
        contactref = {}
        contactref['ele'] = list_contactref['element']
        contactref['pad'] = list_contactref['pad']
        contactref['pos'] = generate_wire_terminal( {'ele': list_contactref['element'], 'pad': list_contactref['pad']}, elements, ic_library)
        contactrefs.append(contactref)

    return contactrefs

# Output wire from signals
def get_wire_signals(list_wires):
    wires = []

    if isinstance(list_wires, list):
        for w in list_wires:
            if w['layer'] == '19':
                wire = {}
                wire['wire'] = get_wire(w)
                wires.append(wire)
    else:
        if list_wires['layer'] == '19':
                wire = {}
                wire['wire'] = get_wire(list_wires)
                wires.append(wire)

    return wires


# Output Signal
def get_signal_info(list_signal,elements,ic_library):
    
    signals = []
    
    for sig in list_signal:
        # print('name',sig['name'])
        signal = {}
        signal['name'] = sig['name']
        signal['contactref'] = []
        if 'contactref' in sig.keys():
            signal['contactref'] = get_contactref(sig['contactref'],elements,ic_library)
        
        signals.append(signal)
        
    return signals

def rotate_point(point, origin=[0, 0], angle=0):
    """Rotate a point counterclockwise by a given angle around a specified origin."""
    radians = np.deg2rad(angle)
    ox, oy = origin
    x, y = point

    x_new = ox + np.cos(radians) * (x - ox) - np.sin(radians) * (y - oy)
    y_new = oy + np.sin(radians) * (x - ox) + np.cos(radians) * (y - oy)

    return [x_new, y_new]

# %%
# Plot wires from a list of wires
def plot_wires(list_wires):
    plt.figure(figsize=(6, 4))
    for wire in list_wires:
        plt.plot(wire[0], wire[1], marker='o')

    # Set the aspect of the plot to be equal
    plt.gca().set_aspect('equal', adjustable='box')

    # Add labels and title
    plt.xlabel('X coordinate')
    plt.ylabel('Y coordinate')
    plt.title('Wires Visualization')

    # Show the grid
    plt.grid(True)

    # Display the plot
    plt.show()


def plot_pcb_and_elements(ax, border_segments, elements, ic_library, signals=None, mirrored=False, legend=False, show_rectangles=True, show_wires=True):
    # Extract the coordinates from the border segments
    x_coords_border = [coord[0] for segment in border_segments for coord in segment]
    y_coords_border = [coord[1] for segment in border_segments for coord in segment]

    x_min, x_max = min(x_coords_border), max(x_coords_border)
    y_min, y_max = min(y_coords_border), max(y_coords_border)

    # Handle mirroring if necessary
    if mirrored:
        x_coords_border = [-x for x in x_coords_border]
        border_segments = [[[-coord[0], coord[1]] for coord in segment] for segment in border_segments]

    # Plot the PCB border
    for segment in border_segments:
        x_values = [point[0] for point in segment]
        y_values = [point[1] for point in segment]
        ax.plot(x_values, y_values, color='black', linestyle='-', linewidth=2, label='PCB Border')

    # Define a colormap for the elements
    num_elements = len(elements)
    color_map = plt.cm.get_cmap('tab20', num_elements)

    for idx, element in enumerate(elements):
        is_mirrored = element.get('rot', '').startswith('MR')

        # Skip elements that don't match the current mirroring state
        if is_mirrored != mirrored:
            continue

        ic = next((item for item in ic_library if item['name'] == element['package']), None)
        if ic is None:
            continue

        element_pos = [float(coord) for coord in element['pos']]
        element_rotation = int(element.get('rot', 'R0')[1:]) if element.get('rot', '').startswith('R') else 0

        if mirrored:
            element_pos[0] = -element_pos[0]
            element_rotation = -element_rotation

        circle = Circle(element_pos, radius=0.05, color=color_map(idx), alpha=0.8, label=f"{element['name']} Position")
        ax.add_patch(circle)

        # Plot pads with drill holes as filled rings (annuli)
        for pad in ic.get('pad', []):
            pad_pos = [pad['pos'][0] + element_pos[0], pad['pos'][1] + element_pos[1]]
            if 'drill' in pad and 'diameter' in pad:
                outer_radius = float(pad['diameter']) / 2
                drill_radius = float(pad['drill']) / 2
                
                # Draw the outer circle of the pad
                pad_circle_outer = Circle(pad_pos, radius=outer_radius, color='blue', fill=True, alpha=0.5)
                ax.add_patch(pad_circle_outer)
                
                # Draw the inner (drill) circle as an empty space
                pad_circle_drill = Circle(pad_pos, radius=drill_radius, color='white', fill=True)
                ax.add_patch(pad_circle_drill)

        # Rotate and plot SMDs
        for smd in ic['smd']:
            smd_rotation_str = smd.get('rot', 'R0') if smd.get('rot') else 'R0'
            smd_rotation = int(smd_rotation_str[1:]) if smd_rotation_str.startswith('R') else 0

            smd_relative_pos = smd['pos']
            smd_wid_len = smd.get('wid_len', [0.1, 0.1])

            smd_corners = [
                [-smd_wid_len[0] / 2, -smd_wid_len[1] / 2],
                [smd_wid_len[0] / 2, -smd_wid_len[1] / 2],
                [smd_wid_len[0] / 2, smd_wid_len[1] / 2],
                [-smd_wid_len[0] / 2, smd_wid_len[1] / 2]
            ]

            smd_corners_rotated = [rotate_point(corner, [0, 0], smd_rotation) for corner in smd_corners]
            smd_corners_rotated = [[corner[0] + smd_relative_pos[0], corner[1] + smd_relative_pos[1]] for corner in smd_corners_rotated]
            smd_corners_final = [rotate_point(corner, [0, 0], element_rotation) for corner in smd_corners_rotated]
            smd_corners_final = [[corner[0] + element_pos[0], corner[1] + element_pos[1]] for corner in smd_corners_final]

            if show_rectangles:
                polygon = Polygon(smd_corners_final, color=color_map(idx), alpha=0.5)
                ax.add_patch(polygon)
            else:
                ax.scatter(*smd_corners_final[0], color=color_map(idx), label=f"{element['name']} SMD {smd['name']}")

            smd_label_x = np.mean([corner[0] for corner in smd_corners_final])
            smd_label_y = np.mean([corner[1] for corner in smd_corners_final])
            ax.text(smd_label_x, smd_label_y, f"{smd['name']}", fontsize=8, ha='center', va='center', color='white')

    # Plot positions of terminals if signals are provided
    if signals:
        for signal in signals:
            for contact in signal['contactref']:
                # Check if the current contact belongs to a mirrored element
                contact_element = next((el for el in elements if el['name'] == contact['ele']), None)
                contact_is_mirrored = contact_element and contact_element.get('rot', '').startswith('MR')

                # Only plot terminals that match the current mirroring state
                if contact_is_mirrored == mirrored:
                    pos = contact['pos']
                    if mirrored:
                        pos = [-pos[0], pos[1]]
                    ax.add_patch(Circle(pos, radius=0.1, color='red', fill=True, alpha=0.6))

    # Set the limits of the plot
    margin = 5.0
    ax.set_xlim(min(x_coords_border) - margin, max(x_coords_border) + margin)
    ax.set_ylim(y_min - margin, y_max + margin)

    # Set the aspect of the plot to be equal
    ax.set_aspect('equal', adjustable='box')

    # Add labels and title
    plot_type = "Mirrored" if mirrored else "Regular"
    ax.set_xlabel('X coordinate')
    ax.set_ylabel('Y coordinate')
    ax.set_title(f'PCB and SMD Positions ({plot_type})')

    # Show the grid
    ax.grid(True, which='both', axis='both', color='gray', linestyle='--', linewidth=0.5)

    # Set mirrored grid settings if necessary
    if mirrored:
        ax.set_xticks(np.arange(x_min - margin, x_max + margin, 1) * -1)
    else:
        ax.set_xticks(np.arange(x_min - margin, x_max + margin, 1))

    ax.set_yticks(np.arange(y_min - margin, y_max + margin, 1))

    # Show legend if requested
    if legend:
        ax.legend(loc='upper right', fontsize='small', markerscale=0.5)

               
def plot_all_elements(border_segments, elements, ic_library, signals=None, view="both", legend=False, show_rectangles=True):
    """Plot all elements with options to display mirrored, regular, or both elements."""
    
    # Determine the number of subplots based on the view parameter
    if view == "both":
        num_plots = 2
    else:
        num_plots = 1
    
    # Create subplots
    fig, axes = plt.subplots(num_plots, 1, figsize=(10, 8 * num_plots))
    
    # If only one plot, axes is not a list
    if not isinstance(axes, np.ndarray):
        axes = [axes]

    # Plot based on the view parameter
    if view in ["regular", "both"]:
        plot_pcb_and_elements(axes[0], border_segments, elements, ic_library, signals=signals, mirrored=False, legend=legend, show_rectangles=show_rectangles)

    if view in ["mirrored", "both"]:
        plot_pcb_and_elements(axes[-1], border_segments, elements, ic_library, signals=signals, mirrored=True, legend=legend, show_rectangles=show_rectangles)

    # Adjust layout to avoid overlap
    plt.tight_layout()

    # plt.show()
    
    # Display the plots
    plt.savefig('pcb_plot.png', dpi=300, bbox_inches='tight')


def process_board_file(file_path):
    """
    Process the board file and extract relevant information.

    Args:
        file_path (str): Path to the board file.

    Returns:
        dict: A dictionary containing board information.
    """
    tree = ET.parse(file_path)
    root = tree.getroot()
    xml_dict = xml_to_dict(root)

    board_dimension = xml_dict['eagle']['drawing']['board']['plain']['wire']
    board_library = xml_dict['eagle']['drawing']['board']['libraries']['library']
    board_element = xml_dict['eagle']['drawing']['board']['elements']['element']
    board_signal = xml_dict['eagle']['drawing']['board']['signals']['signal']

    board_info = {}
    board_info['board dimension'] = get_wires(board_dimension)
    board_info['IC_library'] = get_IC_info(board_library)
    board_info['elements'] = get_element_info(board_element)
    board_info['signals'] = get_signal_info(board_signal, board_info['elements'], board_info['IC_library'])

    return board_info

# %% [markdown]
# # Sample

# %%
if __name__ == "__main__":
    # Load and parse the XML file for the specified IC
    folder_path = r"/Users/linkaiyuan/文件/PSU/Module_library"
    IC_name = "ICM-20948"
    file_name = f"{folder_path}\\{IC_name}\\{IC_name}.brd"

    file_name = r"/Users/linkaiyuan/Documents/EAGLE/projects/sparkfunmicropractis/SparkFun_IMU_Breakout_ICM-20948.brd"
    # Process the board file and plot
    board_info = process_board_file(file_name)
    print(board_info['signals'][1])

    plot_all_elements(border_segments=board_info['board dimension'],
                    elements=board_info['elements'],
                    ic_library=board_info['IC_library'],
                    signals=board_info['signals'],
                    view="both", legend=False, show_rectangles=True)
# Out:
# {'name': 'N$1', 'contactref': [{'ele': 'U2', 'pad': '10', 'pos': [np.float64(5.76), np.float64(2.7199999999999998)]}, {'ele': 'C3', 'pad': '1', 'pos': [np.float64(8.45), np.float64(3.96)]}]}
# /var/folders/tl/q2dlpcnd685cw606gn_pd05h0000gn/T/ipykernel_66723/1460233388.py:100: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = plt.cm.get_cmap('tab20', num_elements)

# %% [markdown]
# # Schematic (.sch) Extract Function

# %%
# Convert XML to dict
def xml_to_dict(element):
    """
    Recursively converts an XML element and its children into a dictionary.
    """
    # Convert attributes and text of the element to a dictionary
    result = {element.tag: {} if element.attrib else None}

    # Add element attributes to the dictionary
    if element.attrib:
        result[element.tag].update((key, value) for key, value in element.attrib.items())

    # Add element text to the dictionary if it exists
    if element.text and element.text.strip():
        text = element.text.strip()
        if result[element.tag]:
            result[element.tag]['text'] = text
        else:
            result[element.tag] = text

    # Convert child elements
    children = list(element)
    if children:
        child_dict = {}
        for child in children:
            child_result = xml_to_dict(child)
            if child.tag in child_dict:
                if isinstance(child_dict[child.tag], list):
                    child_dict[child.tag].append(child_result[child.tag])
                else:
                    child_dict[child.tag] = [child_dict[child.tag], child_result[child.tag]]
            else:
                child_dict.update(child_result)
        if result[element.tag]:
            result[element.tag].update(child_dict)
        else:
            result[element.tag] = child_dict

    return result


def get_deviceset_element(schematic_library, library_name, deviceset_name):
    """
    Extract the entire element of the deviceset from the schematic library.

    Args:
        schematic_library (list): List of libraries from the schematic XML.
        library_name (str): Name of the library containing the deviceset.
        deviceset_name (str): Name of the deviceset to extract.

    Returns:
        dict: The entire element of the deviceset, or None if not found.
    """
    # Find the library with the specified name
    library = next((lib for lib in schematic_library if lib['name'] == library_name), None)
    if not library:
        print(f"Library '{library_name}' not found.")
        return None
    

    # Find the deviceset within the library
    devicesets = library.get('devicesets', {}).get('deviceset', [])
    if not isinstance(devicesets, list):
        devicesets = [devicesets]

    deviceset = next((ds for ds in devicesets if ds['name'] == deviceset_name), None)
    if not deviceset:
        print(f"Deviceset '{deviceset_name}' not found in library '{library_name}'.")
        return None

    return deviceset


def extract_deviceset_info(deviceset_xml, device_name):
    """
    Extract deviceset name, symbol, and package from a deviceset XML.

    Args:
        deviceset_xml (dict): The deviceset XML as a dictionary.
        device_name (str): The name of the device to extract information for.

    Returns:
        dict: A dictionary containing the deviceset name, symbol, and package.
    """
    deviceset_info = {
        'name': deviceset_xml.get('name', 'Unknown'),
        'symbols': 'Unknown',
        'packages': ['Unknown']
    }

    # Extract gates and their symbols
    gates = deviceset_xml.get('gates', {}).get('gate', [])
    if isinstance(gates, dict):
        gates = [gates]
    if gates:
        deviceset_info['symbols'] = gates[0].get('symbol', 'Unknown')

    # Extract devices and their packages
    devices = deviceset_xml.get('devices', {}).get('device', [])
    if isinstance(devices, dict):
        devices = [devices]

    # Find the device with the specified device_name
    device_info = next((device for device in devices if device.get('name') == device_name), None)
    if device_info:
        deviceset_info['packages'] = device_info.get('package', 'Unknown')

    return deviceset_info


def map_part_to_deviceset(schematic_parts, schematic_library, schematic_instance):
    """
    Maps parts to their corresponding deviceset names, libraries, and additional attributes,
    including a list of instances with gate-specific information.

    Args:
        schematic_parts (list): List of parts containing deviceset, library, and value information.
        schematic_instance (list): List of instances containing part names and other attributes.

    Returns:
        dict: A dictionary where keys are part names and values are dictionaries containing deviceset, library,
              device, value, symbol, package, and a list of instances with gate-specific information.
    """
    # Create a mapping of part names to deviceset names, libraries, devices, and values
    # part_to_deviceset_and_library = {
    #     part['name']: {
    #         'deviceset': part['deviceset'],
    #         'library': part.get('library', 'Unknown'),
    #         'device': part.get('device', 'Unknown'),  # Include device information
    #         'value': '' if 'PowerSymbols' in part.get('library', 'Unknown') else part.get('value', ''),  # Conditionally include value information
    #         'package': 'Unknown',  # Initialize package information
    #         'instances': []  # Initialize an empty list for instances
    #     }
    #     for part in schematic_parts
    # }
    part_to_deviceset_and_library = {}

    for part in schematic_parts:
        part_name = part['name']
        part_info = {
            'deviceset': part['deviceset'],
            'library': part.get('library', 'Unknown'),
            'device': part.get('device', 'Unknown'),  # Include device information
            'value': '' if 'PowerSymbols' in part.get('library', 'Unknown') else part.get('value', ''),  # Conditionally include value information
            'package': 'Unknown',  # Initialize package information
            'instances': []  # Initialize an empty list for instances
        }


        # Optional attributes: add only if they exist
        optional_keys = ['library_urn', 'package3d_urn']
        for key in optional_keys:
            if key in part:
                part_info[key] = part[key]

        part_to_deviceset_and_library[part_name] = part_info
        
    # Map instances to their corresponding parts and add gate-specific information
    for instance in schematic_instance:
        
        part_name = instance['part']
        if part_name in part_to_deviceset_and_library:
            library_name = part_to_deviceset_and_library[part_name]['library']
            deviceset_name = part_to_deviceset_and_library[part_name]['deviceset']
            device_name = part_to_deviceset_and_library[part_name]['device']
            deviceset_element = get_deviceset_element(schematic_library, library_name, deviceset_name)

            # Find the symbol for the instance based on the gate name
            gate_name = instance.get('gate', 'Unknown')
            gates = deviceset_element.get('gates', {}).get('gate', [])
            if isinstance(gates, dict):
                gates = [gates]
            symbol = next((gate.get('symbol', 'Unknown') for gate in gates if gate.get('name') == gate_name), 'Unknown')

            instance_data = {
                'gate': gate_name,
                'x': instance.get('x', 'Unknown'),
                'y': instance.get('y', 'Unknown'),
                'rot': instance.get('rot', 'R0'),
                'symbol': symbol,
                "attribute": instance.get('attribute', [])
            }
            
            part_to_deviceset_and_library[part_name]['instances'].append(instance_data)

            # Update package information if not already set
            if part_to_deviceset_and_library[part_name]['package'] == 'Unknown':
                deviceset_info = extract_deviceset_info(deviceset_element, device_name)
                part_to_deviceset_and_library[part_name]['package'] = deviceset_info['packages']

    # for part in part_to_deviceset_and_library:
    #     print("part: ",part, part_to_deviceset_and_library[part])
        # print("--------------------------------------------------")

    return part_to_deviceset_and_library


def get_symbol_element_of_instance_from_library(library_xml, part_name, instance_gate_name, part_library):
    """
    Extract the symbol element from the library XML based on the part name and instance gate name.

    Args:
        library_xml (list): List of libraries from the schematic XML.
        part_name (str): Name of the part to extract the symbol for.
        instance_gate_name (str): Name of the gate to match the instance.
        part_library (dict): Dictionary containing part names mapped to their library, symbol, and other details.

    Returns:
        dict: The symbol element, or None if not found.
    """
    # Find the library name and symbol using the part name from the part library
    part_info = part_library.get(part_name)
    if not part_info:
        print(f"Part '{part_name}' not found in part library.")
        return None

    library_name = part_info.get('library')
    instances = part_info.get('instances', [])
    if not library_name or not instances:
        print(f"Library or instances not found for part '{part_name}'.")
        return None

    # Find the library with the specified name
    library = next((lib for lib in library_xml if lib['name'] == library_name), None)
    if not library:
        print(f"Library '{library_name}' not found.")
        return None

    # Extract symbols for the instance matching the specified gate name
    for instance in instances:
        
        if instance.get('gate') != instance_gate_name:
            continue
        

        symbol_name = instance.get('symbol')
        if not symbol_name:
            print(f"Symbol not found for instance in part '{part_name}'.")
            continue

        # Find the symbol in the library
        library_symbols = library.get('symbols', {}).get('symbol', [])
        if not isinstance(library_symbols, list):
            library_symbols = [library_symbols]

        symbol_element = next((sym for sym in library_symbols if sym['name'] == symbol_name), None)
        if not symbol_element:
            print(f"Symbol '{symbol_name}' not found in library '{library_name}'.")
            continue


        
        
        # print("instance:",instance)
        # print("------------------------")
        # Convert the symbol element into the desired dictionary format
        symbol_data = {
            'name': symbol_element.get('name', 'Unknown'),
            'wire': symbol_element.get('wire', []) if isinstance(symbol_element.get('wire', []), list) else [symbol_element.get('wire', [])],
            'text': instance.get('attribute', []) if isinstance(instance.get('attribute', []), list) else [instance.get('attribute', [])],
            'pin': symbol_element.get('pin', []) if isinstance(symbol_element.get('pin', []), list) else [symbol_element.get('pin', [])],
            'rectangle': symbol_element.get('rectangle', []) if isinstance(symbol_element.get('rectangle', []), list) else [symbol_element.get('rectangle', [])],
            'circle': symbol_element.get('circle', []) if isinstance(symbol_element.get('circle', []), list) else [symbol_element.get('circle', [])],
            'polygon': symbol_element.get('polygon', []) if isinstance(symbol_element.get('polygon', []), list) else [symbol_element.get('polygon', [])],
            'attribute': instance.get('attribute', []),
            'symbol_text': symbol_element.get('text',[]) if isinstance(symbol_element.get('text',[]), list) else [symbol_element.get('text',[])]
        }
        # if (symbol_element.get('name', 'Unknown') == "I2C_STANDARD"):
        #     import json
        #     with open("example_symbol_element.json", "w") as f:
        #                 json.dump(symbol_data, f, indent=4)
        # print("symbol_data:",symbol_data)
        # print("--------------------------------------------------")
        return symbol_data
    
    print(f"No matching symbol found for gate '{instance_gate_name}' in part '{part_name}'.")
    return None



import json

def find_connects(data, library_name, deviceset_name, device_name=""):
    """
    Extracts the 'connects' field from the specified device in the deviceset.

    Args:
        data (dict): The full JSON-parsed data structure.
        library_name (str): The name of the library (e.g. "40xx").
        deviceset_name (str): The name of the deviceset (e.g. "4066").
        device_name (str): The name of the specific device (e.g. "", "D", "N").

    Returns:
        list of dicts: The list of 'connect' entries, or None if not found.
    """
    for library in data.get("IC_library", []):
        if library.get("name") == library_name:
            devicesets = library.get("devicesets", {}).get("deviceset", {})
            if isinstance(devicesets, list):
                for ds in devicesets:
                    if ds.get("name") == deviceset_name:
                        # import json
                        # with open("text.json", "w") as f:
                        #     json.dump(ds, f, indent=2)
                        devices = ds.get("devices", {}).get("device")
                        if isinstance(devices, dict):
                            devices = [devices]
                        for device in devices:
                            if device.get("name") == device_name:
                                return device.get("connects", {}).get("connect", [])
            elif devicesets.get("name") == deviceset_name:
                devices = devicesets.get("devices", {}).get("device", [])
                if isinstance(devices, dict):
                    devices = [devices]
                for device in devices:
                    if device.get("name") == device_name:
                        return device.get("connects", {}).get("connect", [])
    return None

  
def retrieve_net_info(schematic_net):
    """
    Extract net information from the schematic net data.

    Args:
        schematic_net (list): List of nets from the schematic XML.

    Returns:
        dict: A dictionary where keys are net names and values are lists of segments,
              with each segment containing lists of pinrefs, wires, labels, and junctions.
    """
    net_info = {}

    # Ensure schematic_net is a list
    if not isinstance(schematic_net, list):
        schematic_net = [schematic_net]

    for net in schematic_net:
        net_name = net.get('name', 'Unknown')
        segments = net.get('segment', [])
        if not isinstance(segments, list):
            segments = [segments]

        # Process each segment
        processed_segments = []
        for segment in segments:
            processed_segment = {
                'pinref': segment.get('pinref', []) if isinstance(segment.get('pinref', []), list) else [segment.get('pinref', [])],
                'wire': segment.get('wire', []) if isinstance(segment.get('wire', []), list) else [segment.get('wire', [])],
                'label': segment.get('label', []) if isinstance(segment.get('label', []), list) else [segment.get('label', [])],
                'junction': segment.get('junction', []) if isinstance(segment.get('junction', []), list) else [segment.get('junction', [])]
            }
            processed_segments.append(processed_segment)

        net_info[net_name] = processed_segments

    return net_info



def process_schematic_file(file_path):
    """
    Process the board file and extract relevant information.

    Args:
        file_path (str): Path to the board file.

    Returns:
        dict: A dictionary containing board information.
    """
    tree = ET.parse(file_path)
    root = tree.getroot()
    xml_dict = xml_to_dict(root)

    # schematic_library = xml_dict['eagle']['drawing']['schematic']['libraries']['library']
    # schematic_parts = xml_dict['eagle']['drawing']['schematic']['parts']["part"]
    # schematic_instance = xml_dict['eagle']['drawing']['schematic']['sheets']["sheet"]['instances']['instance']
    # schematic_net = xml_dict['eagle']['drawing']['schematic']['sheets']["sheet"]['nets']['net']

        # Handle cases where instances, parts, or nets might not exist
    schematic_library = xml_dict.get('eagle', {}).get('drawing', {}).get('schematic', {}).get('libraries', {})
    if schematic_library is None:
        schematic_library = []
    else:
        schematic_library = schematic_library.get("library", []) or []
        if isinstance(schematic_library, dict):
            schematic_library = [schematic_library]

    schematic_parts = xml_dict.get('eagle', {}).get('drawing', {}).get('schematic', {}).get('parts', {})
    if schematic_parts is None:
        schematic_parts = []
    else:
        schematic_parts = schematic_parts.get("part", []) or []
        if isinstance(schematic_parts, dict):
            schematic_parts = [schematic_parts]

    # schematic_instance = xml_dict.get('eagle', {}).get('drawing', {}).get('schematic', {}).get('sheets', {}).get("sheet", {}).get('instances', {})
    schematic_instance = xml_dict.get('eagle', {})
    schematic_instance = schematic_instance.get('drawing', {})
    schematic_instance = schematic_instance.get('schematic', {}) 
    schematic_instance = schematic_instance.get('sheets', {})
    schematic_instance = schematic_instance.get("sheet", {}) 
    import json
    with open("text2.json", "w") as f:
        json.dump(schematic_instance, f, indent=2)
    schematic_instance = schematic_instance.get('instances', {})
    if schematic_instance is None:
        schematic_instance = []
    else:
        schematic_instance = schematic_instance.get("instance", []) or []
        if isinstance(schematic_instance, dict):
            schematic_instance = [schematic_instance]
    
    schematic_net = xml_dict.get('eagle', {}).get('drawing', {}).get('schematic', {}).get('sheets', {}).get("sheet", {}).get('nets', {})
    if schematic_net is None:
        schematic_net = []
    else:
        schematic_net = schematic_net.get("net", []) or []


    # print("schematic_library:", schematic_library)
    # print("schematic_parts:", schematic_parts)
    # print("schematic_instance:", schematic_instance)
    # print("schematic_net:", schematic_net)

    schematic_info = {}
    schematic_info['IC_library'] = schematic_library
    schematic_info['parts'] = map_part_to_deviceset(schematic_parts, schematic_library, schematic_instance)
    schematic_info['nets'] = retrieve_net_info(schematic_net) if schematic_net else {}


    # for net_name, segments in schematic_info['nets'].items():
    #     print("Net name:", net_name)
    #     print("Segments:")
    #     for segment in segments:
    #         print(segment)
    
    return schematic_info

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    # <pinref part="C2" gate="G$1" pin="1"/>
    # <wire x1="53.34" y1="220.98" x2="53.34" y2="210.82" width="0.1524" layer="91"/>
    # Output elements from a file according the path
    # Load and parse the XML file for the specified IC
    folder_path = r"/Users/linkaiyuan/文件/PSU/products/Big_Easy_Driver/BigEasyDriver_v16a.sch"
    # folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    # IC_name = "ICM-20948"
    # sch_file_name = f"{folder_path}/{IC_name}/{IC_name}.sch"
    sch_file_name = folder_path
    # print("schematic file name:", sch_file_name)
    # sch_file_name = r"F:\GitHub\PCBEDA\sample PCB\custom\template.sch"
    # sch_file_name = r"F:\GitHub\PCBEDA\sample PCB\custom\temp_add.sch"
    schematic_info = process_schematic_file(sch_file_name)

# %%
# for i in schematic_info['IC_library']:
#     print("IC library:", i)
    # for smd in i.get('smd', []):
    #     print("SMD:", smd['name'], "Position:", smd['pos'])


import json


for part_name in schematic_info['parts'].items():
        # print(part_name[1]['deviceset'], part_name[1]['library'], part_name[1]['device'])
        # symbol = part_name[1]['instances'][0]['symbol']
        # new_name = f"name_{part_name[1]['library']}_{symbol}"
         print(part_name)
    # new_name = f"name_{part_name[1]['library']}_{part_name[1]['symbol']}"



# with open("text.json", "w") as f:
#     json.dump(schematic_info, f, indent=2)
# Out:
# ('P+4', {'deviceset': '+5V', 'library': 'supply1', 'device': '', 'value': 'VCC', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '137.16', 'y': '55.88', 'rot': 'R0', 'symbol': '+5V', 'attribute': {'name': 'VALUE', 'x': '137.668', 'y': '56.642', 'size': '1.778', 'layer': '96'}}]})
# ('MOT_PWR', {'deviceset': 'V+', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '63.5', 'y': '58.42', 'rot': 'R0', 'symbol': 'V+', 'attribute': []}]})
# ('GND1', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '137.16', 'y': '68.58', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('FRAME1', {'deviceset': 'FRAME-LETTER', 'library': 'SparkFun-Aesthetics', 'device': '', 'value': '', 'package': 'CREATIVE_COMMONS', 'instances': [{'gate': 'G$1', 'x': '0', 'y': '0', 'rot': 'R0', 'symbol': 'LETTER_L', 'attribute': []}, {'gate': 'G$2', 'x': '147.32', 'y': '0', 'rot': 'R0', 'symbol': 'DOCFIELD', 'attribute': []}]})
# ('R6', {'deviceset': '390OHM1/10W1%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '390', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '78.74', 'y': '30.48', 'rot': 'R90', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R8', {'deviceset': '240OHM1/10W1%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '240', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '96.52', 'y': '43.18', 'rot': 'R90', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('PWR_LED', {'deviceset': 'LED', 'library': 'SparkFun03_30_09', 'device': '0603', 'value': 'YELLOW', 'package': 'LED-0603', 'instances': [{'gate': 'G$1', 'x': '137.16', 'y': '33.02', 'rot': 'R0', 'symbol': 'LED', 'attribute': [{'name': 'NAME', 'x': '140.716', 'y': '25.908', 'size': '1.778', 'layer': '95', 'rot': 'R90'}, {'name': 'VALUE', 'x': '142.875', 'y': '25.908', 'size': '1.778', 'layer': '96', 'rot': 'R90'}]}]})
# ('R9', {'deviceset': '1KOHM1/10W1%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '1K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '137.16', 'y': '43.18', 'rot': 'R90', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('P+1', {'deviceset': '+5V', 'library': 'supply1', 'device': '', 'value': 'VCC', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '137.16', 'y': '101.6', 'rot': 'R0', 'symbol': '+5V', 'attribute': {'name': 'VALUE', 'x': '139.446', 'y': '99.822', 'size': '1.778', 'layer': '96'}}]})
# ('C1', {'deviceset': '0.1UF-100V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.1uF', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '63.5', 'y': '43.18', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('IC2', {'deviceset': 'SPARKFUN03_30_09_V_REG_317', 'library': 'BigEasyDriver_v11', 'device': 'SOT89', 'value': 'LM317L', 'package': 'SCHMALZHAUS_SOT89', 'instances': [{'gate': 'G$1', 'x': '78.74', 'y': '50.8', 'rot': 'R0', 'symbol': 'SPARKFUN03_30_09_78ADJ', 'attribute': [{'name': 'NAME', 'x': '81.28', 'y': '43.18', 'size': '1.778', 'layer': '95'}, {'name': 'VALUE', 'x': '81.28', 'y': '40.64', 'size': '1.778', 'layer': '96'}]}]})
# ('APWR', {'deviceset': 'SOLDERJUMPER', 'library': 'SparkFun03_30_09', 'device': 'TRACE', 'value': '', 'package': 'SJ_2S-TRACE', 'instances': [{'gate': '1', 'x': '111.76', 'y': '50.8', 'rot': 'R0', 'symbol': 'SJ', 'attribute': []}]})
# ('3/5V', {'deviceset': 'SOLDERJUMPER', 'library': 'SparkFun03_30_09', 'device': 'NO', 'value': '', 'package': 'SJ_2S-NO', 'instances': [{'gate': '1', 'x': '86.36', 'y': '22.86', 'rot': 'R0', 'symbol': 'SJ', 'attribute': []}]})
# ('R7', {'deviceset': '330OHM1/10W1%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '330', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '78.74', 'y': '15.24', 'rot': 'R90', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R16', {'deviceset': 'TRIMPOT', 'library': 'SparkFun-Electromechanical', 'device': '3MM-2', 'value': '10K', 'package': 'TRIMPOT-3MM-2', 'instances': [{'gate': 'R?', 'x': '137.16', 'y': '78.74', 'rot': 'R270', 'symbol': 'TRIMPOT-1', 'attribute': [{'name': 'NAME', 'x': '138.938', 'y': '80.4926', 'size': '1.778', 'layer': '95'}, {'name': 'VALUE', 'x': '138.684', 'y': '75.946', 'size': '1.778', 'layer': '96'}]}]})
# ('GND4', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '35.56', 'y': '27.94', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('GND5', {'deviceset': 'GND', 'library': 'SparkFun', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '50.8', 'y': '35.56', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('GND9', {'deviceset': 'GND', 'library': 'SparkFun', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '63.5', 'y': '35.56', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('GND11', {'deviceset': 'GND', 'library': 'SparkFun', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '127', 'y': '22.86', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('GND12', {'deviceset': 'GND', 'library': 'SparkFun', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '137.16', 'y': '22.86', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('GND14', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '93.98', 'y': '5.08', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('GND15', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '78.74', 'y': '5.08', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('U$2', {'deviceset': 'LOGO-SFE', 'library': 'SparkFun', 'device': 'NEW', 'value': '', 'package': 'SFE-NEW-WEBLOGO', 'instances': [{'gate': 'G$1', 'x': '241.3', 'y': '17.78', 'rot': 'R0', 'symbol': 'LOGO1', 'attribute': []}]})
# ('TP1', {'deviceset': 'TP', 'library': 'testpad', 'device': 'PAD1-13', 'value': '', 'package': 'P1-13', 'instances': [{'gate': 'G$1', 'x': '144.78', 'y': '86.36', 'rot': 'R0', 'symbol': 'TP', 'attribute': []}]})
# ('JP8', {'deviceset': 'STAND-OFF', 'library': 'SparkFun-7-28-09', 'device': '', 'value': '', 'package': 'STAND-OFF', 'instances': [{'gate': 'G$1', 'x': '134.62', 'y': '2.54', 'rot': 'R0', 'symbol': 'STAND-OFF', 'attribute': []}]})
# ('JP9', {'deviceset': 'STAND-OFF', 'library': 'SparkFun-7-28-09', 'device': '', 'value': '', 'package': 'STAND-OFF', 'instances': [{'gate': 'G$1', 'x': '139.7', 'y': '2.54', 'rot': 'R0', 'symbol': 'STAND-OFF', 'attribute': []}]})
# ('JP6', {'deviceset': 'M02', 'library': 'SparkFun', 'device': 'PTH', 'value': '', 'package': '1X02', 'instances': [{'gate': 'G$1', 'x': '48.26', 'y': '109.22', 'rot': 'R0', 'symbol': 'M02', 'attribute': []}]})
# ('JP3', {'deviceset': 'M04', 'library': 'SparkFun', 'device': 'PTH', 'value': '', 'package': '1X04', 'instances': [{'gate': 'G$1', 'x': '50.8', 'y': '73.66', 'rot': 'R0', 'symbol': 'M04', 'attribute': []}]})
# ('JP1', {'deviceset': 'M02', 'library': 'SparkFun', 'device': 'PTH', 'value': '', 'package': '1X02', 'instances': [{'gate': 'G$1', 'x': '22.86', 'y': '48.26', 'rot': 'R0', 'symbol': 'M02', 'attribute': []}]})
# ('GND19', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '226.06', 'y': '147.32', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('R18', {'deviceset': '0.11OHM1/2W1%(2010)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '.11', 'package': 'R2010', 'instances': [{'gate': 'G$1', 'x': '218.44', 'y': '152.4', 'rot': 'R180', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R19', {'deviceset': '0.11OHM1/2W1%(2010)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '.11', 'package': 'R2010', 'instances': [{'gate': 'G$1', 'x': '218.44', 'y': '160.02', 'rot': 'R180', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('IC1', {'deviceset': 'A4988', 'library': 'SparkFun-PowerIC', 'device': 'ALT1', 'value': '', 'package': 'QFN-28-5MM_ALT1', 'instances': [{'gate': 'G$1', 'x': '162.56', 'y': '142.24', 'rot': 'R0', 'symbol': 'A4983', 'attribute': [{'name': 'VALUE', 'x': '149.86', 'y': '114.3', 'size': '1.778', 'layer': '96'}, {'name': 'NAME', 'x': '149.86', 'y': '168.148', 'size': '1.778', 'layer': '95'}]}]})
# ('GND16', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '142.24', 'y': '109.22', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('R20', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '190.5', 'y': '121.92', 'rot': 'R270', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('GND17', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '190.5', 'y': '109.22', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('C6', {'deviceset': '0.1UF-100V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.1uf', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '137.16', 'y': '152.4', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('C7', {'deviceset': '0.1UF-100V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.1uf', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '124.46', 'y': '152.4', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('GND18', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '124.46', 'y': '144.78', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('P+2', {'deviceset': 'VCC', 'library': 'SparkFun-2-11-09', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '124.46', 'y': '162.56', 'rot': 'R0', 'symbol': 'VCC2', 'attribute': []}]})
# ('C8', {'deviceset': '0.1UF-100V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.1uf', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '121.92', 'y': '116.84', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('C9', {'deviceset': '0.1UF-100V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.1uf', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '132.08', 'y': '116.84', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('GND20', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '127', 'y': '109.22', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('C10', {'deviceset': '0.22UF50V-20%,+80%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.22uF', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '198.12', 'y': '121.92', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('C11', {'deviceset': '0.1UF-100V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '.1uf', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '210.82', 'y': '137.16', 'rot': 'R90', 'symbol': 'CAP', 'attribute': [{'name': 'NAME', 'x': '207.264', 'y': '140.081', 'size': '1.778', 'layer': '95'}, {'name': 'VALUE', 'x': '207.264', 'y': '132.461', 'size': '1.778', 'layer': '96'}]}]})
# ('D1', {'deviceset': 'DIODE-', 'library': 'diode', 'device': 'DO-214AC', 'value': 'B340A-13-F', 'package': 'DO-214AC', 'instances': [{'gate': 'G$1', 'x': '45.72', 'y': '50.8', 'rot': 'R0', 'symbol': 'D', 'attribute': [{'name': 'NAME', 'x': '44.45', 'y': '52.5526', 'size': '1.778', 'layer': '95'}, {'name': 'VALUE', 'x': '39.624', 'y': '54.8386', 'size': '1.778', 'layer': '96'}]}]})
# ('C14', {'deviceset': '47UF-50V-20%(ELECT)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '47uF', 'package': 'PANASONIC_D', 'instances': [{'gate': 'G$1', 'x': '50.8', 'y': '45.72', 'rot': 'R0', 'symbol': 'CAP_POL', 'attribute': []}]})
# ('JP10', {'deviceset': 'M04', 'library': 'SparkFun', 'device': 'PTH', 'value': '', 'package': '1X04', 'instances': [{'gate': 'G$1', 'x': '50.8', 'y': '124.46', 'rot': 'R0', 'symbol': 'M04', 'attribute': []}]})
# ('JP5', {'deviceset': 'M04', 'library': 'BigEasyDriver_v11', 'device': 'SCREW_LOCK', 'value': '', 'package': 'SCREWTERMINAL-3.5MM-4_LOCK', 'instances': [{'gate': 'G$1', 'x': '78.74', 'y': '73.66', 'rot': 'R0', 'symbol': 'M04', 'attribute': []}]})
# ('JP7', {'deviceset': 'M02', 'library': 'BigEasyDriver_v11', 'device': '3.5MM_LOCK', 'value': '', 'package': 'SCREWTERMINAL-3.5MM-2_LOCK', 'instances': [{'gate': 'G$1', 'x': '22.86', 'y': '35.56', 'rot': 'R0', 'symbol': 'M02', 'attribute': []}]})
# ('R1', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '106.68', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R2', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '99.06', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R3', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '91.44', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R4', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '83.82', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R5', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '76.2', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('P+3', {'deviceset': 'VCC', 'library': 'SparkFun-2-11-09', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '233.68', 'y': '127', 'rot': 'R0', 'symbol': 'VCC2', 'attribute': []}]})
# ('GND3', {'deviceset': 'GND', 'library': 'supply1', 'device': '', 'value': '', 'package': 'Unknown', 'instances': [{'gate': '1', 'x': '233.68', 'y': '63.5', 'rot': 'R0', 'symbol': 'GND', 'attribute': []}]})
# ('R10', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '68.58', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R11', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '114.3', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R12', {'deviceset': '20KOHM1/10W5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '20K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '223.52', 'y': '121.92', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R13', {'deviceset': '8.2KOHM-1/10W-5%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '8.2K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '137.16', 'y': '91.44', 'rot': 'R270', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('JP11', {'deviceset': 'M04', 'library': 'BigEasyDriver_v11', 'device': 'SCREW_LOCK', 'value': '', 'package': 'SCREWTERMINAL-3.5MM-4_LOCK', 'instances': [{'gate': 'G$1', 'x': '78.74', 'y': '124.46', 'rot': 'R0', 'symbol': 'M04', 'attribute': []}]})
# ('JP12', {'deviceset': 'M04', 'library': 'BigEasyDriver_v11', 'device': 'SCREW_LOCK', 'value': '', 'package': 'SCREWTERMINAL-3.5MM-4_LOCK', 'instances': [{'gate': 'G$1', 'x': '78.74', 'y': '93.98', 'rot': 'R0', 'symbol': 'M04', 'attribute': []}]})
# ('JP13', {'deviceset': 'M02', 'library': 'BigEasyDriver_v11', 'device': '3.5MM_LOCK', 'value': '', 'package': 'SCREWTERMINAL-3.5MM-2_LOCK', 'instances': [{'gate': 'G$1', 'x': '76.2', 'y': '109.22', 'rot': 'R0', 'symbol': 'M02', 'attribute': []}]})
# ('JP14', {'deviceset': 'M04', 'library': 'SparkFun', 'device': 'PTH', 'value': '', 'package': '1X04', 'instances': [{'gate': 'G$1', 'x': '50.8', 'y': '93.98', 'rot': 'R0', 'symbol': 'M04', 'attribute': []}]})
# ('C2', {'deviceset': '1.0UF-16V-10%(0603)', 'library': 'SparkFun-Capacitors', 'device': '', 'value': '1uF', 'package': '0603-CAP', 'instances': [{'gate': 'G$1', 'x': '127', 'y': '35.56', 'rot': 'R0', 'symbol': 'CAP', 'attribute': []}]})
# ('LOGO1', {'deviceset': 'OSHW_LOGO_FILL', 'library': 'OSHW', 'device': 'X0100-NT', 'value': '', 'package': 'OSHW_FILLX100_NOTEXT', 'instances': [{'gate': 'G$1', 'x': '127', 'y': '5.08', 'rot': 'R0', 'symbol': 'OSHW_LOGO', 'attribute': []}]})
# ('U$3', {'deviceset': 'PAD', 'library': 'Testing', 'device': '', 'value': '', 'package': 'PAD-0.008', 'instances': [{'gate': 'G$1', 'x': '185.42', 'y': '124.46', 'rot': 'R0', 'symbol': 'PAD', 'attribute': []}]})
# ('U$4', {'deviceset': 'PAD', 'library': 'Testing', 'device': '', 'value': '', 'package': 'PAD-0.008', 'instances': [{'gate': 'G$1', 'x': '185.42', 'y': '121.92', 'rot': 'R0', 'symbol': 'PAD', 'attribute': []}]})
# ('U$5', {'deviceset': 'PAD', 'library': 'Testing', 'device': '', 'value': '', 'package': 'PAD-0.008', 'instances': [{'gate': 'G$1', 'x': '185.42', 'y': '119.38', 'rot': 'R0', 'symbol': 'PAD', 'attribute': []}]})
# ('R14', {'deviceset': '1KOHM1/10W1%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '1K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '116.84', 'y': '101.6', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('R15', {'deviceset': '1KOHM1/10W1%(0603)', 'library': 'SparkFun-Resistors', 'device': '', 'value': '1K', 'package': '0603-RES', 'instances': [{'gate': 'G$1', 'x': '116.84', 'y': '93.98', 'rot': 'R0', 'symbol': 'RESISTOR', 'attribute': []}]})
# ('FID1', {'deviceset': 'FIDUCIAL', 'library': 'SparkFun-Aesthetics', 'device': '1X2', 'value': '', 'package': 'FIDUCIAL-1X2', 'instances': [{'gate': 'G$1', 'x': '134.62', 'y': '7.62', 'rot': 'R0', 'symbol': 'FIDUCIAL', 'attribute': []}]})
# ('FID2', {'deviceset': 'FIDUCIAL', 'library': 'SparkFun-Aesthetics', 'device': '1X2', 'value': '', 'package': 'FIDUCIAL-1X2', 'instances': [{'gate': 'G$1', 'x': '139.7', 'y': '7.62', 'rot': 'R0', 'symbol': 'FIDUCIAL', 'attribute': []}]})

# %% [markdown]
# # Get bounding box of schematic

# %%
import math

def update_bounding_box_from_item(item, min_x, max_x, min_y, max_y):
    """
    Updates the bounding box (min_x, max_x, min_y, max_y) based on the given item.
    (No changes in this function)
    """
    # ... (rest of the function is the same)
    if 'wire' in item:
        if isinstance(item['wire'], list):
            for wire_seg in item['wire']:
                x1 = float(wire_seg['x1'])
                y1 = float(wire_seg['y1'])
                x2 = float(wire_seg['x2'])
                y2 = float(wire_seg['y2'])
                min_x = min(min_x, x1, x2)
                max_x = max(max_x, x1, x2)
                min_y = min(min_y, y1, y2)
                max_y = max(max_y, y1, y2)
        elif isinstance(item['wire'], dict):
            wire_seg = item['wire']
            x1 = float(wire_seg['x1'])
            y1 = float(wire_seg['y1'])
            x2 = float(wire_seg['x2'])
            y2 = float(wire_seg['y2'])
            min_x = min(min_x, x1, x2)
            max_x = max(max_x, x1, x2)
            min_y = min(min_y, y1, y2)
            max_y = max(max_y, y1, y2)

    if 'junction' in item:
        if isinstance(item['junction'], list):
            for junction in item['junction']:
                x = float(junction['x'])
                y = float(junction['y'])
                min_x = min(min_x, x)
                max_x = max(max_x, x)
                min_y = min(min_y, y)
                max_y = max(max_y, y)
        elif isinstance(item['junction'], dict):
            junction = item['junction']
            x = float(junction['x'])
            y = float(junction['y'])
            min_x = min(min_x, x)
            max_x = max(max_x, x)
            min_y = min(min_y, y)
            max_y = max(max_y, y)

    if 'label' in item:
        if isinstance(item['label'], list):
            for label in item['label']:
                x = float(label['x'])
                y = float(label['y'])
                rot = label.get('rot', 'R0').upper()
                label_offset_x = 5 if rot != 'R180' else -5  # Adjust offset based on rotation
                label_x_adjusted = x + label_offset_x # Calculate adjusted x for label
                min_x = min(min_x, label_x_adjusted)
                max_x = max(max_x, label_x_adjusted)
                min_y = min(min_y, y)
                max_y = max(max_y, y)
        elif isinstance(item['label'], dict):
            label = item['label']
            x = float(label['x'])
            y = float(label['y'])
            rot = label.get('rot', 'R0').upper()
            label_offset_x = 5 if rot != 'R180' else -5  # Adjust offset based on rotation
            label_x_adjusted = x + label_offset_x # Calculate adjusted x for label
            min_x = min(min_x, label_x_adjusted)
            max_x = max(max_x, label_x_adjusted)
            min_y = min(min_y, y)
            max_y = max(max_y, y)

    return min_x, max_x, min_y, max_y

def get_bounding_box_for_symbol_instance(symbol_element, instance_x, instance_y, rot_angle_rad="R0", space=10):
    """
    Calculates the bounding box (xlim, ylim) for a single symbol instance.
    (No changes in this function)
    """
    min_x_symbol = float('inf')
    max_x_symbol = float('-inf')
    min_y_symbol = float('inf')
    max_y_symbol = float('-inf')

    rot_angle_deg = 0.0
    if rot_angle_rad.upper().startswith('R180'):
        rot_angle_deg = 0
    elif rot_angle_rad.upper().startswith('R270'):
        rot_angle_deg = 90
    elif rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        rot_angle_deg = 360 - float(rot_angle_rad[2:])
    rot_angle_rad = math.radians(rot_angle_deg)
        

    elements_list = [
        symbol_element.get('pin', []),
        symbol_element.get('wire', []),
        symbol_element.get('rectangle', []),
        symbol_element.get('circle', []),
        symbol_element.get('polygon', []),
        symbol_element.get('text', [])
    ]

    for elements in elements_list:
        for element in elements:
            element_type = None
            if 'x1' in element and 'y1' in element and 'x2' in element and 'y2' in element and 'width' in element and 'layer' in element:
                element_type = 'wire'
            elif 'x' in element and 'y' in element and 'size' in element and 'layer' in element and 'font' in element and 'text' in element:
                element_type = 'text'
            elif 'name' in element and 'x' in element and 'y' in element and 'visible' in element and 'length' in element:
                element_type = 'pin'
            elif 'x1' in element and 'y1' in element and 'x2' in element and 'y2' in element:
                element_type = 'rectangle'
            elif 'x' in element and 'y' in element and 'radius' in element:
                element_type = 'circle'
            elif 'vertex' in element:
                element_type = 'polygon'


            element_min_x = float('inf')
            element_max_x = float('-inf')
            element_min_y = float('inf')
            element_max_y = float('-inf')

            if element_type == 'pin':
                px = float(element['x'])
                py = float(element['y'])
                rotated_x = instance_x + (px * math.cos(rot_angle_rad) - py * math.sin(rot_angle_rad))
                rotated_y = instance_y + (px * math.sin(rot_angle_rad) + py * math.cos(rot_angle_rad))
                element_min_x = min(element_min_x, rotated_x)
                element_max_x = max(element_max_x, rotated_x)
                element_min_y = min(element_min_y, rotated_y)
                element_max_y = max(element_max_y, rotated_y)

            elif element_type == 'wire':
                x1 = float(element['x1'])
                y1 = float(element['y1'])
                x2 = float(element['x2'])
                y2 = float(element['y2'])
                rotated_x1 = instance_x + (x1 * math.cos(rot_angle_rad) - y1 * math.sin(rot_angle_rad))
                rotated_y1 = instance_y + (x1 * math.sin(rot_angle_rad) + y1 * math.cos(rot_angle_rad))
                rotated_x2 = instance_x + (x2 * math.cos(rot_angle_rad) - y2 * math.sin(rot_angle_rad))
                rotated_y2 = instance_y + (x2 * math.sin(rot_angle_rad) + y2 * math.cos(rot_angle_rad))
                element_min_x = min(element_min_x, rotated_x1, rotated_x2)
                element_max_x = max(element_max_x, rotated_x1, rotated_x2)
                element_min_y = min(element_min_y, rotated_y1, rotated_y2)
                element_max_y = max(element_max_y, rotated_y1, rotated_y2)

            elif element_type == 'rectangle':
                x1 = float(element['x1'])
                y1 = float(element['y1'])
                x2 = float(element['x2'])
                y2 = float(element['y2'])
                rect_points = [(x1, y1), (x2, y1), (x2, y2), (x1, y2)]
                for px, py in rect_points:
                    rotated_x = instance_x + (px * math.cos(rot_angle_rad) - py * math.sin(rot_angle_rad))
                    rotated_y = instance_y + (px * math.sin(rot_angle_rad) + py * math.cos(rot_angle_rad))
                    element_min_x = min(element_min_x, rotated_x)
                    element_max_x = max(element_max_x, rotated_x)
                    element_min_y = min(element_min_y, rotated_y)
                    element_max_y = max(element_max_y, rotated_y)

            elif element_type == 'circle':
                x_center = float(element['x'])
                y_center = float(element['y'])
                radius = float(element['radius'])
                # Circle's bounds are center +/- radius in both directions (approximate rotation)
                element_min_x = min(element_min_x, instance_x + ( (x_center - radius) * math.cos(rot_angle_rad) - (y_center + radius) * math.sin(rot_angle_rad)) ) # Approximate
                element_max_x = max(element_max_x, instance_x + ( (x_center + radius) * math.cos(rot_angle_rad) - (y_center - radius) * math.sin(rot_angle_rad)) ) # Approximate
                element_min_y = min(element_min_y, instance_y + ( (x_center - radius) * math.sin(rot_angle_rad) + (y_center - radius) * math.cos(rot_angle_rad)) ) # Approximate
                element_max_y = max(element_max_y, instance_y + ( (x_center + radius) * math.sin(rot_angle_rad) + (y_center + radius) * math.cos(rot_angle_rad)) ) # Approximate

            elif element_type == 'polygon':
                poly_vertices = element.get('vertex', [])
                for v in poly_vertices:
                    px = float(v['x'])
                    py = float(v['y'])
                    rotated_x = instance_x + (px * math.cos(rot_angle_rad) - py * math.sin(rot_angle_rad))
                    rotated_y = instance_y + (px * math.sin(rot_angle_rad) + py * math.cos(rot_angle_rad))
                    element_min_x = min(element_min_x, rotated_x)
                    element_max_x = max(element_max_x, rotated_x)
                    element_min_y = min(element_min_y, rotated_y)
                    element_max_y = max(element_max_y, rotated_y)

            elif element_type == 'text': # Treat text as point for now
                text_x = float(element['x'])
                text_y = float(element['y'])
                rotated_x = instance_x + (text_x * math.cos(rot_angle_rad) - text_y * math.sin(rot_angle_rad))
                rotated_y = instance_y + (text_x * math.sin(rot_angle_rad) + text_y * math.cos(rot_angle_rad))
                element_min_x = min(element_min_x, rotated_x)
                element_max_x = max(element_max_x, rotated_x)
                element_min_y = min(element_min_y, rotated_y)
                element_max_y = max(element_max_y, rotated_y)

            min_x_symbol = min(min_x_symbol, element_min_x)
            max_x_symbol = max(max_x_symbol, element_max_x)
            min_y_symbol = min(min_y_symbol, element_min_y)
            max_y_symbol = max(max_y_symbol, element_max_y)

    if min_x_symbol == float('inf'): # No elements found
        return ((instance_x, instance_x + 200), (instance_y, instance_y + 200)) # Return a default range around instance position
    else:
        xlim = (min_x_symbol-space, max_x_symbol+space)
        ylim = (min_y_symbol-space, max_y_symbol+space)
        return (xlim, ylim)

def get_schematic_bounding_box_from_schematic_info(schematic_info):
    """
    Calculates the bounding box (xlim, ylim) that encompasses all elements (parts and nets)
    in the schematic_info. This version utilizes get_bounding_box_for_symbol_instance for parts.

    Args:
        schematic_info (dict): The schematic information dictionary containing 'parts', 'nets', and 'IC_library'.

    Returns:
        tuple: A tuple containing (xlim, ylim) as tuples, e.g., ((min_x, max_x), (min_y, max_y)).
               Returns None if schematic_info is missing 'parts', 'nets', or 'IC_library'.
    """
    parts_info = schematic_info.get('parts')
    ic_library = schematic_info.get('IC_library')
    nets_info = schematic_info.get('nets')

    if not parts_info or not ic_library:
        return None  # Missing essential schematic data

    min_x_overall = float('inf')
    max_x_overall = float('-inf')
    min_y_overall = float('inf')
    max_y_overall = float('-inf')

    # --- Calculate bounding box for parts using get_bounding_box_for_symbol_instance ---
    if parts_info:
        for part_name, part_data in parts_info.items():
            for instance in part_data.get('instances', []):
                gate_instance = instance.get('gate', '') # Handle cases where gate might be missing
                symbol_element = get_symbol_element_of_instance_from_library(
                    ic_library, part_name, gate_instance, parts_info
                )

                if symbol_element:
                    rot_instance = instance['rot']
                    x_instance = float(instance['x'])
                    y_instance = float(instance['y'])

                    symbol_instance_bbox = get_bounding_box_for_symbol_instance(
                        symbol_element, x_instance, y_instance, rot_instance
                    )
                    xlim_instance, ylim_instance = symbol_instance_bbox

                    min_x_overall = min(min_x_overall, xlim_instance[0])
                    max_x_overall = max(max_x_overall, xlim_instance[1])
                    min_y_overall = min(min_y_overall, ylim_instance[0])
                    max_y_overall = max(max_y_overall, ylim_instance[1])


    # --- Calculate bounding box for nets (no changes here) ---
    if nets_info:
        for net_name, net_data in nets_info.items():
            if isinstance(net_data, list):
                for item in net_data:
                    min_x_overall, max_x_overall, min_y_overall, max_y_overall = update_bounding_box_from_item(
                        item, min_x_overall, max_x_overall, min_y_overall, max_y_overall
                    )
            elif isinstance(net_data, dict): # if net_data is a dict, assume it's like item structure
                min_x_overall, max_x_overall, min_y_overall, max_y_overall = update_bounding_box_from_item(
                    net_data, min_x_overall, max_x_overall, min_y_overall, max_y_overall
                )

    # print("min_x_overall:", min_x_overall, "max_x_overall:", max_x_overall)
    if min_x_overall == float('inf'): # No elements found
        return ((0,100), (0,100)) # Return a default range if no elements are found
    else:
        xlim = (min_x_overall - 5, max_x_overall + 5) # Add some margin
        ylim = (min_y_overall - 5, max_y_overall + 5) # Add some margin
        return (xlim, ylim)

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    bounding_box = get_schematic_bounding_box_from_schematic_info(schematic_info)

    print("bounding_box:",bounding_box)
# Out:
# bounding_box: ((-15.0, 263.92), (-15.0, 200.42))

# %% [markdown]
# # draw schematic

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle, Circle, Arc, Polygon
import math

# Switch to a backend that supports pop-out windows (like Qt5Agg, TkAgg, MacOSX)
# You might need to install the backend if you don't have it (e.g., pip install pyqt5 for Qt5Agg)
matplotlib.use('Agg') # Or try 'TkAgg' or 'MacOSX'

def draw_polygons(polygons, x=0, y=0, rot_angle_rad='R0', color='red', fill=False, facecolor=None, ax = None):
    """
    Draws a list of polygons from EAGLE polygon dictionaries with rotation.

    Each polygon dictionary should have:
      - 'width': the line width (string convertible to float)
      - 'layer': (optional) the layer (not used here)
      - 'vertex': a list of dictionaries, each with keys 'x' and 'y'

    Parameters:
      polygons (list): List of polygon dictionaries.
      x (float): X-coordinate of the center.
      y (float): Y-coordinate of the center.
      rot_angle_rad (float): Rotation angle in radians.
      color (str): Color for the polygon edge.
      fill (bool): Whether to fill the polygon.
      facecolor (str): Color to fill the polygon (if fill is True).
    """
    rot_angle_deg = 0.0
    is_mirrored = False
    if rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        rot_angle_deg = float(rot_angle_rad[2:])

        is_mirrored = True 
    rot_angle_rad = math.radians(rot_angle_deg)

    if ax is None:
        ax = plt.gca()
    for poly in polygons:
        # Extract vertices as a list of (x,y) tuples and apply rotation
        vertices = poly.get('vertex', [])
        rotated_pts = []
        for v in vertices:
            px = float(v['x'])
            py = float(v['y'])
            rotated_x = x + (px * math.cos(rot_angle_rad) - py * math.sin(rot_angle_rad))
            if is_mirrored:
                rotated_x = x + (px * math.cos(rot_angle_rad) + py * math.sin(rot_angle_rad))
            else:
                rotated_x = x + (px * math.cos(rot_angle_rad) - py * math.sin(rot_angle_rad))
            rotated_y = y + (px * math.sin(rot_angle_rad) + py * math.cos(rot_angle_rad))
            rotated_pts.append((rotated_x, rotated_y))

        # Get the line width from the polygon dictionary
        width = float(poly.get('width', '0.1524'))

        # Create a Polygon patch: closed, optionally filled, with specified line width.
        poly_patch = Polygon(
            rotated_pts,
            closed=True,
            fill=fill,
            facecolor=facecolor if fill and facecolor is not None else 'none',
            edgecolor=color,
            linewidth=width
        )
        ax.add_patch(poly_patch)

def draw_circle(circle_data, x=0, y=0, rot_angle_rad='R0', ax = None):
    """
    Draws a circle with rotation.
    """
    rot_angle_deg = 0.0
    is_mirrored = False
    if rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        rot_angle_deg = float(rot_angle_rad[2:])
        is_mirrored = True 
    rot_angle_rad = math.radians(rot_angle_deg)
    
    # Extract circle parameters
    x_center = float(circle_data['x'])
    y_center = float(circle_data['y'])
    radius   = float(circle_data['radius'])
    line_w   = float(circle_data['width'])

    # Apply rotation to the circle center
    rotated_x_center = x + (x_center * math.cos(rot_angle_rad) - y_center * math.sin(rot_angle_rad))
    if is_mirrored:
        rotated_x_center = x + (x_center * math.cos(rot_angle_rad) + y_center * math.sin(rot_angle_rad))
    else:
        rotated_x_center = x + (x_center * math.cos(rot_angle_rad) - y_center * math.sin(rot_angle_rad))

    rotated_y_center = y + (x_center * math.sin(rot_angle_rad) + y_center * math.cos(rot_angle_rad))


    # Create a Circle patch (unfilled by default)
    circle_patch = Circle(
        (rotated_x_center, rotated_y_center),
        radius,
        fill=False,         
        linewidth=line_w,
        edgecolor='red'     
    )

    # Add to the current axes
    if ax is None:
        ax = plt.gca()
    ax.add_patch(circle_patch)


import itertools

def compress_pad_string(pad_str):
    """
    Given a space-separated pad string like '3 4 5',
    returns a compressed format like '3*3'
    """
    parts = pad_str.strip().split()
    
    if not parts:
        return ""
    
    first = parts[0]
    count = len(parts)
    if count == 1:
        return first
    return f"{first}*{count}"





def draw_pins(pins, x=0, y=0, rot_angle_rad='R0', ax=None, schematic_info = None, lib_name = None, de_set_name = None, device_name = None, scale = 1.0, gate = None):
    """
    Draws pins with rotation.
    """
    if ax is None:
        ax = plt.gca()
    is_mirrored = False
    rot_angle_deg = 0.0
    if rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        is_mirrored = True
        rot_angle_deg = float(rot_angle_rad[2:])
    rot_angle_rad = math.radians(rot_angle_deg)
    # font_size = 12.0/100.0 * float(scale)

    if is_mirrored:
        print("is_mirrored:", is_mirrored, "rot_angle_rad:", rot_angle_rad, "rot_angle_deg:", rot_angle_deg)
    # Define the mapping from length strings to extension distances
    length_map = {
        'point': 0.0,
        'short': 2.54,
        'middle': 2.54 * 2,
        'long': 2.54 * 3
    }

    rotated_pin_positions = []
    for pin in pins:
        x_base = float(pin['x'])
        y_base = float(pin['y'])
        x_rot = x + (x_base * math.cos(rot_angle_rad) - y_base * math.sin(rot_angle_rad))
        y_rot = y + (x_base * math.sin(rot_angle_rad) + y_base * math.cos(rot_angle_rad))
        if is_mirrored:
            x_rot = 2*x - x_rot
        rotated_pin_positions.append((x_rot, y_rot))

    def compute_min_spacing(pin_positions):
        min_dist = float('inf')
        for (x1, y1), (x2, y2) in itertools.combinations(pin_positions, 2):
            dx = x2 - x1
            dy = y2 - y1
            dist = math.hypot(dx, dy)
            if dist > 1e-6:
                min_dist = min(min_dist, dist)
        return min_dist
    min_spacing = compute_min_spacing(rotated_pin_positions)
    font_size = max(min(min_spacing * 100, 12), 10)


    for pin in pins:
        # print("pin name:", pin['name'])
        # Get base coordinates
        x_base = float(pin['x'])
        # if is_mirrored:
        #     x_base = -x_base
        y_base = float(pin['y'])

        dotted = pin.get('function','') == 'dot'

        # Apply rotation to the pin base
        rotated_x_base = x + (x_base * math.cos(rot_angle_rad) - y_base * math.sin(rot_angle_rad))
        rotated_y_base = y + (x_base * math.sin(rot_angle_rad) + y_base * math.cos(rot_angle_rad))

        # Determine extension length
        length_type = pin.get('length', 'long').lower()
        extension = length_map.get(length_type, 2.54)

        # Compute pin angle
        rot_pin_str = pin.get('rot', 'R0')
        pin_angle_deg = float(rot_pin_str[1:]) if rot_pin_str.upper().startswith('R') else (float(rot_pin_str[2:]))
        pin_angle_rad = math.radians(pin_angle_deg) + rot_angle_rad
        x_end = rotated_x_base + extension * math.cos(pin_angle_rad)
        y_end = rotated_y_base + extension * math.sin(pin_angle_rad)
        # Compute end of pin


        
        if is_mirrored and dotted:
            circle_centerx = rotated_x_base + (extension - 1) * math.cos(pin_angle_rad)
            circle_centery = rotated_y_base + (extension - 1) * math.sin(pin_angle_rad)
            x_end = rotated_x_base + (extension - 2) * math.cos(pin_angle_rad)
            y_end = rotated_y_base + (extension - 2) * math.sin(pin_angle_rad)

            x_end = 2*x - x_end
            rotated_x_base = 2*x - rotated_x_base
            #print("pin name:", pin['name'], "pin not_mirrored:", pin['name'], "rotated_x_base:", rotated_x_base, "rotated_y_base:", rotated_y_base, "x_end:", x_end, "y_end:", y_end, "calculated angle:", pin_angle_rad)
        elif is_mirrored:
            # x_end = rotated_x_base - extension * math.cos(pin_angle_rad)
            x_end = 2*x - x_end
            rotated_x_base = 2*x - rotated_x_base
            #print("pin name:", pin['name'], "pin is_mirrored:", pin['name'], "rotated_x_base:", rotated_x_base, "rotated_y_base:", rotated_y_base, "x_end:", x_end, "y_end:", y_end, "calculated angle:", pin_angle_rad)
        elif dotted:
            circle_centerx = rotated_x_base + (extension - 1) * math.cos(pin_angle_rad)
            circle_centery = rotated_y_base + (extension - 1) * math.sin(pin_angle_rad)
            x_end = rotated_x_base + (extension - 2) * math.cos(pin_angle_rad)
            y_end = rotated_y_base + (extension - 2) * math.sin(pin_angle_rad)
        
            #print("pin name:", pin['name'], "pin not_mirrored:", pin['name'], "rotated_x_base:", rotated_x_base, "rotated_y_base:", rotated_y_base, "x_end:", x_end, "y_end:", y_end, "calculated angle:", pin_angle_rad)
        
        dx = x_end - rotated_x_base
        dy = y_end - rotated_y_base
        length = math.hypot(dx, dy)
        if length > 1e-6:
            ux, uy = dx/length, dy/length
        else:
            ux, uy = 1.0, 0.0
    # change
        if length_type == 'point':
            offset_pts = -8
        elif length_type == 'short':
            offset_pts = -47
        elif length_type == 'middle':
            offset_pts = -75
        elif length_type == 'long':   
            offset_pts = -103
        offset_x = -ux * offset_pts
        # if is_mirrored:
        #     offset_x = -offset_x
        offset_y = -uy * (offset_pts - 8)
        pin_angle_deg_final = math.degrees(pin_angle_rad)
        pin_angle_deg_final = pin_angle_deg_final % 360
        align_map = {
            0:     ('left',  'center'),
            90:    ('left', 'center'),
            180:   ('right', 'center'),
            270:   ('right',  'center'),
        }
        ha, va = align_map.get(pin_angle_deg_final, ('center', 'center'))

        if is_mirrored:
            ha = 'right' if ha == 'left' else 'left'
        angel_drawed = pin_angle_deg_final
        if pin_angle_deg_final == 180:
            angel_drawed = 0

        if pin_angle_deg_final == 270:
            angel_drawed = 90



        # Draw the pin line and base marker
        if dotted:
            theta = np.linspace(0, 2 * np.pi, 100)
            ax.plot(circle_centerx + np.cos(theta), circle_centery + np.sin(theta), label = 'circle', color='red', lw=1, clip_on=True)
            ax.plot([rotated_x_base, x_end], [rotated_y_base, y_end], color='red', lw=1, clip_on=True)
        else:
            ax.plot([rotated_x_base, x_end], [rotated_y_base, y_end], color='red', clip_on=False, lw=1, zorder=20)
        ax.scatter([rotated_x_base], [rotated_y_base], color='blue', zorder=5, clip_on=True)
        
        # print('pin Name:', pin['name'], 'visible:', pin.get('visible', ''))

        if pin.get('visible', '').lower() in ['pin', 'both', '']:
                ax.annotate(
                    pin['name'],
                    (rotated_x_base, rotated_y_base),
                    textcoords="offset points",
                    xytext=(offset_x, offset_y),
                    ha=ha, va=va,
                    fontsize=font_size, 
                    color = 'Gray',
                    rotation=angel_drawed,
                    rotation_mode='anchor',    
                    clip_on=True
                )
        if pin.get('visible', '').lower() in ['pad', 'both', '']:
            print("Pad Drawn: pin name:", pin['name'], "pin_angle_deg_final:", pin_angle_deg_final, "ha:", ha, "va:", va)
            connects = find_connects(schematic_info, library_name=lib_name, deviceset_name=de_set_name, device_name=device_name)
            with open('connects.json', 'w') as f:
                json.dump(connects, f, indent=2)
            for connect in connects:
                if connect['pin'] == pin['name'] and (connect['gate'] == gate or connect['gate'] is None or connect['gate'] == '' or gate is None or gate == ''):
                    if ha == 'left':
                        ha = 'right'
                    elif ha == 'right':
                        ha = 'left'
                    if va == 'top':
                        va = 'bottom'
                    elif va == 'bottom':
                        va = 'top'
                    if ha == 'left' and pin_angle_deg_final !=90 and pin_angle_deg_final != 270:
                        print("left 0 or 180 Here")
                        if length_type == 'point' or length_type == 'short':
                            offset_x = offset_x + 40    
                        elif length_type == 'middle' or length_type == 'long':
                            offset_x = offset_x + 50
                    elif ha == 'right' and pin_angle_deg_final == 0:
                        if length_type == 'point' or length_type == 'short':
                            offset_x = offset_x -40
                        elif length_type == 'middle' or length_type == 'long':
                            offset_x = offset_x -60
                    elif ha == 'right' and pin_angle_deg_final == 180:
                        if length_type == 'point' or length_type == 'short':
                            offset_x = offset_x -40
                        elif length_type == 'middle' or length_type == 'long':
                            offset_x = offset_x -60



                    
                    if pin_angle_deg_final == 90:
                        
                        if length_type == 'point' or length_type == 'short':
                            offset_y = offset_y -50
                        elif length_type == 'middle' or length_type == 'long':
                            offset_y = offset_y -60
                    if pin_angle_deg_final == 270:
                        if length_type == 'point' or length_type == 'short':
                            offset_y = offset_y + 40    
                        elif length_type == 'middle' or length_type == 'long':
                            offset_y = offset_y + 50
                        print("270 de pin/pad:",ha, va)

                    # elif pin_angle_deg_final == 90:
                    #     offset_x = offset_x  -100
                    # elif pin_angle_deg_final == 270:
                    #     offset_x = offset_x + 5
                      

                    if angel_drawed == 90 :
                        va = 'bottom'
                    # elif pin_angle_deg_final == 270:
                    #     va = 'bottom'
                    # elif ha == 'center' and va == 'bottom':
                    #     offset_x = offset_x
                    # elif ha == 'center' and va == 'top':
                    #     offset_x = offset_x +20

                    if va == 'center':
                        offset_y = offset_y -10
                    angel_drawed = pin_angle_deg_final
                    if pin_angle_deg_final == 180:
                        angel_drawed = 0

                    if pin_angle_deg_final == 270:
                        angel_drawed = 90
                    draw_text = compress_pad_string(connect['pad'])
                    if dotted:
                        
                        ax.annotate(
                            draw_text,
                            (x_end - 2, y_end),
                            textcoords="offset points",
                            xytext=(-offset_x, -offset_y),
                            ha=ha, va=va,
                            fontsize=font_size, 
                            color = 'Gray',
                            rotation=angel_drawed,            # ← rotate text
                            rotation_mode='anchor',    
                            clip_on=True
                        )
                    else:
                        ax.annotate(
                            draw_text,
                            (x_end, y_end),
                            textcoords="offset points",
                            xytext=(-offset_x, -offset_y),
                            ha=ha, va=va,
                            fontsize=font_size, 
                            color = 'Gray',
                            rotation=angel_drawed,            # ← rotate text
                            rotation_mode='anchor',    
                            clip_on=True
                        )
 

    return rot_angle_rad


def draw_rectangle(rect_data,  x=0, y=0, rot_angle_rad='R0', color='red', alpha=1.0, ax = None):
    """
    Draw a rectangle with rotation.
    """
    rot_angle_deg = 0.0
    if rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        rot_angle_deg = float(rot_angle_rad[2:])
    rot_angle_rad = math.radians(rot_angle_deg)
    
    x1 = float(rect_data['x1'])
    y1 = float(rect_data['y1'])
    x2 = float(rect_data['x2'])
    y2 = float(rect_data['y2'])

    # Rotate the rectangle corners
    rotated_x1 = x + (x1 * math.cos(rot_angle_rad) - y1 * math.sin(rot_angle_rad))
    rotated_y1 = y + (x1 * math.sin(rot_angle_rad) + y1 * math.cos(rot_angle_rad))
    rotated_x2 = x + (x2 * math.cos(rot_angle_rad) - y2 * math.sin(rot_angle_rad))
    rotated_y2 = y + (x2 * math.sin(rot_angle_rad) + y2 * math.cos(rot_angle_rad))

    left   = min(rotated_x1, rotated_x2)
    bottom = min(rotated_y1, rotated_y2)
    width  = abs(rotated_x2 - rotated_x1) # width and height are calculated after rotation
    height = abs(rotated_y2 - rotated_y1)


    rect_patch = Rectangle(
        (left, bottom),
        width,
        height,
        fill=True,
        facecolor=color,
        edgecolor='none',   # no edge
        alpha=alpha
    )
    if ax is None:
        ax = plt.gca()
    ax.add_patch(rect_patch)

def draw_wire_eagle_style(wire,  x=0, y=0, rot_angle_rad='R0', ax = None):
    """
    Draws a 'wire' with rotation.
    """
    rot_angle_deg = 0.0
    is_mirrored = False
    if rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        is_mirrored = True
        rot_angle_deg = float(rot_angle_rad[2:])
    rot_angle_rad = math.radians(rot_angle_deg)
    
    # Extract endpoints
    x1_orig = float(wire['x1']) # keep original for center calculation
    y1_orig = float(wire['y1'])
    x2_orig = float(wire['x2'])
    y2_orig = float(wire['y2'])

    # Rotate wire endpoints
    rotated_x1 = x + (x1_orig * math.cos(rot_angle_rad) - y1_orig * math.sin(rot_angle_rad))
    if is_mirrored:
        rotated_x1 = x - (x1_orig * math.cos(rot_angle_rad) + y1_orig * math.sin(rot_angle_rad))
    rotated_y1 = y + (x1_orig * math.sin(rot_angle_rad) + y1_orig * math.cos(rot_angle_rad))
    rotated_x2 = x + (x2_orig * math.cos(rot_angle_rad) - y2_orig * math.sin(rot_angle_rad))
    if is_mirrored:
        rotated_x2 = x - (x2_orig * math.cos(rot_angle_rad) + y2_orig * math.sin(rot_angle_rad))
    rotated_y2 = y + (x2_orig * math.sin(rot_angle_rad) + y2_orig * math.cos(rot_angle_rad))
    x1 = rotated_x1
    y1 = rotated_y1
    x2 = rotated_x2
    y2 = rotated_y2


    # Check for a 'curve' parameter
    c = wire.get('curve', 0)
    curve_deg = float(c)

    # If no curve (or zero), draw a straight line
    if abs(curve_deg) < 1e-9:
        plt.plot([x1, x2], [y1, y2], 'r-')
        return

    # 1) Compute chord length
    chord_len = math.hypot(x2_orig - x1_orig, y2_orig - y1_orig) # use original points
    if chord_len < 1e-9:
        # Degenerate case: start == end
        return

    # 2) Convert curve to radians (absolute value)
    theta = math.radians(abs(curve_deg))

    # 3) Compute radius
    R = chord_len / (2.0 * math.sin(theta / 2.0))

    # 4) Find the midpoint of the chord (using original points)
    mx_orig = (x1_orig + x2_orig) / 2.0
    my_orig = (y1_orig + y2_orig) / 2.0

    # 5) Distance from midpoint to center
    d = math.sqrt(R*R - (chord_len / 2.0)**2)

    # 6) Compute the direction perpendicular to the chord (using original points)
    vx_orig = x2_orig - x1_orig
    vy_orig = y2_orig - y1_orig
    nx_orig = -vy_orig
    ny_orig =  vx_orig
    length_n_orig = math.hypot(nx_orig, ny_orig)
    nx_orig /= length_n_orig
    ny_orig /= length_n_orig

    # 7) Depending on the sign of 'curve', pick which side of the chord the center is on (using original points)
    if curve_deg > 0:
        cx_orig = mx_orig + d * nx_orig
        cy_orig = my_orig + d * ny_orig
    else:
        cx_orig = mx_orig - d * nx_orig
        cy_orig = my_orig - d * ny_orig

    # Rotate the arc center - now rotate the original center, and then translate
    rotated_cx = x + (cx_orig * math.cos(rot_angle_rad) - cy_orig * math.sin(rot_angle_rad))
    rotated_cy = y + (cx_orig * math.sin(rot_angle_rad) + cy_orig * math.cos(rot_angle_rad))
    cx = rotated_cx
    cy = rotated_cy


    # 8) Compute start/end angles for the arc in degrees (using rotated endpoints and rotated center)
    start_angle = math.degrees(math.atan2(y1 - cy, x1 - cx))
    end_angle   = math.degrees(math.atan2(y2 - cy, x2 - cx))

    def normalize_angle(a):
        return a % 360

    start_angle = normalize_angle(start_angle)
    end_angle   = normalize_angle(end_angle)

    if curve_deg > 0:
        diff = end_angle - start_angle
        if diff < 0:
            diff += 360
        if abs(diff - curve_deg) > 1e-3:
            if diff < curve_deg:
                end_angle += 360
            else:
                end_angle -= 360
    else:
        temp = start_angle
        start_angle = end_angle
        end_angle   = temp


    # 9) Finally, draw the arc
    arc = Arc(
        (cx, cy),           # center
        2*R, 2*R,           # width, height
        angle=0,            # rotation of the whole arc ellipse (0 for a circle)
        theta1=start_angle, # start angle in degrees
        theta2=end_angle,   # end angle in degrees
        color='red'
    )
    if ax is None:
        ax = plt.gca()
    ax.add_patch(arc)


def draw_text_eagle_style(text_element, x=0, y=0, rot_angle_rad='R0', ax = None):
    """
    Draws text based on the provided text element, with optional position offset and rotation.
    """
    print("text_element:",text_element)
    if ax is None:
        ax = plt.gca()
    # Extract attributes
    text_x_orig = float(text_element['x'])
    text_y_orig = float(text_element['y'])
    text_size = float(text_element['size'])*10
    text_content = text_element['name']

    # if text_content.upper() in ['NAME','VALUE']:
    #     return 
    
    # Rotation
    rot_angle_rad_val = 0
    if rot_angle_rad != 'R0':
        if rot_angle_rad.startswith('R'):
            rot_angle_deg = float(rot_angle_rad[1:])
            rot_angle_rad_val = math.radians(rot_angle_deg)
        else: # Assume direct radian value if not 'R' prefix, though 'R' prefix is eagle style
            try:
                rot_angle_rad_val = float(rot_angle_rad)
            except ValueError:
                rot_angle_rad_val = 0 # Default to 0 if parsing fails

    # Rotate text position
    rotated_x = x + (text_x_orig * math.cos(rot_angle_rad_val) - text_y_orig * math.sin(rot_angle_rad_val))
    rotated_y = y + (text_x_orig * math.sin(rot_angle_rad_val) + text_y_orig * math.cos(rot_angle_rad_val))
    final_x = rotated_x
    final_y = rotated_y

    rotation_deg = math.degrees(rot_angle_rad_val)



    print("Drawing text:", text_content, "at position:", final_x, final_y, "with rotation:", rotation_deg)
    # Draw text using plt.text
    ax.text(final_x, final_y, text_content, fontsize=text_size, ha='center', va='center', rotation=rotation_deg, color='red') # ha and va for centering similar to eagle

    return

from matplotlib.patches import Polygon

def get_arrow_triangle(x, y, angle_deg, size=20):
    """
    Returns triangle points for an arrowhead.
    - (x, y) is the tip of the arrow
    - angle_deg is the rotation angle (in degrees)
    - size is the size of the arrowhead
    """
    # Define triangle in local coords, tip at (0, 0)
    tri = np.array([
        [-size/2, 0],              # Tip of arrow
        [0, size / 2],   # Left base
        [0, -size / 2],  # Right base
    ])

    # Rotate the triangle
    theta = np.radians(angle_deg)
    rot_matrix = np.array([
        [np.cos(theta), -np.sin(theta)],
        [np.sin(theta),  np.cos(theta)]
    ])
    tri_rotated = tri @ rot_matrix.T

    # Translate to (x, y)
    tri_translated = tri_rotated + np.array([x, y])
    return tri_translated




def draw_part_attributes(attributes, part_name="Unknown", part_value="Unknown", symbol_name="Unknown", ax = None, rot_angle=None, gate = None):
    """
    Draws part attributes such as name and value on the plot.

    Args:
        attributes (list or dict): List or dictionary of attributes to draw.
        x (float): X-coordinate of the center.
        y (float): Y-coordinate of the center.
        rot_angle_rad (float): Rotation angle in radians.
        part_name (str): Name of the part.
        part_value (str): Value of the part.
        symbol_name (str): Name of the symbol.
    """

    if not attributes:  # Check if attributes is empty
        return
    if ax is None:
        ax = plt.gca()
    if isinstance(attributes, dict):  # Convert dictionary to list for uniform processing
        attributes = [attributes]

    for attribute in attributes:
        if attribute.get('display', 'on').lower() == 'off':
            continue
        attr_name = attribute.get('name', '').upper()
        attr_x = float(attribute.get('x', 0))
        attr_y = float(attribute.get('y', 0))
        attr_size = float(attribute.get('size', 1.0))
        xref_yes  = attribute.get('xref', 'no').lower() == 'yes'
        attr_rot = attribute.get('rot', 'R0')
        attr_rot = attr_rot.upper()
        is_mirrored = attr_rot.startswith('MR')
        rot_val = attr_rot[2:] if is_mirrored else attr_rot[1:]

        try:
            rot_deg = int(rot_val)
        except ValueError:
            rot_deg = 0
        align_map = {
            0:     ('left',  'bottom'),
            90:    ('right', 'bottom'),
            180:   ('right', 'top'),
            270:   ('left',  'top'),
        }

        ha, va = align_map.get(rot_deg % 360, ('center', 'center'))
        if is_mirrored:
            ha = 'right' if ha == 'left' else 'left'


        attr_rot_deg = rot_deg


        if attr_rot_deg == 180:
            attr_rot_deg = 0
        elif attr_rot_deg == 270:
            attr_rot_deg = 90
        
        bbox_kw = None
        if xref_yes:
            bbox_kw = dict(
                boxstyle="square,pad=0.2",
                facecolor="white",
                edgecolor="gray",
                linewidth=1
            )

        # print("Drawing attribute:", attr_name, "at position:", attr_x, attr_y, "with rotation:", attr_rot_deg, "and size:", attr_size, 'ha', ha, 'va:', va)
        # Determine if the attribute is for part name or part value
        if attr_name == "NAME" and part_name != "Unknown":
            if gate:
                
                ax.text(attr_x, attr_y, part_name + gate, fontsize=attr_size * 5, ha=ha, va=va, 
                        rotation=attr_rot_deg, color='blue')
            else:
                ax.text(attr_x, attr_y, part_name, fontsize=attr_size * 5, ha=ha, va=va, 
                        rotation=attr_rot_deg, color='blue')
        elif attr_name == "VALUE":
            # Use symbol_name as part_value if part_value is unknown
            display_value = part_value if part_value not in ["Unknown", ""] else symbol_name
            ax.text(attr_x, attr_y, display_value, fontsize=attr_size * 5, ha=ha, va=va, 
                        rotation=attr_rot_deg, color='green')
        elif  "GND" != symbol_name:
            print(f"Drawing attribute '{attr_name}' for part '{part_name}'")
            ax.text(attr_x, attr_y, attr_name, fontsize=attr_size * 5, ha=ha, va=va, 
                        rotation=attr_rot_deg, color='red')
            

        cross_size = 0.3
        ax.plot([attr_x - cross_size, attr_x + cross_size],
        [attr_y, attr_y],
        color='lightgray', linewidth=1, zorder=0)


        ax.plot([attr_x, attr_x],
                [attr_y + cross_size, attr_y - cross_size],
                color='lightgray', linewidth=1, zorder=0)



                

def visualize_wires_junctions(data, net_name, ax = None):
    """
    Visualizes wires, junctions, and labels from the given data using matplotlib.
    """
    if ax is None:
        ax = plt.gca()  # Get current axes
    ax.yaxis.set_inverted(True)  # Invert y-axis here, within the function itself
    ax.set_aspect('equal', adjustable='box')

    min_x, max_x, min_y, max_y = float('inf'), float('-inf'), float('inf'), float('-inf')
    data_found = False  # Flag to track if any wire/junction data was processed

    for item in data:
        if 'wire' in item:
            data_found = True  # Set flag to True because we found wire data
            if isinstance(item['wire'], list):
                for wire_seg in item['wire']:
                    x1 = float(wire_seg['x1'])
                    y1 = float(wire_seg['y1'])
                    x2 = float(wire_seg['x2'])
                    y2 = float(wire_seg['y2'])
                    width = float(wire_seg['width']) if 'width' in wire_seg else 0.1524
                    layer = wire_seg['layer'] if 'layer' in wire_seg else '91'
                    ax.plot([x1, x2], [y1, y2], linewidth=width * 10, color='green')
                    min_x = min(min_x, x1, x2)
                    max_x = max(max_x, x1, x2)
                    min_y = min(min_y, y1, y2)
                    max_y = max(max_y, y1, y2)
            elif isinstance(item['wire'], dict):
                wire_seg = item['wire']
                x1 = float(wire_seg['x1'])
                y1 = float(wire_seg['y1'])
                x2 = float(wire_seg['x2'])
                y2 = float(wire_seg['y2'])
                width = float(wire_seg['width']) if 'width' in wire_seg else 0.1524
                layer = wire_seg['layer'] if 'layer' in wire_seg else '91'
                ax.plot([x1, x2], [y1, y2], linewidth=width * 20, color='green')
                min_x = min(min_x, x1, x2)
                max_x = max(max_x, x1, x2)
                min_y = min(min_y, y1, y2)
                max_y = max(max_y, y1, y2)

        if 'junction' in item:
            data_found = True  # Set flag to True because we found junction data
            if isinstance(item['junction'], list):
                for junction in item['junction']:
                    x = float(junction['x'])
                    y = float(junction['y'])
                    ax.plot(x, y, marker='o', markersize=5, color='green')
                    min_x = min(min_x, x)
                    max_x = max(max_x, x)
                    min_y = min(min_y, y)
                    max_y = max(max_y, y)
            elif isinstance(item['junction'], dict):
                junction = item['junction']
                x = float(junction['x'])
                y = float(junction['y'])
                ax.plot(x, y, marker='o', markersize=5, color='green')
                min_x = min(min_x, x)
                max_x = max(max_x, x)
                min_y = min(min_y, y)
                max_y = max(max_y, y)

        if 'label' in item:
            data_found = True  # Set flag to True because we found label data
            if isinstance(item['label'], list):
                for label in item['label']:
                    x = float(label['x'])
                    y = float(label['y'])
                    font_size = float(label.get('size', 8)) * 15  # Dynamically get font size, default to 8
                    rot = label.get('rot', 'R0').upper()
                    

                    if rot.startswith('MR'):
                        is_mirrored = True
                        rot = rot[2:]
                    else:
                        is_mirrored = False
                        rot = rot[1:]
                    rot = int(rot)
                    print("label:", net_name, "rot:", rot)
                    # label_offset_x = -1 if rot != 'R180' else 1  # Adjust offset based on rotation
                    label_offset_y = 0  # No distance for y-coordinate
                    is_xref = label.get('xref', '').lower() == 'yes'

                    if not is_mirrored:
                        if rot == 0 or rot == 90:
                            ha = 'left'
                            label_offset_x = 1
                        elif  rot == 180 or rot == 270:
                            ha = 'right'
                            label_offset_x = -1
                        else:
                            ha = 'center'
                            label_offset_x = 0
                    else:
                        if rot == 0 or rot == 90:
                            ha = 'right'
                            label_offset_x = 1
                        elif  rot == 180 or rot == 270:
                            ha = 'left'
                            label_offset_x = -1
                        else:
                            ha = 'center'
                            label_offset_x = 0

                    if rot == 90:
                        va = 'center'
                        label_offset_x = 0
                    elif rot == 270:
                        va = 'center'
                        label_offset_x = 0
                    else:
                        va = 'center'
                        label_offset_y = 0
                    label_offset_y = 0

                    if net_name == "ADC":
                        print("net found:", net_name, "rot:", rot, "y:", y + label_offset_y, 'va:', va, 'ha:', ha)
                    bbox_kw = dict(
                        boxstyle="square,pad=0.2",
                        facecolor="white",
                        edgecolor="gray",
                        linewidth=1
                    ) if is_xref else None


                    tri = get_arrow_triangle(x + label_offset_x, y + label_offset_y, rot, 2.7)
                    if rot == 180:
                        rot = 0
                    elif rot == 270:
                        rot = 90

                    if net_name == "LD1" or net_name == "SW3V3":
                        print("net found:", net_name, "rot:", rot, "y:", y + label_offset_y)
                    # print("rot angle:",rot)
                    ax.text(x + label_offset_x, y + label_offset_y, 
                            net_name, 
                            fontsize=font_size, 
                            ha=ha, 
                            color='gray', 
                            bbox = bbox_kw, 
                            clip_on=True, 
                            rotation=rot,
                        rotation_mode='anchor', va=va)
                   
                    if is_xref:
                        ax.add_patch(Polygon(tri, closed=True, color='gray'))
                    min_x = min(min_x, x + label_offset_x)
                    max_x = max(max_x, x + label_offset_x)
                    min_y = min(min_y, y)
                    max_y = max(max_y, y)
            elif isinstance(item['label'], dict):
                label = item['label']
                x = float(label['x'])
                y = float(label['y'])
                font_size = float(label.get('size', 8)) * 15  # Dynamically get font size, default to 8
                rot = label.get('rot', 'R0').upper()

                if rot.startswith('MR'):
                    is_mirrored = True
                    rot = rot[2:]
                else:
                    is_mirrored = False
                    rot = rot[1:]
                rot = int(rot) if not is_mirrored else 360 - int(rot)

                label_offset_y = 0  # No distance for y-coordinate
                is_xref = label.get('xref', '').lower() == 'yes'


                if not is_mirrored:
                    if rot == 0 or rot == 90:
                        ha = 'left'
                        label_offset_x = 1
                    elif  rot == 180 or rot == 270:
                        ha = 'right'
                        label_offset_x = -1
                    else:
                        ha = 'center'
                        label_offset_x = 0
                else:
                    if rot == 0 or rot == 90:
                        ha = 'right'
                        label_offset_x = 1
                    elif  rot == 180 or rot == 270:
                        ha = 'left'
                        label_offset_x = -1
                    else:
                        ha = 'center'
                        label_offset_x = 0

                if rot == 90:
                    va = 'center'
                    label_offset_x = 0
                    label_offset_y = 0
                elif rot == 270:
                    va = 'center'
                    label_offset_x = 0
                    label_offset_y = 0
                else:
                    va = 'center'
                    label_offset_y = 0
                bbox_kw = dict(
                    boxstyle="square,pad=0.2",
                    facecolor="white",
                    edgecolor="gray",
                    linewidth=1
                ) if is_xref else None



                if net_name == "ADC":
                        print("net found:", net_name, "rot:", rot, "y:", y + label_offset_y, 'va:', va, 'ha:', ha)

                tri = get_arrow_triangle(x + label_offset_x, y + label_offset_y, rot, 2.7)
                if rot == 180:
                    rot = 0
                elif rot == 270:
                    rot = 90
                if net_name == "LD1" or net_name == "SW3V3":
                    print("net found:", net_name, "rot:", rot, "y:", y + label_offset_y)


                ax.text(x + label_offset_x, y + label_offset_y, 
                            net_name, 
                            fontsize=font_size, 
                            ha=ha, 
                            color='gray', 
                            bbox = bbox_kw, 
                            clip_on=True, 
                            rotation=rot,
                        rotation_mode='anchor', va=va)
                
                min_x = min(min_x, x + label_offset_x)
                max_x = max(max_x, x + label_offset_x)
                min_y = min(min_y, y)
                max_y = max(max_y, y)


                if is_xref:
                    ax.add_patch(Polygon(tri, closed=True, color='gray'))



                # label_offset_x = 5 if rot != 'R180' else -5  # Adjust offset based on rotation
                # label_offset_y = 0  # No distance for y-coordinate

                # is_xref = label.get('xref', '').lower() == 'yes'




    if data_found:  # Only set limits and labels if data was found
        ax.set_xlim(min_x - 5, max_x + 5)
        ax.set_ylim(min_y - 5, max_y + 5)
        ax.set_xlabel("X Coordinate")
        ax.set_ylabel("Y Coordinate")
        ax.set_title("Visualization of Wires, Junctions, and Labels")
        plt.grid(True, linestyle='--', alpha=0.6)
    else:
        ax.text(0.5, 0.5, "No wire, junction, or label data to display", ha='center', va='center', fontsize=12, color='gray')  # Display message if no data


# Function to visualize symbol with rotation
def visualize_symbol_from_dict(symbol_data, x=0, y=0, rot_angle_rad='R0', part_name="Unknown", part_value="Unknown",symbol_name="Unknown", ax = None, gate = None, schematic_info  = None, lib_name = None, de_set_name = None, device_name = None):
    """
    Visualizes the symbol data with rotation.

    Args:
        symbol_data (dict): Dictionary containing symbol information.
        x (float): X-coordinate of the center.
        y (float): Y-coordinate of the center.
        rot (str): Rotation of the symbol, e.g., 'R90', 'R0', 'R270'.
    """
    # Convert rotation string to radians
    # rot_angle_deg = 0.0
    # if rot.upper().startswith('R'):
    #     rot_angle_deg = float(rot[1:])
    # rot_angle_rad = math.radians(rot_angle_rad)

    # Extract symbol elements
    pins = symbol_data.get('pin', [])
    # print("pins:",pins)
    wires = symbol_data.get('wire', [])
    rectangles = symbol_data.get('rectangle', [])
    circles = symbol_data.get('circle', [])
    polygons = symbol_data.get('polygon', [])
    attributes = symbol_data.get('attribute', [])
    texts = symbol_data.get('symbol_text', [])
    # print("here is the texts:",texts)
    # if part_name == "J6":
    #     import json
    #     with open("example_text_symbol.json", "w") as f:
    #                     json.dump(symbol_data, f, indent=4)
    if gate == "G$1":
        gate = None

    # print(symbol_data['name'],"text:",text)
    # if symbol_data['name'] == 'FIDUCIAL':
    #     for text_element in text:
    #         draw_text_eagle_style(text_element, x, y, rot_angle_rad)
    # print("starting to draw symbol:",symbol_name, "at", x, y, "with rotation", rot_angle_rad)
    
    # Plot circles
    for circle in circles:
        
        draw_circle(circle, x, y, rot_angle_rad, ax)


    # Plot polygons
    if polygons:
        
        draw_polygons(polygons, x, y, rot_angle_rad, color='red', fill=True, facecolor='red', ax = ax)


    # Plot pins
    # print("start to draw pins")
    # print("pins")
    
    angle = draw_pins(pins, x, y, rot_angle_rad, ax, schematic_info = schematic_info, lib_name = lib_name, de_set_name = de_set_name, device_name = device_name, gate = gate)
    # Draw wires
    for wire in wires:
        draw_wire_eagle_style(wire, x, y, rot_angle_rad, ax)

                                                                
    # Draw rectangles

    for rect_data in rectangles:
        
        draw_rectangle(rect_data, x, y, rot_angle_rad, color='red', alpha=1.0, ax =ax)


    print("here are the texts:",texts)
    draw_texts(texts, part_name, part_value, symbol_name, ax = ax, rot_angle_rad=rot_angle_rad, gate = gate, x = x, y = y)
    
    # if angle == 'R180':
    #     angle = 'R0'
    # if angle == 'R270':
    #     angle = 'R90'
    draw_part_attributes(attributes, part_name, part_value, symbol_name, ax = ax, rot_angle=angle, gate = gate)
        
def draw_texts(attributes, part_name="Unknown", part_value="Unknown", symbol_name="Unknown", ax = None, rot_angle_rad=None, gate = None, x = 0, y = 0):
    """
    Draws part attributes such as name and value on the plot.

    Args:
        attributes (list or dict): List or dictionary of attributes to draw.
        x (float): X-coordinate of the center.
        y (float): Y-coordinate of the center.
        rot_angle_rad (float): Rotation angle in radians.
        part_name (str): Name of the part.
        part_value (str): Value of the part.
        symbol_name (str): Name of the symbol.
    """
    # if part_name == "J6":
    #     import json
    #     with open("example_text_part.json", "w") as f:
    #                     json.dump(attributes, f, indent=4)
    if not attributes:  # Check if attributes is empty
        return
    is_mirrored = False
    rot_angle_deg = 0.0
    if rot_angle_rad.upper().startswith('R'):
        rot_angle_deg = float(rot_angle_rad[1:])
    elif rot_angle_rad.upper().startswith('MR'):
        is_mirrored = True
        rot_angle_deg = float(rot_angle_rad[2:])
    rot_angle_rad = math.radians(rot_angle_deg)

    if ax is None:
        ax = plt.gca()
    if isinstance(attributes, dict):  # Convert dictionary to list for uniform processing
        attributes = [attributes]

    for attribute in attributes:
        if attribute.get('display', 'on').lower() == 'off':
            continue
        attr_name = attribute.get('text', '').upper()
        if attr_name.startswith('>'):
            continue
        print("text content:", attr_name)
        x_base = float(attribute.get('x', 0))
        y_base = float(attribute.get('y', 0))
        attr_size = float(attribute.get('size', 1.0))
        xref_yes  = attribute.get('xref', 'no').lower() == 'yes'
        attr_rot = attribute.get('rot', 'R0')

        pin_angle_deg = float(attr_rot[1:]) if attr_rot.upper().startswith('R') else (float(attr_rot[2:]))
        pin_angle_rad = math.radians(pin_angle_deg) + rot_angle_rad
        pin_angle_deg_final = math.degrees(pin_angle_rad)
        rot_val = attr_rot[2:] if is_mirrored else attr_rot[1:]

        x_rot = x + (x_base * math.cos(rot_angle_rad) - y_base * math.sin(rot_angle_rad))
        y_rot = y + (x_base * math.sin(rot_angle_rad) + y_base * math.cos(rot_angle_rad))
        if is_mirrored:
            x_rot = 2*x - x_rot


        attr_x = x_rot
        attr_y = y_rot
        try:
            rot_deg = int(rot_val)
        except ValueError:
            rot_deg = 0
        align_map = {
            0:     ('left',  'bottom'),
            90:    ('right', 'bottom'),
            180:   ('right', 'top'),
            270:   ('left',  'top'),
        }

        ha, va = align_map.get(pin_angle_deg_final % 360, ('center', 'center'))
        if is_mirrored:
            ha = 'right' if ha == 'left' else 'left'


        attr_rot_deg = pin_angle_deg_final


        if attr_rot_deg == 180:
            attr_rot_deg = 0
        elif attr_rot_deg == 270:
            attr_rot_deg = 90
        
        bbox_kw = None
        if xref_yes:
            bbox_kw = dict(
                boxstyle="square,pad=0.2",
                facecolor="white",
                edgecolor="gray",
                linewidth=1
            )

        # print("Drawing attribute:", attr_name, "at position:", attr_x, attr_y, "with rotation:", attr_rot_deg, "and size:", attr_size, 'ha', ha, 'va:', va)
        # Determine if the attribute is for part name or part value

        ax.text(attr_x, attr_y, attr_name, fontsize=attr_size * 5, ha=ha, va=va, 
                        rotation=attr_rot_deg, color='red')
            

        cross_size = 0.3
        ax.plot([attr_x - cross_size, attr_x + cross_size],
        [attr_y, attr_y],
        color='lightgray', linewidth=1, zorder=0)


        ax.plot([attr_x, attr_x],
                [attr_y + cross_size, attr_y - cross_size],
                color='lightgray', linewidth=1, zorder=0)



def visualize_schematic(schematic_file_path, save_path=None):
    """
    Visualizes the schematic based on the provided schematic_info.

    Args:
        schematic_info (dict): Dictionary containing schematic information, including parts and nets.
    """
    [x,y] = show_dimension(schematic_file_path)
    print("Dimensions of schematic:", x, y)
    if (x == -1):
        print("Error: Invalid schematic file or empty schematic.")
        return
    fig, ax = plt.subplots(figsize=(x, y), dpi=100)  # Create figure and axes
    # ax = plt.gca()  # Get current axes
    # print("Parts in schematic:", schematic_info['parts'])

    schematic_info = process_schematic_file(schematic_file_path)  # Parse the schematic file
    import json
    with open("example_symbol_part.json", "w") as f:
                    json.dump(schematic_info, f, indent=4)
    # Visualize parts
    for part_name, part_data in schematic_info['parts'].items():
        part_value = part_data.get('value', 'Unknown')
        lib_name = part_data.get('library', 'Unknown')
        de_set_name = part_data.get('deviceset', 'Unknown')
        device_name = part_data.get('device', 'Unknown')
        for instance in part_data.get('instances', []):
            symbol_name = instance['symbol']
            x = float(instance['x'])
            y = float(instance['y'])
            rot = instance['rot']
            gate = instance['gate']
            print("part_name:", part_name, "part_value:", part_value, "symbol_name:", symbol_name, "x:", x, "y:", y, "rot:", rot, "gate:", gate)

            symbol_element = get_symbol_element_of_instance_from_library(
                schematic_info['IC_library'], part_name, gate, schematic_info['parts']
            )
            # print("part_data:", symbol_name)
            # test
            if symbol_element:
                visualize_symbol_from_dict(symbol_element, x, y, rot, part_name, part_value, symbol_name, gate = gate, schematic_info = schematic_info, ax = ax, lib_name = lib_name, de_set_name = de_set_name, device_name = device_name)

    # Visualize nets
    for net_name, net_data in schematic_info['nets'].items():
        visualize_wires_junctions(net_data, net_name)

    # Calculate and display bounding box
    bounding_box = get_schematic_bounding_box_from_schematic_info(schematic_info)
    # print("Bounding box:", bounding_box)

    if bounding_box:
        xlim, ylim = bounding_box
        # print(f"Bounding Box for entire schematic: xlim = {xlim}, ylim = {ylim}")
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)

        # Draw bounding box in red dashed line
        rect = Rectangle(
            (xlim[0], ylim[0]),  # Bottom-left corner
            xlim[1] - xlim[0],   # Width
            ylim[1] - ylim[0],   # Height
            linewidth=10,
            edgecolor='red',
            linestyle='--',
            facecolor='none'
        )
        ax.add_patch(rect)
    else:
        print("Empty schematic.")

    plt.axis('equal') 
    # Add labels, legend, and grid
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.legend()
    plt.grid(True)

    if save_path:
        print("plt saved")
        plt.savefig(save_path, bbox_inches='tight')
    fig = plt.gcf()
    fig.canvas.draw()


    src_xlim = ax.get_xlim()
    src_ylim = ax.get_ylim()
    src_width = src_xlim[1] - src_xlim[0]
    src_height = src_ylim[1] - src_ylim[0]


    bbox_inches = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    pixel_width = bbox_inches.width * fig.dpi
    pixel_height = bbox_inches.height * fig.dpi


    pixels_per_unit_x = pixel_width / src_width
    pixels_per_unit_y = pixel_height / src_height
    return pixels_per_unit_x, pixels_per_unit_y, src_width, src_height, pixel_width, pixel_height



def visualize_schematic_nobounding(schematic_file_path, save_path=None):
    """
    Visualizes the schematic without drawing the bounding box, and returns:
      pixels_per_unit_x, pixels_per_unit_y,
      schematic_width, schematic_height,
      img_width, img_height
    """
    # 1) parse & get raw schematic extents
    [x,y] = show_dimension(schematic_file_path)
    print("Dimensions of schematic:", x, y)
    if (x == -1):
        print("Error: Invalid schematic file or empty schematic.")
        return
    fig, ax = plt.subplots(figsize=(x, y), dpi=100)  # Create figure and axes
    # ax = plt.gca()  # Get current axes
    # print("Parts in schematic:", schematic_info['parts'])

    schematic_info = process_schematic_file(schematic_file_path)  # Parse the schematic file
    import json
    with open("example_symbol_part.json", "w") as f:
                    json.dump(schematic_info, f, indent=4)
    # Visualize parts
    for part_name, part_data in schematic_info['parts'].items():
        part_value = part_data.get('value', 'Unknown')
        lib_name = part_data.get('library', 'Unknown')
        de_set_name = part_data.get('deviceset', 'Unknown')
        device_name = part_data.get('device', 'Unknown')
        for instance in part_data.get('instances', []):
            symbol_name = instance['symbol']
            x = float(instance['x'])
            y = float(instance['y'])
            rot = instance['rot']
            gate = instance['gate']
            print("part_name:", part_name, "part_value:", part_value, "symbol_name:", symbol_name, "x:", x, "y:", y, "rot:", rot, "gate:", gate)

            symbol_element = get_symbol_element_of_instance_from_library(
                schematic_info['IC_library'], part_name, gate, schematic_info['parts']
            )
            # print("part_data:", symbol_name)
            # test
            if symbol_element:
                visualize_symbol_from_dict(symbol_element, x, y, rot, part_name, part_value, symbol_name, gate = gate, schematic_info = schematic_info, ax = ax, lib_name = lib_name, de_set_name = de_set_name, device_name = device_name)

    # Visualize nets
    for net_name, net_data in schematic_info['nets'].items():
        visualize_wires_junctions(net_data, net_name)

    # Calculate and display bounding box
    bounding_box = get_schematic_bounding_box_from_schematic_info(schematic_info)
    # print("Bounding box:", bounding_box)

    if bounding_box:
        xlim, ylim = bounding_box
        # print(f"Bounding Box for entire schematic: xlim = {xlim}, ylim = {ylim}")
        ax.set_xlim(xlim)
        ax.set_ylim(ylim)

        # Draw bounding box in red dashed line
        rect = Rectangle(
            (xlim[0], ylim[0]),  # Bottom-left corner
            xlim[1] - xlim[0],   # Width
            ylim[1] - ylim[0],   # Height
            linewidth=10,
            edgecolor='none',
            linestyle='--',
            facecolor='none'
        )
        ax.add_patch(rect)
    else:
        print("Empty schematic.")

    plt.axis('equal') 
    # Add labels, legend, and grid
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.legend()
    plt.grid(False)

    if save_path:
        print("plt saved")
        plt.savefig(save_path, bbox_inches='tight')
    fig = plt.gcf()
    fig.canvas.draw()


    src_xlim = ax.get_xlim()
    src_ylim = ax.get_ylim()
    src_width = src_xlim[1] - src_xlim[0]
    src_height = src_ylim[1] - src_ylim[0]


    bbox_inches = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    pixel_width = bbox_inches.width * fig.dpi
    pixel_height = bbox_inches.height * fig.dpi


    pixels_per_unit_x = pixel_width / src_width
    pixels_per_unit_y = pixel_height / src_height
    return pixels_per_unit_x, pixels_per_unit_y, src_width, src_height, pixel_width, pixel_height



def show_dimension(schematic_file_path):
    info = process_schematic_file(schematic_file_path)
    bounding_box = get_schematic_bounding_box_from_schematic_info(info)
    if bounding_box:
        (xmin, xmax), (ymin, ymax) = bounding_box
        raw_w  = xmax - xmin
        raw_h  = ymax - ymin
        print("schematics_raw_dimensions:", raw_w, raw_h)
        fig_w    = raw_w  / 5.0
        fig_h    = raw_h  / 5.0
        print("schematics_png_dimensions:", fig_w, fig_h)
        return [fig_w, fig_h]
        
    else: 
        return [-1,-1]

# %%
schematic_info['IC_library']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 schematic_info['IC_library']
#
# NameError: name 'schematic_info' is not defined

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    # Load and parse the XML file for the specified IC
    # folder_path = r"/Users/linkaiyuan/文件/PSU/test_single_sch/A111_Pulsed_Radar_Breakout_SparkFun-Connectors_RASPBERRYPI-26-PIN-GPIO.sch"
    # # folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    # IC_name = "ICM-20948"
    # sch_file_name = f"{folder_path}\\{IC_name}\\{IC_name}.sch"
    # # sch_file_name = r"F:\GitHub\PCBEDA\sample PCB\custom\template.sch"
    # visualize_schematic(folder_path)



    output_dir = "/Users/linkaiyuan/文件/PSU/icm20948_4.png"
    sch_file = "/Users/linkaiyuan/Downloads/SparkFun_IMU_Breakout_ICM-20948.sch"
    sch_file = "/Users/linkaiyuan/文件/PSU/products/Bare_Conductive_Touch_Board/touch-board-ks-edition.sch"
    # visualize_schematic_tiled(sch_file, output_dir, rows=3, cols=3, dpi=300)
    visualize_schematic(sch_file, save_path=output_dir)
# Out:
# schematics_raw_dimensions: 621.82 374.29060000000004
# schematics_png_dimensions: 124.364 74.85812000000001
# Dimensions of schematic: 124.364 74.85812000000001
# part_name: U$23 part_value:  symbol_name: VUSB x: 38.1 y: 325.12 rot: R0 gate: G$1
# starting to draw symbol: VUSB at 38.1 325.12 with rotation R0
# start to draw pins
# part_name: GND8 part_value:  symbol_name: GND x: 27.94 y: 284.48 rot: R0 gate: 1
# starting to draw symbol: GND at 27.94 284.48 with rotation R0
# start to draw pins
# part_name: X1 part_value: USB MICRO symbol_name: MYCON2_USB x: 66.04 y: 320.04 rot: MR0 gate: G$1
# starting to draw symbol: MYCON2_USB at 66.04 320.04 with rotation MR0
# start to draw pins
# part_name: GND2 part_value:  symbol_name: GND x: 48.26 y: 284.48 rot: R0 gate: 1
# starting to draw symbol: GND at 48.26 284.48 with rotation R0
# start to draw pins
# part_name: X2 part_value: Batt symbol_name: M02 x: 185.42 y: 302.26 rot: R0 gate: G$1
# starting to draw symbol: M02 at 185.42 302.26 with rotation R0
# start to draw pins
# part_name: GND19 part_value:  symbol_name: GND x: 213.36 y: 284.48 rot: R0 gate: 1
# starting to draw symbol: GND at 213.36 284.48 with rotation R0
# start to draw pins
# part_name: GND30 part_value:  symbol_name: GND x: 22.86 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 22.86 55.88 with rotation R0
# start to draw pins
# part_name: IC4 part_value:  symbol_name: MCP73831 x: 60.96 y: 81.28 rot: R0 gate: G$1
# starting to draw symbol: MCP73831 at 60.96 81.28 with rotation R0
# start to draw pins
# part_name: GND53 part_value:  symbol_name: GND x: 73.66 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 73.66 55.88 with rotation R0
# start to draw pins
# part_name: JP1 part_value: External symbol_name: M02 x: 157.48 y: 302.26 rot: R0 gate: G$1
# starting to draw symbol: M02 at 157.48 302.26 with rotation R0
# start to draw pins
# part_name: GND7 part_value:  symbol_name: GND x: 177.8 y: 284.48 rot: R0 gate: 1
# starting to draw symbol: GND at 177.8 284.48 with rotation R0
# start to draw pins
# part_name: CHG part_value: Yellow symbol_name: LED x: 33.02 y: 73.66 rot: R0 gate: G$1
# starting to draw symbol: LED at 33.02 73.66 with rotation R0
# start to draw pins
# part_name: IC8 part_value: MIC5219 symbol_name: V-REG-LDO x: 528.32 y: 251.46 rot: R0 gate: G$1
# starting to draw symbol: V-REG-LDO at 528.32 251.46 with rotation R0
# start to draw pins
# part_name: GND52 part_value:  symbol_name: GND x: 513.08 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 513.08 238.76 with rotation R0
# start to draw pins
# part_name: GND14 part_value:  symbol_name: GND x: 38.1 y: 284.48 rot: R0 gate: 1
# starting to draw symbol: GND at 38.1 284.48 with rotation R0
# start to draw pins
# part_name: J3 part_value: 8x1F-H8.5 symbol_name: PINHD8 x: 289.56 y: 53.34 rot: MR180 gate: A
# starting to draw symbol: PINHD8 at 289.56 53.34 with rotation MR180
# start to draw pins
# part_name: J2 part_value: 6x1F-H8.5 symbol_name: PINHD6 x: 233.68 y: 50.8 rot: R180 gate: A
# starting to draw symbol: PINHD6 at 233.68 50.8 with rotation R180
# start to draw pins
# part_name: GND5 part_value:  symbol_name: GND x: 266.7 y: 86.36 rot: MR0 gate: 1
# starting to draw symbol: GND at 266.7 86.36 with rotation MR0
# start to draw pins
# part_name: ON part_value: Green symbol_name: LED x: 302.26 y: 292.1 rot: R0 gate: G$1
# starting to draw symbol: LED at 302.26 292.1 with rotation R0
# start to draw pins
# part_name: L part_value: Red symbol_name: LED x: 281.94 y: 292.1 rot: R0 gate: G$1
# starting to draw symbol: LED at 281.94 292.1 with rotation R0
# start to draw pins
# part_name: RN3 part_value: 1K symbol_name: R1NV x: 266.7 y: 302.26 rot: R270 gate: A
# starting to draw symbol: R1NV at 266.7 302.26 with rotation R270
# start to draw pins
# part_name: RN3 part_value: 1K symbol_name: R1NV x: 254.0 y: 302.26 rot: R270 gate: B
# starting to draw symbol: R1NV at 254.0 302.26 with rotation R270
# start to draw pins
# part_name: RN3 part_value: 1K symbol_name: R1NV x: 281.94 y: 302.26 rot: R270 gate: C
# starting to draw symbol: R1NV at 281.94 302.26 with rotation R270
# start to draw pins
# part_name: RN3 part_value: 1K symbol_name: R1NV x: 302.26 y: 302.26 rot: R270 gate: D
# starting to draw symbol: R1NV at 302.26 302.26 with rotation R270
# start to draw pins
# part_name: TX part_value: Yellow symbol_name: LED x: 254.0 y: 292.1 rot: R0 gate: G$1
# starting to draw symbol: LED at 254.0 292.1 with rotation R0
# start to draw pins
# part_name: RX part_value: Yellow symbol_name: LED x: 266.7 y: 292.1 rot: R0 gate: G$1
# starting to draw symbol: LED at 266.7 292.1 with rotation R0
# start to draw pins
# part_name: J1 part_value: 8x1F-H8.5 symbol_name: PINHD8 x: 233.68 y: 81.28 rot: MR0 gate: A
# starting to draw symbol: PINHD8 at 233.68 81.28 with rotation MR0
# start to draw pins
# part_name: JP3 part_value: 10x1F-H8.5 symbol_name: PINHD10 x: 289.56 y: 83.82 rot: MR180 gate: A
# starting to draw symbol: PINHD10 at 289.56 83.82 with rotation MR180
# start to draw pins
# part_name: ORIGIN part_value:  symbol_name: TP-SP x: 2.54 y: 48.26 rot: R90 gate: G$1
# starting to draw symbol: TP-SP at 2.54 48.26 with rotation R90
# start to draw pins
# part_name: P+4 part_value:  symbol_name: 3.3V x: 256.54 y: 83.82 rot: R270 gate: G$1
# starting to draw symbol: 3.3V at 256.54 83.82 with rotation R270
# start to draw pins
# part_name: GND11 part_value:  symbol_name: GND x: 259.08 y: 71.12 rot: MR0 gate: 1
# starting to draw symbol: GND at 259.08 71.12 with rotation MR0
# start to draw pins
# part_name: GND10 part_value:  symbol_name: GND x: 292.1 y: 274.32 rot: R0 gate: 1
# starting to draw symbol: GND at 292.1 274.32 with rotation R0
# start to draw pins
# part_name: SUPPLY2 part_value:  symbol_name: V_BATT x: 213.36 y: 327.66 rot: R0 gate: G$1
# starting to draw symbol: V_BATT at 213.36 327.66 with rotation R0
# start to draw pins
# part_name: T1 part_value: FDN340P symbol_name: P_MOSFET x: 88.9 y: 83.82 rot: MR270 gate: A
# starting to draw symbol: P_MOSFET at 88.9 83.82 with rotation MR270
# start to draw pins
# part_name: SUPPLY4 part_value:  symbol_name: V_BATT x: 78.74 y: 88.9 rot: R0 gate: G$1
# starting to draw symbol: V_BATT at 78.74 88.9 with rotation R0
# start to draw pins
# part_name: U$2 part_value:  symbol_name: VUSB x: 175.26 y: 330.2 rot: R0 gate: G$1
# starting to draw symbol: VUSB at 175.26 330.2 with rotation R0
# start to draw pins
# part_name: SUPPLY5 part_value:  symbol_name: 5V x: 215.9 y: 86.36 rot: R0 gate: G$1
# starting to draw symbol: 5V at 215.9 86.36 with rotation R0
# start to draw pins
# part_name: GND9 part_value:  symbol_name: GND x: 132.08 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 132.08 55.88 with rotation R0
# start to draw pins
# part_name: GND12 part_value:  symbol_name: GND x: 215.9 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 215.9 55.88 with rotation R0
# start to draw pins
# part_name: IC3 part_value: LM358 symbol_name: OPAMP x: 254.0 y: 266.7 rot: R0 gate: A
# starting to draw symbol: OPAMP at 254.0 266.7 with rotation R0
# start to draw pins
# part_name: IC3 part_value: LM358 symbol_name: PWR+- x: 228.6 y: 314.96 rot: R0 gate: P
# starting to draw symbol: PWR+- at 228.6 314.96 with rotation R0
# start to draw pins
# part_name: IC3 part_value: LM358 symbol_name: OPAMP x: 254.0 y: 327.66 rot: R0 gate: B
# starting to draw symbol: OPAMP at 254.0 327.66 with rotation R0
# start to draw pins
# part_name: SUPPLY11 part_value:  symbol_name: 5V x: 248.92 y: 81.28 rot: R270 gate: G$1
# starting to draw symbol: 5V at 248.92 81.28 with rotation R270
# start to draw pins
# part_name: GND3 part_value:  symbol_name: GND x: 502.92 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 502.92 238.76 with rotation R0
# start to draw pins
# part_name: ICSP part_value: ICSP symbol_name: PINH2X3 x: 91.44 y: 251.46 rot: R0 gate: A
# starting to draw symbol: PINH2X3 at 91.44 251.46 with rotation R0
# start to draw pins
# part_name: GND4 part_value:  symbol_name: GND x: 27.94 y: 248.92 rot: R0 gate: 1
# starting to draw symbol: GND at 27.94 248.92 with rotation R0
# start to draw pins
# part_name: U$25 part_value:  symbol_name: VUSB x: 106.68 y: 165.1 rot: R90 gate: G$1
# starting to draw symbol: VUSB at 106.68 165.1 with rotation R90
# start to draw pins
# part_name: GND17 part_value:  symbol_name: GND x: 111.76 y: 139.7 rot: R0 gate: 1
# starting to draw symbol: GND at 111.76 139.7 with rotation R0
# start to draw pins
# part_name: GND20 part_value:  symbol_name: GND x: 38.1 y: 210.82 rot: R270 gate: 1
# starting to draw symbol: GND at 38.1 210.82 with rotation R270
# start to draw pins
# part_name: GND21 part_value:  symbol_name: GND x: 38.1 y: 200.66 rot: R270 gate: 1
# starting to draw symbol: GND at 38.1 200.66 with rotation R270
# start to draw pins
# part_name: GND22 part_value:  symbol_name: GND x: 38.1 y: 139.7 rot: R0 gate: 1
# starting to draw symbol: GND at 38.1 139.7 with rotation R0
# start to draw pins
# part_name: GND23 part_value:  symbol_name: GND x: 248.92 y: 185.42 rot: R90 gate: 1
# starting to draw symbol: GND at 248.92 185.42 with rotation R90
# start to draw pins
# part_name: S1 part_value: RESET symbol_name: SWITCH-MOMENTARY x: 40.64 y: 259.08 rot: R270 gate: S
# starting to draw symbol: SWITCH-MOMENTARY at 40.64 259.08 with rotation R270
# start to draw pins
# part_name: IC6 part_value: MPR121 symbol_name: MPR121 x: 434.34 y: 71.12 rot: R0 gate: G$1
# starting to draw symbol: MPR121 at 434.34 71.12 with rotation R0
# start to draw pins
# part_name: GND24 part_value:  symbol_name: GND x: 396.24 y: 30.48 rot: R0 gate: 1
# starting to draw symbol: GND at 396.24 30.48 with rotation R0
# start to draw pins
# part_name: GND25 part_value:  symbol_name: GND x: 408.94 y: 30.48 rot: R0 gate: 1
# starting to draw symbol: GND at 408.94 30.48 with rotation R0
# start to draw pins
# part_name: P+9 part_value:  symbol_name: 3.3V x: 406.4 y: 99.06 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 406.4 99.06 with rotation R0
# start to draw pins
# part_name: GND27 part_value:  symbol_name: GND x: 388.62 y: 30.48 rot: R0 gate: 1
# starting to draw symbol: GND at 388.62 30.48 with rotation R0
# start to draw pins
# part_name: P+10 part_value:  symbol_name: 3.3V x: 424.18 y: 45.72 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 424.18 45.72 with rotation R0
# start to draw pins
# part_name: GND28 part_value:  symbol_name: GND x: 424.18 y: 30.48 rot: R0 gate: 1
# starting to draw symbol: GND at 424.18 30.48 with rotation R0
# start to draw pins
# part_name: U2 part_value: VS1053 symbol_name: VS1033D x: 406.4 y: 205.74 rot: R0 gate: G$1
# starting to draw symbol: VS1033D at 406.4 205.74 with rotation R0
# start to draw pins
# part_name: Q4 part_value: 12.288MHz symbol_name: Q x: 360.68 y: 203.2 rot: R90 gate: G$1
# starting to draw symbol: Q at 360.68 203.2 with rotation R90
# start to draw pins
# part_name: IC7 part_value: 1.8V symbol_name: V-REG-LDO x: 525.78 y: 218.44 rot: R0 gate: G$1
# starting to draw symbol: V-REG-LDO at 525.78 218.44 with rotation R0
# start to draw pins
# part_name: GND32 part_value:  symbol_name: GND x: 543.56 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 543.56 238.76 with rotation R0
# start to draw pins
# part_name: GND33 part_value:  symbol_name: GND x: 513.08 y: 205.74 rot: R0 gate: 1
# starting to draw symbol: GND at 513.08 205.74 with rotation R0
# start to draw pins
# part_name: GND34 part_value:  symbol_name: GND x: 543.56 y: 205.74 rot: R0 gate: 1
# starting to draw symbol: GND at 543.56 205.74 with rotation R0
# start to draw pins
# part_name: GND35 part_value:  symbol_name: GND x: 553.72 y: 205.74 rot: R0 gate: 1
# starting to draw symbol: GND at 553.72 205.74 with rotation R0
# start to draw pins
# part_name: GND36 part_value:  symbol_name: GND x: 342.9 y: 195.58 rot: R270 gate: 1
# starting to draw symbol: GND at 342.9 195.58 with rotation R270
# start to draw pins
# part_name: GND37 part_value:  symbol_name: GND x: 398.78 y: 157.48 rot: R0 gate: 1
# starting to draw symbol: GND at 398.78 157.48 with rotation R0
# start to draw pins
# part_name: GND39 part_value:  symbol_name: GND x: 449.58 y: 190.5 rot: R0 gate: 1
# starting to draw symbol: GND at 449.58 190.5 with rotation R0
# start to draw pins
# part_name: GND40 part_value:  symbol_name: GND x: 525.78 y: 152.4 rot: R0 gate: 1
# starting to draw symbol: GND at 525.78 152.4 with rotation R0
# start to draw pins
# part_name: GND41 part_value:  symbol_name: GND x: 553.72 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 553.72 238.76 with rotation R0
# start to draw pins
# part_name: P+11 part_value:  symbol_name: 3.3V x: 396.24 y: 248.92 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 396.24 248.92 with rotation R0
# start to draw pins
# part_name: P+16 part_value:  symbol_name: 3.3V x: 469.9 y: 236.22 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 469.9 236.22 with rotation R0
# start to draw pins
# part_name: GND42 part_value:  symbol_name: GND x: 469.9 y: 177.8 rot: R0 gate: 1
# starting to draw symbol: GND at 469.9 177.8 with rotation R0
# start to draw pins
# part_name: U$4 part_value:  symbol_name: 1.8V x: 408.94 y: 246.38 rot: R0 gate: G$1
# starting to draw symbol: 1.8V at 408.94 246.38 with rotation R0
# start to draw pins
# part_name: GND44 part_value:  symbol_name: GND x: 378.46 y: 172.72 rot: R0 gate: 1
# starting to draw symbol: GND at 378.46 172.72 with rotation R0
# start to draw pins
# part_name: GND46 part_value:  symbol_name: GND x: 563.88 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 563.88 238.76 with rotation R0
# start to draw pins
# part_name: GND47 part_value:  symbol_name: GND x: 574.04 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 574.04 238.76 with rotation R0
# start to draw pins
# part_name: GND48 part_value:  symbol_name: GND x: 436.88 y: 172.72 rot: R0 gate: 1
# starting to draw symbol: GND at 436.88 172.72 with rotation R0
# start to draw pins
# part_name: GND49 part_value:  symbol_name: GND x: 444.5 y: 172.72 rot: R0 gate: 1
# starting to draw symbol: GND at 444.5 172.72 with rotation R0
# start to draw pins
# part_name: GND51 part_value:  symbol_name: GND x: 563.88 y: 205.74 rot: R0 gate: 1
# starting to draw symbol: GND at 563.88 205.74 with rotation R0
# start to draw pins
# part_name: U$5 part_value:  symbol_name: 1.8V x: 563.88 y: 226.06 rot: R0 gate: G$1
# starting to draw symbol: 1.8V at 563.88 226.06 with rotation R0
# start to draw pins
# part_name: P+19 part_value:  symbol_name: 3.3V x: 584.2 y: 259.08 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 584.2 259.08 with rotation R0
# start to draw pins
# part_name: P+20 part_value:  symbol_name: 3.3V x: 510.54 y: 226.06 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 510.54 226.06 with rotation R0
# start to draw pins
# part_name: P+21 part_value:  symbol_name: 3.3V x: 477.52 y: 218.44 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 477.52 218.44 with rotation R0
# start to draw pins
# part_name: GND54 part_value:  symbol_name: GND x: 477.52 y: 177.8 rot: R0 gate: 1
# starting to draw symbol: GND at 477.52 177.8 with rotation R0
# start to draw pins
# part_name: Q1 part_value: 16MHz symbol_name: Q x: 60.96 y: 205.74 rot: R90 gate: G$1
# starting to draw symbol: Q at 60.96 205.74 with rotation R90
# start to draw pins
# part_name: GND56 part_value:  symbol_name: GND x: 53.34 y: 139.7 rot: R0 gate: 1
# starting to draw symbol: GND at 53.34 139.7 with rotation R0
# start to draw pins
# part_name: GND57 part_value:  symbol_name: GND x: 109.22 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 109.22 238.76 with rotation R0
# start to draw pins
# part_name: GND58 part_value:  symbol_name: GND x: 68.58 y: 182.88 rot: R0 gate: 1
# starting to draw symbol: GND at 68.58 182.88 with rotation R0
# start to draw pins
# part_name: GND60 part_value:  symbol_name: GND x: 76.2 y: 220.98 rot: R0 gate: 1
# starting to draw symbol: GND at 76.2 220.98 with rotation R0
# start to draw pins
# part_name: GND62 part_value:  symbol_name: GND x: 515.62 y: 152.4 rot: R0 gate: 1
# starting to draw symbol: GND at 515.62 152.4 with rotation R0
# start to draw pins
# part_name: GND64 part_value:  symbol_name: GND x: 342.9 y: 210.82 rot: R270 gate: 1
# starting to draw symbol: GND at 342.9 210.82 with rotation R270
# start to draw pins
# part_name: GND65 part_value:  symbol_name: GND x: 91.44 y: 220.98 rot: R0 gate: 1
# starting to draw symbol: GND at 91.44 220.98 with rotation R0
# start to draw pins
# part_name: GND66 part_value:  symbol_name: GND x: 391.16 y: 162.56 rot: R0 gate: 1
# starting to draw symbol: GND at 391.16 162.56 with rotation R0
# start to draw pins
# part_name: GND67 part_value:  symbol_name: GND x: 396.24 y: 162.56 rot: R0 gate: 1
# starting to draw symbol: GND at 396.24 162.56 with rotation R0
# start to draw pins
# part_name: GND68 part_value:  symbol_name: GND x: 393.7 y: 157.48 rot: R0 gate: 1
# starting to draw symbol: GND at 393.7 157.48 with rotation R0
# start to draw pins
# part_name: GND70 part_value:  symbol_name: GND x: 401.32 y: 162.56 rot: R0 gate: 1
# starting to draw symbol: GND at 401.32 162.56 with rotation R0
# start to draw pins
# part_name: GND71 part_value:  symbol_name: GND x: 403.86 y: 157.48 rot: R0 gate: 1
# starting to draw symbol: GND at 403.86 157.48 with rotation R0
# start to draw pins
# part_name: C3 part_value: 10uF symbol_name: CAP x: 27.94 y: 302.26 rot: R0 gate: G$1
# starting to draw symbol: CAP at 27.94 302.26 with rotation R0
# start to draw pins
# part_name: C1 part_value: 10uF symbol_name: CAP x: 124.46 y: 76.2 rot: R0 gate: G$1
# starting to draw symbol: CAP at 124.46 76.2 with rotation R0
# start to draw pins
# part_name: C2 part_value: 10uF symbol_name: CAP x: 132.08 y: 76.2 rot: R0 gate: G$1
# starting to draw symbol: CAP at 132.08 76.2 with rotation R0
# start to draw pins
# part_name: C14 part_value: 10uF symbol_name: CAP x: 208.28 y: 71.12 rot: R0 gate: G$1
# starting to draw symbol: CAP at 208.28 71.12 with rotation R0
# start to draw pins
# part_name: C15 part_value: 10uF symbol_name: CAP x: 215.9 y: 71.12 rot: R0 gate: G$1
# starting to draw symbol: CAP at 215.9 71.12 with rotation R0
# start to draw pins
# part_name: C28 part_value: 10uF symbol_name: CAP x: 543.56 y: 248.92 rot: R0 gate: G$1
# starting to draw symbol: CAP at 543.56 248.92 with rotation R0
# start to draw pins
# part_name: C29 part_value: 10uF symbol_name: CAP x: 543.56 y: 215.9 rot: R0 gate: G$1
# starting to draw symbol: CAP at 543.56 215.9 with rotation R0
# start to draw pins
# part_name: SUPPLY14 part_value:  symbol_name: 5V x: 502.92 y: 264.16 rot: R0 gate: G$1
# starting to draw symbol: 5V at 502.92 264.16 with rotation R0
# start to draw pins
# part_name: GND43 part_value:  symbol_name: GND x: 231.14 y: 294.64 rot: R0 gate: 1
# starting to draw symbol: GND at 231.14 294.64 with rotation R0
# start to draw pins
# part_name: SUPPLY15 part_value:  symbol_name: 5V x: 231.14 y: 327.66 rot: R0 gate: G$1
# starting to draw symbol: 5V at 231.14 327.66 with rotation R0
# start to draw pins
# part_name: GND1 part_value:  symbol_name: GND x: 124.46 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 124.46 55.88 with rotation R0
# start to draw pins
# part_name: SUPPLY16 part_value:  symbol_name: 5V x: 256.54 y: 88.9 rot: R270 gate: G$1
# starting to draw symbol: 5V at 256.54 88.9 with rotation R270
# start to draw pins
# part_name: SUPPLY18 part_value:  symbol_name: 5V x: 109.22 y: 264.16 rot: R0 gate: G$1
# starting to draw symbol: 5V at 109.22 264.16 with rotation R0
# start to draw pins
# part_name: SUPPLY19 part_value:  symbol_name: 5V x: 111.76 y: 226.06 rot: R0 gate: G$1
# starting to draw symbol: 5V at 111.76 226.06 with rotation R0
# start to draw pins
# part_name: SUPPLY21 part_value:  symbol_name: 5V x: 83.82 y: 187.96 rot: R90 gate: G$1
# starting to draw symbol: 5V at 83.82 187.96 with rotation R90
# start to draw pins
# part_name: JP7 part_value:  symbol_name: JUMPER-2 x: 299.72 y: 180.34 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 299.72 180.34 with rotation R180
# start to draw pins
# part_name: JP8 part_value:  symbol_name: JUMPER-2 x: 299.72 y: 170.18 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 299.72 170.18 with rotation R180
# start to draw pins
# part_name: JP5 part_value:  symbol_name: JUMPER-2 x: 299.72 y: 200.66 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 299.72 200.66 with rotation R180
# start to draw pins
# part_name: JP4 part_value:  symbol_name: JUMPER-2 x: 299.72 y: 231.14 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 299.72 231.14 with rotation R180
# start to draw pins
# part_name: JP6 part_value:  symbol_name: JUMPER-2 x: 299.72 y: 190.5 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 299.72 190.5 with rotation R180
# start to draw pins
# part_name: JP9 part_value:  symbol_name: JUMPER-2 x: 299.72 y: 160.02 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 299.72 160.02 with rotation R180
# start to draw pins
# part_name: JP10 part_value:  symbol_name: JUMPER-2 x: 452.12 y: 157.48 rot: R180 gate: A
# starting to draw symbol: JUMPER-2 at 452.12 157.48 with rotation R180
# start to draw pins
# part_name: P+1 part_value:  symbol_name: 3.3V x: 444.5 y: 162.56 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 444.5 162.56 with rotation R0
# start to draw pins
# part_name: U1 part_value: ATMEGA32U4 symbol_name: ATMEGA32U4 x: 154.94 y: 198.12 rot: R0 gate: G$1
# starting to draw symbol: ATMEGA32U4 at 154.94 198.12 with rotation R0
# start to draw pins
# part_name: SUPPLY22 part_value:  symbol_name: 5V x: 66.04 y: 238.76 rot: R0 gate: G$1
# starting to draw symbol: 5V at 66.04 238.76 with rotation R0
# start to draw pins
# part_name: SUPPLY17 part_value:  symbol_name: 5V x: 248.92 y: 73.66 rot: R270 gate: G$1
# starting to draw symbol: 5V at 248.92 73.66 with rotation R270
# start to draw pins
# part_name: SUPPLY23 part_value:  symbol_name: 5V x: 106.68 y: 175.26 rot: R90 gate: G$1
# starting to draw symbol: 5V at 106.68 175.26 with rotation R90
# start to draw pins
# part_name: GND6 part_value:  symbol_name: GND x: 119.38 y: 284.48 rot: R0 gate: 1
# starting to draw symbol: GND at 119.38 284.48 with rotation R0
# start to draw pins
# part_name: GND86 part_value:  symbol_name: GND x: 208.28 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 208.28 55.88 with rotation R0
# start to draw pins
# part_name: GND87 part_value:  symbol_name: GND x: 200.66 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 200.66 55.88 with rotation R0
# start to draw pins
# part_name: GND88 part_value:  symbol_name: GND x: 180.34 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 180.34 55.88 with rotation R0
# start to draw pins
# part_name: SUPPLY8 part_value:  symbol_name: 5V x: 259.08 y: 312.42 rot: R0 gate: G$1
# starting to draw symbol: 5V at 259.08 312.42 with rotation R0
# start to draw pins
# part_name: GND89 part_value:  symbol_name: GND x: 106.68 y: 218.44 rot: R270 gate: 1
# starting to draw symbol: GND at 106.68 218.44 with rotation R270
# start to draw pins
# part_name: U$19 part_value:  symbol_name: 5V x: 363.22 y: 99.06 rot: R0 gate: G$1
# starting to draw symbol: 5V at 363.22 99.06 with rotation R0
# start to draw pins
# part_name: P+13 part_value:  symbol_name: 3.3V x: 342.9 y: 99.06 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 342.9 99.06 with rotation R0
# start to draw pins
# part_name: Q2 part_value: BSS138 symbol_name: MOSFET-NCHANNEL x: 353.06 y: 81.28 rot: R270 gate: G$1
# starting to draw symbol: MOSFET-NCHANNEL at 353.06 81.28 with rotation R270
# start to draw pins
# part_name: U$20 part_value:  symbol_name: 5V x: 363.22 y: 53.34 rot: R0 gate: G$1
# starting to draw symbol: 5V at 363.22 53.34 with rotation R0
# start to draw pins
# part_name: P+14 part_value:  symbol_name: 3.3V x: 342.9 y: 53.34 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 342.9 53.34 with rotation R0
# start to draw pins
# part_name: Q3 part_value: BSS138 symbol_name: MOSFET-NCHANNEL x: 353.06 y: 35.56 rot: R270 gate: G$1
# starting to draw symbol: MOSFET-NCHANNEL at 353.06 35.56 with rotation R270
# start to draw pins
# part_name: JP11 part_value: External Speaker symbol_name: M03 x: 586.74 y: 167.64 rot: MR0 gate: G$1
# starting to draw symbol: M03 at 586.74 167.64 with rotation MR0
# start to draw pins
# part_name: GND13 part_value:  symbol_name: GND x: 170.18 y: 63.5 rot: R0 gate: 1
# starting to draw symbol: GND at 170.18 63.5 with rotation R0
# start to draw pins
# part_name: P+3 part_value:  symbol_name: 3.3V x: 436.88 y: 317.5 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 436.88 317.5 with rotation R0
# start to draw pins
# part_name: GND31 part_value:  symbol_name: GND x: 447.04 y: 276.86 rot: R0 gate: 1
# starting to draw symbol: GND at 447.04 276.86 with rotation R0
# start to draw pins
# part_name: GND45 part_value:  symbol_name: GND x: 365.76 y: 325.12 rot: R0 gate: 1
# starting to draw symbol: GND at 365.76 325.12 with rotation R0
# start to draw pins
# part_name: P+2 part_value:  symbol_name: 3.3V x: 365.76 y: 340.36 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 365.76 340.36 with rotation R0
# start to draw pins
# part_name: GND50 part_value:  symbol_name: GND x: 581.66 y: 238.76 rot: R0 gate: 1
# starting to draw symbol: GND at 581.66 238.76 with rotation R0
# start to draw pins
# part_name: PC2 part_value: 220uF symbol_name: CPOL x: 543.56 y: 182.88 rot: R90 gate: G$1
# starting to draw symbol: CPOL at 543.56 182.88 with rotation R90
# start to draw pins
# part_name: PC1 part_value: 220uF symbol_name: CPOL x: 533.4 y: 185.42 rot: R90 gate: G$1
# starting to draw symbol: CPOL at 533.4 185.42 with rotation R90
# start to draw pins
# part_name: R12 part_value: 75k symbol_name: RESISTOR x: 469.9 y: 228.6 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 469.9 228.6 with rotation R270
# start to draw pins
# part_name: R14 part_value: 75k symbol_name: RESISTOR x: 477.52 y: 210.82 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 477.52 210.82 with rotation R270
# start to draw pins
# part_name: R15 part_value: 75k symbol_name: RESISTOR x: 477.52 y: 187.96 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 477.52 187.96 with rotation R270
# start to draw pins
# part_name: R13 part_value: 75k symbol_name: RESISTOR x: 469.9 y: 187.96 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 469.9 187.96 with rotation R270
# start to draw pins
# part_name: R11 part_value: 75k symbol_name: RESISTOR x: 444.5 y: 182.88 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 444.5 182.88 with rotation R270
# start to draw pins
# part_name: R10 part_value: 75k symbol_name: RESISTOR x: 436.88 y: 182.88 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 436.88 182.88 with rotation R270
# start to draw pins
# part_name: R7 part_value: 976k symbol_name: RESISTOR x: 365.76 y: 203.2 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 365.76 203.2 with rotation R270
# start to draw pins
# part_name: C18 part_value: 22pF symbol_name: CAP x: 353.06 y: 210.82 rot: R270 gate: G$1
# starting to draw symbol: CAP at 353.06 210.82 with rotation R270
# start to draw pins
# part_name: C19 part_value: 22pF symbol_name: CAP x: 353.06 y: 195.58 rot: R270 gate: G$1
# starting to draw symbol: CAP at 353.06 195.58 with rotation R270
# start to draw pins
# part_name: R8 part_value: 75k symbol_name: RESISTOR x: 408.94 y: 60.96 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 408.94 60.96 with rotation R270
# start to draw pins
# part_name: C22 part_value: 0.1uF symbol_name: CAP x: 424.18 y: 40.64 rot: R180 gate: G$1
# starting to draw symbol: CAP at 424.18 40.64 with rotation R180
# start to draw pins
# part_name: C20 part_value: 0.1uF symbol_name: CAP x: 396.24 y: 60.96 rot: R180 gate: G$1
# starting to draw symbol: CAP at 396.24 60.96 with rotation R180
# start to draw pins
# part_name: R17 part_value: 22R symbol_name: RESISTOR x: 515.62 y: 175.26 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 515.62 175.26 with rotation R270
# start to draw pins
# part_name: R18 part_value: 22R symbol_name: RESISTOR x: 525.78 y: 175.26 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 525.78 175.26 with rotation R270
# start to draw pins
# part_name: C26 part_value: 0.01uF symbol_name: CAP x: 525.78 y: 165.1 rot: R180 gate: G$1
# starting to draw symbol: CAP at 525.78 165.1 with rotation R180
# start to draw pins
# part_name: C25 part_value: 0.01uF symbol_name: CAP x: 515.62 y: 165.1 rot: R180 gate: G$1
# starting to draw symbol: CAP at 515.62 165.1 with rotation R180
# start to draw pins
# part_name: R16 part_value: 75k symbol_name: RESISTOR x: 462.28 y: 160.02 rot: R0 gate: G$1
# starting to draw symbol: RESISTOR at 462.28 160.02 with rotation R0
# start to draw pins
# part_name: C33 part_value: 0.1uF symbol_name: CAP x: 563.88 y: 218.44 rot: R180 gate: G$1
# starting to draw symbol: CAP at 563.88 218.44 with rotation R180
# start to draw pins
# part_name: C31 part_value: 0.1uF symbol_name: CAP x: 553.72 y: 218.44 rot: R180 gate: G$1
# starting to draw symbol: CAP at 553.72 218.44 with rotation R180
# start to draw pins
# part_name: C30 part_value: 0.1uF symbol_name: CAP x: 553.72 y: 251.46 rot: R180 gate: G$1
# starting to draw symbol: CAP at 553.72 251.46 with rotation R180
# start to draw pins
# part_name: C32 part_value: 0.1uF symbol_name: CAP x: 563.88 y: 251.46 rot: R180 gate: G$1
# starting to draw symbol: CAP at 563.88 251.46 with rotation R180
# start to draw pins
# part_name: C34 part_value: 0.1uF symbol_name: CAP x: 574.04 y: 251.46 rot: R180 gate: G$1
# starting to draw symbol: CAP at 574.04 251.46 with rotation R180
# start to draw pins
# part_name: C35 part_value: 0.1uF symbol_name: CAP x: 581.66 y: 251.46 rot: R180 gate: G$1
# starting to draw symbol: CAP at 581.66 251.46 with rotation R180
# start to draw pins
# part_name: C24 part_value: 1uF symbol_name: CAP x: 502.92 y: 251.46 rot: R180 gate: G$1
# starting to draw symbol: CAP at 502.92 251.46 with rotation R180
# start to draw pins
# part_name: C21 part_value: 0.1uF symbol_name: CAP x: 365.76 y: 335.28 rot: R180 gate: G$1
# starting to draw symbol: CAP at 365.76 335.28 with rotation R180
# start to draw pins
# part_name: C5 part_value: 1uF symbol_name: CAP x: 38.1 y: 175.26 rot: R180 gate: G$1
# starting to draw symbol: CAP at 38.1 175.26 with rotation R180
# start to draw pins
# part_name: C11 part_value: 0.1uF symbol_name: CAP x: 76.2 y: 231.14 rot: R180 gate: G$1
# starting to draw symbol: CAP at 76.2 231.14 with rotation R180
# start to draw pins
# part_name: C13 part_value: 0.1uF symbol_name: CAP x: 91.44 y: 231.14 rot: R180 gate: G$1
# starting to draw symbol: CAP at 91.44 231.14 with rotation R180
# start to draw pins
# part_name: R1 part_value: 75k symbol_name: RESISTOR x: 66.04 y: 223.52 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 66.04 223.52 with rotation R270
# start to draw pins
# part_name: C7 part_value: 22pF symbol_name: CAP x: 50.8 y: 210.82 rot: R270 gate: G$1
# starting to draw symbol: CAP at 50.8 210.82 with rotation R270
# start to draw pins
# part_name: C8 part_value: 22pF symbol_name: CAP x: 50.8 y: 200.66 rot: R270 gate: G$1
# starting to draw symbol: CAP at 50.8 200.66 with rotation R270
# start to draw pins
# part_name: C10 part_value: 1uF symbol_name: CAP x: 60.96 y: 175.26 rot: R180 gate: G$1
# starting to draw symbol: CAP at 60.96 175.26 with rotation R180
# start to draw pins
# part_name: C9 part_value: 0.1uF symbol_name: CAP x: 53.34 y: 175.26 rot: R180 gate: G$1
# starting to draw symbol: CAP at 53.34 175.26 with rotation R180
# start to draw pins
# part_name: R4 part_value: 22R symbol_name: RESISTOR x: 142.24 y: 322.58 rot: R0 gate: G$1
# starting to draw symbol: RESISTOR at 142.24 322.58 with rotation R0
# start to draw pins
# part_name: R5 part_value: 22R symbol_name: RESISTOR x: 142.24 y: 314.96 rot: R0 gate: G$1
# starting to draw symbol: RESISTOR at 142.24 314.96 with rotation R0
# start to draw pins
# part_name: C17 part_value: 1uF symbol_name: CAP x: 22.86 y: 73.66 rot: R180 gate: G$1
# starting to draw symbol: CAP at 22.86 73.66 with rotation R180
# start to draw pins
# part_name: C4 part_value: 0.1uF symbol_name: CAP x: 38.1 y: 304.8 rot: R180 gate: G$1
# starting to draw symbol: CAP at 38.1 304.8 with rotation R180
# start to draw pins
# part_name: R3 part_value: 309K symbol_name: RESISTOR x: 193.04 y: 68.58 rot: R0 gate: G$1
# starting to draw symbol: RESISTOR at 193.04 68.58 with rotation R0
# start to draw pins
# part_name: R2 part_value: 976K symbol_name: RESISTOR x: 193.04 y: 78.74 rot: R0 gate: G$1
# starting to draw symbol: RESISTOR at 193.04 78.74 with rotation R0
# start to draw pins
# part_name: C12 part_value: 0.1uF symbol_name: CAP x: 236.22 y: 314.96 rot: R180 gate: G$1
# starting to draw symbol: CAP at 236.22 314.96 with rotation R180
# start to draw pins
# part_name: R9 part_value: 75k symbol_name: RESISTOR x: 378.46 y: 182.88 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 378.46 182.88 with rotation R270
# start to draw pins
# part_name: C23 part_value: 1uF symbol_name: CAP x: 449.58 y: 198.12 rot: R0 gate: G$1
# starting to draw symbol: CAP at 449.58 198.12 with rotation R0
# start to draw pins
# part_name: IC5 part_value: 74HC4050 symbol_name: CD74HC4050PW x: 365.76 y: 307.34 rot: R0 gate: G$1
# starting to draw symbol: CD74HC4050PW at 365.76 307.34 with rotation R0
# start to draw pins
# part_name: P+8 part_value:  symbol_name: 3.3V x: 347.98 y: 325.12 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 347.98 325.12 with rotation R0
# start to draw pins
# part_name: GND74 part_value:  symbol_name: GND x: 388.62 y: 320.04 rot: R0 gate: 1
# starting to draw symbol: GND at 388.62 320.04 with rotation R0
# start to draw pins
# part_name: AGND1 part_value:  symbol_name: AGND x: 398.78 y: 139.7 rot: R0 gate: VR1
# starting to draw symbol: AGND at 398.78 139.7 with rotation R0
# start to draw pins
# part_name: GND59 part_value:  symbol_name: GND x: 419.1 y: 139.7 rot: R0 gate: 1
# starting to draw symbol: GND at 419.1 139.7 with rotation R0
# start to draw pins
# part_name: P+6 part_value:  symbol_name: 3.3V x: 396.24 y: 264.16 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 396.24 264.16 with rotation R0
# start to draw pins
# part_name: IC2 part_value: ESD Diode symbol_name: ESD-DIODE x: 119.38 y: 299.72 rot: R0 gate: G$1
# starting to draw symbol: ESD-DIODE at 119.38 299.72 with rotation R0
# start to draw pins
# part_name: F2 part_value: 1.1A symbol_name: FUSE x: 205.74 y: 304.8 rot: R0 gate: G$1
# starting to draw symbol: FUSE at 205.74 304.8 with rotation R0
# start to draw pins
# part_name: F1 part_value: 500mA symbol_name: FUSE x: 167.64 y: 325.12 rot: R0 gate: G$1
# starting to draw symbol: FUSE at 167.64 325.12 with rotation R0
# start to draw pins
# part_name: S2 part_value: DPDT symbol_name: DPDT-SWITCH x: 160.02 y: 60.96 rot: R0 gate: G$1
# starting to draw symbol: DPDT-SWITCH at 160.02 60.96 with rotation R0
# start to draw pins
# part_name: IC1 part_value: MCP1640 symbol_name: MCP1640 x: 162.56 y: 78.74 rot: R0 gate: G$1
# starting to draw symbol: MCP1640 at 162.56 78.74 with rotation R0
# start to draw pins
# part_name: L1 part_value:  symbol_name: INDUCTOR x: 139.7 y: 73.66 rot: R90 gate: G$1
# starting to draw symbol: INDUCTOR at 139.7 73.66 with rotation R90
# start to draw pins
# part_name: AGND2 part_value:  symbol_name: AGND x: 414.02 y: 157.48 rot: R0 gate: VR1
# starting to draw symbol: AGND at 414.02 157.48 with rotation R0
# start to draw pins
# part_name: AGND3 part_value:  symbol_name: AGND x: 416.56 y: 162.56 rot: R0 gate: VR1
# starting to draw symbol: AGND at 416.56 162.56 with rotation R0
# start to draw pins
# part_name: AGND4 part_value:  symbol_name: AGND x: 419.1 y: 157.48 rot: R0 gate: VR1
# starting to draw symbol: AGND at 419.1 157.48 with rotation R0
# start to draw pins
# part_name: AGND5 part_value:  symbol_name: AGND x: 421.64 y: 162.56 rot: R0 gate: VR1
# starting to draw symbol: AGND at 421.64 162.56 with rotation R0
# start to draw pins
# part_name: RN5 part_value: 10k symbol_name: R1NV x: 312.42 y: 233.68 rot: R180 gate: A
# starting to draw symbol: R1NV at 312.42 233.68 with rotation R180
# start to draw pins
# part_name: RN5 part_value: 10k symbol_name: R1NV x: 325.12 y: 218.44 rot: R180 gate: B
# starting to draw symbol: R1NV at 325.12 218.44 with rotation R180
# start to draw pins
# part_name: RN5 part_value: 10k symbol_name: R1NV x: 312.42 y: 218.44 rot: R0 gate: C
# starting to draw symbol: R1NV at 312.42 218.44 with rotation R0
# start to draw pins
# part_name: RN5 part_value: 10k symbol_name: R1NV x: 297.18 y: 243.84 rot: R180 gate: D
# starting to draw symbol: R1NV at 297.18 243.84 with rotation R180
# start to draw pins
# part_name: GND38 part_value:  symbol_name: GND x: 299.72 y: 210.82 rot: R0 gate: 1
# starting to draw symbol: GND at 299.72 210.82 with rotation R0
# start to draw pins
# part_name: R6 part_value: 75k symbol_name: RESISTOR x: 332.74 y: 292.1 rot: R270 gate: G$1
# starting to draw symbol: RESISTOR at 332.74 292.1 with rotation R270
# start to draw pins
# part_name: GND69 part_value:  symbol_name: GND x: 332.74 y: 281.94 rot: R0 gate: 1
# starting to draw symbol: GND at 332.74 281.94 with rotation R0
# start to draw pins
# part_name: RN2 part_value: 1K symbol_name: R1NV x: 40.64 y: 55.88 rot: R0 gate: A
# starting to draw symbol: R1NV at 40.64 55.88 with rotation R0
# start to draw pins
# part_name: RN2 part_value: 1K symbol_name: R1NV x: 40.64 y: 63.5 rot: R0 gate: B
# starting to draw symbol: R1NV at 40.64 63.5 with rotation R0
# start to draw pins
# part_name: RN2 part_value: 1K symbol_name: R1NV x: 111.76 y: 43.18 rot: R0 gate: C
# starting to draw symbol: R1NV at 111.76 43.18 with rotation R0
# start to draw pins
# part_name: RN2 part_value: 1K symbol_name: R1NV x: 111.76 y: 45.72 rot: R180 gate: D
# starting to draw symbol: R1NV at 111.76 45.72 with rotation R180
# start to draw pins
# part_name: GND55 part_value:  symbol_name: GND x: 81.28 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 81.28 55.88 with rotation R0
# start to draw pins
# part_name: L5 part_value: Ferrite symbol_name: L x: 408.94 y: 147.32 rot: R0 gate: G$1
# starting to draw symbol: L at 408.94 147.32 with rotation R0
# start to draw pins
# part_name: L4 part_value: Ferrite symbol_name: L x: 406.4 y: 261.62 rot: R0 gate: G$1
# starting to draw symbol: L at 406.4 261.62 with rotation R0
# start to draw pins
# part_name: L2 part_value: Ferrite symbol_name: L x: 66.04 y: 299.72 rot: R0 gate: G$1
# starting to draw symbol: L at 66.04 299.72 with rotation R0
# start to draw pins
# part_name: L3 part_value:  symbol_name: L x: 99.06 y: 198.12 rot: R0 gate: G$1
# starting to draw symbol: L at 99.06 198.12 with rotation R0
# start to draw pins
# part_name: X3 part_value: MICRO-SD symbol_name: MICRO-SD-CARD x: 467.36 y: 299.72 rot: R0 gate: G$1
# starting to draw symbol: MICRO-SD-CARD at 467.36 299.72 with rotation R0
# start to draw pins
# part_name: RN4 part_value: 1K symbol_name: R1NV x: 342.9 y: 88.9 rot: R90 gate: A
# starting to draw symbol: R1NV at 342.9 88.9 with rotation R90
# start to draw pins
# part_name: RN4 part_value: 1K symbol_name: R1NV x: 363.22 y: 88.9 rot: R90 gate: B
# starting to draw symbol: R1NV at 363.22 88.9 with rotation R90
# start to draw pins
# part_name: RN4 part_value: 1K symbol_name: R1NV x: 342.9 y: 43.18 rot: R90 gate: C
# starting to draw symbol: R1NV at 342.9 43.18 with rotation R90
# start to draw pins
# part_name: RN4 part_value: 1K symbol_name: R1NV x: 363.22 y: 43.18 rot: R90 gate: D
# starting to draw symbol: R1NV at 363.22 43.18 with rotation R90
# start to draw pins
# part_name: GND26 part_value:  symbol_name: GND x: 449.58 y: 30.48 rot: R0 gate: 1
# starting to draw symbol: GND at 449.58 30.48 with rotation R0
# start to draw pins
# part_name: SUPPLY1 part_value: UGND symbol_name: GND1 x: 60.96 y: 139.7 rot: R0 gate: G$1
# starting to draw symbol: GND1 at 60.96 139.7 with rotation R0
# start to draw pins
# part_name: X4 part_value:  symbol_name: 3POLE-AUDIO-JACK x: 584.2 y: 185.42 rot: R0 gate: G$1
# starting to draw symbol: 3POLE-AUDIO-JACK at 584.2 185.42 with rotation R0
# start to draw pins
# part_name: GND29 part_value:  symbol_name: GND x: 287.02 y: 30.48 rot: MR0 gate: 1
# starting to draw symbol: GND at 287.02 30.48 with rotation MR0
# start to draw pins
# part_name: JP13 part_value: Touch Electrodes symbol_name: PINHD13 x: 261.62 y: 27.94 rot: MR270 gate: A
# starting to draw symbol: PINHD13 at 261.62 27.94 with rotation MR270
# start to draw pins
# part_name: U$17 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 93.98 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 93.98 with rotation R0
# start to draw pins
# part_name: U$18 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 88.9 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 88.9 with rotation R0
# start to draw pins
# part_name: U$22 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 83.82 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 83.82 with rotation R0
# start to draw pins
# part_name: U$24 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 78.74 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 78.74 with rotation R0
# start to draw pins
# part_name: U$26 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 73.66 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 73.66 with rotation R0
# start to draw pins
# part_name: U$27 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 68.58 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 68.58 with rotation R0
# start to draw pins
# part_name: U$28 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 63.5 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 63.5 with rotation R0
# start to draw pins
# part_name: U$29 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 58.42 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 58.42 with rotation R0
# start to draw pins
# part_name: U$30 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 53.34 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 53.34 with rotation R0
# start to draw pins
# part_name: U$31 part_value:  symbol_name: EDGE-ELEC x: 543.56 y: 48.26 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC at 543.56 48.26 with rotation R0
# start to draw pins
# part_name: U$1 part_value:  symbol_name: EDGE-ELEC-LEFT x: 543.56 y: 43.18 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC-LEFT at 543.56 43.18 with rotation R0
# start to draw pins
# part_name: U$3 part_value:  symbol_name: EDGE-ELEC-RIGHT x: 543.56 y: 99.06 rot: R0 gate: G$1
# starting to draw symbol: EDGE-ELEC-RIGHT at 543.56 99.06 with rotation R0
# start to draw pins
# part_name: U$6 part_value:  symbol_name: EDGE-GND x: 449.58 y: 45.72 rot: R0 gate: G$1
# starting to draw symbol: EDGE-GND at 449.58 45.72 with rotation R0
# start to draw pins
# part_name: SUPPLY13 part_value:  symbol_name: 5V x: 302.26 y: 325.12 rot: R0 gate: G$1
# starting to draw symbol: 5V at 302.26 325.12 with rotation R0
# start to draw pins
# part_name: RN6 part_value: 10K symbol_name: R1NV x: 81.28 y: 68.58 rot: R270 gate: A
# starting to draw symbol: R1NV at 81.28 68.58 with rotation R270
# start to draw pins
# part_name: RN6 part_value: 10K symbol_name: R1NV x: 86.36 y: 68.58 rot: R270 gate: B
# starting to draw symbol: R1NV at 86.36 68.58 with rotation R270
# start to draw pins
# part_name: RN6 part_value: 10K symbol_name: R1NV x: 96.52 y: 66.04 rot: R270 gate: C
# starting to draw symbol: R1NV at 96.52 66.04 with rotation R270
# start to draw pins
# part_name: RN6 part_value: 10K symbol_name: R1NV x: 106.68 y: 101.6 rot: R270 gate: D
# starting to draw symbol: R1NV at 106.68 101.6 with rotation R270
# start to draw pins
# part_name: U$7 part_value:  symbol_name: VUSB x: 17.78 y: 91.44 rot: R0 gate: G$1
# starting to draw symbol: VUSB at 17.78 91.44 with rotation R0
# start to draw pins
# part_name: D2 part_value: B340 symbol_name: DIODE-SCHOTTKY x: 99.06 y: 101.6 rot: R270 gate: G$1
# starting to draw symbol: DIODE-SCHOTTKY at 99.06 101.6 with rotation R270
# start to draw pins
# part_name: GND15 part_value:  symbol_name: GND x: 106.68 y: 91.44 rot: R0 gate: 1
# starting to draw symbol: GND at 106.68 91.44 with rotation R0
# start to draw pins
# part_name: P+5 part_value: VIN symbol_name: VCC x: 116.84 y: 88.9 rot: R0 gate: VCC
# starting to draw symbol: VCC at 116.84 88.9 with rotation R0
# start to draw pins
# part_name: P+7 part_value: VIN symbol_name: VCC x: 170.18 y: 55.88 rot: R0 gate: VCC
# starting to draw symbol: VCC at 170.18 55.88 with rotation R0
# start to draw pins
# part_name: P+12 part_value:  symbol_name: 3.3V x: 236.22 y: 269.24 rot: R0 gate: G$1
# starting to draw symbol: 3.3V at 236.22 269.24 with rotation R0
# start to draw pins
# part_name: GND16 part_value:  symbol_name: GND x: 96.52 y: 55.88 rot: R0 gate: 1
# starting to draw symbol: GND at 96.52 55.88 with rotation R0
# start to draw pins
# part_name: U$8 part_value:  symbol_name: OSHW-LOGO x: 187.96 y: 7.62 rot: R0 gate: G$1
# starting to draw symbol: OSHW-LOGO at 187.96 7.62 with rotation R0
# start to draw pins
# plt saved

# %% [markdown]
# # Add unit ic to schematic

# %%
import xml.etree.ElementTree as ET

def get_symbol_element(schematic_library, library, deviceset):
    """
    Extracts detailed gate symbols from the schematic information based on the library, deviceset, and device.
    Includes deviceset_prefix in the output.

    Args:
        schematic_library (list): The schematic information containing IC libraries.
        library (str): The name of the library.
        deviceset (str): The name of the deviceset.
        device (str): The name of the device.

    Returns:
        dict: A dictionary with the deviceset_prefix and gate details in the format:
              {deviceset_prefix: prefix, gate_name: {symbol_name: str, description: str, wire: list, text: list}}
    """
    # Extract the library data based on the library name
    library_data = next((lib for lib in schematic_library if lib['name'] == library), None)

    if library_data:
        # Extract the deviceset list
        deviceset_list = library_data.get("devicesets", {}).get("deviceset", [])
        if not isinstance(deviceset_list, list):
            deviceset_list = [deviceset_list]

        # Find the specific deviceset
        deviceset_data = next((ds for ds in deviceset_list if ds['name'] == deviceset), None)
        if deviceset_data:
            # Extract the deviceset prefix
            deviceset_prefix = deviceset_data.get("prefix", "")

            # Extract gates and their corresponding detailed symbols
            gates = deviceset_data.get("gates", {}).get("gate", [])
            if not isinstance(gates, list):
                gates = [gates]

            gate_details = {}
            for gate in gates:
                gate_name = gate['name']
                symbol_name = gate['symbol']

                # Find the detailed symbol in the library
                symbols = library_data.get("symbols", {}).get("symbol", [])
                if not isinstance(symbols, list):
                    symbols = [symbols]

                detailed_symbol = next((sym for sym in symbols if sym['name'] == symbol_name), None)
                if detailed_symbol:
                    gate_details[gate_name] = {
                        "symbol_name": symbol_name,
                        "description": detailed_symbol.get("description", ""),
                        "wire": detailed_symbol.get("wire", []),
                        "text": detailed_symbol.get("text", [])
                    }

            return {
                "deviceset_prefix": deviceset_prefix,
                **gate_details
            }
        else:
            print(f"Deviceset '{deviceset}' not found in library '{library}'.")
    else:
        print(f"Library '{library}' not found.")
    return {}

def get_text_from_symbol(schematic_library, library, deviceset_name, gate_name):
    """
    Extracts the x and y coordinates of all text elements from a symbol in the schematic library.

    Args:
        schematic_library (list): The list of library dictionaries.
        deviceset_name (str): The name of the deviceset to search for.
        device_name (str): The name of the device inside the deviceset.
        library_name (str): The name of the library to match.

    Returns:
        dict: A dictionary where keys are text strings and values are tuples (x, y),
              or an empty dictionary if not found.
    """
    symbol_element = get_symbol_element(schematic_library, library, deviceset_name).get(gate_name, {})
    # print("text_elements:",gate_name,":",symbol_element['text'])
    if symbol_element:
        text_elements = symbol_element.get('text', [])
        result = {}
        for text in text_elements:
            if isinstance(text, dict) and 'text' in text and 'x' in text and 'y' in text:
                result[text['text']] = (float(text['x']), float(text['y']))
            else:
                print(f"Invalid text element format: {text}")
        return result
    return {}

def get_position_for_new_symbol(schematic_info, new_symbol_element, spacing=20, max_width=500):
    """
    Places a new symbol using a bottom-left strategy.
    It wraps to a new column if width exceeds max_width.

    Args:
        schematic_info (dict): Schematic info including parts and IC_library.
        new_symbol_element (dict): Symbol to place.
        spacing (int): Minimum spacing between symbols.
        max_width (int): Maximum horizontal extent allowed.

    Returns:
        list: [x, y] position to place the new symbol (bottom-left placement).
    """
    parts_info = schematic_info.get("parts", {})
    ic_library = schematic_info.get("IC_library", {})

    placed_boxes = []

    min_x = float('inf')

    for part_name, part_data in parts_info.items():
        for instance in part_data.get("instances", []):
            gate = instance.get("gate", "")
            symbol = get_symbol_element_of_instance_from_library(ic_library, part_name, gate, parts_info)
            if not symbol:
                continue

            inst_x = float(instance["x"])
            inst_y = float(instance["y"])
            rot = instance.get("rot", "R0")

            xlim, ylim = get_bounding_box_for_symbol_instance(symbol, inst_x, inst_y, rot)
            placed_boxes.append((xlim, ylim))
            min_x = min(min_x, xlim[0])

    # Default starting point if no symbols placed yet
    if not placed_boxes:
        min_x = 0

    # New symbol dimensions at origin
    symbol_xlim, symbol_ylim = get_bounding_box_for_symbol_instance(new_symbol_element, 0, 0, "R0")
    symbol_width = symbol_xlim[1] - symbol_xlim[0]
    symbol_height = symbol_ylim[1] - symbol_ylim[0]

    # Bottom-left placement within width constraint
    for y in range(0, 10000):  # large enough to cover practical height
        for x in range(int(min_x), int(min_x + max_width - symbol_width) + 1):
            proposed_xlim = [x, x + symbol_width]
            proposed_ylim = [y, y + symbol_height]

            collides = False
            for existing_xlim, existing_ylim in placed_boxes:
                if not (proposed_xlim[1] + spacing <= existing_xlim[0] or
                        proposed_xlim[0] >= existing_xlim[1] + spacing or
                        proposed_ylim[1] + spacing <= existing_ylim[0] or
                        proposed_ylim[0] >= existing_ylim[1] + spacing):
                    collides = True
                    break

            if not collides:
                return [x - symbol_xlim[0], y - symbol_ylim[0]]  # Adjust for symbol origin

    return [0, 0]  # Fallback

def find_unique_part_name(schematic_file, new_symbol_element):
    """
    Finds a unique part name that does not appear in the schematic file's part list.
    The prefix is determined based on the library name.

    Args:
        schematic_file (str): Path to the schematic file.
        library_name (str): Name of the library.
        default_prefix (str): Default prefix for the part name (default is "U").

    Returns:
        str: A unique part name.
    """
    prefix = new_symbol_element.get('deviceset_prefix',"IC")
    # Process the schematic file to get the latest part list
    schematic_info = process_schematic_file(schematic_file)
    part_names = list(schematic_info['parts'].keys())

    # Find a unique part name
    index = 1
    while f"{prefix}{index}" in part_names:
        index += 1
    return f"{prefix}{index}"


def add_unit_to_schematic_full(schematic_file, library, deviceset, device, value, name, x_pos, y_pos):
    """
    Adds a new unit to the schematic file, placing the <part> element
    after the last existing part with a name like 'U[number]' within the <parts> section.

    Args:
        schematic_file (str): Path to the schematic file in XML format.
        library (str): Library name for the part.
        deviceset (str): Deviceset name.
        device (str): Device name.
        value (str): Value of the part.
        name (str): Name of the part.
        x_pos (float): X-coordinate for the instance.
        y_pos (float): Y-coordinate for the instance.
    """
    schematic_info = process_schematic_file(schematic_file)
    schematic_library = schematic_info['IC_library']
    symbol_element = get_symbol_element(schematic_library, library, deviceset)

    # Parse the schematic file
    tree = ET.parse(schematic_file)
    root = tree.getroot()

    # Navigate to the parts and instances sections
    parts_section = root.find(".//parts")
    instances_section = root.find(".//instances")

    if parts_section is None or instances_section is None:
        raise ValueError("Invalid schematic file structure. Missing parts or instances section.")

    # Check if the part already exists
    existing_part = parts_section.find(f"./part[@name='{name}']")
    if existing_part is not None:
        print(f"Part with name '{name}' already exists. Skipping addition.")
        return

    # Find the index to insert the new part
    last_u_part_index = -1
    parts_list = list(parts_section)
    for index, part in enumerate(parts_list):
        if part.tag == 'part' and part.get('name', '').startswith('U') and part.get('name', '')[1:].isdigit():
            last_u_part_index = index

    # Create the new <part> element
    part_element = ET.Element("part", {
        "name": name,
        "library": library,
        "deviceset": deviceset,
        "device": device,
        "value": value
    })
    part_element.tail = "\n"

    if last_u_part_index != -1:
        parts_section.insert(last_u_part_index + 1, part_element)
    else:
        parts_section.insert(0, part_element)

    # Ensure all parts have newlines between them
    for part in parts_section.findall("part"):
        part.tail = "\n"

    # Create attributes and instances for each gate
    for gate_name, gate_data in symbol_element.items():
        if gate_name == "deviceset_prefix":
            continue  # Skip the deviceset_prefix key

        # Create the <instance> element
        instance_element = ET.Element("instance", {
            "part": name,
            "gate": gate_name,
            "x": str(x_pos),
            "y": str(y_pos),
            "smashed": "yes"
        })
        instance_element.text = "\n"   # Add newline after opening <instance>
        instance_element.tail = "\n"   # Add newline after closing </instance>

        # Get text positions for the current gate
        text_pos = get_text_from_symbol(schematic_library, library, deviceset, gate_name)
        for text_key, text_coordinates in text_pos.items():
            if ">" in text_key:
                value_attribute_pos = text_coordinates
                sanitized_text_key = text_key.replace(">", "")

                # Add attributes for each text position
                attribute_element = ET.Element("attribute", {
                    "name": sanitized_text_key,
                    "x": str(int(x_pos - value_attribute_pos[0])),
                    "y": str(int(y_pos - value_attribute_pos[1])),
                    "size": "1.778",
                    "layer": "96",
                    "font": "vector",
                    "align": "top-left"
                })
                attribute_element.tail = "\n"
                instance_element.append(attribute_element)

        # Add instance to <instances>
        instances_section.append(instance_element)

    # Ensure all existing instances and attributes have newlines
    for inst in instances_section.findall("instance"):
        inst.tail = "\n"
        if inst.text is None or not inst.text.strip():
            inst.text = "\n"
        for child in inst:
            child.tail = "\n"

    # Write to file (compact with line-by-line structure)
    tree.write(schematic_file, encoding="utf-8", xml_declaration=True)


def add_unit_to_schematic(schematic_file,library, deviceset, device, value):
    """
    Adds a new unit to the schematic file, placing the <part> element
    after the last existing part with a name like 'U[number]' within the <parts> section.

    Args:
        schematic_file (str): Path to the schematic file in XML format.
        library (str): Library name for the part.
        deviceset (str): Deviceset name.
        device (str): Device name.
        value (str): Value of the part.
    """
    # Determine a unique part name
    schematic_info = process_schematic_file(schematic_file)
    schematic_library = schematic_info['IC_library']

    # Check if the library exists
    library_data = next((lib for lib in schematic_library if lib['name'] == library), None)
    print(library)
    if not library_data:
        print(f"Library '{library}' not found in the schematic library.")
        return

    # Check if the deviceset exists in the library
    deviceset_list = library_data.get("devicesets", {}).get("deviceset", [])
    if not isinstance(deviceset_list, list):
        deviceset_list = [deviceset_list]
    deviceset_data = next((ds for ds in deviceset_list if ds['name'] == deviceset), None)
    if not deviceset_data:
        print(f"Deviceset '{deviceset}' not found in library '{library}'.")
        return

    # Check if the device exists in the deviceset
    device_list = deviceset_data.get("devices", {}).get("device", [])
    if not isinstance(device_list, list):
        device_list = [device_list]
    device_data = next((dev for dev in device_list if dev['name'] == device), None)
    if not device_data:
        print(f"Device '{device}' not found in deviceset '{deviceset}'.")
        return
    
    new_symbol_element = get_symbol_element(schematic_info['IC_library'], library, deviceset)
    part_name = find_unique_part_name(schematic_file, new_symbol_element)

    # Get the position for the new instance
    position = get_position_for_new_symbol(schematic_info, new_symbol_element)
    print(f"Suggested position for new symbol '{part_name}': {position}")
    x_pos = position[0] # Replace with desired x-coordinate
    y_pos = position[1] # Replace with desired y-coordinate

    # Add the unit to the schematic
    add_unit_to_schematic_full(schematic_file, library, deviceset, device, value, part_name, x_pos, y_pos)

# %%
import xml.etree.ElementTree as ET

def get_gate_symbol_for_layout(library_xml, part_name, gate_name, part_library):
    """
    Return the raw symbol dict for a single gate, suitable for layout.

    Args:
        library_xml (list): schematic_info['IC_library']
        part_name (str): the <part>@name from your schematic
        gate_name (str): which gate (e.g. 'A', 'B', etc.) to fetch
        part_library (dict): schematic_info['parts']
    Returns:
        dict: the gate’s symbol data (with 'wire','pin','polygon',…), or None if not found.
    """
    part_info = part_library.get(part_name)
    if not part_info:
        print(f"[get_gate_symbol_for_layout] part '{part_name}' not in library")
        return None

    libname   = part_info.get('library')
    deviceset = part_info.get('deviceset')
    if not libname or not deviceset:
        print(f"[get_gate_symbol_for_layout] missing library/deviceset for '{part_name}'")
        return None

    # get the full gate→symbol map for that deviceset
    full_symbol_map = get_symbol_element(library_xml, libname, deviceset)
    gate_sym = full_symbol_map.get(gate_name)
    if gate_sym is None:
        print(f"[get_gate_symbol_for_layout] gate '{gate_name}' not found in symbol map")
    return gate_sym


def get_position_for_new_gate(schematic_info, gate_symbol, spacing=20, max_width=500):
    """
    Place a single gate using a bottom-left strategy, avoiding collisions with
    existing instances.

    Args:
        schematic_info (dict): Schematic info including 'parts' and 'IC_library'.
        gate_symbol (dict): The symbol definition for one gate.
        spacing (int): Minimum gap between bounding boxes.
        max_width (int): Max horizontal extent before wrapping.

    Returns:
        [x, y]: Coordinates at which to place this gate.
    """
    parts_info = schematic_info.get("parts", {})
    ic_library = schematic_info.get("IC_library", {})
    placed_boxes = []

    # 1) Gather existing instance boxes
    for part_name, part_data in parts_info.items():
        for inst in part_data.get("instances", []):
            sym = get_symbol_element_of_instance_from_library(
                ic_library, part_name, inst.get("gate"), parts_info
            )
            if not sym:
                continue
            ix, iy = float(inst["x"]), float(inst["y"])
            rot = inst.get("rot", "R0")
            xlim, ylim = get_bounding_box_for_symbol_instance(sym, ix, iy, rot)
            placed_boxes.append((xlim, ylim))

    # 2) Determine starting x
    min_x = min((box[0][0] for box in placed_boxes), default=0)

    # 3) Compute this gate’s size at origin
    gate_xlim, gate_ylim = get_bounding_box_for_symbol_instance(gate_symbol, 0, 0, "R0")
    gate_w = gate_xlim[1] - gate_xlim[0]
    gate_h = gate_ylim[1] - gate_ylim[0]

    # 4) Scan for the first free spot
    for y in range(0, 10000, spacing):
        for x in range(int(min_x), int(min_x + max_width - gate_w) + 1, spacing):
            prop_xlim = [x, x + gate_w]
            prop_ylim = [y, y + gate_h]
            collision = False
            for ex_xlim, ex_ylim in placed_boxes:
                if not (
                    prop_xlim[1] + spacing <= ex_xlim[0] or
                    prop_xlim[0] >= ex_xlim[1] + spacing or
                    prop_ylim[1] + spacing <= ex_ylim[0] or
                    prop_ylim[0] >= ex_ylim[1] + spacing
                ):
                    collision = True
                    break
            if not collision:
                # adjust by symbol origin
                return [x - gate_xlim[0], y - gate_ylim[0]]

    # fallback
    return [0, 0]




def add_unit_to_schematic_full(schematic_file, library, deviceset, device, value, name, x_pos, y_pos):
    """
    Adds a new unit to the schematic, placing each gate using collision-aware layout.
    """
    schematic_info   = process_schematic_file(schematic_file)
    schematic_library= schematic_info['IC_library']
    symbol_element   = get_symbol_element(schematic_library, library, deviceset)

    tree = ET.parse(schematic_file)
    root = tree.getroot()
    parts_section    = root.find(".//parts")
    instances_section= root.find(".//instances")
    if parts_section is None or instances_section is None:
        raise ValueError("Missing <parts> or <instances> in schematic.")

    # skip if already exists
    if parts_section.find(f"./part[@name='{name}']") is not None:
        print(f"Part '{name}' exists; skipping.")
        return

    # find insert index for 'U#' parts
    parts_list = list(parts_section)
    last_u = max(
        (i for i,p in enumerate(parts_list)
         if p.tag=='part' and p.get('name','').startswith('U') and p.get('name')[1:].isdigit()),
        default=-1
    )

    # create and insert <part>
    part_el = ET.Element("part", {
        "name": name, "library": library,
        "deviceset": deviceset, "device": device,
        "value": value
    })
    part_el.tail = "\n"
    idx = last_u+1 if last_u!=-1 else 0
    parts_section.insert(idx, part_el)
    for p in parts_section.findall("part"):
        p.tail = "\n"

    # register the new part in schematic_info
    schematic_info.setdefault('parts', {})[name] = {
        'library': library,
        'deviceset': deviceset,
        'device': device,
        'instances': []
    }

    # for each gate, get its symbol and place it
    for gate_name in symbol_element:
        if gate_name == "deviceset_prefix":
            continue

        gate_sym = get_gate_symbol_for_layout(
            schematic_library, name, gate_name, schematic_info['parts']
        )
        if gate_sym is None:
            continue

        # compute non-colliding position
        xg, yg = get_position_for_new_gate(schematic_info, gate_sym)
        print(f"Placing gate '{gate_name}' at ({xg}, {yg}) for part '{name}'")
        inst = ET.Element("instance", {
            "part": name, "gate": gate_name,
            "x": str(xg), "y": str(yg),
            "smashed": "yes"
        })
        inst.text = "\n"
        inst.tail = "\n"

        # build each text attribute at gate-relative offsets
        text_pos = get_text_from_symbol(schematic_library, library, deviceset, gate_name)
        for key, (dx, dy) in text_pos.items():
            clean = key.replace(">", "")
            attr = ET.Element("attribute", {
                "name":  clean,
                "x":     str(int(xg + dx)),
                "y":     str(int(yg + dy)),
                "size":  "1.778",
                "layer": "96",
                "font":  "vector",
                "align": "top-left"
            })
            attr.tail = "\n"
            inst.append(attr)

        instances_section.append(inst)

        # update schematic_info so next gate won't overlap
        schematic_info['parts'][name]['instances'].append({
            'gate': gate_name, 'x': xg, 'y': yg, 'rot': 'R0'
        })

    # normalize tails on instances/attrs
    for inst in instances_section.findall("instance"):
        inst.tail = "\n"
        if not (inst.text or "").strip():
            inst.text = "\n"
        for ch in inst:
            ch.tail = "\n"

    tree.write(schematic_file, encoding="utf-8", xml_declaration=True)

# %% [markdown]
# ## test2

# %%
import xml.etree.ElementTree as ET

def get_gate_symbol_for_layout(library_xml, part_name, gate_name, part_library):
    """
    Return the raw symbol dict for a single gate, suitable for layout.
    """
    part_info = part_library.get(part_name)
    if not part_info:
        print(f"[get_gate_symbol_for_layout] part '{part_name}' not in library")
        return None

    libname   = part_info.get('library')
    deviceset = part_info.get('deviceset')
    if not libname or not deviceset:
        print(f"[get_gate_symbol_for_layout] missing library/deviceset for '{part_name}'")
        return None

    full_symbol_map = get_symbol_element(library_xml, libname, deviceset)
    gate_sym = full_symbol_map.get(gate_name)
    if gate_sym is None:
        print(f"[get_gate_symbol_for_layout] gate '{gate_name}' not found in symbol map")
    return gate_sym


def get_position_for_new_gate(schematic_info, gate_symbol, spacing=20, max_width=500):
    """
    Place a single gate using a bottom-left strategy, avoiding collisions
    with every other instance already in schematic_info.
    """
    parts_info = schematic_info.get("parts", {})
    ic_library = schematic_info.get("IC_library", {})
    placed_boxes = []

    # 1) Gather bounding boxes for every existing instance
    for p_name, p_data in parts_info.items():
        for inst in p_data.get("instances", []):
            # pull the exact gate-symbol for this existing instance
            sym = get_gate_symbol_for_layout(
                ic_library,
                p_name,
                inst.get("gate"),
                parts_info
            )
            if not sym:
                continue

            ix, iy = float(inst["x"]), float(inst["y"])
            rot     = inst.get("rot", "R0")
            xlim, ylim = get_bounding_box_for_symbol_instance(sym, ix, iy, rot)
            placed_boxes.append((xlim, ylim))

    # 2) Find the leftmost x among placed boxes (or 0 if none)
    min_x = min((box[0][0] for box in placed_boxes), default=0)

    # 3) Measure the new gate at origin
    gate_xlim, gate_ylim = get_bounding_box_for_symbol_instance(gate_symbol, 0, 0, "R0")
    gate_w = gate_xlim[1] - gate_xlim[0]
    gate_h = gate_ylim[1] - gate_ylim[0]

    # 4) Scan for the first free slot
    for yy in range(0, 10000, spacing):
        for xx in range(int(min_x), int(min_x + max_width - gate_w) + 1, spacing):
            prop_xlim = [xx,       xx + gate_w]
            prop_ylim = [yy,       yy + gate_h]
            collision = False

            for ex_xlim, ex_ylim in placed_boxes:
                if not (
                    prop_xlim[1] + spacing <= ex_xlim[0] or
                    prop_xlim[0]        >= ex_xlim[1] + spacing or
                    prop_ylim[1] + spacing <= ex_ylim[0] or
                    prop_ylim[0]        >= ex_ylim[1] + spacing
                ):
                    collision = True
                    break

            if not collision:
                # adjust for the symbol’s native origin
                return [xx - gate_xlim[0], yy - gate_ylim[0]]

    # fallback
    return [0, 0]


def add_unit_to_schematic_full(schematic_file, library, deviceset, device, value, name, x_pos, y_pos):
    """
    Adds a new unit to the schematic, placing each gate using collision-aware layout.
    """
    schematic_info    = process_schematic_file(schematic_file)
    ic_lib            = schematic_info['IC_library']
    symbol_element    = get_symbol_element(ic_lib, library, deviceset)

    tree              = ET.parse(schematic_file)
    root              = tree.getroot()
    parts_sec         = root.find(".//parts")
    insts_sec         = root.find(".//instances")
    if parts_sec is None or insts_sec is None:
        raise ValueError("Missing <parts> or <instances> in schematic.")

    # 1) Insert <part> exactly as before
    if parts_sec.find(f"./part[@name='{name}']") is not None:
        print(f"Part '{name}' exists; skipping.")
        return

    parts_list = list(parts_sec)
    last_u = max(
        (i for i,p in enumerate(parts_list)
         if p.tag=='part'
         and p.get('name','').startswith('U')
         and p.get('name')[1:].isdigit()),
        default=-1
    )

    part_el = ET.Element("part", {
        "name":      name,
        "library":   library,
        "deviceset": deviceset,
        "device":    device,
        "value":     value
    })
    part_el.tail = "\n"
    idx = last_u + 1 if last_u != -1 else 0
    parts_sec.insert(idx, part_el)
    for p in parts_sec.findall("part"):
        p.tail = "\n"

    # 2) Register the new part in schematic_info
    schematic_info.setdefault('parts', {})[name] = {
        'library':   library,
        'deviceset': deviceset,
        'device':    device,
        'instances': []
    }

    # 3) For each gate, compute a non‐colliding spot and place it
    for gate_name in symbol_element:
        if gate_name == "deviceset_prefix":
            continue

        gate_sym = get_gate_symbol_for_layout(ic_lib, name, gate_name, schematic_info['parts'])
        if gate_sym is None:
            continue

        xg, yg = get_position_for_new_gate(schematic_info, gate_sym)
        print(f"Placing gate '{gate_name}' at ({xg}, {yg}) for part '{name}'")

        inst = ET.Element("instance", {
            "part":    name,
            "gate":    gate_name,
            "x":       str(xg),
            "y":       str(yg),
            "smashed": "yes"
        })
        inst.text = "\n"
        inst.tail = "\n"

        # 3a) add its attributes
        text_pos = get_text_from_symbol(ic_lib, library, deviceset, gate_name)
        for key, (dx, dy) in text_pos.items():
            clean = key.replace(">", "")
            attr = ET.Element("attribute", {
                "name":  clean,
                "x":     str(int(xg + dx)),
                "y":     str(int(yg + dy)),
                "size":  "1.778",
                "layer": "96",
                "font":  "vector",
                "align": "top-left"
            })
            attr.tail = "\n"
            inst.append(attr)

        insts_sec.append(inst)

        # 3b) record it so that future gates see it
        schematic_info['parts'][name]['instances'].append({
            'gate': gate_name,
            'x':     xg,
            'y':     yg,
            'rot':   'R0'
        })

    # 4) Normalize newlines and write out
    for inst in insts_sec.findall("instance"):
        inst.tail = "\n"
        if not (inst.text or "").strip():
            inst.text = "\n"
        for ch in inst:
            ch.tail = "\n"

    tree.write(schematic_file, encoding="utf-8", xml_declaration=True)

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\Module_library"
    # folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    IC_name = "ICM-20948"
    sch_file_name = f"{folder_path}\\{IC_name}\\{IC_name}.sch"
    sch_file_name = r"/Users/linkaiyuan/文件/PSU/template_sch/template.sch"
    library = "SparkFun-Sensors"
    deviceset = 'ICM-20948'
    device = ""
    value = "9DoF IMU"

    # library = "SparkFun-Aesthetics"
    # deviceset = 'FRAME-LEDGER'
    # device = ""
    # value = ""

    # library = "SparkFun-Capacitors"
    # deviceset = '0.1UF'
    # device = "-0402-16V-10%"
    # value = ""
    
    merge_schematic_libraries(source_sch_file, destination_sch_file, debug=False)
    for i in range(5):
        add_unit_to_schematic(sch_file_name,library, deviceset, device, value)
    # add_unit_to_schematic(sch_file_name,library, deviceset, device, value)


    visualize_schematic(sch_file_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[119], line 22
#      10 value = "9DoF IMU"
#      12 # library = "SparkFun-Aesthetics"
#      13 # deviceset = 'FRAME-LEDGER'
#      14 # device = ""
#    (...)     19 # device = "-0402-16V-10%"
#      20 # value = ""
# ---> 22 merge_schematic_libraries(source_sch_file, destination_sch_file, debug=False)
#      23 for i in range(5):
#      24     add_unit_to_schematic(sch_file_name,library, deviceset, device, value)
#
# NameError: name 'source_sch_file' is not defined

# %% [markdown]
# # Add module to schematic

# %%
import xml.etree.ElementTree as ET


def has_label_in_segment(net_element):
    """
    Checks if a <label> element exists inside a <segment> element under the given <net> element.

    Args:
        net_element (xml.etree.ElementTree.Element): The <net> element to check.

    Returns:
        bool: True if a <label> element exists, False otherwise.
    """
    for segment in net_element.findall("segment"):
        if segment.find("label") is not None:
            return True
    return False


def udpate_net_name(existing_nets, net_name):
    """
    Checks if the given net_name exists in existing_nets and contains a label in its segment.
    If not, generates a new net_name with the prefix N$[number].

    Args:
        existing_nets (dict): Dictionary of existing nets.
        net_name (str): The net name to check.

    Returns:
        str: The original net_name if it contains a label or matches specific names,
             otherwise a new net_name with the prefix N$[number].
    """
    # Check if the net_name is in the special list
    special_nets = {"3.3V", "GND", "1.8V"}
    net_element = existing_nets.get(net_name)
    if net_name in special_nets or has_label_in_segment(net_element):
        return net_name

    # Generate a new net_name with the prefix N$[number]
    existing_net_names = set(existing_nets.keys())
    index = 1
    while f"N${index}" in existing_net_names:
        index += 1
    return f"N${index}"



def merge_schematic_libraries(source_schematic, destination_schematic, debug=False):
    """
    Merges libraries from the source schematic into the destination schematic.
    Ensures line-by-line formatting without indentation.
    """
    if debug:
        print(f"------------Start Merge------------")

    # Parse source and destination schematics
    source_tree = ET.parse(source_schematic)
    source_root = source_tree.getroot()
    destination_tree = ET.parse(destination_schematic)
    destination_root = destination_tree.getroot()

    # Locate the libraries sections
    source_libraries = source_root.find(".//libraries")
    destination_libraries = destination_root.find(".//libraries")

    if source_libraries is None or destination_libraries is None:
        raise ValueError("Invalid schematic file structure. Missing libraries section.")

    if debug:
        print("Located libraries in both source and destination schematics.")

    destination_library_dict = {
        lib.get("name"): lib for lib in destination_libraries.findall("library")
    }

    if debug:
        print(f"Destination libraries found: {list(destination_library_dict.keys())}")

    for source_library in source_libraries.findall("library"):
        source_library_name = source_library.get("name")

        if debug:
            print(f"Processing source library: {source_library_name}")

        if source_library_name in destination_library_dict:
            destination_library = destination_library_dict[source_library_name]

            # Merge packages
            src_pkgs = source_library.find("packages")
            dst_pkgs = destination_library.find("packages")
            if src_pkgs is not None and dst_pkgs is not None:
                dst_pkg_names = {pkg.get("name") for pkg in dst_pkgs.findall("package")}
                for pkg in src_pkgs.findall("package"):
                    if pkg.get("name") not in dst_pkg_names:
                        if debug:
                            print(f"Adding missing package '{pkg.get('name')}'")
                        pkg.tail = "\n"
                        dst_pkgs.append(pkg)

            # Merge symbols
            src_syms = source_library.find("symbols")
            dst_syms = destination_library.find("symbols")
            if src_syms is not None and dst_syms is not None:
                dst_sym_names = {sym.get("name") for sym in dst_syms.findall("symbol")}
                for sym in src_syms.findall("symbol"):
                    if sym.get("name") not in dst_sym_names:
                        if debug:
                            print(f"Adding missing symbol '{sym.get('name')}'")
                        sym.tail = "\n"
                        dst_syms.append(sym)

            # Merge devicesets
            src_dsets = source_library.find("devicesets")
            dst_dsets = destination_library.find("devicesets")
            if src_dsets is not None and dst_dsets is not None:
                dst_dset_names = {ds.get("name") for ds in dst_dsets.findall("deviceset")}
                for dset in src_dsets.findall("deviceset"):
                    if dset.get("name") not in dst_dset_names:
                        if debug:
                            print(f"Adding missing deviceset '{dset.get('name')}'")
                        dset.tail = "\n"
                        dst_dsets.append(dset)
        else:
            if debug:
                print(f"Adding entire library '{source_library_name}' to destination.")
            source_library.text = "\n"
            source_library.tail = "\n"
            destination_libraries.append(source_library)

    # Ensure clean line-by-line formatting for all child elements
    for lib in destination_libraries.findall("library"):
        if lib.text is None or not lib.text.strip():
            lib.text = "\n"
        lib.tail = "\n"
        for section in ['packages', 'symbols', 'devicesets']:
            sub = lib.find(section)
            if sub is not None:
                if sub.text is None or not sub.text.strip():
                    sub.text = "\n"
                sub.tail = "\n"
                for child in sub:
                    child.tail = "\n"

    destination_libraries.tail = "\n"

    # Write final result
    destination_tree.write(destination_schematic, encoding="utf-8", xml_declaration=True)

    if debug:
        print(f"------------Merge completed------------")




def find_unique_part_name_for_module(source_part_names, destination_part_names, old_part_name, new_symbol_element):
    """
    Determines a unique part name to avoid conflicts when merging schematics.

    Args:
        source_part_names (list): Part names from source schematic.
        destination_part_names (list): Part names from destination schematic.
        old_part_name (str): The original part name in source schematic.
        new_symbol_element (dict): Contains deviceset info including prefix.

    Returns:
        str: A part name that avoids conflict.
    """
    if old_part_name not in destination_part_names:
        return old_part_name  # No conflict

    prefix = new_symbol_element.get('deviceset_prefix', 'IC')
    index = 1
    while True:
        new_part_name = f"{prefix}{index}"
        if new_part_name not in source_part_names and new_part_name not in destination_part_names:
            return new_part_name
        index += 1


def get_position_for_schematic_integration(source_sch_file,destination_sch_file, spacing=20, max_width=500, debug=False):
    import copy

    destination_info = process_schematic_file(destination_sch_file)
    source_info = process_schematic_file(source_sch_file)
    # print("Destination schematic info:", source_info['nets'])
    parts_info = destination_info.get("parts", {})
    ic_library = destination_info.get("IC_library", {})

    dest_boxes = []

    for part_name, part_data in parts_info.items():
        for instance in part_data.get("instances", []):
            gate = instance.get("gate", "")
            symbol = get_symbol_element_of_instance_from_library(ic_library, part_name, gate, parts_info)
            if not symbol:
                continue
            inst_x = float(instance["x"])
            inst_y = float(instance["y"])
            rot = instance.get("rot", "R0")
            xlim, ylim = get_bounding_box_for_symbol_instance(symbol, inst_x, inst_y, rot)
            dest_boxes.append((xlim, ylim))

    src_xlim, src_ylim = get_schematic_bounding_box_from_schematic_info(source_info)
    source_width = src_xlim[1] - src_xlim[0]
    source_height = src_ylim[1] - src_ylim[0]

    if debug:
        print("Original source schematic bounding box:", src_xlim, src_ylim)

    if not dest_boxes:
        dx = int(-src_xlim[0])
        dy = int(-src_ylim[0])
    else:
        min_x = min(xlim[0] for xlim, _ in dest_boxes)
        dx, dy = None, None
        for y in range(0, 10000):
            for x in range(int(min_x), int(min_x + max_width - source_width) + 1):
                proposed_xlim = [x, x + source_width]
                proposed_ylim = [y, y + source_height]
                collides = False
                for dest_xlim, dest_ylim in dest_boxes:
                    if not (proposed_xlim[1] + spacing <= dest_xlim[0] or
                            proposed_xlim[0] >= dest_xlim[1] + spacing or
                            proposed_ylim[1] + spacing <= dest_ylim[0] or
                            proposed_ylim[0] >= dest_ylim[1] + spacing):
                        collides = True
                        break
                if not collides:
                    dx = int(x - src_xlim[0])
                    dy = int(y - src_ylim[0])
                    break
            if dx is not None:
                break

        if dx is None:
            dx = int(-src_xlim[0])
            dy = int(-src_ylim[0])

    if debug:
        print("Offset applied to source schematic:", dx, dy)

    updated_parts = {}
    part_name_map = {}
    original_parts = source_info.get("parts", {})
    source_part_names = list(original_parts.keys())
    destination_part_names = list(destination_info.get("parts", {}).keys())

    for part_name, part_data in original_parts.items():
        copied_part_data = copy.deepcopy(part_data)
        new_symbol_element = get_symbol_element(destination_info['IC_library'], part_data['library'], part_data["deviceset"])
        new_part_name = find_unique_part_name_for_module(source_part_names, destination_part_names, part_name, new_symbol_element)
        part_name_map[part_name] = new_part_name
        if debug:
            print(f"Renaming part '{part_name}' to '{new_part_name}'")
        destination_part_names.append(new_part_name)

        for instance in copied_part_data.get("instances", []):
            old_x = instance["x"]
            old_y = instance["y"]
            instance["x"] = str(float(instance["x"]) + dx)
            instance["y"] = str(float(instance["y"]) + dy)
            instance["part"] = new_part_name
            if debug:
                print(f"Updated instance {part_name} from ({old_x}, {old_y}) to ({instance['x']}, {instance['y']})")

            attr_data = instance.get("attributes")
            if isinstance(attr_data, dict):
                attr_list = [attr_data]
            elif isinstance(attr_data, list):
                attr_list = attr_data
            else:
                attr_list = []

            alt_attr_data = instance.get("attribute")
            if isinstance(alt_attr_data, dict):
                attr_list.append(alt_attr_data)
            elif isinstance(alt_attr_data, list):
                attr_list.extend(alt_attr_data)

            for attr in attr_list:
                if "x" in attr:
                    old_x_val = attr["x"]
                    attr["x"] = str(float(attr["x"]) + dx)
                    if debug:
                        print(f"Updated attribute x from {old_x_val} to {attr['x']}")
                if "y" in attr:
                    old_y_val = attr["y"]
                    attr["y"] = str(float(attr["y"]) + dy)
                    if debug:
                        print(f"Updated attribute y from {old_y_val} to {attr['y']}")

        copied_part_data["name"] = new_part_name
        updated_parts[new_part_name] = copied_part_data

    source_info["parts"] = updated_parts

    for netname, net_items in source_info.get("nets", {}).items():
        if debug:
            print(f"Processing net '{netname}'")
        for item in net_items:
            for pinref in item.get("pinref", []):
                old_part = pinref.get("part")
                if old_part in part_name_map:
                    pinref["part"] = part_name_map[old_part]
                    if debug:
                        print(f"Updated pinref part from {old_part} to {pinref['part']}")
            for wire in item.get("wire", []):
                for key in ["x1", "y1", "x2", "y2"]:
                    if key in wire:
                        old_val = wire[key]
                        wire[key] = str(float(wire[key]) + (dx if 'x' in key else dy))
                        if debug:
                            print(f"Updated wire {key} from {old_val} to {wire[key]}")
            for label in item.get("label", []):
                for key in ["x", "y"]:
                    if key in label:
                        old_val = label[key]
                        label[key] = str(float(label[key]) + (dx if key == 'x' else dy))
                        if debug:
                            print(f"Updated label {key} from {old_val} to {label[key]}")
            for junction in item.get("junction", []):
                for key in ["x", "y"]:
                    if key in junction:
                        old_val = junction[key]
                        junction[key] = str(float(junction[key]) + (dx if key == 'x' else dy))
                        if debug:
                            print(f"Updated junction {key} from {old_val} to {junction[key]}")

    return source_info

def add_parts_and_instances_to_sch_file(update_sch_source_info, destination_sch_file):
    """
    Adds parts, instances, and nets from source_info to the destination .sch file (XML format).

    Args:
        destination_sch_file (str): Path to the destination schematic XML file.
        source_info (dict): Updated source_info with parts, instances, and nets.
    """
    import xml.etree.ElementTree as ET

    # Parse destination schematic XML
    tree = ET.parse(destination_sch_file)
    root = tree.getroot()

    parts_section = root.find(".//parts")
    instances_section = root.find(".//instances")
    sheets_section = root.find(".//sheets")
    sheet = sheets_section.find("sheet") if sheets_section is not None else None

    if parts_section is None or instances_section is None or sheet is None:
        raise ValueError("Invalid schematic file structure. Missing <parts>, <instances>, or <sheet> section.")

    nets_section = sheet.find("nets")
    if nets_section is None:
        nets_section = ET.SubElement(sheet, "nets")

    existing_nets = {net.get("name"): net for net in nets_section.findall("net")}

    # Add each part and its instances
    for part_name, part_data in update_sch_source_info.get("parts", {}).items():
        # print(f"Adding part '{part_name}'")
        # print(f"Part data: {part_data}")
        part_element = ET.Element("part", {
            "name": part_name,
            "library": part_data.get("library", ""),
            "deviceset": part_data.get("deviceset", ""),
            "device": part_data.get("device", "")
        })

        # Include additional attributes if present in part_data
        if "value" in part_data:
            part_element.set("value", part_data["value"])
        if "library_urn" in part_data:
            part_element.set("library_urn", part_data["library_urn"])
        if "package3d_urn" in part_data:
            part_element.set("package3d_urn", part_data["package3d_urn"])
        if part_data.get("deviceset") not in ['GND','3.3V','1.8V']:
            part_element.set("value", part_data.get("value", ""))

        part_element.tail = "\n"
        parts_section.append(part_element)

        for instance in part_data.get("instances", []):
            instance_element = ET.Element("instance", {
                "part": instance.get("part", part_name),
                "gate": instance.get("gate", "G$1"),
                "x": instance.get("x", "0"),
                "y": instance.get("y", "0"),
                "smashed": instance.get("smashed", "yes"),
            })
            if "rot" in instance:
                instance_element.set("rot", instance["rot"])
            instance_element.tail = "\n"
            instance_element.text = "\n"

            attr_data = instance.get("attributes")
            if isinstance(attr_data, dict):
                attributes = [attr_data]
            elif isinstance(attr_data, list):
                attributes = attr_data
            else:
                attributes = []

            alt_attr_data = instance.get("attribute")
            if isinstance(alt_attr_data, dict):
                attributes.append(alt_attr_data)
            elif isinstance(alt_attr_data, list):
                attributes.extend(alt_attr_data)

            for attr in attributes:
                attr_element = ET.Element("attribute", {
                    "name": attr.get("name", ""),
                    "x": attr.get("x", "0"),
                    "y": attr.get("y", "0"),
                    "size": attr.get("size", "1.778"),
                    "layer": attr.get("layer", "96")
                })
                if "font" in attr:
                    attr_element.set("font", attr["font"])
                if "align" in attr:
                    attr_element.set("align", attr["align"])
                if "rot" in attr:
                    attr_element.set("rot", attr["rot"])
                attr_element.tail = "\n"
                instance_element.append(attr_element)

            instances_section.append(instance_element)

    # Add nets
    for net_name, segments in update_sch_source_info.get("nets", {}).items():
        existing_nets = {net.get("name"): net for net in nets_section.findall("net")}
        # print(net_name,list(existing_nets.keys()))
        
        if net_name in existing_nets:
            new_net_name = udpate_net_name(existing_nets, net_name)
            # print(f"'{net_name}' to '{new_net_name}'")
            if new_net_name != net_name:
                net_element = ET.Element("net", {"name": new_net_name, "class": "0"})
                net_element.text = "\n"
                net_element.tail = "\n"
                nets_section.append(net_element)
            else:
                net_element = existing_nets[net_name]
        else:
            net_element = ET.Element("net", {"name": net_name, "class": "0"})
            net_element.text = "\n"
            net_element.tail = "\n"
            nets_section.append(net_element)

        for segment in segments:
            segment_element = ET.SubElement(net_element, "segment")
            segment_element.text = "\n"
            segment_element.tail = "\n"

            for pinref in segment.get("pinref", []):
                pinref_element = ET.SubElement(segment_element, "pinref", {
                    "part": pinref.get("part", ""),
                    "gate": pinref.get("gate", ""),
                    "pin": pinref.get("pin", "")
                })
                pinref_element.tail = "\n"

            for wire in segment.get("wire", []):
                wire_element = ET.SubElement(segment_element, "wire", wire)
                wire_element.tail = "\n"

            for label in segment.get("label", []):
                label_element = ET.SubElement(segment_element, "label", label)
                label_element.tail = "\n"

            for junction in segment.get("junction", []):
                junction_element = ET.SubElement(segment_element, "junction", junction)
                junction_element.tail = "\n"

    for inst in instances_section.findall("instance"):
        inst.tail = "\n"
        if inst.text is None or not inst.text.strip():
            inst.text = "\n"

    for part in parts_section.findall("part"):
        part.tail = "\n"

    tree.write(destination_sch_file, encoding="utf-8", xml_declaration=True)
    # print(f"Parts, instances, and nets added to '{destination_sch_file}'")


def add_module_to_sch(source_sch_file, destination_sch_file, spacing=20, max_width=500):
    """
    Merges a module from source schematic to destination schematic.

    Args:
        source_sch_file (str): Path to the source schematic XML file.
        destination_sch_file (str): Path to the destination schematic XML file.
        debug (bool): If True, prints debug information.
    """

    merge_schematic_libraries(source_sch_file, destination_sch_file, debug=False)
    update_sch_source_info = get_position_for_schematic_integration(source_sch_file,destination_sch_file, spacing, max_width,debug=False)
    add_parts_and_instances_to_sch_file(update_sch_source_info,destination_sch_file)

# %% [markdown]
# # Example1

# %%
if __name__ == "__main__":
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\Module_library"
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    IC_name = "TMP117MAIDRVT"
    sch_file_name_source = f"{folder_path}\\{IC_name}\\{IC_name}.sch"
    # sch_file_name_source = r"F:\GitHub\PCBEDA\sample PCB\custom\temp_add.sch"
    sch_file_name_dest = r"F:\GitHub\PCBEDA\sample PCB\custom\template.sch"
    # sch_file_name_merge = r"F:\GitHub\PCBEDA\sample PCB\custom\template2.sch"

    add_module_to_sch(sch_file_name_source, sch_file_name_dest)
    visualize_schematic(sch_file_name_dest)

# %% [markdown]
# # Example2

# %%
if __name__ == "__main__":
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    # List of source schematic files
    sch_file_name_sources = [
        f"{folder_path}\\ICM-20948\\ICM-20948.sch",
        f"{folder_path}\\ICS-41350\\ICS-41350.sch",
        f"{folder_path}\\BMI270\\BMI270.sch",
        f"{folder_path}\\BME680\\BME680.sch",
        f"{folder_path}\\BMA400\\BMA400.sch"
    ]

    sch_file_name_dest = r"F:\GitHub\PCBEDA\sample PCB\custom\template.sch"

    # Add all source schematic files to the destination schematic
    for sch_file_name_source in sch_file_name_sources:
        add_module_to_sch(sch_file_name_source, sch_file_name_dest, spacing=5, max_width=400)

    # Visualize the final schematic
    visualize_schematic(sch_file_name_dest)

# %% [markdown]
# # Clean sch file

# %%
def clean_schematic_file(sch_file_path):
    """
    Removes all libraries, parts, instances, and nets from the given schematic file.

    Args:
        sch_file_path (str): Path to the Eagle .sch file.
    """
    tree = ET.parse(sch_file_path)
    root = tree.getroot()

    drawing = root.find("drawing")
    if drawing is None:
        raise ValueError("Invalid schematic: missing <drawing>")

    schematic = drawing.find("schematic")
    if schematic is None:
        raise ValueError("Invalid schematic: missing <schematic>")

    # Remove all libraries
    libraries = schematic.find("libraries")
    if libraries is not None:
        for lib in list(libraries.findall("library")):
            libraries.remove(lib)

    # Remove all parts
    parts = schematic.find("parts")
    if parts is not None:
        for part in list(parts.findall("part")):
            parts.remove(part)

    # Remove all instances
    sheets = schematic.find("sheets")
    if sheets is not None:
        sheet = sheets.find("sheet")
        if sheet is not None:
            instances = sheet.find("instances")
            if instances is not None:
                for instance in list(instances.findall("instance")):
                    instances.remove(instance)

            # Remove all nets
            nets = sheet.find("nets")
            if nets is not None:
                for net in list(nets.findall("net")):
                    nets.remove(net)

    # Save cleaned schematic
    tree.write(sch_file_path, encoding="utf-8", xml_declaration=True)
    print(f"Cleaned schematic file: {sch_file_path}")

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    sch_file_name_dest = r"F:\GitHub\PCBEDA\sample PCB\custom\template.sch"
    clean_schematic_file(sch_file_name_dest)
    visualize_schematic(sch_file_name_dest)

# %% [markdown]
# # Preprocessing Schematic file Update label name

# %%
def has_label_in_segment(net_element):
    """
    Checks if a <label> element exists inside a <segment> element under the given <net> element.

    Args:
        net_element (xml.etree.ElementTree.Element): The <net> element to check.

    Returns:
        bool: True if a <label> element exists, False otherwise.
    """
    for segment in net_element.findall("segment"):
        if segment.find("label") is not None:
            return True
    return False



def update_net_names_in_schematic(sch_file_name, ic_name):
    """
    Updates net names in the schematic file by prefixing them with the IC name if they have labels
    and the IC name is not already present in the net name.

    Args:
        sch_file_name (str): Path to the schematic file.
        ic_name (str): Name of the IC to prefix the net names.
    """

    # Parse the schematic file
    tree = ET.parse(sch_file_name)
    root = tree.getroot()

    # Locate the nets section
    sheets_section = root.find(".//sheets")
    sheet = sheets_section.find("sheet") if sheets_section is not None else None
    nets_section = sheet.find("nets") if sheet is not None else None

    if nets_section is None:
        print("No nets section found in the schematic file.")
        return

    # Get existing nets
    existing_nets = {net.get("name"): net for net in nets_section.findall("net")}

    # Update net names
    for net_name, net_element in existing_nets.items():
        # Check if the net has a label in its segments using has_label_in_segment
        if has_label_in_segment(net_element):
            # Only update the net name if ic_name is not already in the net name
            if ic_name not in net_name:
                new_name = f"{ic_name}#{net_name}"
                net_element.set("name", new_name)
                print(f"Updated net name: {net_name} -> {new_name}")
            else:
                print(f"Net name '{net_name}'Skipping update.")

    # Save the updated schematic file
    tree.write(sch_file_name, encoding="utf-8", xml_declaration=True)
    print(f"Updated schematic file saved: {sch_file_name}")


def revert_net_names_in_schematic(sch_file_name, ic_name):
    """
    Reverts net names in the schematic file by removing the IC name prefix if present.

    Args:
        sch_file_name (str): Path to the schematic file.
        ic_name (str): Name of the IC to remove from the net names.
    """

    # Parse the schematic file
    tree = ET.parse(sch_file_name)
    root = tree.getroot()

    # Locate the nets section
    sheets_section = root.find(".//sheets")
    sheet = sheets_section.find("sheet") if sheets_section is not None else None
    nets_section = sheet.find("nets") if sheet is not None else None

    if nets_section is None:
        print("No nets section found in the schematic file.")
        return

    # Get existing nets
    existing_nets = {net.get("name"): net for net in nets_section.findall("net")}

    # Revert net names
    for net_name, net_element in existing_nets.items():
        # Check if the net name starts with the IC name followed by '#'
        prefix = f"{ic_name}#"
        if net_name.startswith(prefix):
            original_name = net_name[len(prefix):]
            net_element.set("name", original_name)
            print(f"Reverted net name: {net_name} -> {original_name}")
        else:
            print(f"Net name '{net_name}' Skipping revert.")

    # Save the updated schematic file
    tree.write(sch_file_name, encoding="utf-8", xml_declaration=True)
    print(f"Reverted schematic file saved: {sch_file_name}")

# %% [markdown]
# # Example1

# %%
if __name__ == "__main__":
    # Example usage
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library_net_with_ic_name"
    IC_name = "ICS-41350"
    sch_file_name_source = f"{folder_path}\\{IC_name}\\{IC_name}.sch"
    update_net_names_in_schematic(sch_file_name_source, IC_name)

# %%
import os

def update_net_names_in_all_subfolders(folder_path):
    """
    Iterates through all subfolders in the given folder path, extracts the subfolder name,
    and calls update_net_names_in_schematic for each subfolder.

    Args:
        folder_path (str): Path to the folder containing subfolders with schematic files.
    """
    for subfolder_name in os.listdir(folder_path):
        subfolder_path = os.path.join(folder_path, subfolder_name)
        if os.path.isdir(subfolder_path):  # Check if it's a directory
            sch_file_name_source = os.path.join(subfolder_path, f"{subfolder_name}.sch")
            if os.path.exists(sch_file_name_source):  # Check if the schematic file exists
                print(f"Updating net names for: {sch_file_name_source}")
                update_net_names_in_schematic(sch_file_name_source, subfolder_name)
            else:
                print(f"Schematic file not found in: {subfolder_path}")

# Call the function
if __name__ == "__main__":
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library_net_with_ic_name"
    update_net_names_in_all_subfolders(folder_path)

# %% [markdown]
# # Example2

# %%
if __name__ == "__main__":
    # Example usage
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library_net_with_ic_name"
    IC_name = "ICS-41350"
    sch_file_name_source = f"{folder_path}\\{IC_name}\\{IC_name}.sch"
    revert_net_names_in_schematic(sch_file_name_source, IC_name)

# %% [markdown]
# # Update attributes and net class

# %%
import xml.etree.ElementTree as ET

def remove_elements_under_attributes(sch_file_path, debug=False):
    """
    Removes all elements under the 'attributes' tag in the schematic file,
    leaving the 'attributes' tag empty.

    Args:
        sch_file_path (str): Path to the Eagle .sch file.
        debug (bool): If True, print debug messages.
    """
    tree = ET.parse(sch_file_path)
    root = tree.getroot()

    attributes_section = root.find(".//attributes")
    if attributes_section is not None:
        for child in list(attributes_section):
            attributes_section.remove(child)
        if debug:
            print("Removed all elements under the 'attributes' tag.")
    else:
        if debug:
            print("No 'attributes' element found in the schematic.")

    tree.write(sch_file_path, encoding="utf-8", xml_declaration=True)
    if debug:
        print(f"Attribute Updated schematic file saved: {sch_file_path}")

def update_net_classes(sch_file, class_number, net_name=None, debug=False):
    """
    Updates the class attribute for all nets or a specific net in the given schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        class_number (str): The class number to set for the net(s).
        net_name (str, optional): The name of the specific net to update. If None, updates all nets.
        debug (bool): If True, print debug messages.
    """
    tree = ET.parse(sch_file)
    root = tree.getroot()

    sheets_section = root.find(".//sheets")
    sheet = sheets_section.find("sheet") if sheets_section is not None else None

    if sheet is None:
        raise ValueError("Invalid schematic file structure. Missing <sheet> section.")

    nets_section = sheet.find("nets")
    if nets_section is None:
        raise ValueError("Invalid schematic file structure. Missing <nets> section.")

    if net_name:
        net = nets_section.find(f"net[@name='{net_name}']")
        old_class_number = net.get("class") if net is not None else None
        if net is not None:
            if old_class_number != str(class_number):
                net.set("class", str(class_number))
                if debug:
                    print(f"Net '{net_name}' class '{old_class_number}' updated to '{class_number}'.")
            else:
                if debug:
                    print(f"Net '{net_name}' already has class {class_number}")
        else:
            if debug:
                print(f"Net '{net_name}' not found in the schematic.")
    else:
        for net in nets_section.findall("net"):
            net.set("class", str(class_number))
        if debug:
            print(f"All net classes updated to '{class_number}'.")

    tree.write(sch_file, encoding="utf-8", xml_declaration=True)

def check_net_class_exists(sch_file, class_name, class_number):
    """
    Checks if a net class with the specified name and number exists in the schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        class_name (str): The name of the net class to check.
        class_number (int): The number of the net class to check.
        debug (bool): If True, print debug messages.

    Returns:
        bool: True if the net class with the specified name and number exists, False otherwise.
    """
    tree = ET.parse(sch_file)
    root = tree.getroot()

    classes_section = root.find(".//classes")
    if classes_section is None:
        return False

    for net_class in classes_section.findall("class"):
        if net_class.get("name") == class_name and net_class.get("number") == str(class_number):
            return True

    return False

def get_all_net_names(sch_file):
    """
    Extracts all net names from the given schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        debug (bool): If True, print debug messages.

    Returns:
        list: A list of net names found in the schematic.
    """
    tree = ET.parse(sch_file)
    root = tree.getroot()

    sheets_section = root.find(".//sheets")
    sheet = sheets_section.find("sheet") if sheets_section is not None else None

    if sheet is None:
        raise ValueError("Invalid schematic file structure. Missing <sheet> section.")

    nets_section = sheet.find("nets")
    if nets_section is None:
        raise ValueError("Invalid schematic file structure. Missing <nets> section.")

    net_names = [net.get("name") for net in nets_section.findall("net")]
    return net_names

import xml.etree.ElementTree as ET

def add_net_class_to_schematic(sch_file, class_number, class_name, width="0.1016", drill="0", debug=False):
    """
    Adds a new net class to the <classes> section of the schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        class_number (str): The class number for the new net class.
        class_name (str): The name of the new net class.
        width (str): The width attribute for the new net class.
        drill (str): The drill attribute for the new net class.
        debug (bool): If True, print debug messages.
    """
    tree = ET.parse(sch_file)
    root = tree.getroot()

    classes_section = root.find(".//classes")
    if classes_section is None:
        schematic = root.find(".//schematic")
        if schematic is None:
            raise ValueError("Invalid schematic file structure. Missing <schematic> section.")
        classes_section = ET.SubElement(schematic, "classes")
        classes_section.text = "\n"

    for existing_class in classes_section.findall("class"):
        if existing_class.get("number") == str(class_number):
            if debug:
                print(f"Class with number '{class_number}' already exists. Skipping addition.")
            return False
        if existing_class.get("name") == class_name:
            if debug:
                print(f"Class with name '{class_name}' already exists. Skipping addition.")
            return False

    new_class = ET.Element("class", {
        "number": str(class_number),
        "name": class_name,
        "width": str(width),
        "drill": str(drill)
    })
    new_class.text = "\n"   # Add line break inside <class>...</class>
    new_class.tail = "\n"   # Add line break after </class>

    classes_section.append(new_class)

    tree.write(sch_file, encoding="utf-8", xml_declaration=True, short_empty_elements=False)
    return True


def delete_net_class_from_schematic(sch_file, class_name, debug=False):
    """
    Deletes a net class with the specified class name from the <classes> section of the schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        class_name (str): The name of the net class to delete.
        debug (bool): If True, print debug messages.
    """
    tree = ET.parse(sch_file)
    root = tree.getroot()

    classes_section = root.find(".//classes")
    if classes_section is None:
        if debug:
            print("No <classes> section found in the schematic file.")
        return

    class_found = False
    for net_class in classes_section.findall("class"):
        if net_class.get("name") == class_name:
            classes_section.remove(net_class)
            class_found = True
            if debug:
                print(f"Deleted net class '{class_name}' from the schematic file.")
            break

    if not class_found and debug:
        print(f"Net class '{class_name}' not found in the schematic file.")

    tree.write(sch_file, encoding="utf-8", xml_declaration=True)
    if debug:
        print(f"Updated schematic file saved: {sch_file}")

def delete_all_net_classes_except_default(sch_file, default_class_name, debug=False):
    """
    Deletes all net classes from the <classes> section of the schematic file,
    except for the specified default class name.

    Args:
        sch_file (str): Path to the schematic XML file.
        default_class_name (str): The name of the net class to retain.
        debug (bool): If True, print debug messages.
    """
    tree = ET.parse(sch_file)
    root = tree.getroot()

    classes_section = root.find(".//classes")
    if classes_section is None:
        if debug:
            print("No <classes> section found in the schematic file.")
        return

    for net_class in list(classes_section.findall("class")):
        if net_class.get("name") != default_class_name:
            classes_section.remove(net_class)
            if debug:
                print(f"Deleted net class '{net_class.get('name')}' with '{net_class.get('number')}' from the schematic file.")

    tree.write(sch_file, encoding="utf-8", xml_declaration=True)

def update_net_classes_for_list(sch_file, class_number, class_name, net_names, debug=False):
    """
    Updates the class attribute for the specified list of nets in the given schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        class_number (str): The class number to set for the nets.
        class_name (str): The name of the net class.
        net_names (list): List of net names to update.
        debug (bool): If True, print debug messages.
    """
    if check_net_class_exists(sch_file, class_name, class_number):
        for net_name in net_names:
            update_net_classes(sch_file, class_number, net_name, debug)
    else:
        if debug:
            print(f"Net class {class_name} does not exist.")


def polish_net_class_and_name(sch_file, debug =False):
    """
    Polishes the net class and name in the schematic file.

    Args:
        sch_file (str): Path to the schematic XML file.
        class_name (str): The name of the net class to polish.
    """
    remove_elements_under_attributes(sch_file,debug)
    net_names = get_all_net_names(sch_file)
    class_name = 'default'
    class_number = 0
    add_net_class_to_schematic(sch_file, class_number, class_name, debug=debug)
    update_net_classes_for_list(sch_file, class_number, class_name, net_names, debug)
    delete_all_net_classes_except_default(sch_file, class_name,debug)

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    IC_name = "XC6222B331MR-G"
    sch_file_name_source = f"{folder_path}\\{IC_name}\\{IC_name}.sch"
    polish_net_class_and_name(sch_file_name_source,debug=True)

# %% [markdown]
# # Check if package3d exist in sch

# %%
import os

def check_package3d_in_sch(folder_name):
    """
    Iterates through subfolders in the given folder, retrieves .sch files based on subfolder names,
    and checks if 'package3d' exists in the .sch files.

    Args:
        folder_name (str): Path to the folder containing subfolders.

    Returns:
        list: A list of .sch file paths where 'package3d' exists.
    """
    sch_with_package3d = []
    for subfolder in os.listdir(folder_name):
        subfolder_path = os.path.join(folder_name, subfolder)
        if os.path.isdir(subfolder_path):  # Check if it's a subfolder
            sch_file_path = os.path.join(subfolder_path, f"{subfolder}.sch")
            if os.path.exists(sch_file_path):  # Check if the .sch file exists
                with open(sch_file_path, 'r', encoding='utf-8', errors='ignore') as sch_file:
                    content = sch_file.read()
                    if 'package3d' in content:
                        sch_with_package3d.append(sch_file_path)
    return sch_with_package3d

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    # Example usage
    folder_name = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    sch_with_package3d = check_package3d_in_sch(folder_name)
    print("Schematic files containing 'package3d':")
    for sch_file in sch_with_package3d:
        print(sch_file)

# %% [markdown]
# # Remove all 3d package from sch

# %%
import xml.etree.ElementTree as ET

def remove_packages3d_from_sch(sch_file):
    """
    Removes the 'packages3d' element, 'package3dinstances', and attributes containing 'package3d'
    from the specified .sch file.

    Args:
        sch_file (str): Path to the .sch file.

    Returns:
        None
    """
    try:
        # Parse the XML file
        tree = ET.parse(sch_file)
        root = tree.getroot()

        # Navigate to the 'packages3d' element
        libraries = root.find("./drawing/schematic/libraries")
        if libraries is not None:
            for library in libraries.findall("library"):
                # Remove 'packages3d' element
                packages3d = library.find("packages3d")
                if packages3d is not None:
                    library.remove(packages3d)
                    print(f"Removed 'packages3d' from library: {library.get('name')}")

                # Remove 'package3dinstances' element
                devicesets = library.find("devicesets")
                if devicesets is not None:
                    for deviceset in devicesets.findall("deviceset"):
                        devices = deviceset.find("devices")
                        if devices is not None:
                            for device in devices.findall("device"):
                                package3dinstances = device.find("package3dinstances")
                                if package3dinstances is not None:
                                    device.remove(package3dinstances)
                                    print(f"Removed 'package3dinstances' from device in library: {library.get('name')}")

        # Navigate to the 'parts' section and remove attributes containing 'package3d' or named 'override_package_urn'
        parts = root.find("./drawing/schematic/parts")
        if parts is not None:
            for part in parts.findall("part"):
                attributes_to_remove = [attr for attr in part.attrib if "package3d" in attr.lower() or attr == "override_package_urn"]
                for attr in attributes_to_remove:
                    del part.attrib[attr]
                    print(f"Removed attribute '{attr}' from part: {part.get('name')}")

        # Save the modified XML back to the file
        tree.write(sch_file, encoding="utf-8", xml_declaration=True)
        print(f"Updated .sch file saved: {sch_file}")

    except Exception as e:
        print(f"Error processing .sch file: {e}")

# %% [markdown]
# # Example

# %%
if __name__ == "__main__":
    # Example usage
    sch_file_name_dest = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library\USB4110-GF-A\USB4110-GF-A.sch"
    remove_packages3d_from_sch(sch_file_name_dest)

# %%
import glob
import zipfile
import os

root_dir = r"/Users/linkaiyuan/文件/PSU/products"
for zip_path in glob.glob(os.path.join(root_dir, "**", "*.zip"), recursive=True):
    print(zip_path)
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(os.path.dirname(zip_path))

# %%
root_dir = r"/Users/linkaiyuan/文件/PSU/products"
all_sch_files = []
count = 0
for sch_file_path in glob.glob(os.path.join(root_dir, "**", "*.sch"), recursive=True):
    # all_sch_files.append(process_schematic_file(sch_file_path))
    try:
        all_sch_files.append(process_schematic_file(sch_file_path))
    except Exception as e:
        print(f"Skipping {sch_file_path} due to error: {e}")
        count += 1
        continue

# %%
print(count)
all_parts = []
for i in all_sch_files:
    if isinstance(i['parts'], dict):
        all_parts.append(i['parts'])
    elif isinstance(i['parts'], list):
        all_parts.extend(i['parts'])

# %%
import json
from collections import Counter
import pandas as pd

# 1. Load JSON data
with open("text1.json", "r") as f:
    data = json.load(f)

counter = Counter()

# 2. Iterate through each schematic’s parts and build keys
for schematic in data:
    for part_ref, part_info in schematic.items():
        lib       = part_info.get("library", "").lower()
        deviceset = part_info.get("deviceset", "")
        package   = part_info.get("package", "")

        # 2a. If it’s a resistor, group under ("resistor",)
        if "resistor" in lib:
            key = ("resistor",)

        # 2b. If it’s a capacitor, group under ("capacitor",)
        elif "capacitor" in lib:
            key = ("capacitor",)

        # 2c. Otherwise, use (library, deviceset, package) as the key
        else:
            key = (lib, deviceset, package)

        counter[key] += 1

# 3. Convert counts into a DataFrame
rows = []
for key, count in counter.items():
    if len(key) == 1:
        # All resistors → show as “Group/Resistor/US”
        # All capacitors → show as “Group/Capacitor/EU”
        group_tag = key[0]  # either "resistor" or "capacitor"
        if group_tag == "resistor":
            rows.append({
                "Library/Group":      "Group",
                "DeviceSet/Category": "Resistor",
                "Package/Group":      "US",
                "Count":              count
            })
        else:
            rows.append({
                "Library/Group":      "Group",
                "DeviceSet/Category": "Capacitor",
                "Package/Group":      "EU",
                "Count":              count
            })
    else:
        lib, deviceset, package = key
        rows.append({
            "Library/Group":      lib,
            "DeviceSet/Category": deviceset,
            "Package/Group":      package,
            "Count":              count
        })

df = pd.DataFrame(rows).sort_values(by="Count", ascending=False)

# 4a. Print top 20 rows to console
print("\n—— Top 20 component groups by count ——\n")
print(df.head(20).to_string(index=False))

# 4b. Save the full table to CSV
output_csv = "component_counts.csv"
df.to_csv(output_csv, index=False)
print(f"\n✔ Full results written to {output_csv}")

# %% [markdown]
# ## Extract IC from Schematic

# %%
## /Users/linkaiyuan/文件/PSU/products/SparkFun_Environmental_Combo_Breakout_-_ENS160_BME
if __name__ == "__main__":
    # <pinref part="C2" gate="G$1" pin="1"/>
    # <wire x1="53.34" y1="220.98" x2="53.34" y2="210.82" width="0.1524" layer="91"/>
    # Output elements from a file according the path
    # Load and parse the XML file for the specified IC
    folder_path = r"/Users/linkaiyuan/文件/PSU/products/SparkFun_Environmental_Combo_Breakout_-_ENS160_BME/SparkFun_ENS160_BME280_Breakout.sch"
    # folder_path = r"F:\GitHub\PCBEDA\sample PCB\sparkfun\simplified_Module_library"
    # IC_name = "ICM-20948"
    # sch_file_name = f"{folder_path}/{IC_name}/{IC_name}.sch"
    sch_file_name = folder_path
    # print("schematic file name:", sch_file_name)
    # sch_file_name = r"F:\GitHub\PCBEDA\sample PCB\custom\template.sch"
    # sch_file_name = r"F:\GitHub\PCBEDA\sample PCB\custom\temp_add.sch"
    schematic_info = process_schematic_file(sch_file_name)

# %% [markdown]
# ### Save the generated json obj

# %%
schematic_info['parts']

import json

with open("text3.json", "w") as f:
    json.dump(schematic_info, f, indent=2)
# print keys of librarys

# %% [markdown]
# # single part generate (ori, not working for instances list, only instance json)

# %%
from xml.etree.ElementTree import ParseError
import os
import stat
if __name__ == "__main__":

    root_dir = "/Users/linkaiyuan/文件/PSU/products"
    temp_path = "/Users/linkaiyuan/文件/PSU/template_sch/template.sch"
    # os.makedirs(temp_path, exist_ok=True)
    os.chmod(temp_path, stat.S_IRWXU)
    os.chmod(root_dir, stat.S_IRWXU)
    import shutil
    import glob
    import os
    import json
    import stat

    unique_symbols = set()
    count = 0

    for sch_file_path in glob.glob(os.path.join(root_dir, "**", "*.sch"), recursive=True):
        # if count > 1:
        #     break
        name = os.path.basename(sch_file_path)
        stem = os.path.splitext(name)[0]
        os.chmod(sch_file_path, stat.S_IRWXU)
        try:
            schematic_info = process_schematic_file(sch_file_path)
            for part_name in schematic_info['parts'].items():
                # count += 1
                # if count > 1:
                #     break
                # print(part_name)
                symbol = part_name[1]['instances'][0]['symbol']
                lib = part_name[1]['library']
                if (symbol, lib) in unique_symbols:
                    continue
                unique_symbols.add((symbol, lib))

                new_name = f"{os.path.splitext(name)[0]}_{lib}_{symbol}.sch".replace("/", "slash")
                if ("MGM240P_EFM32GG12B410F1024GL120_EFM32GG12B410F1024GL120_A" in new_name):
                    print("name find:",sch_file_path)
                # dst_path = os.path.join("/Users/linkaiyuan/文件/PSU/test_single_sch", new_name)
                dst_path = os.path.join("/Users/linkaiyuan/文件/PSU/test_single_sch", new_name)
                # os.chmod(dst_path, stat.S_IRWXU))
                if os.path.exists(dst_path):
                    os.chmod(dst_path, stat.S_IRWXU)
                shutil.copy(temp_path, dst_path)
                os.chmod(dst_path, stat.S_IRWXU)
                # print(dst_path)

                    
                deviceset = part_name[1]['deviceset']
                device = part_name[1]['device']
                value = part_name[1]['value']
                print(sch_file_path, dst_path, lib, deviceset, device, value)
                merge_schematic_libraries(sch_file_path, dst_path, debug=False)
                add_unit_to_schematic(dst_path,lib, deviceset, device, value)
                print(f"Orgional schematic file: {sch_file_path}")
                print(f"New schematic file: {dst_path}")
                print(f"added unit: {lib}, {deviceset}, {device}, {value}")
    # # device = ""
    # # value = ""
        except AttributeError as e:
            print(f"Skipping {sch_file_path} due to error: {e}")
            continue
        except ParseError as e:
            print(f"Skipping {sch_file_path} due to XML parsing error: {e}")
            continue
        except TypeError as e:
            print(f"Skipping {sch_file_path} due to TypeError: {e}")
            continue
# Out:
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Switches_SWITCH-MOMENTARY.sch SparkFun-Switches MOMENTARY-SWITCH-SPST-2 -SMD-4.6X2.8MM RESET
# SparkFun-Switches
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.794) for part 'S1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Switches_SWITCH-MOMENTARY.sch
# added unit: SparkFun-Switches, MOMENTARY-SWITCH-SPST-2, -SMD-4.6X2.8MM, RESET
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_DGND.sch SparkFun-Aesthetics GND
# SparkFun-Aesthetics
# Suggested position for new symbol 'GND1': [0, 0]
# Placing gate '1' at (0, 0) for part 'GND1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_DGND.sch
# added unit: SparkFun-Aesthetics, GND, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_FRAME_LEDGER.sch SparkFun-Aesthetics FRAME-LEDGER
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'G$2' at (10.0, 330.0) for part 'FRAME1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_FRAME_LEDGER.sch
# added unit: SparkFun-Aesthetics, FRAME-LEDGER, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Capacitors_CAP.sch SparkFun-Capacitors 1.0UF -0603-16V-10%-X7R 1.0uF
# SparkFun-Capacitors
# Suggested position for new symbol 'C1': [0, 0]
# Placing gate 'G$1' at (10.0, 12.158999999999999) for part 'C1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Capacitors_CAP.sch
# added unit: SparkFun-Capacitors, 1.0UF, -0603-16V-10%-X7R, 1.0uF
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerIC_MCP73831.sch SparkFun-PowerIC MCP73831
# SparkFun-PowerIC
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 15.08) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerIC_MCP73831.sch
# added unit: SparkFun-PowerIC, MCP73831, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-DiscreteSemi_DIODE-SCHOTTKY.sch SparkFun-DiscreteSemi DIODE-SCHOTTKY -BAT20J 1A/23V/620mV
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'D1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.032) for part 'D1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-DiscreteSemi_DIODE-SCHOTTKY.sch
# added unit: SparkFun-DiscreteSemi, DIODE-SCHOTTKY, -BAT20J, 1A/23V/620mV
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Resistors_RESISTOR.sch SparkFun-Resistors 10KOHM -0603-1/10W-1% 10k
# SparkFun-Resistors
# Suggested position for new symbol 'R1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.524000000000001) for part 'R1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Resistors_RESISTOR.sch
# added unit: SparkFun-Resistors, 10KOHM, -0603-1/10W-1%, 10k
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_VIN.sch SparkFun-Aesthetics VIN
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_VIN.sch
# added unit: SparkFun-Aesthetics, VIN, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-LED_LED.sch SparkFun-LED LED-YELLOW 0603 Yellow
# SparkFun-LED
# Suggested position for new symbol 'D1': [0, 0]
# Placing gate 'G$1' at (13.429, 14.572) for part 'D1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-LED_LED.sch
# added unit: SparkFun-LED, LED-YELLOW, 0603, Yellow
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerIC_V-REG-LDO.sch SparkFun-PowerIC V_REG_LDO SMD AP2112K-3.3V
# SparkFun-PowerIC
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 17.62) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerIC_V-REG-LDO.sch
# added unit: SparkFun-PowerIC, V_REG_LDO, SMD, AP2112K-3.3V
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-DiscreteSemi_MOSFET-PCHANNEL.sch SparkFun-DiscreteSemi MOSFET-PCHANNEL DMG2307L 2.5A/30V
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'Q1': [0, 0]
# Placing gate 'G$1' at (15.08, 12.54) for part 'Q1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-DiscreteSemi_MOSFET-PCHANNEL.sch
# added unit: SparkFun-DiscreteSemi, MOSFET-PCHANNEL, DMG2307L, 2.5A/30V
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_V_USB.sch SparkFun-Aesthetics V_USB
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_V_USB.sch
# added unit: SparkFun-Aesthetics, V_USB, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_V_BATT.sch SparkFun-Aesthetics V_BATT
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_V_BATT.sch
# added unit: SparkFun-Aesthetics, V_BATT, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_3.3V.sch SparkFun-Aesthetics 3.3V
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_3.3V.sch
# added unit: SparkFun-Aesthetics, 3.3V, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_OSHW-LOGO.sch SparkFun-Aesthetics OSHW-LOGO MINI OSHW-LOGOMINI
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_OSHW-LOGO.sch
# added unit: SparkFun-Aesthetics, OSHW-LOGO, MINI, OSHW-LOGOMINI
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_FIDUCIAL.sch SparkFun-Aesthetics FIDUCIAL UFIDUCIAL FIDUCIALUFIDUCIAL
# SparkFun-Aesthetics
# Suggested position for new symbol 'FD1': [0, 0]
# Placing gate 'G$1' at (10.762, 10.762) for part 'FD1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_FIDUCIAL.sch
# added unit: SparkFun-Aesthetics, FIDUCIAL, UFIDUCIAL, FIDUCIALUFIDUCIAL
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_I2C_STANDARD.sch SparkFun-Connectors QWIIC_CONNECTOR JS-1MM
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (15.08, 15.334) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_I2C_STANDARD.sch
# added unit: SparkFun-Connectors, QWIIC_CONNECTOR, JS-1MM,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-IC-Microcontroller_ATSAMD51J20.sch SparkFun-IC-Microcontroller ATSAMD51J20A-A
# SparkFun-IC-Microcontroller
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (30.32, 65.88) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-IC-Microcontroller_ATSAMD51J20.sch
# added unit: SparkFun-IC-Microcontroller, ATSAMD51J20A-A, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerSymbols_VDDA.sch SparkFun-PowerSymbols VDDA
# SparkFun-PowerSymbols
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part '1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerSymbols_VDDA.sch
# added unit: SparkFun-PowerSymbols, VDDA, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerSymbols_VCC.sch SparkFun-PowerSymbols VCC
# SparkFun-PowerSymbols
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-PowerSymbols_VCC.sch
# added unit: SparkFun-PowerSymbols, VCC, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Clocks_CRYSTAL.sch SparkFun-Clocks CRYSTAL-32.768KHZ SMD-3.2X1.5 32.768kHz
# SparkFun-Clocks
# Suggested position for new symbol 'Y1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.032) for part 'Y1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Clocks_CRYSTAL.sch
# added unit: SparkFun-Clocks, CRYSTAL-32.768KHZ, SMD-3.2X1.5, 32.768kHz
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Coils_INDUCTOR.sch SparkFun-Coils INDUCTOR FB-30OHM FB - 30Ohm
# SparkFun-Coils
# Suggested position for new symbol 'L1': [0, 0]
# Placing gate 'G$1' at (10.0, 12.54) for part 'L1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Coils_INDUCTOR.sch
# added unit: SparkFun-Coils, INDUCTOR, FB-30OHM, FB - 30Ohm
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_USB-5PIN.sch SparkFun-Connectors USB_MICRO-B _HALF_PTH_MILL AMP FCI 10103594-0001LF
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'J1' at (12.54, 19.906) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_USB-5PIN.sch
# added unit: SparkFun-Connectors, USB_MICRO-B, _HALF_PTH_MILL, AMP FCI 10103594-0001LF
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_CONN_12.sch SparkFun-Connectors CONN_12 SM_SQ_NO_SILK
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (10.0, 30.066) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_CONN_12.sch
# added unit: SparkFun-Connectors, CONN_12, SM_SQ_NO_SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_CONN_16.sch SparkFun-Connectors CONN_16 1X16_SM_SQ_NOSILK
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (10.0, 35.146) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_CONN_16.sch
# added unit: SparkFun-Connectors, CONN_16, 1X16_SM_SQ_NOSILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_TEST-POINT.sch SparkFun-Connectors TEST-POINT TP_15TH_THRU
# SparkFun-Connectors
# Suggested position for new symbol 'TP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'TP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_TEST-POINT.sch
# added unit: SparkFun-Connectors, TEST-POINT, TP_15TH_THRU,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-IC-Memory_SPI_FLASH_DUALslashQUAD.sch SparkFun-IC-Memory AT25SF041  4Mb Flash
# SparkFun-IC-Memory
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 15.334) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-IC-Memory_SPI_FLASH_DUALslashQUAD.sch
# added unit: SparkFun-IC-Memory, AT25SF041, , 4Mb Flash
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_FOUR_LAYER_WARNING.sch SparkFun-Aesthetics FOUR_LAYER_WARNING
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_FOUR_LAYER_WARNING.sch
# added unit: SparkFun-Aesthetics, FOUR_LAYER_WARNING, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_SFE_LOGO_NAME_FLAME.sch SparkFun-Aesthetics SFE_LOGO_NAME_FLAME .1_INCH
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_SFE_LOGO_NAME_FLAME.sch
# added unit: SparkFun-Aesthetics, SFE_LOGO_NAME_FLAME, .1_INCH,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_SFE_LOGO_FLAME.sch SparkFun-Aesthetics SFE_LOGO_FLAME .1_INCH
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_SFE_LOGO_FLAME.sch
# added unit: SparkFun-Aesthetics, SFE_LOGO_FLAME, .1_INCH,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_JST_2MM_MALE.sch SparkFun-Connectors JST_2MM_MALE
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'J1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Connectors_JST_2MM_MALE.sch
# added unit: SparkFun-Connectors, JST_2MM_MALE, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Jumpers_SMT-JUMPER_3_2-NC_TRACE.sch SparkFun-Jumpers JUMPER-SMT_3_2-NC_TRACE _SILK
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.778) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Jumpers_SMT-JUMPER_3_2-NC_TRACE.sch
# added unit: SparkFun-Jumpers, JUMPER-SMT_3_2-NC_TRACE, _SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Hardware_STAND-OFF.sch SparkFun-Hardware STAND-OFF
# SparkFun-Hardware
# Suggested position for new symbol 'H1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'H1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Hardware_STAND-OFF.sch
# added unit: SparkFun-Hardware, STAND-OFF, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_LOGO.sch SparkFun-Aesthetics QWIIC_LOGO _5MM
# SparkFun-Aesthetics
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SAMD51_Thing_Plus_SparkFun-Aesthetics_LOGO.sch
# added unit: SparkFun-Aesthetics, QWIIC_LOGO, _5MM,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Aesthetics_FRAME-LETTER.sch SparkFun-Aesthetics FRAME-LETTER
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'V' at (310.0, 10.0) for part 'FRAME1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Aesthetics_FRAME-LETTER.sch
# added unit: SparkFun-Aesthetics, FRAME-LETTER, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-PowerSymbols_DGND.sch SparkFun-PowerSymbols GND
# SparkFun-PowerSymbols
# Suggested position for new symbol 'GND1': [0, 0]
# Placing gate '1' at (0, 0) for part 'GND1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-PowerSymbols_DGND.sch
# added unit: SparkFun-PowerSymbols, GND, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-PowerSymbols_3.3V.sch SparkFun-PowerSymbols 3.3V
# SparkFun-PowerSymbols
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-PowerSymbols_3.3V.sch
# added unit: SparkFun-PowerSymbols, 3.3V, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_AVR_SPI_PROGRAMMER_6.sch SparkFun-Connectors AVR_SPI_PROG_3X2 TESTPOINTS
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (15.207, 17.366) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_AVR_SPI_PROGRAMMER_6.sch
# added unit: SparkFun-Connectors, AVR_SPI_PROG_3X2, TESTPOINTS,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_CONN_04.sch SparkFun-Connectors CONN_04 1X04_NO_SILK
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'J1' at (15.08, 17.366) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_CONN_04.sch
# added unit: SparkFun-Connectors, CONN_04, 1X04_NO_SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-IC-Microcontroller_ATTINY84-ARDUINO.sch SparkFun-IC-Microcontroller ATTINY84-ARDUINO
# SparkFun-IC-Microcontroller
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'U1' at (25.240000000000002, 27.78) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-IC-Microcontroller_ATTINY84-ARDUINO.sch
# added unit: SparkFun-IC-Microcontroller, ATTINY84-ARDUINO, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Jumpers_SMT-JUMPER_2_NC_TRACE.sch SparkFun-Jumpers JUMPER-SMT_2_NC_TRACE _SILK
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Jumpers_SMT-JUMPER_2_NC_TRACE.sch
# added unit: SparkFun-Jumpers, JUMPER-SMT_2_NC_TRACE, _SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-DiscreteSemi_NPN.sch SparkFun-DiscreteSemi TRANS_NPN -MMBT2222AL 600mA/40V
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'Q1': [0, 0]
# Placing gate 'G$1' at (9.692, 12.54) for part 'Q1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-DiscreteSemi_NPN.sch
# added unit: SparkFun-DiscreteSemi, TRANS_NPN, -MMBT2222AL, 600mA/40V
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-DiscreteSemi_SOLIDSTATE_RELAY.sch SparkFun-DiscreteSemi SIP_SOLIDSTATERELAY  25A Solid State Relay
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'K1': [0, 0]
# Placing gate 'G$1' at (17.62, 20.16) for part 'K1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-DiscreteSemi_SOLIDSTATE_RELAY.sch
# added unit: SparkFun-DiscreteSemi, SIP_SOLIDSTATERELAY, , 25A Solid State Relay
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_CONN_02.sch SparkFun-Connectors CONN_02 SCREWTERMINAL-6.35MM-2
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 14.826) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_CONN_02.sch
# added unit: SparkFun-Connectors, CONN_02, SCREWTERMINAL-6.35MM-2,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_CONN_01.sch SparkFun-Connectors CONN_01 PTH_NO_SILK_YES_STOP
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 14.826) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic Dual Solid State Relay_SparkFun-Connectors_CONN_01.sch
# added unit: SparkFun-Connectors, CONN_01, PTH_NO_SILK_YES_STOP,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_LilyPad-Wearables_SEWTAP.sch LilyPad-Wearables SEWTAP 9
# LilyPad-Wearables
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (12.54, 10.762) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_LilyPad-Wearables_SEWTAP.sch
# added unit: LilyPad-Wearables, SEWTAP, 9,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_LilyPad-Wearables_LOGO-LP.sch LilyPad-Wearables LOGO-LP LP
# LilyPad-Wearables
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part '1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_LilyPad-Wearables_LOGO-LP.sch
# added unit: LilyPad-Wearables, LOGO-LP, LP,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_Testing_ATMEGA32U4.sch Testing ATMEGA32U4 1:1-LESS_PASTE ATMEGA32U41:1-LESS_PASTE
# Testing
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 50.64) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_Testing_ATMEGA32U4.sch
# added unit: Testing, ATMEGA32U4, 1:1-LESS_PASTE, ATMEGA32U41:1-LESS_PASTE
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Connectors_M02.sch SparkFun-Connectors M02 -JST-2MM-SMT JST-2
# SparkFun-Connectors
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Connectors_M02.sch
# added unit: SparkFun-Connectors, M02, -JST-2MM-SMT, JST-2
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Passives_CAP.sch SparkFun-Passives CAP 0603-CAP 470pF
# SparkFun-Passives
# Suggested position for new symbol 'C1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'C1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Passives_CAP.sch
# added unit: SparkFun-Passives, CAP, 0603-CAP, 470pF
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Passives_RESISTOR.sch SparkFun-Passives RESISTOR 0603-RES 330
# SparkFun-Passives
# Suggested position for new symbol 'R1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.016) for part 'R1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Passives_RESISTOR.sch
# added unit: SparkFun-Passives, RESISTOR, 0603-RES, 330
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Electromechanical_AYZ0202.sch SparkFun-Electromechanical SWITCH-DPDT AYZ0202
# SparkFun-Electromechanical
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate 'G$1' at (12.54, 20.16) for part 'S1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Electromechanical_AYZ0202.sch
# added unit: SparkFun-Electromechanical, SWITCH-DPDT, AYZ0202,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Electromechanical_SWITCH-MOMENTARY-2.sch SparkFun-Electromechanical SWITCH-MOMENTARY-2 SMD !RESET
# SparkFun-Electromechanical
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate 'G$1' at (12.54, 10.0) for part 'S1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Electromechanical_SWITCH-MOMENTARY-2.sch
# added unit: SparkFun-Electromechanical, SWITCH-MOMENTARY-2, SMD, !RESET
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Aesthetics_LETTER_L.sch SparkFun-Aesthetics FRAME-LETTER
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'G$2' at (310.0, 10.0) for part 'FRAME1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Aesthetics_LETTER_L.sch
# added unit: SparkFun-Aesthetics, FRAME-LETTER, ,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Aesthetics_5V.sch SparkFun-Aesthetics 5V  VBUS
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Aesthetics_5V.sch
# added unit: SparkFun-Aesthetics, 5V, , VBUS
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-FreqCtrl_RESONATOR.sch SparkFun-FreqCtrl RESONATOR 8MHZ 8MHz
# SparkFun-FreqCtrl
# Suggested position for new symbol 'Y1': [0, 0]
# Placing gate 'G$1' at (13.302, 17.62) for part 'Y1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-FreqCtrl_RESONATOR.sch
# added unit: SparkFun-FreqCtrl, RESONATOR, 8MHZ, 8MHz
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun_FIDUCIAL.sch SparkFun FIDUCIAL 1X2
# SparkFun
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (10.762, 10.762) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun_FIDUCIAL.sch
# added unit: SparkFun, FIDUCIAL, 1X2,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun_OSHW-LOGO.sch SparkFun OSHW-LOGO M
# SparkFun
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun_OSHW-LOGO.sch
# added unit: SparkFun, OSHW-LOGO, M,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Connectors_USB_AB.sch SparkFun-Connectors USB-AB CONN-11794
# SparkFun-Connectors
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (12.54, 16.35) for part 'U1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: rot
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Lilypad_Arduino_USB_v12_SparkFun-Connectors_USB_AB.sch
# added unit: SparkFun-Connectors, USB-AB, CONN-11794,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun_GND.sch SparkFun GND
# SparkFun
# Suggested position for new symbol 'GND1': [0, 0]
# Placing gate '1' at (0, 0) for part 'GND1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun_GND.sch
# added unit: SparkFun, GND, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Sensors_LIS331.sch SparkFun-Sensors H3LIS331DL  H3LIS331DL
# SparkFun-Sensors
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 22.954) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Sensors_LIS331.sch
# added unit: SparkFun-Sensors, H3LIS331DL, , H3LIS331DL
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Capacitors_CAP_POL.sch SparkFun-Capacitors 10UF-POLAR -EIA3216-16V-10%(TANT) 10uF
# SparkFun-Capacitors
# Suggested position for new symbol 'C1': [0, 0]
# Placing gate 'G$1' at (12.54, 14.190999999999999) for part 'C1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Capacitors_CAP_POL.sch
# added unit: SparkFun-Capacitors, 10UF-POLAR, -EIA3216-16V-10%(TANT), 10uF
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun_STAND-OFF.sch SparkFun STAND-OFF
# SparkFun
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun_STAND-OFF.sch
# added unit: SparkFun, STAND-OFF, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Jumpers_SMT-JUMPER_2_NO.sch SparkFun-Jumpers JUMPER-SMT_2_NO _NO-SILK
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Jumpers_SMT-JUMPER_2_NO.sch
# added unit: SparkFun-Jumpers, JUMPER-SMT_2_NO, _NO-SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Jumpers_SMT-JUMPER_3_2-NC_PASTE.sch SparkFun-Jumpers JUMPER-SMT_3_2-NC_PASTE _NO-SILK
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.397) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Jumpers_SMT-JUMPER_3_2-NC_PASTE.sch
# added unit: SparkFun-Jumpers, JUMPER-SMT_3_2-NC_PASTE, _NO-SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Jumpers_SMT-JUMPER_2_NC_PASTE.sch SparkFun-Jumpers JUMPER-SMT_2_NC_PASTE _NO-SILK
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL_SparkFun-Jumpers_SMT-JUMPER_2_NC_PASTE.sch
# added unit: SparkFun-Jumpers, JUMPER-SMT_2_NC_PASTE, _NO-SILK,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/sparkfun-battery-babysitter_battery-management-temp_BQ27441-G1.sch battery-management-temp BQ27441-G1
# battery-management-temp
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 20.16) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/sparkfun-battery-babysitter_battery-management-temp_BQ27441-G1.sch
# added unit: battery-management-temp, BQ27441-G1, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/sparkfun-battery-babysitter_battery-management-temp_BQ24075.sch battery-management-temp BQ24075
# battery-management-temp
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 25.240000000000002) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/sparkfun-battery-babysitter_battery-management-temp_BQ24075.sch
# added unit: battery-management-temp, BQ24075, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/sparkfun-battery-babysitter_SparkFun-Connectors_M01.sch SparkFun-Connectors M01 PTH_NO_SILK_YES_STOP
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/sparkfun-battery-babysitter_SparkFun-Connectors_M01.sch
# added unit: SparkFun-Connectors, M01, PTH_NO_SILK_YES_STOP,
# ...
# robertsonics
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (20.16, 17.62) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/wavtrigger_v11_robertsonics_LM4990.sch
# added unit: robertsonics, LM4990, ,
# /Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch /Users/linkaiyuan/文件/PSU/test_single_sch/wavtrigger_v11_robertsonics_USDCARD.sch robertsonics USD-SOCKET NEW
# robertsonics
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (12.54, 30.32) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/wavtrigger_v11_robertsonics_USDCARD.sch
# added unit: robertsonics, USD-SOCKET, NEW,
# /Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch /Users/linkaiyuan/文件/PSU/test_single_sch/wavtrigger_v11_SparkFun-Connectors_M2X8.sch SparkFun-Connectors M08X2
# SparkFun-Connectors
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (13.81, 20.16) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/wavtrigger_v11_SparkFun-Connectors_M2X8.sch
# added unit: SparkFun-Connectors, M08X2, ,
# Deviceset 'OSHW-LOGO' not found in library 'SparkFun-Aesthetics'.
# Skipping /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Thermocouple_Amplifier_-_MCP9600_(P/SparkFun_Qwiic_Thermocouple_Amplifier_PCC.sch due to error: 'NoneType' object has no attribute 'get'
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-RF_ARTIC_R2.sch SparkFun-RF ARTIC_R2
# SparkFun-RF
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (35.4, 37.94) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-RF_ARTIC_R2.sch
# added unit: SparkFun-RF, ARTIC_R2, ,
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_New_Parts_Boards_THING_PLUS.sch New_Parts_Boards THING_PLUS
# New_Parts_Boards
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (20.16, 43.02) for part 'J1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_New_Parts_Boards_THING_PLUS.sch
# added unit: New_Parts_Boards, THING_PLUS, ,
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-RF_RFPA0133.sch SparkFun-RF RFPA0133
# SparkFun-RF
# Suggested position for new symbol 'IC1': [0, 0]
# Placing gate 'G$1' at (22.7, 22.7) for part 'IC1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-RF_RFPA0133.sch
# added unit: SparkFun-RF, RFPA0133, ,
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-RF_AS179-92LF.sch SparkFun-RF AS179-92LF
# SparkFun-RF
# Suggested position for new symbol 'IC1': [0, 0]
# Placing gate 'G$1' at (17.62, 15.08) for part 'IC1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-RF_AS179-92LF.sch
# added unit: SparkFun-RF, AS179-92LF, ,
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-Clocks_CRYSTAL-TCXO.sch SparkFun-Clocks CRYSTAL-TCXO-26MHZ
# SparkFun-Clocks
# Suggested position for new symbol 'Y1': [0, 0]
# Placing gate 'G$1' at (17.62, 15.334) for part 'Y1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-Clocks_CRYSTAL-TCXO.sch
# added unit: SparkFun-Clocks, CRYSTAL-TCXO-26MHZ, ,
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-IC-Memory_SPI_FLASH-1.sch SparkFun-IC-Memory SST25VF020B SO08_INDUSTRIAL_TEMP 2Mbit SPI Flash
# SparkFun-IC-Memory
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 17.874) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-IC-Memory_SPI_FLASH-1.sch
# added unit: SparkFun-IC-Memory, SST25VF020B, SO08_INDUSTRIAL_TEMP, 2Mbit SPI Flash
# /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-DiscreteSemi_TLP3475R.sch SparkFun-DiscreteSemi TLP3475R
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'K1': [0, 0]
# Placing gate 'G$1' at (22.7, 15.08) for part 'K1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/ARGOS_Satellite_Transceiver_Shield_-_ARTIC_R2/ARTIC_R2.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ARTIC_R2_SparkFun-DiscreteSemi_TLP3475R.sch
# added unit: SparkFun-DiscreteSemi, TLP3475R, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Serial_Basic_Breakout_-_CH340G/SparkFun-Serial-Basic-CH340-v10.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun-Serial-Basic-CH340-v10_SparkFun-DigitalIC_CH340G.sch SparkFun-DigitalIC CH340G SMD CH340G
# SparkFun-DigitalIC
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'U1' at (17.62, 22.7) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Serial_Basic_Breakout_-_CH340G/SparkFun-Serial-Basic-CH340-v10.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun-Serial-Basic-CH340-v10_SparkFun-DigitalIC_CH340G.sch
# added unit: SparkFun-DigitalIC, CH340G, SMD, CH340G
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Serial_Basic_Breakout_-_CH340G/SparkFun-Serial-Basic-CH340-v10.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun-Serial-Basic-CH340-v10_USB Basic_CRYSTAL-GND.sch USB Basic CRYSTAL-GROUNDED 3.2X2.5 12MHz
# USB Basic
# Suggested position for new symbol 'Y1': [0, 0]
# Placing gate 'Y1' at (12.54, 12.8) for part 'Y1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Serial_Basic_Breakout_-_CH340G/SparkFun-Serial-Basic-CH340-v10.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun-Serial-Basic-CH340-v10_USB Basic_CRYSTAL-GND.sch
# added unit: USB Basic, CRYSTAL-GROUNDED, 3.2X2.5, 12MHz
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Serial_Basic_Breakout_-_CH340G/SparkFun-Serial-Basic-CH340-v10.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun-Serial-Basic-CH340-v10_Serial-Basic_GATE_AND_2.sch Serial-Basic 74*08  74LVC1G08SE
# Serial-Basic
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G1' at (17.62, 17.62) for part 'U1'
# Placing gate 'G2' at (73.30199999999999, 15.08) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Serial_Basic_Breakout_-_CH340G/SparkFun-Serial-Basic-CH340-v10.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun-Serial-Basic-CH340-v10_Serial-Basic_GATE_AND_2.sch
# added unit: Serial-Basic, 74*08, , 74LVC1G08SE
# Skipping /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Speaker_Kit/RedBoard-Artemis-Nano.sch due to error: 'list' object has no attribute 'get'
# /Users/linkaiyuan/文件/PSU/products/SparkFun_SSOP_to_DIP_Adapter_-_16-Pin/SparkFun_SSOP16_Breakout_v21.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_SSOP16_Breakout_v21_generic-ssop16_SSOP16.sch generic-ssop16 SSOP16
# generic-ssop16
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 22.7) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_SSOP_to_DIP_Adapter_-_16-Pin/SparkFun_SSOP16_Breakout_v21.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_SSOP16_Breakout_v21_generic-ssop16_SSOP16.sch
# added unit: generic-ssop16, SSOP16, ,
# /Users/linkaiyuan/文件/PSU/products/Teensy_Arduino_Shield_Adapter/SparkFun_Teensy_Adapter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Teensy_Adapter_Testing_ARDUINO_R3_SHIELD.sch Testing ARDUINO_R3_SHIELD UNO_R3_SHIELD_HOLES
# Testing
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (20.16, 35.4) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/Teensy_Arduino_Shield_Adapter/SparkFun_Teensy_Adapter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Teensy_Adapter_Testing_ARDUINO_R3_SHIELD.sch
# added unit: Testing, ARDUINO_R3_SHIELD, UNO_R3_SHIELD_HOLES,
# /Users/linkaiyuan/文件/PSU/products/Teensy_Arduino_Shield_Adapter/SparkFun_Teensy_Adapter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Teensy_Adapter_Testing_TEENSY-31.sch Testing TEENSY-3.1 SILK
# Testing
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 43.02) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/Teensy_Arduino_Shield_Adapter/SparkFun_Teensy_Adapter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Teensy_Adapter_Testing_TEENSY-31.sch
# added unit: Testing, TEENSY-3.1, SILK,
# /Users/linkaiyuan/文件/PSU/products/Teensy_Arduino_Shield_Adapter/SparkFun_Teensy_Adapter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Teensy_Adapter_SparkFun-PowerIC_78XX.sch SparkFun-PowerIC V_REG_78XX -TO-220 5V
# SparkFun-PowerIC
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (15.08, 15.08) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/Teensy_Arduino_Shield_Adapter/SparkFun_Teensy_Adapter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_Teensy_Adapter_SparkFun-PowerIC_78XX.sch
# added unit: SparkFun-PowerIC, V_REG_78XX, -TO-220, 5V
# /Users/linkaiyuan/文件/PSU/products/SparkFun_USB_to_Serial_Breakout_-_FT232RL/FT232R-Breakout_v37.sch /Users/linkaiyuan/文件/PSU/test_single_sch/FT232R-Breakout_v37_SparkFun_M09.sch SparkFun M09
# SparkFun
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (10.0, 22.7) for part 'JP1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_USB_to_Serial_Breakout_-_FT232RL/FT232R-Breakout_v37.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/FT232R-Breakout_v37_SparkFun_M09.sch
# added unit: SparkFun, M09, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_USB_to_Serial_Breakout_-_FT232RL/FT232R-Breakout_v37.sch /Users/linkaiyuan/文件/PSU/test_single_sch/FT232R-Breakout_v37_SparkFun_PTC.sch SparkFun PTC SMD 500mA
# SparkFun
# Suggested position for new symbol 'F1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'F1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_USB_to_Serial_Breakout_-_FT232RL/FT232R-Breakout_v37.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/FT232R-Breakout_v37_SparkFun_PTC.sch
# added unit: SparkFun, PTC, SMD, 500mA
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_ADXL/ADXL335_Breakout.sch /Users/linkaiyuan/文件/PSU/test_single_sch/ADXL335_Breakout_Testing_ADXL335.sch Testing ADXL335-PATRICK ""
# Testing
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 20.16) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_ADXL/ADXL335_Breakout.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/ADXL335_Breakout_Testing_ADXL335.sch
# added unit: Testing, ADXL335-PATRICK, "",
# Skipping /Users/linkaiyuan/文件/PSU/products/SparkFun_Learn_to_Solder_-_Simon_Says/Simon-PTH-v17.sch due to XML parsing error: not well-formed (invalid token): line 1, column 0
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Pressure_Sensor_-_BMP384_(Qwiic)/BMP384 Breakout.sch /Users/linkaiyuan/文件/PSU/test_single_sch/BMP384 Breakout_bmp384_BMP384.sch bmp384 BMP384
# bmp384
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (22.7, 22.7) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Pressure_Sensor_-_BMP384_(Qwiic)/BMP384 Breakout.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/BMP384 Breakout_bmp384_BMP384.sch
# added unit: bmp384, BMP384, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_LIS3/SparkFun_LIS3DH-Breakout.sch /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_LIS3DH-Breakout_SparkFun-Sensors_LIS3DH.sch SparkFun-Sensors LIS3DH
# SparkFun-Sensors
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 25.494) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_LIS3/SparkFun_LIS3DH-Breakout.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/SparkFun_LIS3DH-Breakout_SparkFun-Sensors_LIS3DH.sch
# added unit: SparkFun-Sensors, LIS3DH, ,
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Environmental_Sensor_-_BME688_(Qwiic)/Qwiic_BME688.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic_BME688_BME688_BME688.sch BME688 BME688 LGA
# BME688
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'U1' at (20.16, 20.16) for part 'U1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkFun_Environmental_Sensor_-_BME688_(Qwiic)/Qwiic_BME688.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic_BME688_BME688_BME688.sch
# added unit: BME688, BME688, LGA,
# /Users/linkaiyuan/文件/PSU/products/GNSS_Antenna_Splitter_(Power_Divider)_with_DC_Pass/GNSS_Splitter.sch /Users/linkaiyuan/文件/PSU/test_single_sch/GNSS_Splitter_SparkFun-RF_BP2G1+.sch SparkFun-RF BP2G1+_POWER_SPLITTER
# SparkFun-RF
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'U1' at (17.62, 15.08) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/GNSS_Antenna_Splitter_(Power_Divider)_with_DC_Pass/GNSS_Splitter.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/GNSS_Splitter_SparkFun-RF_BP2G1+.sch
# added unit: SparkFun-RF, BP2G1+_POWER_SPLITTER, ,
# /Users/linkaiyuan/文件/PSU/products/SparkX_Power_Meter_-_ACS37800_(Qwiic)/Qwiic_Power_Meter-ACS37800.sch /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic_Power_Meter-ACS37800_New-Parts_SparkFun-IC-Power_ACS37800.sch New-Parts_SparkFun-IC-Power ACS37800
# New-Parts_SparkFun-IC-Power
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (20.16, 22.7) for part '1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/SparkX_Power_Meter_-_ACS37800_(Qwiic)/Qwiic_Power_Meter-ACS37800.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/Qwiic_Power_Meter-ACS37800_New-Parts_SparkFun-IC-Power_ACS37800.sch
# added unit: New-Parts_SparkFun-IC-Power, ACS37800, ,
# /Users/linkaiyuan/文件/PSU/products/LilyPad_Simple_Power/LilyPad_Simple_Power_v21.sch /Users/linkaiyuan/文件/PSU/test_single_sch/LilyPad_Simple_Power_v21_Local Library_SEW-HOLE-NO-PIN.sch Local Library SEW-HOLE-NO-PAD
# Local Library
# Suggested position for new symbol 'STANDOFF1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'STANDOFF1'
# Orgional schematic file: /Users/linkaiyuan/文件/PSU/products/LilyPad_Simple_Power/LilyPad_Simple_Power_v21.sch
# New schematic file: /Users/linkaiyuan/文件/PSU/test_single_sch/LilyPad_Simple_Power_v21_Local Library_SEW-HOLE-NO-PIN.sch
# added unit: Local Library, SEW-HOLE-NO-PAD, ,

# %% [markdown]
# # single part generate (Latest for multi instances)

# %%
import os, glob, shutil, stat
from xml.etree.ElementTree import ParseError

if __name__ == "__main__":
    root_dir   = "/Users/linkaiyuan/文件/PSU/products"
    temp_path  = "/Users/linkaiyuan/文件/PSU/template_sch/template.sch"
    out_dir    = "/Users/linkaiyuan/文件/PSU/multi_instances2"
    os.makedirs(out_dir, exist_ok=True)
    part = {}
    unique_keys = set()
    for sch_path in glob.glob(os.path.join(root_dir, "**", "*.sch"), recursive=True):
        try:
            schematic_info = process_schematic_file(sch_path)
        except (AttributeError, ParseError, TypeError):
            continue

        stem = os.path.splitext(os.path.basename(sch_path))[0]
        part_dict = schematic_info['parts']
        part = {}
        # iterate over every part...
        for part_name, part_info in part_dict.items():
            if part_name in part:
                
                continue
            part[part_name] = part_info
            print("Here is part_name:", part_name)
            lib       = part_info['library']
            deviceset = part_info['deviceset']
            device    = part_info['device']
            value     = part_info['value']

            # now iterate _all_ instances
            for idx, inst in enumerate(part_info.get('instances', [])):
                symbol = inst['symbol']

                # if you still want to dedupe by (lib,symbol) you can:
                key = (lib, symbol, idx)
                if key in unique_keys:
                    continue
                unique_keys.add(key)

                # build a unique filename per instance
                new_name = f"{stem}#{lib}#{symbol}.sch".replace("/", "slash")
                dst = os.path.join(out_dir, new_name)

                # copy your template & merge/add as before
                os.chmod(temp_path, stat.S_IRWXU)
                shutil.copy(temp_path, dst)
                os.chmod(dst,       stat.S_IRWXU)

                # merge & add one unit
                merge_schematic_libraries(sch_path, dst, debug=False)
                add_unit_to_schematic(dst, lib, deviceset, device, value)

                print(f"""
    Source:    {sch_path}
    Instance:  [{idx}] symbol={symbol}, lib={lib}, deviceset={deviceset}, device={device}, value={value}
    Written to: {dst}
    """)
# Out:
# Here is part_name: S1
# SparkFun-Switches
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.794) for part 'S1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=SWITCH-MOMENTARY, lib=SparkFun-Switches, deviceset=MOMENTARY-SWITCH-SPST-2, device=-SMD-4.6X2.8MM, value=RESET
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Switches#SWITCH-MOMENTARY.sch
#
# Here is part_name: GND1
# SparkFun-Aesthetics
# Suggested position for new symbol 'GND1': [0, 0]
# Placing gate '1' at (0, 0) for part 'GND1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=DGND, lib=SparkFun-Aesthetics, deviceset=GND, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#DGND.sch
#
# Here is part_name: FRAME1
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'G$2' at (10.0, 330.0) for part 'FRAME1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=FRAME_LEDGER, lib=SparkFun-Aesthetics, deviceset=FRAME-LEDGER, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#FRAME_LEDGER.sch
#
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'G$2' at (10.0, 330.0) for part 'FRAME1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [1] symbol=DOCFIELD, lib=SparkFun-Aesthetics, deviceset=FRAME-LEDGER, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#DOCFIELD.sch
#
# Here is part_name: GND26
# Here is part_name: GND15
# Here is part_name: C7
# SparkFun-Capacitors
# Suggested position for new symbol 'C1': [0, 0]
# Placing gate 'G$1' at (10.0, 12.158999999999999) for part 'C1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=CAP, lib=SparkFun-Capacitors, deviceset=1.0UF, device=-0603-16V-10%-X7R, value=1.0uF
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Capacitors#CAP.sch
#
# Here is part_name: C10
# Here is part_name: GND21
# Here is part_name: GND14
# Here is part_name: U1
# SparkFun-PowerIC
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 15.08) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=MCP73831, lib=SparkFun-PowerIC, deviceset=MCP73831, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-PowerIC#MCP73831.sch
#
# Here is part_name: GND9
# Here is part_name: GND11
# Here is part_name: GND12
# Here is part_name: C6
# Here is part_name: D2
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'D1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.032) for part 'D1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=DIODE-SCHOTTKY, lib=SparkFun-DiscreteSemi, deviceset=DIODE-SCHOTTKY, device=-BAT20J, value=1A/23V/620mV
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-DiscreteSemi#DIODE-SCHOTTKY.sch
#
# Here is part_name: R7
# SparkFun-Resistors
# Suggested position for new symbol 'R1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.524000000000001) for part 'R1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=RESISTOR, lib=SparkFun-Resistors, deviceset=10KOHM, device=-0603-1/10W-1%, value=10k
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Resistors#RESISTOR.sch
#
# Here is part_name: GND13
# Here is part_name: SUPPLY7
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=VIN, lib=SparkFun-Aesthetics, deviceset=VIN, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#VIN.sch
#
# Here is part_name: GND4
# Here is part_name: D1
# SparkFun-LED
# Suggested position for new symbol 'D1': [0, 0]
# Placing gate 'G$1' at (13.429, 14.572) for part 'D1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=LED, lib=SparkFun-LED, deviceset=LED-YELLOW, device=0603, value=Yellow
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-LED#LED.sch
#
# Here is part_name: R3
# Here is part_name: U3
# SparkFun-PowerIC
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 17.62) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=V-REG-LDO, lib=SparkFun-PowerIC, deviceset=V_REG_LDO, device=SMD, value=AP2112K-3.3V
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-PowerIC#V-REG-LDO.sch
#
# Here is part_name: Q1
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'Q1': [0, 0]
# Placing gate 'G$1' at (15.08, 12.54) for part 'Q1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=MOSFET-PCHANNEL, lib=SparkFun-DiscreteSemi, deviceset=MOSFET-PCHANNEL, device=DMG2307L, value=2.5A/30V
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-DiscreteSemi#MOSFET-PCHANNEL.sch
#
# Here is part_name: R6
# Here is part_name: SUPPLY14
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=V_USB, lib=SparkFun-Aesthetics, deviceset=V_USB, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#V_USB.sch
#
# Here is part_name: SUPPLY22
# Here is part_name: SUPPLY25
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=V_BATT, lib=SparkFun-Aesthetics, deviceset=V_BATT, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#V_BATT.sch
#
# Here is part_name: SUPPLY27
# Here is part_name: C19
# Here is part_name: SUPPLY23
# Here is part_name: GND41
# Here is part_name: SUPPLY8
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=3.3V, lib=SparkFun-Aesthetics, deviceset=3.3V, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#3.3V.sch
#
# Here is part_name: D4
# Here is part_name: R8
# Here is part_name: GND37
# Here is part_name: LOGO2
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=OSHW-LOGO, lib=SparkFun-Aesthetics, deviceset=OSHW-LOGO, device=MINI, value=OSHW-LOGOMINI
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#OSHW-LOGO.sch
#
# Here is part_name: FD1
# SparkFun-Aesthetics
# Suggested position for new symbol 'FD1': [0, 0]
# Placing gate 'G$1' at (10.762, 10.762) for part 'FD1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=FIDUCIAL, lib=SparkFun-Aesthetics, deviceset=FIDUCIAL, device=UFIDUCIAL, value=FIDUCIALUFIDUCIAL
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#FIDUCIAL.sch
#
# Here is part_name: FD2
# Here is part_name: J3
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (15.08, 15.334) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=I2C_STANDARD, lib=SparkFun-Connectors, deviceset=QWIIC_CONNECTOR, device=JS-1MM, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Connectors#I2C_STANDARD.sch
#
# Here is part_name: SUPPLY1
# Here is part_name: GND6
# Here is part_name: FD3
# Here is part_name: FD4
# Here is part_name: U2
# SparkFun-IC-Microcontroller
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (30.32, 65.88) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=ATSAMD51J20, lib=SparkFun-IC-Microcontroller, deviceset=ATSAMD51J20A-A, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-IC-Microcontroller#ATSAMD51J20.sch
#
# Here is part_name: SUPPLY2
# Here is part_name: U$1
# SparkFun-PowerSymbols
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part '1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=VDDA, lib=SparkFun-PowerSymbols, deviceset=VDDA, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-PowerSymbols#VDDA.sch
#
# Here is part_name: SUPPLY3
# SparkFun-PowerSymbols
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=VCC, lib=SparkFun-PowerSymbols, deviceset=VCC, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-PowerSymbols#VCC.sch
#
# Here is part_name: U$2
# Here is part_name: GND2
# Here is part_name: Y1
# SparkFun-Clocks
# Suggested position for new symbol 'Y1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.032) for part 'Y1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=CRYSTAL, lib=SparkFun-Clocks, deviceset=CRYSTAL-32.768KHZ, device=SMD-3.2X1.5, value=32.768kHz
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Clocks#CRYSTAL.sch
#
# Here is part_name: C1
# Here is part_name: C2
# Here is part_name: C3
# Here is part_name: C11
# Here is part_name: L1
# SparkFun-Coils
# Suggested position for new symbol 'L1': [0, 0]
# Placing gate 'G$1' at (10.0, 12.54) for part 'L1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=INDUCTOR, lib=SparkFun-Coils, deviceset=INDUCTOR, device=FB-30OHM, value=FB - 30Ohm
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Coils#INDUCTOR.sch
#
# Here is part_name: SUPPLY12
# Here is part_name: C12
# Here is part_name: GND28
# Here is part_name: C8
# Here is part_name: C9
# Here is part_name: SUPPLY13
# Here is part_name: C13
# Here is part_name: C14
# Here is part_name: C15
# Here is part_name: U$3
# Here is part_name: R1
# Here is part_name: SUPPLY10
# Here is part_name: GND8
# Here is part_name: J6
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'J1' at (12.54, 19.906) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=USB-5PIN, lib=SparkFun-Connectors, deviceset=USB_MICRO-B, device=_HALF_PTH_MILL, value=AMP FCI 10103594-0001LF
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Connectors#USB-5PIN.sch
#
# Here is part_name: J1
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (10.0, 30.066) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=CONN_12, lib=SparkFun-Connectors, deviceset=CONN_12, device=SM_SQ_NO_SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Connectors#CONN_12.sch
#
# Here is part_name: J2
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (10.0, 35.146) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=CONN_16, lib=SparkFun-Connectors, deviceset=CONN_16, device=1X16_SM_SQ_NOSILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Connectors#CONN_16.sch
#
# Here is part_name: GND7
# Here is part_name: SUPPLY4
# Here is part_name: SUPPLY5
# Here is part_name: SUPPLY6
# Here is part_name: R2
# Here is part_name: TP1
# SparkFun-Connectors
# Suggested position for new symbol 'TP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'TP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=TEST-POINT, lib=SparkFun-Connectors, deviceset=TEST-POINT, device=TP_15TH_THRU, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Connectors#TEST-POINT.sch
#
# Here is part_name: TP2
# Here is part_name: U4
# SparkFun-IC-Memory
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 15.334) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=SPI_FLASH_DUAL/QUAD, lib=SparkFun-IC-Memory, deviceset=AT25SF041, device=, value=4Mb Flash
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-IC-Memory#SPI_FLASH_DUALslashQUAD.sch
#
# Here is part_name: R4
# Here is part_name: SUPPLY9
# Here is part_name: SUPPLY11
# Here is part_name: GND3
# Here is part_name: LOGO1
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=FOUR_LAYER_WARNING, lib=SparkFun-Aesthetics, deviceset=FOUR_LAYER_WARNING, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#FOUR_LAYER_WARNING.sch
#
# Here is part_name: LOGO3
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=SFE_LOGO_NAME_FLAME, lib=SparkFun-Aesthetics, deviceset=SFE_LOGO_NAME_FLAME, device=.1_INCH, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#SFE_LOGO_NAME_FLAME.sch
#
# Here is part_name: LOGO4
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=SFE_LOGO_FLAME, lib=SparkFun-Aesthetics, deviceset=SFE_LOGO_FLAME, device=.1_INCH, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#SFE_LOGO_FLAME.sch
#
# Here is part_name: J4
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'J1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=JST_2MM_MALE, lib=SparkFun-Connectors, deviceset=JST_2MM_MALE, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Connectors#JST_2MM_MALE.sch
#
# Here is part_name: R5
# Here is part_name: R9
# Here is part_name: JP1
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.778) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=SMT-JUMPER_3_2-NC_TRACE, lib=SparkFun-Jumpers, deviceset=JUMPER-SMT_3_2-NC_TRACE, device=_SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Jumpers#SMT-JUMPER_3_2-NC_TRACE.sch
#
# Here is part_name: SUPPLY15
# Here is part_name: H1
# SparkFun-Hardware
# Suggested position for new symbol 'H1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'H1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=STAND-OFF, lib=SparkFun-Hardware, deviceset=STAND-OFF, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Hardware#STAND-OFF.sch
#
# Here is part_name: H2
# Here is part_name: H3
# Here is part_name: H4
# Here is part_name: U$69
# SparkFun-Aesthetics
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part '1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Thing_Plus_-_SAMD51/SAMD51_Thing_Plus.sch
#     Instance:  [0] symbol=LOGO, lib=SparkFun-Aesthetics, deviceset=QWIIC_LOGO, device=_5MM, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SAMD51_Thing_Plus#SparkFun-Aesthetics#LOGO.sch
#
# Here is part_name: FRAME1
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'V' at (310.0, 10.0) for part 'FRAME1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=FRAME-LETTER, lib=SparkFun-Aesthetics, deviceset=FRAME-LETTER, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-Aesthetics#FRAME-LETTER.sch
#
# Here is part_name: GND3
# SparkFun-PowerSymbols
# Suggested position for new symbol 'GND1': [0, 0]
# Placing gate '1' at (0, 0) for part 'GND1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=DGND, lib=SparkFun-PowerSymbols, deviceset=GND, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-PowerSymbols#DGND.sch
#
# Here is part_name: J2
# Here is part_name: SUPPLY6
# SparkFun-PowerSymbols
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: align
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=3.3V, lib=SparkFun-PowerSymbols, deviceset=3.3V, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-PowerSymbols#3.3V.sch
#
# Here is part_name: C5
# Here is part_name: J3
# Here is part_name: JP4
# Here is part_name: JP5
# Here is part_name: FD1
# Here is part_name: FD3
# Here is part_name: J9
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (15.207, 17.366) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=AVR_SPI_PROGRAMMER_6, lib=SparkFun-Connectors, deviceset=AVR_SPI_PROG_3X2, device=TESTPOINTS, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-Connectors#AVR_SPI_PROGRAMMER_6.sch
#
# Here is part_name: R17
# Here is part_name: R11
# Here is part_name: D11
# Here is part_name: JP6
# Here is part_name: JP7
# Here is part_name: FD2
# Here is part_name: FD4
# Here is part_name: GND8
# Here is part_name: J1
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'J1' at (15.08, 17.366) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=CONN_04, lib=SparkFun-Connectors, deviceset=CONN_04, device=1X04_NO_SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-Connectors#CONN_04.sch
#
# Here is part_name: U4
# SparkFun-IC-Microcontroller
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'U1' at (25.240000000000002, 27.78) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=ATTINY84-ARDUINO, lib=SparkFun-IC-Microcontroller, deviceset=ATTINY84-ARDUINO, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-IC-Microcontroller#ATTINY84-ARDUINO.sch
#
# Here is part_name: SUPPLY5
# Here is part_name: SUPPLY1
# Here is part_name: SUPPLY17
# Here is part_name: LOGO2
# Here is part_name: GND18
# Here is part_name: ADR
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=SMT-JUMPER_2_NC_TRACE, lib=SparkFun-Jumpers, deviceset=JUMPER-SMT_2_NC_TRACE, device=_SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-Jumpers#SMT-JUMPER_2_NC_TRACE.sch
#
# Here is part_name: PWR
# Here is part_name: GND7
# Here is part_name: GND1
# Here is part_name: D1
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: Q1
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'Q1': [0, 0]
# Placing gate 'G$1' at (9.692, 12.54) for part 'Q1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=NPN, lib=SparkFun-DiscreteSemi, deviceset=TRANS_NPN, device=-MMBT2222AL, value=600mA/40V
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-DiscreteSemi#NPN.sch
#
# Here is part_name: SUPPLY3
# Here is part_name: SUPPLY4
# Here is part_name: R3
# Here is part_name: GND2
# Here is part_name: D2
# Here is part_name: R4
# Here is part_name: R5
# Here is part_name: Q2
# Here is part_name: SUPPLY7
# Here is part_name: SUPPLY8
# Here is part_name: R6
# Here is part_name: SUPPLY2
# Here is part_name: I2C
# Here is part_name: R14
# Here is part_name: R15
# Here is part_name: SUPPLY13
# Here is part_name: K1
# SparkFun-DiscreteSemi
# Suggested position for new symbol 'K1': [0, 0]
# Placing gate 'G$1' at (17.62, 20.16) for part 'K1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=SOLIDSTATE_RELAY, lib=SparkFun-DiscreteSemi, deviceset=SIP_SOLIDSTATERELAY, device=, value=25A Solid State Relay
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-DiscreteSemi#SOLIDSTATE_RELAY.sch
#
# Here is part_name: K2
# Here is part_name: J4
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 14.826) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=CONN_02, lib=SparkFun-Connectors, deviceset=CONN_02, device=SCREWTERMINAL-6.35MM-2, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-Connectors#CONN_02.sch
#
# Here is part_name: J5
# Here is part_name: JP1
# Here is part_name: JP2
# Here is part_name: LOGO1
# Here is part_name: LOGO3
# Here is part_name: LOGO4
# Here is part_name: J6
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 14.826) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Dual_Solid_State_Relay/Qwiic Dual Solid State Relay.sch
#     Instance:  [0] symbol=CONN_01, lib=SparkFun-Connectors, deviceset=CONN_01, device=PTH_NO_SILK_YES_STOP, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic Dual Solid State Relay#SparkFun-Connectors#CONN_01.sch
#
# Here is part_name: R7
# Here is part_name: SUPPLY9
# Here is part_name: R8
# Here is part_name: SUPPLY10
# Here is part_name: D3
# Here is part_name: D4
# Here is part_name: JP3
# Here is part_name: JP8
# Here is part_name: JP10
# Here is part_name: A2
# LilyPad-Wearables
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (12.54, 10.762) for part '1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=SEWTAP, lib=LilyPad-Wearables, deviceset=SEWTAP, device=9, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#LilyPad-Wearables#SEWTAP.sch
#
# Here is part_name: A3
# Here is part_name: A5
# Here is part_name: D5
# Here is part_name: D9
# Here is part_name: D6
# Here is part_name: A4
# Here is part_name: D10
# Here is part_name: D11
# Here is part_name: +
# Here is part_name: -
# Here is part_name: U$13
# LilyPad-Wearables
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part '1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=LOGO-LP, lib=LilyPad-Wearables, deviceset=LOGO-LP, device=LP, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#LilyPad-Wearables#LOGO-LP.sch
#
# Here is part_name: U3
# Testing
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 50.64) for part '1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=ATMEGA32U4, lib=Testing, deviceset=ATMEGA32U4, device=1:1-LESS_PASTE, value=ATMEGA32U41:1-LESS_PASTE
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#Testing#ATMEGA32U4.sch
#
# Here is part_name: U1
# Here is part_name: U2
# Here is part_name: JP1
# SparkFun-Connectors
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=M02, lib=SparkFun-Connectors, deviceset=M02, device=-JST-2MM-SMT, value=JST-2
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Connectors#M02.sch
#
# Here is part_name: LED1
# Here is part_name: C1
# SparkFun-Passives
# Suggested position for new symbol 'C1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'C1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=CAP, lib=SparkFun-Passives, deviceset=CAP, device=0603-CAP, value=470pF
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Passives#CAP.sch
#
# Here is part_name: R1
# SparkFun-Passives
# Suggested position for new symbol 'R1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.016) for part 'R1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=RESISTOR, lib=SparkFun-Passives, deviceset=RESISTOR, device=0603-RES, value=330
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Passives#RESISTOR.sch
#
# Here is part_name: S1
# SparkFun-Electromechanical
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate 'G$1' at (12.54, 20.16) for part 'S1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=AYZ0202, lib=SparkFun-Electromechanical, deviceset=SWITCH-DPDT, device=AYZ0202, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Electromechanical#AYZ0202.sch
#
# Here is part_name: S2
# SparkFun-Electromechanical
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate 'G$1' at (12.54, 10.0) for part 'S1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=SWITCH-MOMENTARY-2, lib=SparkFun-Electromechanical, deviceset=SWITCH-MOMENTARY-2, device=SMD, value=!RESET
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Electromechanical#SWITCH-MOMENTARY-2.sch
#
# Here is part_name: FRAME1
# SparkFun-Aesthetics
# Suggested position for new symbol 'FRAME1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.0) for part 'FRAME1'
# Placing gate 'G$2' at (310.0, 10.0) for part 'FRAME1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=LETTER_L, lib=SparkFun-Aesthetics, deviceset=FRAME-LETTER, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Aesthetics#LETTER_L.sch
#
# Here is part_name: GND1
# Here is part_name: GND2
# Here is part_name: GND3
# Here is part_name: U$12
# SparkFun-Aesthetics
# Suggested position for new symbol 'SUPPLY1': [0, 0]
# Placing gate 'G$1' at (10.762, 8.73) for part 'SUPPLY1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=5V, lib=SparkFun-Aesthetics, deviceset=5V, device=, value=VBUS
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Aesthetics#5V.sch
#
# Here is part_name: P+1
# Here is part_name: U$14
# Here is part_name: R2
# Here is part_name: GND4
# Here is part_name: P+2
# Here is part_name: R3
# Here is part_name: GND5
# Here is part_name: U$16
# Here is part_name: R4
# Here is part_name: R5
# Here is part_name: GND7
# Here is part_name: R6
# Here is part_name: R7
# Here is part_name: LED2
# Here is part_name: LED3
# Here is part_name: LED4
# Here is part_name: R8
# Here is part_name: P+3
# Here is part_name: C2
# Here is part_name: P+4
# Here is part_name: GND6
# Here is part_name: C3
# Here is part_name: C4
# Here is part_name: C5
# Here is part_name: C6
# Here is part_name: U$17
# Here is part_name: U$18
# Here is part_name: GND8
# Here is part_name: GND9
# Here is part_name: C7
# Here is part_name: C8
# Here is part_name: Y1
# SparkFun-FreqCtrl
# Suggested position for new symbol 'Y1': [0, 0]
# Placing gate 'G$1' at (13.302, 17.62) for part 'Y1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=RESONATOR, lib=SparkFun-FreqCtrl, deviceset=RESONATOR, device=8MHZ, value=8MHz
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-FreqCtrl#RESONATOR.sch
#
# Here is part_name: GND10
# Here is part_name: JP2
# SparkFun
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (10.762, 10.762) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=FIDUCIAL, lib=SparkFun, deviceset=FIDUCIAL, device=1X2, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun#FIDUCIAL.sch
#
# Here is part_name: JP3
# Here is part_name: U$2
# Here is part_name: U$3
# Here is part_name: GND11
# Here is part_name: U$4
# Here is part_name: U$1
# Here is part_name: GND12
# Here is part_name: U$5
# SparkFun
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part '1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=OSHW-LOGO, lib=SparkFun, deviceset=OSHW-LOGO, device=M, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun#OSHW-LOGO.sch
#
# Here is part_name: D1
# Here is part_name: U5
# SparkFun-Connectors
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (12.54, 16.35) for part 'U1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: rot
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Arduino_USB_-_ATmega32U4_Board/Lilypad_Arduino_USB_v12.sch
#     Instance:  [0] symbol=USB_AB, lib=SparkFun-Connectors, deviceset=USB-AB, device=CONN-11794, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Lilypad_Arduino_USB_v12#SparkFun-Connectors#USB_AB.sch
#
# Here is part_name: C2
# Here is part_name: GND1
# SparkFun
# Suggested position for new symbol 'GND1': [0, 0]
# Placing gate '1' at (0, 0) for part 'GND1'
# Invalid text element format: x
# Invalid text element format: y
# Invalid text element format: size
# Invalid text element format: layer
# Invalid text element format: text
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=GND, lib=SparkFun, deviceset=GND, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun#GND.sch
#
# Here is part_name: GND5
# Here is part_name: U1
# SparkFun-Sensors
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 22.954) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=LIS331, lib=SparkFun-Sensors, deviceset=H3LIS331DL, device=, value=H3LIS331DL
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun-Sensors#LIS331.sch
#
# Here is part_name: GND2
# Here is part_name: C1
# SparkFun-Capacitors
# Suggested position for new symbol 'C1': [0, 0]
# Placing gate 'G$1' at (12.54, 14.190999999999999) for part 'C1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=CAP_POL, lib=SparkFun-Capacitors, deviceset=10UF-POLAR, device=-EIA3216-16V-10%(TANT), value=10uF
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun-Capacitors#CAP_POL.sch
#
# Here is part_name: JP11
# SparkFun
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=STAND-OFF, lib=SparkFun, deviceset=STAND-OFF, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun#STAND-OFF.sch
#
# Here is part_name: JP10
# Here is part_name: JP4
# Here is part_name: JP6
# Here is part_name: SUPPLY6
# Here is part_name: SUPPLY2
# Here is part_name: SUPPLY1
# Here is part_name: J2
# Here is part_name: J1
# Here is part_name: JP8
# Here is part_name: JP9
# Here is part_name: JP5
# Here is part_name: JP7
# Here is part_name: R4
# Here is part_name: JP2
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=SMT-JUMPER_2_NO, lib=SparkFun-Jumpers, deviceset=JUMPER-SMT_2_NO, device=_NO-SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun-Jumpers#SMT-JUMPER_2_NO.sch
#
# Here is part_name: GND4
# Here is part_name: SUPPLY5
# Here is part_name: JP1
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 11.397) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=SMT-JUMPER_3_2-NC_PASTE, lib=SparkFun-Jumpers, deviceset=JUMPER-SMT_3_2-NC_PASTE, device=_NO-SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun-Jumpers#SMT-JUMPER_3_2-NC_PASTE.sch
#
# Here is part_name: R2
# Here is part_name: R3
# Here is part_name: SUPPLY4
# Here is part_name: FRAME1
# Here is part_name: LOGO2
# Here is part_name: LOGO1
# Here is part_name: R1
# Here is part_name: GND3
# Here is part_name: SUPPLY3
# Here is part_name: JP3
# SparkFun-Jumpers
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_H3LI/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL.sch
#     Instance:  [0] symbol=SMT-JUMPER_2_NC_PASTE, lib=SparkFun-Jumpers, deviceset=JUMPER-SMT_2_NC_PASTE, device=_NO-SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun-Jumpers#SMT-JUMPER_2_NC_PASTE.sch
#
# Here is part_name: FRAME1
# Here is part_name: JP1
# Here is part_name: JP6
# Here is part_name: GND13
# Here is part_name: GND3
# Here is part_name: SUPPLY1
# Here is part_name: U2
# battery-management-temp
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (17.62, 20.16) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=BQ27441-G1, lib=battery-management-temp, deviceset=BQ27441-G1, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#battery-management-temp#BQ27441-G1.sch
#
# Here is part_name: R11
# Here is part_name: SUPPLY7
# Here is part_name: GND17
# Here is part_name: C5
# Here is part_name: GND20
# Here is part_name: C4
# Here is part_name: GND19
# Here is part_name: R13
# Here is part_name: R14
# Here is part_name: U1
# battery-management-temp
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 25.240000000000002) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=BQ24075, lib=battery-management-temp, deviceset=BQ24075, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#battery-management-temp#BQ24075.sch
#
# Here is part_name: GND10
# Here is part_name: GND2
# Here is part_name: SUPPLY3
# Here is part_name: SUPPLY4
# Here is part_name: R5
# Here is part_name: R7
# Here is part_name: GND6
# Here is part_name: GND9
# Here is part_name: GND12
# Here is part_name: SUPPLY6
# Here is part_name: D1
# Here is part_name: D2
# Here is part_name: R9
# Here is part_name: R10
# Here is part_name: C3
# Here is part_name: GND15
# Here is part_name: GND18
# Here is part_name: JP10
# Here is part_name: GND22
# Here is part_name: JP12
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=M01, lib=SparkFun-Connectors, deviceset=M01, device=PTH_NO_SILK_YES_STOP, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Connectors#M01.sch
#
# Here is part_name: JP5
# Here is part_name: R8
# Here is part_name: GND14
# Here is part_name: R16
# Here is part_name: R17
# Here is part_name: R6
# Here is part_name: GND8
# Here is part_name: R4
# Here is part_name: GND5
# Here is part_name: SUPPLY5
# Here is part_name: GND11
# Here is part_name: C1
# Here is part_name: SUPPLY2
# Here is part_name: GND7
# Here is part_name: STANDOFF3
# SparkFun-Electromechanical
# Suggested position for new symbol 'H1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'H1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=STAND-OFF, lib=SparkFun-Electromechanical, deviceset=STAND-OFF, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Electromechanical#STAND-OFF.sch
#
# Here is part_name: STANDOFF1
# Here is part_name: STANDOFF2
# Here is part_name: STANDOFF4
# Here is part_name: S1
# SparkFun-Electromechanical
# Suggested position for new symbol 'S1': [0, 0]
# Placing gate '1' at (10.0, 12.54) for part 'S1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=TOGGLE, lib=SparkFun-Electromechanical, deviceset=SWITCH-SPDT, device=-SMD-A, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Electromechanical#TOGGLE.sch
#
# Here is part_name: JP3
# Here is part_name: JP7
# Here is part_name: JP8
# Here is part_name: GND16
# Here is part_name: JP9
# Here is part_name: R2
# Here is part_name: SJ1
# SparkFun-Passives
# Suggested position for new symbol 'SJ1': [0, 0]
# Placing gate 'G$1' at (12.54, 10.635) for part 'SJ1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=PAD-JUMPER-2-NC_BY_TRACE, lib=SparkFun-Passives, deviceset=JUMPER-PAD-2-NC_BY_TRACE, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Passives#PAD-JUMPER-2-NC_BY_TRACE.sch
#
# Here is part_name: SUPPLY8
# Here is part_name: GND21
# Here is part_name: R3
# Here is part_name: GND4
# Here is part_name: SJ4
# Here is part_name: SJ3
# Here is part_name: JP4
# Here is part_name: LOGO1
# SparkFun-Aesthetics
# Suggested position for new symbol 'LOGO1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'LOGO1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=SFE_LOGO_NAME, lib=SparkFun-Aesthetics, deviceset=SFE_LOGO_NAME, device=.1_INCH, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Aesthetics#SFE_LOGO_NAME.sch
#
# Here is part_name: LOGO3
# Here is part_name: R12
# Here is part_name: JP11
# Here is part_name: LOGO2
# Here is part_name: JP13
# Here is part_name: R1
# Here is part_name: GND1
# Here is part_name: R15
# Here is part_name: C2
# Here is part_name: SJ2
# Here is part_name: GND23
# Here is part_name: FID1
# Here is part_name: FID2
# Here is part_name: S2
# SparkFun-Electromechanical
# Suggested position for new symbol 'SW1': [0, 0]
# Placing gate 'G$1' at (15.08, 15.08) for part 'SW1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=SW_DIP-2, lib=SparkFun-Electromechanical, deviceset=SW_DIP-2, device=-SMT-HALFSIZE, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Electromechanical#SW_DIP-2.sch
#
# Here is part_name: GND24
# Here is part_name: SJ5
# SparkFun-Passives
# Suggested position for new symbol 'JP1': [0, 0]
# Placing gate 'G$1' at (12.54, 12.54) for part 'JP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=PAD-JUMPER-3-2OF3-NC_BY_TRACE, lib=SparkFun-Passives, deviceset=JUMPER-PAD-3-2OF3_NC_BY_TRACE, device=_SMALL, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Passives#PAD-JUMPER-3-2OF3-NC_BY_TRACE.sch
#
# Here is part_name: JP2
# Here is part_name: TP1
# SparkFun-Passives
# Suggested position for new symbol 'TP1': [0, 0]
# Placing gate 'G$1' at (10.0, 10.762) for part 'TP1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Battery_Babysitter_-_LiPo_Battery_Manager/sparkfun-battery-babysitter.sch
#     Instance:  [0] symbol=TEST-POINT, lib=SparkFun-Passives, deviceset=TEST-POINT, device=3X4, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/sparkfun-battery-babysitter#SparkFun-Passives#TEST-POINT.sch
#
# Here is part_name: TP2
# Here is part_name: J3
# Here is part_name: R23
# Here is part_name: R16
# Here is part_name: I2C
# Here is part_name: GND12
# Here is part_name: SUPPLY5
# Here is part_name: GND19
# Here is part_name: SUPPLY8
# Here is part_name: J5
# SparkFun-Connectors
# Suggested position for new symbol 'J1': [0, 0]
# Placing gate 'G$1' at (10.0, 27.526) for part 'J1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_GPS-RTK_Dead_Reckoning_Breakout_-_ZED-F9R/SparkFun_ZED-F9R_v12_uFL.sch
#     Instance:  [0] symbol=CONN_11, lib=SparkFun-Connectors, deviceset=CONN_11, device=1X11_NO_SILK, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_ZED-F9R_v12_uFL#SparkFun-Connectors#CONN_11.sch
#
# Here is part_name: D8
# Here is part_name: R24
# Here is part_name: SUPPLY16
# ...
# Here is part_name: GND3
# Here is part_name: GND4
# Here is part_name: GND5
# Here is part_name: GND6
# Here is part_name: SL1
# Here is part_name: P+1
# Here is part_name: P+2
# Here is part_name: U$1
# Here is part_name: U$3
# Here is part_name: U$4
# Testing
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (20.16, 20.16) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_ADXL/ADXL335_Breakout.sch
#     Instance:  [0] symbol=ADXL335, lib=Testing, deviceset=ADXL335-PATRICK, device="", value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/ADXL335_Breakout#Testing#ADXL335.sch
#
# Here is part_name: FRAME1
# Here is part_name: U1
# Here is part_name: U2
# Here is part_name: J1
# Here is part_name: J2
# Here is part_name: J3
# Here is part_name: J4
# Here is part_name: H1
# Here is part_name: H2
# Here is part_name: H3
# Here is part_name: H4
# Here is part_name: GND1
# Here is part_name: GND2
# Here is part_name: GND3
# Here is part_name: GND4
# Here is part_name: GND5
# Here is part_name: GND6
# Here is part_name: SUPPLY1
# Here is part_name: SUPPLY2
# Here is part_name: SUPPLY3
# Here is part_name: SUPPLY5
# Here is part_name: SUPPLY6
# Here is part_name: SUPPLY7
# Here is part_name: SUPPLY8
# Here is part_name: SUPPLY9
# Here is part_name: FB1
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: LOGO1
# Here is part_name: LOGO2
# Here is part_name: LOGO3
# Here is part_name: SHLD
# Here is part_name: R3
# Here is part_name: R4
# Here is part_name: GND7
# Here is part_name: GND8
# Here is part_name: GND9
# Here is part_name: R5
# Here is part_name: R6
# Here is part_name: I2C
# Here is part_name: U3
# Here is part_name: C1
# Here is part_name: C2
# Here is part_name: GND11
# Here is part_name: GND12
# Here is part_name: GND13
# Here is part_name: SUPPLY12
# Here is part_name: R7
# Here is part_name: U4
# Here is part_name: GND14
# Here is part_name: R8
# Here is part_name: GND15
# Here is part_name: SUPPLY13
# Here is part_name: SUPPLY14
# Here is part_name: SUPPLY15
# Here is part_name: FRAME1
# Here is part_name: Y1
# Here is part_name: R9
# Here is part_name: C3
# Here is part_name: C4
# Here is part_name: GND16
# Here is part_name: R12
# Here is part_name: SUPPLY16
# Here is part_name: GND17
# Here is part_name: BOOT
# Here is part_name: RESET
# Here is part_name: GND18
# Here is part_name: U5
# Here is part_name: GND19
# Here is part_name: SUPPLY17
# Here is part_name: R13
# Here is part_name: R14
# Here is part_name: SUPPLY18
# Here is part_name: J5
# Here is part_name: GND20
# Here is part_name: U6
# Here is part_name: C5
# Here is part_name: C6
# Here is part_name: GND21
# Here is part_name: GND22
# Here is part_name: C9
# Here is part_name: GND23
# Here is part_name: SUPPLY19
# Here is part_name: C12
# Here is part_name: GND24
# Here is part_name: SUPPLY20
# Here is part_name: C14
# Here is part_name: GND25
# Here is part_name: SUPPLY21
# Here is part_name: C15
# Here is part_name: GND26
# Here is part_name: SUPPLY22
# Here is part_name: C16
# Here is part_name: GND27
# Here is part_name: SUPPLY23
# Here is part_name: C17
# Here is part_name: GND28
# Here is part_name: SUPPLY24
# Here is part_name: C18
# Here is part_name: GND29
# Here is part_name: C19
# Here is part_name: GND30
# Here is part_name: SUPPLY25
# Here is part_name: SUPPLY26
# Here is part_name: C20
# Here is part_name: C21
# Here is part_name: SUPPLY27
# Here is part_name: SUPPLY28
# Here is part_name: GND31
# Here is part_name: GND32
# Here is part_name: C7
# Here is part_name: GND33
# Here is part_name: SUPPLY29
# Here is part_name: C8
# Here is part_name: GND34
# Here is part_name: SUPPLY30
# Here is part_name: U7
# Here is part_name: GND35
# Here is part_name: C10
# Here is part_name: C11
# Here is part_name: GND36
# Here is part_name: GND37
# Here is part_name: SUPPLY32
# Here is part_name: SUPPLY33
# Here is part_name: D2
# Here is part_name: R15
# Here is part_name: PWR
# Here is part_name: SUPPLY34
# Here is part_name: GND38
# Here is part_name: R16
# Here is part_name: GND39
# Here is part_name: D3
# Here is part_name: R17
# Here is part_name: GND40
# Here is part_name: SUPPLY35
# Here is part_name: SUPPLY37
# Here is part_name: L1
# Here is part_name: R18
# Here is part_name: C22
# Here is part_name: SUPPLY38
# Here is part_name: GND42
# Here is part_name: SUPPLY39
# Here is part_name: R10
# Here is part_name: R11
# Here is part_name: GND43
# Here is part_name: SUPPLY41
# Here is part_name: U8
# Here is part_name: GND44
# Here is part_name: GND45
# Here is part_name: SUPPLY42
# Here is part_name: C23
# Here is part_name: GND46
# Here is part_name: SUPPLY43
# Here is part_name: C24
# Here is part_name: GND47
# Here is part_name: D4
# Here is part_name: R19
# Here is part_name: GND48
# Here is part_name: Q1
# Here is part_name: SUPPLY36
# Here is part_name: R20
# Here is part_name: GND41
# Here is part_name: J6
# Here is part_name: U9
# Here is part_name: SUPPLY11
# Here is part_name: SUPPLY31
# Here is part_name: SUPPLY40
# Here is part_name: SUPPLY44
# Here is part_name: GND49
# Here is part_name: SUPPLY45
# Here is part_name: SUPPLY46
# Here is part_name: C13
# Here is part_name: GND50
# Here is part_name: R21
# Here is part_name: SUPPLY48
# Here is part_name: LP
# Here is part_name: R22
# Here is part_name: GND51
# Here is part_name: SUPPLY4
# Here is part_name: C25
# Here is part_name: GND52
# Here is part_name: SUPPLY47
# Here is part_name: TP1
# Here is part_name: FD1
# Here is part_name: FD2
# Here is part_name: FD3
# Here is part_name: FD4
# Here is part_name: U10
# Here is part_name: GND53
# Here is part_name: SUPPLY49
# Here is part_name: LOGO5
# Here is part_name: U11
# Here is part_name: GND10
# Here is part_name: SUPPLY10
# Here is part_name: R23
# Here is part_name: SUPPLY50
# Here is part_name: C26
# Here is part_name: GND54
# Here is part_name: SUPPLY51
# Here is part_name: FRAME1
# Here is part_name: R2
# Here is part_name: C3
# Here is part_name: GND1
# Here is part_name: R6
# Here is part_name: D3
# Here is part_name: GND8
# Here is part_name: P+11
# Here is part_name: P+15
# Here is part_name: Q1
# Here is part_name: GND4
# Here is part_name: P+1
# Here is part_name: GND5
# Here is part_name: C2
# Here is part_name: R1
# Here is part_name: D1
# Here is part_name: GND2
# Here is part_name: P+2
# Here is part_name: GND3
# Here is part_name: FID1
# Here is part_name: FID2
# Here is part_name: GND6
# Here is part_name: LOGO2
# Here is part_name: FID3
# Here is part_name: FID4
# Here is part_name: SUPPLY4
# Here is part_name: J2
# Here is part_name: GND11
# Here is part_name: SUPPLY7
# Here is part_name: J3
# Here is part_name: GND12
# Here is part_name: SUPPLY8
# Here is part_name: J4
# Here is part_name: GND13
# Here is part_name: C1
# Here is part_name: P+3
# Here is part_name: GND7
# Here is part_name: P+4
# Here is part_name: GND10
# Here is part_name: ADR
# Here is part_name: R4
# Here is part_name: R5
# Here is part_name: I2C
# Here is part_name: SUPPLY1
# Here is part_name: JP3
# Here is part_name: JP4
# Here is part_name: J5
# Here is part_name: SUPPLY2
# Here is part_name: GND9
# Here is part_name: U2
# Here is part_name: R3
# Here is part_name: P+5
# Here is part_name: J6
# Here is part_name: J1
# Here is part_name: LOGO4
# Here is part_name: LOGO1
# Here is part_name: FRAME1
# Here is part_name: U1
# bmp384
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (22.7, 22.7) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Pressure_Sensor_-_BMP384_(Qwiic)/BMP384 Breakout.sch
#     Instance:  [0] symbol=BMP384, lib=bmp384, deviceset=BMP384, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/BMP384 Breakout#bmp384#BMP384.sch
#
# Here is part_name: GND1
# Here is part_name: SUPPLY1
# Here is part_name: J1
# Here is part_name: GND2
# Here is part_name: SUPPLY2
# Here is part_name: J2
# Here is part_name: GND3
# Here is part_name: SUPPLY3
# Here is part_name: C1
# Here is part_name: H1
# Here is part_name: H2
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: SUPPLY5
# Here is part_name: GND4
# Here is part_name: FD1
# Here is part_name: FD2
# Here is part_name: FD3
# Here is part_name: FD4
# Here is part_name: J3
# Here is part_name: GND5
# Here is part_name: SUPPLY6
# Here is part_name: R3
# Here is part_name: SUPPLY7
# Here is part_name: JP1
# Here is part_name: R4
# Here is part_name: GND6
# Here is part_name: LOGO1
# Here is part_name: LOGO3
# Here is part_name: JP2
# Here is part_name: D1
# Here is part_name: R5
# Here is part_name: JP3
# Here is part_name: SUPPLY4
# Here is part_name: GND7
# Here is part_name: LOGO2
# Here is part_name: LOGO4
# Here is part_name: C1
# Here is part_name: C2
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: P+1
# Here is part_name: GND1
# Here is part_name: P+2
# Here is part_name: P+3
# Here is part_name: U$1
# Here is part_name: JP3
# Here is part_name: JP4
# Here is part_name: R3
# Here is part_name: P+4
# Here is part_name: GND2
# Here is part_name: SJ1
# Here is part_name: JP2
# Here is part_name: JP6
# Here is part_name: U1
# SparkFun-Sensors
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'G$1' at (25.240000000000002, 25.494) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Triple_Axis_Accelerometer_Breakout_-_LIS3/SparkFun_LIS3DH-Breakout.sch
#     Instance:  [0] symbol=LIS3DH, lib=SparkFun-Sensors, deviceset=LIS3DH, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/SparkFun_LIS3DH-Breakout#SparkFun-Sensors#LIS3DH.sch
#
# Here is part_name: SJ2
# Here is part_name: R4
# Here is part_name: J1
# Here is part_name: FRAME2
# Here is part_name: LOGO1
# Here is part_name: SUPPLY1
# Here is part_name: GND3
# Here is part_name: J2
# Here is part_name: GND4
# Here is part_name: LOGO2
# Here is part_name: JP3
# Here is part_name: JP4
# Here is part_name: JP2
# Here is part_name: JP6
# Here is part_name: SUPPLY4
# Here is part_name: J2
# Here is part_name: GND6
# Here is part_name: SUPPLY7
# Here is part_name: GND7
# Here is part_name: FRAME1
# Here is part_name: SUPPLY8
# Here is part_name: J4
# Here is part_name: GND8
# Here is part_name: JP1
# Here is part_name: JP5
# Here is part_name: R3
# Here is part_name: SUPPLY10
# Here is part_name: D1
# Here is part_name: GND3
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: SUPPLY9
# Here is part_name: LED
# Here is part_name: LOGO5
# Here is part_name: I2C
# Here is part_name: LOGO1
# Here is part_name: LOGO2
# Here is part_name: LOGO3
# Here is part_name: LOGO4
# Here is part_name: LOGO6
# Here is part_name: JP7
# Here is part_name: JP8
# Here is part_name: U1
# BME688
# Suggested position for new symbol 'U1': [0, 0]
# Placing gate 'U1' at (20.16, 20.16) for part 'U1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkFun_Environmental_Sensor_-_BME688_(Qwiic)/Qwiic_BME688.sch
#     Instance:  [0] symbol=BME688, lib=BME688, deviceset=BME688, device=LGA, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic_BME688#BME688#BME688.sch
#
# Here is part_name: GND1
# Here is part_name: GND2
# Here is part_name: SUPPLY1
# Here is part_name: C1
# Here is part_name: C2
# Here is part_name: SUPPLY2
# Here is part_name: SUPPLY3
# Here is part_name: GND4
# Here is part_name: GND5
# Here is part_name: ADR
# Here is part_name: SUPPLY5
# Here is part_name: J3
# Here is part_name: CSB
# Here is part_name: R4
# Here is part_name: FRAME1
# Here is part_name: S
# Here is part_name: 2
# Here is part_name: 1
# Here is part_name: U1
# SparkFun-RF
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'U1' at (17.62, 15.08) for part '1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/GNSS_Antenna_Splitter_(Power_Divider)_with_DC_Pass/GNSS_Splitter.sch
#     Instance:  [0] symbol=BP2G1+, lib=SparkFun-RF, deviceset=BP2G1+_POWER_SPLITTER, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/GNSS_Splitter#SparkFun-RF#BP2G1+.sch
#
# Here is part_name: JP1
# Here is part_name: JP2
# Here is part_name: GND1
# Here is part_name: GND2
# Here is part_name: GND3
# Here is part_name: GND4
# Here is part_name: J1
# Here is part_name: U$1
# Here is part_name: U$2
# Here is part_name: J2
# Here is part_name: GND5
# Here is part_name: GND6
# Here is part_name: C3
# Here is part_name: R1
# Here is part_name: GND18
# Here is part_name: FB1
# Here is part_name: D1
# Here is part_name: GND12
# Here is part_name: C1
# Here is part_name: C2
# Here is part_name: LOGO1
# Here is part_name: LOGO2
# Here is part_name: FD1
# Here is part_name: FD2
# Here is part_name: FD3
# Here is part_name: FD4
# Here is part_name: H1
# Here is part_name: H2
# Here is part_name: ILIM
# Here is part_name: LOGO3
# Here is part_name: SUPPLY1
# Here is part_name: SUPPLY2
# Here is part_name: SUPPLY3
# Here is part_name: FD1
# Here is part_name: FD2
# Here is part_name: FD3
# Here is part_name: FD4
# Here is part_name: FRAME1
# Here is part_name: H1
# Here is part_name: H2
# Here is part_name: H4
# Here is part_name: J1
# Here is part_name: J2
# Here is part_name: J3
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: U$1
# Here is part_name: GND2
# Here is part_name: GND3
# Here is part_name: GND4
# Here is part_name: R4
# Here is part_name: D1
# Here is part_name: JP1
# Here is part_name: GND5
# Here is part_name: JP3
# Here is part_name: U1
# Here is part_name: M1
# Here is part_name: GND1
# Here is part_name: C1
# Here is part_name: GND6
# Here is part_name: J4
# Here is part_name: R3
# Here is part_name: C2
# Here is part_name: GND7
# Here is part_name: JP2
# Here is part_name: SUPPLY10
# Here is part_name: SUPPLY11
# Here is part_name: SUPPLY12
# Here is part_name: SUPPLY13
# Here is part_name: SUPPLY14
# Here is part_name: SUPPLY1
# Here is part_name: SUPPLY2
# Here is part_name: J5
# Here is part_name: LOGO1
# Here is part_name: SUPPLY3
# Here is part_name: JP4
# Here is part_name: LOGO2
# Here is part_name: LOGO4
# Here is part_name: SUPPLY4
# Here is part_name: JP3
# Here is part_name: JP4
# Here is part_name: JP2
# Here is part_name: JP6
# Here is part_name: SUPPLY4
# Here is part_name: J2
# Here is part_name: GND6
# Here is part_name: SUPPLY7
# Here is part_name: GND7
# Here is part_name: FRAME1
# Here is part_name: SUPPLY8
# Here is part_name: J4
# Here is part_name: GND8
# Here is part_name: JP1
# Here is part_name: JP5
# Here is part_name: R3
# Here is part_name: SUPPLY10
# Here is part_name: D1
# Here is part_name: GND3
# Here is part_name: GND1
# Here is part_name: R1
# Here is part_name: R2
# Here is part_name: SUPPLY9
# Here is part_name: PWR
# Here is part_name: LOGO5
# Here is part_name: J1
# Here is part_name: I2C
# Here is part_name: GND2
# Here is part_name: C1
# Here is part_name: SUPPLY3
# Here is part_name: U$18
# Here is part_name: LOGO1
# Here is part_name: SUPPLY1
# Here is part_name: J3
# Here is part_name: VINN
# Here is part_name: GND4
# Here is part_name: J5
# Here is part_name: U1
# New-Parts_SparkFun-IC-Power
# Suggested position for new symbol '1': [0, 0]
# Placing gate 'G$1' at (20.16, 22.7) for part '1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/SparkX_Power_Meter_-_ACS37800_(Qwiic)/Qwiic_Power_Meter-ACS37800.sch
#     Instance:  [0] symbol=ACS37800, lib=New-Parts_SparkFun-IC-Power, deviceset=ACS37800, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/Qwiic_Power_Meter-ACS37800#New-Parts_SparkFun-IC-Power#ACS37800.sch
#
# Here is part_name: R4
# Here is part_name: GND5
# Here is part_name: R5
# Here is part_name: GND9
# Here is part_name: HI
# Here is part_name: LO
# Here is part_name: R6
# Here is part_name: R7
# Here is part_name: R8
# Here is part_name: R9
# Here is part_name: IP+
# Here is part_name: RSENSE
# Here is part_name: FRAME1
# Here is part_name: S1
# Here is part_name: JP1
# Here is part_name: JP3
# Here is part_name: JP2
# Here is part_name: U$5
# Here is part_name: JP5
# Here is part_name: U1
# Here is part_name: JP4
# Here is part_name: GND1
# Here is part_name: C1
# Here is part_name: GND2
# Here is part_name: R3
# Here is part_name: D1
# Here is part_name: C2
# Here is part_name: GND3
# Here is part_name: GND4
# Here is part_name: R4
# Here is part_name: GND5
# Here is part_name: U$6
# Here is part_name: U$1
# Here is part_name: STANDOFF1
# Local Library
# Suggested position for new symbol 'STANDOFF1': [0, 0]
# Placing gate 'G$1' at (0, 0) for part 'STANDOFF1'
#
#     Source:    /Users/linkaiyuan/文件/PSU/products/LilyPad_Simple_Power/LilyPad_Simple_Power_v21.sch
#     Instance:  [0] symbol=SEW-HOLE-NO-PIN, lib=Local Library, deviceset=SEW-HOLE-NO-PAD, device=, value=
#     Written to: /Users/linkaiyuan/文件/PSU/multi_instances2/LilyPad_Simple_Power_v21#Local Library#SEW-HOLE-NO-PIN.sch
#
# Here is part_name: STANDOFF2
# Here is part_name: STANDOFF3
# Here is part_name: STANDOFF4
# Here is part_name: FID1
# Here is part_name: FID2

# %% [markdown]
# # Generate Training Data (Images for each single symbols)

# %% [markdown]
# ### Function to filter out the blank symols

# %%
from PIL import Image
import numpy as np
import os
def is_blank_image(path, white_tol=250, blank_frac=0.99):
    """
    Returns True if more than blank_frac of the pixels are
    (R,G,B) >= white_tol.
    """
    im = Image.open(path).convert("RGB")
    arr = np.array(im)
    # mask of pixels that are “almost white”
    white = (arr[:,:,0] >= white_tol) & (arr[:,:,1] >= white_tol) & (arr[:,:,2] >= white_tol)
    return white.mean() >= blank_frac

# %% [markdown]
# ### loop over single instances to generate single symbol images

# %%
import glob
import os
import shutil


folder_path = r"/Users/linkaiyuan/文件/PSU/multi_instances2"

# img_dir   = r"/Users/linkaiyuan/文件/PSU/problem_image_debug/"
img_dir     = r"/Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/train/images"
lbl_dir     = r"/Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/train/labels"
sch_store_dir = r"/Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/train/sch"




# save_path = "/Users/linkaiyuan/Downloads/"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/Bus_Pirate_-_v3.6a/BusPirate-v3.6a.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/multi_instances/MicroMod_Processor_STM32WB5MMG_stm32wb5mmg_STM32WB5MMG_COMMS.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Buzzer/SparkFun_Qwiic_Buzzer.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/SparkFun_MicroMod_WiFi_Function_Board_-_DA16200/SparkFun_MicroMod_DA16200_Function.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch"


limit = 50

for p in (folder_path, img_dir, lbl_dir, sch_store_dir):
    os.makedirs(p, exist_ok=True)

class_order = 0
class_map   = {}
with open("/Users/linkaiyuan/文件/PSU/wrong_image_list.txt", "r") as f:
        wrong_list = [os.path.splitext(os.path.basename(line.strip()))[0] for line in f]
print(wrong_list)

base = ""


for sch_file in glob.glob(os.path.join(folder_path, "*.sch")):
    # if os.path.splitext(os.path.basename(sch_file))[0] not in wrong_list:
    #         # print(f"Skipping {os.path.splitext(os.path.basename(sch_file))[0]} as it is not in the wrong list.")
    #     continue
    limit = limit - 1
    if limit == 0:
        break
    try:
        # parse schematic and get its full‐sheet bounds
        schematic_info = process_schematic_file(sch_file)
        src_xlim, src_ylim = get_schematic_bounding_box_from_schematic_info(schematic_info)
        # print(sch_file)
        # render and save
        # png_path = os.path.join(img_dir, "version_with_bounding" + os.path.basename(sch_file).replace(".sch", ".png"))
        base = os.path.splitext(os.path.basename(sch_file))[0]
        png_path = os.path.join(img_dir, base + ".png")
        sch_file_path = os.path.join(sch_store_dir, base + ".sch")
        # sizes    = visualize_schematic(sch_file, png_path)
        sizes   = visualize_schematic_nobounding(sch_file, save_path=png_path)
        px_per_x, px_per_y, _, _, img_w, img_h = sizes
        if is_blank_image(png_path):
                print(f"Blank → removing {base}")
                os.remove(png_path)
                continue
        else:
                print(f"Kept → {base}")
                shutil.copy(sch_file, sch_file_path)


        
        if base not in class_map:
                class_map[base] = class_order
                class_order += 1
        cls_id = class_map[base]
        png_path = os.path.join(img_dir, base + ".png")

        label_file = ""
        ic_library = schematic_info.get('IC_library')
        parts_info = schematic_info.get('parts')

        # loop over each part instance
        for part_name, part_data in parts_info.items():
            for instance in part_data.get('instances', []):
                symbol_element = get_symbol_element_of_instance_from_library(
                    ic_library, part_name, instance.get('gate', ''), parts_info
                )
                if not symbol_element:
                    continue

                # get this symbol’s world‐space bbox
                rot_inst = instance['rot']
                x_inst   = float(instance['x'])
                y_inst   = float(instance['y'])
                (x0, x1), (y0, y1) = get_bounding_box_for_symbol_instance(
                    symbol_element, x_inst, y_inst, rot_inst
                )

                # convert to pixels
                w_px  = (x1 - x0) * px_per_x
                h_px  = (y1 - y0) * px_per_y
                cx_px = ((x0 + x1)/2 - src_xlim[0]) * px_per_x
                cy_px = ((y0 + y1)/2 - src_ylim[0]) * px_per_y

                # normalize for YOLO (flip y so origin is top‐left)
                norm_x_center = cx_px / img_w
                norm_y_center = 1.0 - (cy_px / img_h)
                norm_width    = w_px    / img_w
                norm_height   = h_px    / img_h

                # lookup class
                lib          = part_data['library']
                symbol       = instance['symbol']
                base_name    = os.path.splitext(os.path.basename(sch_file))[0]
                key          = f"{base_name}_{lib}_{symbol}"
                if class_map is not None:
                    class_number = class_map.get(key, -1)
                    if class_number == -1:
                        continue

                label_file += f"{class_number} {norm_x_center:.6f} {norm_y_center:.6f} {norm_width:.6f} {norm_height:.6f}\n"

        # write out labels
        label_filename = os.path.join(lbl_dir, base + ".txt")
        with open(label_filename, "w") as f:
            f.write(label_file)

    except Exception as e:
        print(f"Skipping {sch_file} due to error: {e}")
# Out:
# ['ArtemisDevKit_SparkFun-Clocks_CRYSTAL-GND', 'ArtemisDevKit_SparkFun-Connectors_CAMERA-OV7670-MODULE', 'ArtemisDevKit_SparkFun-Connectors_CAMERA-OV7670-MODULE', 'ArtemisDevKit_SparkFun-Connectors_CONN_08', 'ArtemisDevKit_SparkFun-Connectors_CORTEX_DEBUG_MINIMUM', 'ArtemisDevKit_SparkFun-Connectors_CORTEX_DEBUG', 'ArtemisDevKit_SparkFun-IC-Microcontroller_ARTEMIS_MODULE', 'ArtemisDevKit_SparkFun-IC-Microcontroller_DAPLINK_MKL26Z', 'ArtemisDevKit_SparkFun-PowerSymbols_1.8V', 'ArtemisDevKit_SparkFun-PowerSymbols_V_USB', 'ArtemisDevKit_SparkFun-Sensors_LIS2DH12', 'ArtemisDevKit_SparkFun-Sensors_SPH0641LM4H-1_MICROPHONE', 'ArtemisDevKit_SparkFun-Switches_SWITCH-MOMENTARY-2']
# schematics_raw_dimensions: 40.16 40.160000000000004
# schematics_png_dimensions: 8.032 8.032
# Dimensions of schematic: 8.032 8.032
# part_name: B1 part_value:  symbol_name: BREADBOARD x: 15.08 y: 15.334 rot: R0 gate: G$1
# here are the texts: [{'x': '-5.08', 'y': '5.334', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-5.08', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_ProtoShield_Kit_rev40#SparkFun-Boards#BREADBOARD
# schematics_raw_dimensions: 52.9108 44.683
# schematics_png_dimensions: 10.58216 8.9366
# Dimensions of schematic: 10.58216 8.9366
# /var/folders/tl/q2dlpcnd685cw606gn_pd05h0000gn/T/ipykernel_38471/3723974411.py:1375: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# part_name: 1 part_value:  symbol_name: OSHW-LOGO x: 0.0 y: 0.0 rot: R0 gate: G$1
# here are the texts: []
# plt saved
# Kept → Lilypad_Arduino_USB_v12#SparkFun#OSHW-LOGO
# schematics_raw_dimensions: 50.32 57.940000000000005
# schematics_png_dimensions: 10.064 11.588000000000001
# Dimensions of schematic: 10.064 11.588000000000001
# part_name: U1 part_value:  symbol_name: RM2 x: 20.16 y: 27.78 rot: R0 gate: G$1
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SCLK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PICO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: POCI pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: !CS! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GPIO0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: WLON pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDIO pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDBAT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GPIO1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GPIO2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: BTON pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: IRQ pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-10.16', 'y': '15.24', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'top-left', 'text': '>Name'}, {'x': '-10.16', 'y': '-17.78', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# plt saved
# Kept → SparkFun_Thing_Plus_RP2350#RM2#RM2
# schematics_raw_dimensions: 60.48 45.24
# schematics_png_dimensions: 12.096 9.048
# Dimensions of schematic: 12.096 9.048
# part_name: 1 part_value:  symbol_name: DRV2605L x: 20.16 y: 17.62 rot: R0 gate: DRV2605
# here are the texts: [{'x': '-2.54', 'y': '8.382', 'size': '1.27', 'layer': '95', 'text': '>NAME'}, {'x': '-3.048', 'y': '-9.652', 'size': '1.27', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → Haptic_Motor_Driver_DRV2605L_v20#SparkFun-PowerIC#DRV2605L
# schematics_raw_dimensions: 35.08 40.16
# schematics_png_dimensions: 7.016 8.032
# Dimensions of schematic: 7.016 8.032
# part_name: Q1 part_value: 600mA/40V symbol_name: NPN x: 9.692 y: 12.54 rot: R0 gate: G$1
# here are the texts: [{'x': '2.54', 'y': '0', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '2.54', 'y': '-2.286', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# plt saved
# Kept → Qwiic Dual Solid State Relay#SparkFun-DiscreteSemi#NPN
# schematics_raw_dimensions: 32.54 32.54
# schematics_png_dimensions: 6.508 6.508
# Dimensions of schematic: 6.508 6.508
# part_name: JP1 part_value:  symbol_name: FIDUCIAL x: 10.762 y: 10.762 rot: R0 gate: G$1
# here are the texts: []
# plt saved
# Kept → TLC5940-Breakout-v12#SparkFun#FIDUCIAL
# schematics_raw_dimensions: 45.24 60.480000000000004
# schematics_png_dimensions: 9.048 12.096
# Dimensions of schematic: 9.048 12.096
# part_name: U1 part_value: TCA9534 symbol_name: TCA9534 x: 17.62 y: 30.066 rot: R0 gate: U1
# Pad Drawn: pin name: !INT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: A0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: A1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: A2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: P7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SCL pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SDA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCC pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '13.208', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-7.62', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# plt saved
# Kept → SparkFun_Qwiic_GPIO#SparkFun-IC-Conversion#TCA9534
# schematics_raw_dimensions: 31.524 32.54
# schematics_png_dimensions: 6.3048 6.508
# Dimensions of schematic: 6.3048 6.508
# part_name: SUPPLY1 part_value:  symbol_name: VUSB x: 10.762 y: 8.73 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → RedBoard_Turbo#sparkfun_photon_temp#VUSB
# schematics_raw_dimensions: 295.4 73.18
# schematics_png_dimensions: 59.08 14.636000000000001
# Dimensions of schematic: 59.08 14.636000000000001
# part_name: U1 part_value:  symbol_name: EFM32GG12B410F1024GL120_A x: 25.240000000000002 y: 32.86 rot: R0 gate: A
# Pad Drawn: pin name: PA0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA4/UART0_RX pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA7 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA8 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USART4_RX/PB8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA9 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA10 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA11 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA12 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA13 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: HFXTAL_P/PB13 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA14 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: HFXTAL_N/PB14 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PA15 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB15 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-15.24', 'y': '25.4', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'top-left', 'text': '>NAME'}, {'x': '-15.24', 'y': '-22.86', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: U1 part_value:  symbol_name: EFM32GG12B410F1024GL120_B x: 105.24000000000001 y: 32.86 rot: R0 gate: B
# Pad Drawn: pin name: PC0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC2/USART2_TX pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC3/USART2_RX pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC4/USART4_CLK pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC5/USART4_CS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC6/I2C0_SDA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC7/I2C0_SCL pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC8 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC9 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC10 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC11 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC12/USART2_CTS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC13 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD13 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC14/USART_RTS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD14 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PC15 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PD15 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-15.24', 'y': '25.4', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'top-left', 'text': '>NAME'}, {'x': '-15.24', 'y': '-22.86', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: U1 part_value:  symbol_name: EFM32GG12B410F1024GL120_C x: 187.78 y: 32.86 rot: R0 gate: C
# Pad Drawn: pin name: PE0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DBG_SWCLK/PF0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DBG_SWDIO/PF1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DBG_SWO/PF2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE7 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE8 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE9 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PF9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE10/USART0_TX pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_N/PF10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE11/USART0_RX pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_P/PF11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE12/USART0_CLK pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_ID/PF12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PE13/USART0_CS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PE14/LEUSART0_TX pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PE15/LEUSART0_RX pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-17.78', 'y': '25.4', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'top-left', 'text': '>NAME'}, {'x': '-17.78', 'y': '-22.86', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: U1 part_value:  symbol_name: EFM32GG12B410F1024GL120_D x: 262.7 y: 25.240000000000002 rot: R0 gate: D
# Pad Drawn: pin name: VREGI pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VREGO pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VBUS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: IOVDD1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: IOVDD0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DVDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DECOUPLE pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: !RESET! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: AVDD pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-12.7', 'y': '15.24', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'top-left', 'text': '>NAME'}, {'x': '-12.7', 'y': '-15.24', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# plt saved
# Kept → Thing_Plus_MGM240P#EFM32GG12B410F1024GL120#EFM32GG12B410F1024GL120_B
# schematics_raw_dimensions: 50.32 45.24
# schematics_png_dimensions: 10.064 9.048
# Dimensions of schematic: 10.064 9.048
# part_name: D1 part_value:  symbol_name: PRTR5V0U2 x: 17.62 y: 17.62 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-7.62', 'y': '7.874', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-7.62', 'y': '-7.874', 'size': '1.778', 'layer': '96', 'align': 'top-left', 'text': '>Value'}]
# plt saved
# Kept → Qwiic GPS-RTK - ublox NEO-M8P#funbit#PRTR5V0U2
# schematics_raw_dimensions: 32.54 32.54
# schematics_png_dimensions: 6.508 6.508
# Dimensions of schematic: 6.508 6.508
# part_name: JP1 part_value:  symbol_name: STAND-OFF x: 0.0 y: 0.0 rot: R0 gate: G$1
# here are the texts: []
# plt saved
# Kept → SparkFun_Tri_Axis_Accel_Breakout-H3LIS331DL#SparkFun#STAND-OFF
# schematics_raw_dimensions: 60.48 47.78
# schematics_png_dimensions: 12.096 9.556000000000001
# Dimensions of schematic: 12.096 9.556000000000001
# part_name: U1 part_value: MPR Series symbol_name: MPR_SERIES_PRESSURE_I2C x: 22.7 y: 20.922 rot: R0 gate: G$1
# here are the texts: [{'x': '-9.144', 'y': '8.128', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-8.89', 'y': '-10.922', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_MicroPressure_Sensor#SparkFun-Sensors#MPR_SERIES_PRESSURE_I2C
# schematics_raw_dimensions: 33.302 31.524
# schematics_png_dimensions: 6.6604 6.3048
# Dimensions of schematic: 6.6604 6.3048
# part_name: TP1 part_value:  symbol_name: TEST-POINT x: 10.0 y: 10.762 rot: R0 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>Value'}]
# plt saved
# Kept → sparkfun-battery-babysitter#SparkFun-Passives#TEST-POINT
# schematics_raw_dimensions: 40.16 40.16
# schematics_png_dimensions: 8.032 8.032
# Dimensions of schematic: 8.032 8.032
# part_name: JP1 part_value:  symbol_name: M03 x: 12.54 y: 15.08 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-2.54', 'y': '-7.62', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '-2.54', 'y': '5.842', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# plt saved
# Kept → Solderable_Breadboard_Large#SparkFun-Connectors#M03
# schematics_raw_dimensions: 155.73000000000002 50.4
# schematics_png_dimensions: 31.146000000000004 10.08
# Dimensions of schematic: 31.146000000000004 10.08
# part_name: 1 part_value: DNP symbol_name: A3L-LOC x: -247.81 y: 6.1899999999999995 rot: R0 gate: G$1
# here are the texts: [{'x': '344.17', 'y': '15.24', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>DRAWING_NAME'}, {'x': '344.17', 'y': '10.16', 'size': '2.286', 'layer': '94', 'font': 'vector', 'text': '>LAST_DATE_TIME'}, {'x': '357.505', 'y': '5.08', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>SHEET'}, {'x': '343.916', 'y': '4.953', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Sheet:'}, {'x': '381', 'y': '25.4', 'size': '1.6764', 'layer': '97', 'rot': 'R90', 'text': 'Reference Designs ARE PROVIDED "AS IS" AND "WITH ALL FAULTS. Arduino SA DISCLAIMS ALL OTHER WARRANTIES, EXPRESS OR IMPLIED,\nREGARDING PRODUCTS, INCLUDING BUT NOT LIMITED TO, ANY IMPLIED WARRANTIES OF MERCHANTABILITY OR FITNESS FOR A PARTICULAR PURPOSE \n\nArduino SA may make changes to specifications and product descriptions at any time, without notice. The Customer must not\nrely on the absence or characteristics of any features or instructions marked "reserved" or "undefined." Arduino SA reserves\nthese for future definition and shall have no responsibility whatsoever for conflicts or incompatibilities arising from future changes to them.\nThe product information on the Web Site or Materials is subject to change without notice. Do not finalize a design with this info\n\nARDUINO and other Arduino brands and logos and Trademarks of Arduino SA. All Arduino SA Trademarks cannot be used without owner\'s formal permission'}, {'x': '256.54', 'y': '25.4', 'size': '1.27', 'layer': '97', 'text': 'This work is licensed under a Creative Commons Attribution-ShareAlike 4.0 International License.'}]
# text content: SHEET:
# text content: REFERENCE DESIGNS ARE PROVIDED "AS IS" AND "WITH ALL FAULTS. ARDUINO SA DISCLAIMS ALL OTHER WARRANTIES, EXPRESS OR IMPLIED,
# REGARDING PRODUCTS, INCLUDING BUT NOT LIMITED TO, ANY IMPLIED WARRANTIES OF MERCHANTABILITY OR FITNESS FOR A PARTICULAR PURPOSE
#
# ARDUINO SA MAY MAKE CHANGES TO SPECIFICATIONS AND PRODUCT DESCRIPTIONS AT ANY TIME, WITHOUT NOTICE. THE CUSTOMER MUST NOT
# RELY ON THE ABSENCE OR CHARACTERISTICS OF ANY FEATURES OR INSTRUCTIONS MARKED "RESERVED" OR "UNDEFINED." ARDUINO SA RESERVES
# THESE FOR FUTURE DEFINITION AND SHALL HAVE NO RESPONSIBILITY WHATSOEVER FOR CONFLICTS OR INCOMPATIBILITIES ARISING FROM FUTURE CHANGES TO THEM.
# THE PRODUCT INFORMATION ON THE WEB SITE OR MATERIALS IS SUBJECT TO CHANGE WITHOUT NOTICE. DO NOT FINALIZE A DESIGN WITH THIS INFO
#
# ARDUINO AND OTHER ARDUINO BRANDS AND LOGOS AND TRADEMARKS OF ARDUINO SA. ALL ARDUINO SA TRADEMARKS CANNOT BE USED WITHOUT OWNER'S FORMAL PERMISSION
# text content: THIS WORK IS LICENSED UNDER A CREATIVE COMMONS ATTRIBUTION-SHAREALIKE 4.0 INTERNATIONAL LICENSE.
# Drawing attribute 'DRAWING_NAME' for part '1'
# Drawing attribute 'LAST_DATE_TIME' for part '1'
# Drawing attribute 'SHEET' for part '1'
# Drawing attribute 'SHEET:' for part '1'
# Drawing attribute 'REFERENCE DESIGNS ARE PROVIDED "AS IS" AND "WITH ALL FAULTS. ARDUINO SA DISCLAIMS ALL OTHER WARRANTIES, EXPRESS OR IMPLIED,
# REGARDING PRODUCTS, INCLUDING BUT NOT LIMITED TO, ANY IMPLIED WARRANTIES OF MERCHANTABILITY OR FITNESS FOR A PARTICULAR PURPOSE
#
# ARDUINO SA MAY MAKE CHANGES TO SPECIFICATIONS AND PRODUCT DESCRIPTIONS AT ANY TIME, WITHOUT NOTICE. THE CUSTOMER MUST NOT
# RELY ON THE ABSENCE OR CHARACTERISTICS OF ANY FEATURES OR INSTRUCTIONS MARKED "RESERVED" OR "UNDEFINED." ARDUINO SA RESERVES
# THESE FOR FUTURE DEFINITION AND SHALL HAVE NO RESPONSIBILITY WHATSOEVER FOR CONFLICTS OR INCOMPATIBILITIES ARISING FROM FUTURE CHANGES TO THEM.
# THE PRODUCT INFORMATION ON THE WEB SITE OR MATERIALS IS SUBJECT TO CHANGE WITHOUT NOTICE. DO NOT FINALIZE A DESIGN WITH THIS INFO
#
# ARDUINO AND OTHER ARDUINO BRANDS AND LOGOS AND TRADEMARKS OF ARDUINO SA. ALL ARDUINO SA TRADEMARKS CANNOT BE USED WITHOUT OWNER'S FORMAL PERMISSION' for part '1'
# Drawing attribute 'THIS WORK IS LICENSED UNDER A CREATIVE COMMONS ATTRIBUTION-SHAREALIKE 4.0 INTERNATIONAL LICENSE.' for part '1'
# plt saved
# Kept → NANOEveryV3.0#Arduino-utility#A3L-LOC
# schematics_raw_dimensions: 40.16 57.94
# schematics_png_dimensions: 8.032 11.588
# Dimensions of schematic: 8.032 11.588
# part_name: JP1 part_value:  symbol_name: M10 x: 10.0 y: 30.32 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-22.86', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '0', 'y': '8.89', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# plt saved
# Kept → SD_MMC Breakout-v20#SparkFun-Connectors#M10
# schematics_raw_dimensions: 42.7 42.699999999999996
# schematics_png_dimensions: 8.540000000000001 8.54
# Dimensions of schematic: 8.540000000000001 8.54
# part_name: 1 part_value:  symbol_name: QRE1113 x: 15.08 y: 15.08 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.778', 'y': '3.048', 'size': '1.778', 'layer': '96', 'text': '>Value'}, {'x': '-1.27', 'y': '-7.112', 'size': '1.778', 'layer': '95', 'text': '>Name'}]
# plt saved
# Kept → QRE1113 Line Sensor Breakout - Analog#Testing#QRE1113
# schematics_raw_dimensions: 57.94 57.94
# schematics_png_dimensions: 11.588 11.588
# Dimensions of schematic: 11.588 11.588
# /var/folders/tl/q2dlpcnd685cw606gn_pd05h0000gn/T/ipykernel_38471/3723974411.py:1313: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(figsize=(x, y), dpi=100)  # Create figure and axes
# part_name: IC1 part_value: MAX98357A symbol_name: MAX98357A x: 20.16 y: 25.240000000000002 rot: R0 gate: G$1
# here are the texts: [{'x': '-10.16', 'y': '13.462', 'size': '1.27', 'layer': '95', 'text': '>NAME'}, {'x': '-10.16', 'y': '-17.78', 'size': '1.27', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_I2S_Audio_Breakout#SparkFun-IC-Amplifiers#MAX98357A
# schematics_raw_dimensions: 40.16 32.032
# schematics_png_dimensions: 8.032 6.4064
# Dimensions of schematic: 8.032 6.4064
# part_name: R1 part_value: 6.49k symbol_name: R-US x: 12.54 y: 11.016 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.81', 'y': '1.4986', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-3.81', 'y': '-3.302', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → MyoWare_LED_Shield#resistor#R-US
# schematics_raw_dimensions: 345.24 52.86
# schematics_png_dimensions: 69.048 10.572
# Dimensions of schematic: 69.048 10.572
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT0 x: 17.62 y: 22.954 rot: R0 gate: G1
# Pad Drawn: pin name: P0.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.7 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT1 x: 77.62 y: 22.954 rot: R0 gate: G2
# Pad Drawn: pin name: P1.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.4 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT2 x: 137.62 y: 22.954 rot: R0 gate: G3
# Pad Drawn: pin name: P2.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.7 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT3 x: 197.62 y: 22.954 rot: R0 gate: G4
# Pad Drawn: pin name: P3.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.7 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT4 x: 257.62 y: 22.954 rot: R0 gate: G5
# Pad Drawn: pin name: P4.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P4.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P4.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P4.3 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_POWER x: 317.62 y: 22.954 rot: R0 gate: G6
# Pad Drawn: pin name: VCCD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VREF pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSSA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: XRES pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# plt saved
# Kept → SparkFun_Qwiic_Motor_Driver#SparkFun-IC-Microcontroller#CY8C4245LQI_40QFN_PORT3
# schematics_raw_dimensions: 98.382 45.24
# schematics_png_dimensions: 19.6764 9.048
# Dimensions of schematic: 19.6764 9.048
# part_name: U1 part_value: 74HC1G04 symbol_name: GATE_INVERTER x: 12.54 y: 17.62 rot: R0 gate: G1
# Pad Drawn: pin name: Y pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: A pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-2.54', 'y': '5.842', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-2.54', 'y': '-7.62', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>VALUE'}]
# part_name: U1 part_value: 74HC1G04 symbol_name: POWER_CONSORT x: 73.30199999999999 y: 15.08 rot: R0 gate: G2
# Pad Drawn: pin name: P$V+ pin_angle_deg_final: 270.0 ha: right va: center
# 270 de pin/pad: left center
# Pad Drawn: pin name: P$V- pin_angle_deg_final: 90.0 ha: left va: center
# here are the texts: [{'x': '-3.302', 'y': '-5.08', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '5.08', 'y': '-5.08', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>VALUE'}, {'x': '0.127', 'y': '-4.699', 'size': '1.27', 'layer': '94', 'font': 'vector', 'align': 'bottom-center', 'text': 'VEE'}, {'x': '0.127', 'y': '3.429', 'size': '1.27', 'layer': '94', 'font': 'vector', 'align': 'bottom-center', 'text': 'VCC'}]
# text content: VEE
# text content: VCC
# Drawing attribute 'VEE' for part 'U1'
# Drawing attribute 'VCC' for part 'U1'
# plt saved
# Kept → Qwiic Power Switch#SparkFun-IC-Logic#POWER_CONSORT
# schematics_raw_dimensions: 52.86 50.32
# schematics_png_dimensions: 10.572 10.064
# Dimensions of schematic: 10.572 10.064
# part_name: U1 part_value: MAX17048 symbol_name: MAX17048 x: 20.16 y: 22.7 rot: R0 gate: U1
# here are the texts: [{'x': '-10.16', 'y': '10.668', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-10.16', 'y': '-12.7', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# plt saved
# Kept → SparkFun_Thing_Plus_RP2350#SparkFun-IC-Power#MAX17048
# schematics_raw_dimensions: 45.24 57.94
# schematics_png_dimensions: 9.048 11.588
# Dimensions of schematic: 9.048 11.588
# part_name: J1 part_value:  symbol_name: MICROSD x: 15.08 y: 22.7 rot: R0 gate: J1
# here are the texts: [{'x': '-5.08', 'y': '15.748', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-5.08', 'y': '-15.24', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → LCD_TFT_Breakout_1in8_128x160#SparkFun-Connectors#MICROSD
# schematics_raw_dimensions: 45.24 65.56
# schematics_png_dimensions: 9.048 13.112
# Dimensions of schematic: 9.048 13.112
# part_name: 1 part_value: MICRO-SD symbol_name: MICRO-SD-CARD x: 17.62 y: 27.78 rot: R0 gate: G$1
# Pad Drawn: pin name: NC pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: CS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DI pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCC pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SCK pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: DO pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: RSV pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: CD1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: CD2 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '10.16', 'y': '0', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '10.16', 'y': '2.54', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# plt saved
# Kept → touch-board-ks-edition#BareConductive#MICRO-SD-CARD
# schematics_raw_dimensions: 40.16 40.16
# schematics_png_dimensions: 8.032 8.032
# Dimensions of schematic: 8.032 8.032
# part_name: J1 part_value:  symbol_name: CONN_03 x: 12.54 y: 17.366 rot: R0 gate: J$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-2.54', 'y': '-7.366', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '-2.54', 'y': '5.588', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# plt saved
# Kept → SparkFun_ProtoShield_Kit_rev40#SparkFun-Connectors#CONN_03
# schematics_raw_dimensions: 42.7 50.32
# schematics_png_dimensions: 8.540000000000001 10.064
# Dimensions of schematic: 8.540000000000001 10.064
# part_name: LS1 part_value: CVS-1508 symbol_name: SPEAKER x: 15.08 y: 20.16 rot: R0 gate: G$1
# Pad Drawn: pin name: + pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: - pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '2.54', 'y': '5.334', 'size': '1.27', 'layer': '95', 'font': 'vector', 'rot': 'MR0', 'text': '>NAME'}, {'x': '2.54', 'y': '-5.334', 'size': '1.27', 'layer': '96', 'font': 'vector', 'rot': 'R180', 'text': '>VALUE'}]
# plt saved
# Kept → Top pHAT#SparkFun-Electromechanical#SPEAKER
# schematics_raw_dimensions: 31.524 32.54
# schematics_png_dimensions: 6.3048 6.508
# Dimensions of schematic: 6.3048 6.508
# part_name: SUPPLY1 part_value:  symbol_name: VCCIO x: 10.762 y: 8.73 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'bottom-center', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_MicroMod_Function_SARA-R5#SparkFun-PowerSymbols#VCCIO
# schematics_raw_dimensions: 33.302 31.524
# schematics_png_dimensions: 6.6604 6.3048
# Dimensions of schematic: 6.6604 6.3048
# part_name: TP1 part_value:  symbol_name: TEST-POINT x: 12.54 y: 12.54 rot: R0 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# plt saved
# Kept → SAMD51_Thing_Plus#SparkFun-Connectors#TEST-POINT
# schematics_raw_dimensions: 35.08 31.27
# schematics_png_dimensions: 7.016 6.254
# Dimensions of schematic: 7.016 6.254
# part_name: 1 part_value:  symbol_name: INDUCTOR x: 12.54 y: 10.0 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '-2.54', 'y': '5.08', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# plt saved
# Kept → touch-board-ks-edition#BareConductive#INDUCTOR
# schematics_raw_dimensions: 45.24 40.16
# schematics_png_dimensions: 9.048 8.032
# Dimensions of schematic: 9.048 8.032
# part_name: 1 part_value: IP20(RJ50) symbol_name: CONN_02 x: 15.08 y: 15.841999999999999 rot: R0 gate: G$1
# here are the texts: [{'x': '1.016', 'y': '-5.842', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}, {'x': '1.27', 'y': '5.588', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}]
# plt saved
# Kept → SparkFun_MicroMod_Function_ADIN1110#ADIN1110#CONN_02
# schematics_raw_dimensions: 36.604 39.397999999999996
# schematics_png_dimensions: 7.3208 7.879599999999999
# Dimensions of schematic: 7.3208 7.879599999999999
# part_name: Y1 part_value: 16MHz symbol_name: RESONATOR x: 13.302 y: 17.62 rot: R0 gate: G$1
# here are the texts: [{'x': '2.54', 'y': '1.016', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '2.54', 'y': '-7.62', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → MicroView#microView-temp#RESONATOR
# schematics_raw_dimensions: 220.16 32.032
# schematics_png_dimensions: 44.032 6.4064
# Dimensions of schematic: 44.032 6.4064
# part_name: R1 part_value: 33 symbol_name: RESISTOR x: 12.54 y: 11.524000000000001 rot: R0 gate: A
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R1 part_value: 33 symbol_name: RESISTOR x: 72.53999999999999 y: 11.524000000000001 rot: R0 gate: B
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R1 part_value: 33 symbol_name: RESISTOR x: 132.54 y: 11.524000000000001 rot: R0 gate: C
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R1 part_value: 33 symbol_name: RESISTOR x: 192.54 y: 11.524000000000001 rot: R0 gate: D
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_ZED-F9R_v12_uFL#SparkFun-Resistors#RESISTOR
# schematics_raw_dimensions: 31.524 32.54
# schematics_png_dimensions: 6.3048 6.508
# Dimensions of schematic: 6.3048 6.508
# part_name: SUPPLY1 part_value:  symbol_name: 3.3V x: 10.762 y: 8.73 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → SAMD51_Thing_Plus#SparkFun-Aesthetics#3.3V
# schematics_raw_dimensions: 45.24 37.620000000000005
# schematics_png_dimensions: 9.048 7.524000000000001
# Dimensions of schematic: 9.048 7.524000000000001
# part_name: SW1 part_value:  symbol_name: SW_DIP-2 x: 15.08 y: 15.08 rot: R0 gate: G$1
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-5.08', 'y': '3.175', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-5.08', 'y': '-7.62', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '4.826', 'y': '-2.667', 'size': '1.27', 'layer': '94', 'ratio': '10', 'rot': 'R90', 'text': '1'}, {'x': '4.826', 'y': '-0.381', 'size': '1.27', 'layer': '94', 'ratio': '10', 'rot': 'R90', 'text': '2'}, {'x': '-3.556', 'y': '-4.699', 'size': '1.27', 'layer': '94', 'ratio': '10', 'rot': 'R90', 'text': 'ON'}]
# text content: 1
# text content: 2
# text content: ON
# Drawing attribute '1' for part 'SW1'
# Drawing attribute '2' for part 'SW1'
# Drawing attribute 'ON' for part 'SW1'
# plt saved
# Kept → sparkfun-battery-babysitter#SparkFun-Electromechanical#SW_DIP-2
# schematics_raw_dimensions: 55.4 65.56
# schematics_png_dimensions: 11.08 13.112
# Dimensions of schematic: 11.08 13.112
# part_name: U1 part_value: AS7331 symbol_name: AS7331 x: 20.16 y: 30.32 rot: R0 gate: G$1
# here are the texts: [{'x': '-10.16', 'y': '18.288', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-10.16', 'y': '-20.32', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_Qwiic_Mini_UV_Sensor_AS7331#SparkFun_Qwiic_UV_Sensor_AS7331#AS7331
# schematics_raw_dimensions: 40.16 31.27
# schematics_png_dimensions: 8.032 6.254
# Dimensions of schematic: 8.032 6.254
# part_name: SJ1 part_value:  symbol_name: SJ x: 12.54 y: 10.635 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-2.54', 'y': '-5.08', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → Wireless_Motor_Driver_Shield#SparkFun-Retired#SJ
# schematics_raw_dimensions: 60.48 40.16
# schematics_png_dimensions: 12.096 8.032
# Dimensions of schematic: 12.096 8.032
# part_name: LED1 part_value: TRICOLOR-5050 symbol_name: LED-TRICOLOR-INDV x: 22.7 y: 15.08 rot: R0 gate: D1
# here are the texts: [{'x': '-12.7', 'y': '5.842', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-12.7', 'y': '-7.62', 'size': '1.778', 'layer': '95', 'text': '>VALUE'}]
# plt saved
# Kept → LP55231_breakout#SparkFun-LED#LED-TRICOLOR-INDV
# schematics_raw_dimensions: 40.16 37.620000000000005
# schematics_png_dimensions: 8.032 7.524000000000001
# Dimensions of schematic: 8.032 7.524000000000001
# part_name: BAT1 part_value: CR2032 symbol_name: BATTERY x: 12.54 y: 13.81 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.81', 'y': '5.08', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-3.81', 'y': '-6.35', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → LilyMini_Protosnap#mike-temp#BATTERY
# schematics_raw_dimensions: 36.096000000000004 45.24
# schematics_png_dimensions: 7.219200000000001 9.048
# Dimensions of schematic: 7.219200000000001 9.048
# part_name: RV1 part_value: 10k symbol_name: POT x: 11.016 y: 15.08 rot: R0 gate: G$1
# here are the texts: [{'x': '5.08', 'y': '-10.16', 'size': '1.778', 'layer': '95', 'rot': 'R90', 'text': '>NAME'}, {'x': '-2.54', 'y': '-10.16', 'size': '1.778', 'layer': '95', 'rot': 'R90', 'text': '>Value'}]
# plt saved
# Kept → SparkFun_MIDI_Shield#SparkFun-Electromechanical#POT
# schematics_raw_dimensions: 345.24 52.86
# schematics_png_dimensions: 69.048 10.572
# Dimensions of schematic: 69.048 10.572
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT0 x: 17.62 y: 22.954 rot: R0 gate: G1
# Pad Drawn: pin name: P0.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P0.7 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT1 x: 77.62 y: 22.954 rot: R0 gate: G2
# Pad Drawn: pin name: P1.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P1.4 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT2 x: 137.62 y: 22.954 rot: R0 gate: G3
# Pad Drawn: pin name: P2.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P2.7 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT3 x: 197.62 y: 22.954 rot: R0 gate: G4
# Pad Drawn: pin name: P3.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P3.7 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_PORT4 x: 257.62 y: 22.954 rot: R0 gate: G5
# Pad Drawn: pin name: P4.0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P4.1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P4.2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: P4.3 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# part_name: U1 part_value: CY8C4245LQI-483 symbol_name: CY8C4245LQI_40QFN_POWER x: 317.62 y: 22.954 rot: R0 gate: G6
# Pad Drawn: pin name: VCCD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VREF pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSSA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: XRES pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-7.62', 'y': '-12.954', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>Value'}, {'x': '-7.366', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}]
# plt saved
# Kept → SparkFun_Qwiic_Motor_Driver#SparkFun-IC-Microcontroller#CY8C4245LQI_40QFN_PORT2
# schematics_raw_dimensions: 45.24 45.24
# schematics_png_dimensions: 9.048 9.048
# Dimensions of schematic: 9.048 9.048
# part_name: K1 part_value: 25A Solid State Relay symbol_name: SOLIDSTATE_RELAY x: 17.62 y: 20.16 rot: R0 gate: G$1
# Pad Drawn: pin name: + pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: - pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: ~AC2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: ~AC1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-7.62', 'y': '8.128', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-7.62', 'y': '-10.16', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# plt saved
# Kept → Qwiic Dual Solid State Relay#SparkFun-DiscreteSemi#SOLIDSTATE_RELAY
# schematics_raw_dimensions: 31.524 32.54
# schematics_png_dimensions: 6.3048 6.508
# Dimensions of schematic: 6.3048 6.508
# part_name: SUPPLY1 part_value:  symbol_name: 1.8V x: 10.762 y: 8.73 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun_MAX30101_Qwiic#SparkFun-Aesthetics#1.8V
# schematics_raw_dimensions: 40.16 47.78
# schematics_png_dimensions: 8.032 9.556000000000001
# Dimensions of schematic: 8.032 9.556000000000001
# part_name: S1 part_value:  symbol_name: SWITCH-DPDT x: 12.54 y: 20.414 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-10.414', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# plt saved
# Kept → RedBoard_Plus#SparkFun-Switches#SWITCH-DPDT
# schematics_raw_dimensions: 65.56 85.88
# schematics_png_dimensions: 13.112 17.176
# Dimensions of schematic: 13.112 17.176
# part_name: OLED1 part_value:  symbol_name: OLED0.66 x: 27.78 y: 41.242000000000004 rot: R0 gate: G1
# Pad Drawn: pin name: !CS! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: !RESET! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: BS1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: BS2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: C1N pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: C1P pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: C2N pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: C2P pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: D/!C! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D0/SCK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D1/MOSI pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: E/!RD! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND@1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND@2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: IREF pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: R/!W! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VBAT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCC pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCOMH pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VLSS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSS pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '0', 'y': '0', 'size': '2.54', 'layer': '94', 'font': 'vector', 'align': 'center', 'text': 'OLED'}, {'x': '0', 'y': '25.908', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>Name'}, {'x': '0', 'y': '-31.242', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>Value'}]
# text content: OLED
# Drawing attribute 'OLED' for part 'OLED1'
# plt saved
# Kept → Qwiic_OLED_Breakout#SparkFun-Displays#OLED0.66
# schematics_raw_dimensions: 40.16 37.62
# schematics_png_dimensions: 8.032 7.523999999999999
# Dimensions of schematic: 8.032 7.523999999999999
# part_name: JP1 part_value:  symbol_name: M02 x: 12.54 y: 12.54 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-2.54', 'y': '-5.08', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '-2.54', 'y': '5.842', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# plt saved
# Kept → Solderable_Breadboard_Large#SparkFun-Connectors#M02
# schematics_raw_dimensions: 60.480000000000004 57.94
# schematics_png_dimensions: 12.096 11.588
# Dimensions of schematic: 12.096 11.588
# part_name: U1 part_value:  symbol_name: SPARKX_VCNL4040 x: 25.240000000000002 y: 28.034 rot: R0 gate: U1
# Pad Drawn: pin name: ANODE pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: CATHODE_LED pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: CATHODE_SEN pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: INT pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SCL pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SDA pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VDD pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-15.24', 'y': '12.954', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-15.24', 'y': '-18.034', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# plt saved
# Kept → Qwiic Proximity Sensor - VCNL4040#SparkFun-Sensors#SPARKX_VCNL4040
# schematics_raw_dimensions: 31.524 32.54
# schematics_png_dimensions: 6.3048 6.508
# Dimensions of schematic: 6.3048 6.508
# part_name: SUPPLY1 part_value:  symbol_name: 5V x: 10.762 y: 8.73 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# plt saved
# Kept → SparkFun ESP32 Thing Plus DMX to LED Shield#SparkFun-PowerSymbols#5V
# schematics_raw_dimensions: 33.81 32.54
# schematics_png_dimensions: 6.7620000000000005 6.508
# Dimensions of schematic: 6.7620000000000005 6.508
# part_name: GND1 part_value:  symbol_name: GND x: 0.0 y: 0.0 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# plt saved
# Kept → touch-board-ks-edition#supply1#GND
# schematics_raw_dimensions: 57.94 68.1
# schematics_png_dimensions: 11.588 13.62
# Dimensions of schematic: 11.588 13.62
# part_name: U1 part_value: NEO-M8P symbol_name: NEO-M8P x: 22.7 y: 30.32 rot: R0 gate: U1
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCC pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: !RST pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: INT pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SDA/SPI_!CS! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SCL/SPI_CLK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TX/SPI_MISO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: RX/SPI_MOSI pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: LNA_EN pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: RTK_STAT pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GEO_STAT pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: V_BKCP pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: RF_IN pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCC_RF pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDD_USB pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_D+ pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_D- pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: TIMEPULSE pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D_SEL pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: !SAFEBOOT! pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-12.7', 'y': '18.288', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-12.7', 'y': '-22.86', 'size': '1.778', 'layer': '96', 'text': '>Value'}]
# plt saved
# Kept → Qwiic GPS-RTK - ublox NEO-M8P#NEO-M8P#NEO-M8P

# %% [markdown]
# ### Generate yaml file for yolo training

# %%
import yaml

dataset_root = "/Users/linkaiyuan/文件/PSU/yolo_training_22"
data_yaml_path = os.path.join(dataset_root, "data.yaml")

index_to_name = {v: k for k, v in class_map.items()} 

data_yaml = {
    "path": "/Users/linkaiyuan/文件/PSU/yolo_training_22/dataset",
    "train": "train",
    "val": "val",
    "names": index_to_name
}

with open("/Users/linkaiyuan/文件/PSU/yolo_training_22/data.yaml", "w") as f:
    yaml.dump(data_yaml, f, sort_keys=False, allow_unicode=True)

# %% [markdown]
# ### generate Images for full sch files

# %%
import glob
import os

folder_path       = r"/Users/linkaiyuan/文件/PSU/products"
save_path         = r"/Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/images"
# save_path         = r"/Users/linkaiyuan/文件/PSU/problem_image_debug/"
label_file_path   = r"/Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels"
count             = 0
sch_store_dir = r"/Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/sch"


paths = [
        folder_path,
        save_path,
        label_file_path,
        sch_store_dir
    ]

for p in (folder_path, save_path, label_file_path, sch_store_dir):
    if not os.path.isdir(p):
        os.makedirs(p, exist_ok=True)
        print(f"   → Created: {p}")
    else:
        print(f"✅ Directory exists: {p}")

for sch_file in glob.glob(os.path.join(folder_path, "**", "*.sch"), recursive=True):
    label_file = ""
    if count > 50:
        break
    count += 1
    
    try:
        # parse schematic and get its full‐sheet bounds
        schematic_info = process_schematic_file(sch_file)
        src_xlim, src_ylim = get_schematic_bounding_box_from_schematic_info(schematic_info)

        # render and save
        png_path = os.path.join(save_path, os.path.basename(sch_file).replace(".sch", ".png"))
        sch_file_path = os.path.join(sch_store_dir, os.path.basename(sch_file))
        sizes    = visualize_schematic(sch_file, png_path)
        px_per_x, px_per_y, _, _, img_w, img_h = sizes

        # skip blank images
        if is_blank_image(png_path):
            print(f"Blank → removing {os.path.basename(png_path)}")
            os.remove(png_path)
            continue
        else:
            print(f"Kept → {os.path.basename(png_path)}")
            shutil.copy(sch_file, sch_file_path)

        ic_library = schematic_info.get('IC_library')
        parts_info = schematic_info.get('parts')
        if not parts_info or not ic_library:
            continue

        # loop over each part instance
        for part_name, part_data in parts_info.items():
            for instance in part_data.get('instances', []):
                symbol_element = get_symbol_element_of_instance_from_library(
                    ic_library, part_name, instance.get('gate', ''), parts_info
                )
                if not symbol_element:
                    continue

                # get this symbol’s world‐space bbox
                rot_inst = instance['rot']
                x_inst   = float(instance['x'])
                y_inst   = float(instance['y'])
                (x0, x1), (y0, y1) = get_bounding_box_for_symbol_instance(
                    symbol_element, x_inst, y_inst, rot_inst
                )

                # convert to pixels
                w_px  = (x1 - x0) * px_per_x
                h_px  = (y1 - y0) * px_per_y
                cx_px = ((x0 + x1)/2 - src_xlim[0]) * px_per_x
                cy_px = ((y0 + y1)/2 - src_ylim[0]) * px_per_y

                # normalize for YOLO (flip y so origin is top‐left)
                norm_x_center = cx_px / img_w
                norm_y_center = 1.0 - (cy_px / img_h)
                norm_width    = w_px    / img_w
                norm_height   = h_px    / img_h

                # lookup class
                lib          = part_data['library']
                symbol       = instance['symbol']
                base_name    = os.path.splitext(os.path.basename(sch_file))[0]
                key          = f"{base_name}_{lib}_{symbol}"
                class_number = class_map.get(key, -1)
                if class_number == -1:
                    continue

                label_file += f"{class_number} {norm_x_center:.6f} {norm_y_center:.6f} {norm_width:.6f} {norm_height:.6f}\n"

        # write out labels
        label_filename = os.path.join(label_file_path, os.path.basename(sch_file).replace(".sch", ".txt"))
        print("label_filename:", label_filename)
        print("label_file:", label_file)
        with open(label_filename, "w") as f:
            f.write(label_file)
            print("label_filename:", label_filename)

    except Exception as e:
        print(f"Skipping {sch_file} due to error: {e}")
        continue
# Out:
# ✅ Directory exists: /Users/linkaiyuan/文件/PSU/products
# ✅ Directory exists: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/images
# ✅ Directory exists: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels
#    → Created: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/sch
# schematics_raw_dimensions: 613.7 309.4
# schematics_png_dimensions: 122.74000000000001 61.879999999999995
# Dimensions of schematic: 122.74000000000001 61.879999999999995
# part_name: S1 part_value: RESET symbol_name: SWITCH-MOMENTARY x: 294.64 y: 38.1 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '0', 'y': '4.826', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-2.794', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND1 part_value:  symbol_name: DGND x: 287.02 y: 33.02 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: FRAME1 part_value:  symbol_name: FRAME_LEDGER x: 0.0 y: 0.0 rot: R0 gate: G$1
# here are the texts: []
# part_name: FRAME1 part_value:  symbol_name: DOCFIELD x: 330.2 y: 0.0 rot: R0 gate: G$2
# here are the texts: [{'x': '1.27', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Date:'}, {'x': '12.7', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>LAST_DATE_TIME'}, {'x': '72.39', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Sheet:'}, {'x': '86.36', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>SHEET'}, {'x': '88.9', 'y': '11.43', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'REV:'}, {'x': '1.524', 'y': '17.78', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'TITLE:'}, {'x': '15.494', 'y': '17.78', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DRAWING_NAME'}, {'x': '2.54', 'y': '31.75', 'size': '1.9304', 'layer': '94', 'text': 'Released under the Creative Commons'}, {'x': '2.54', 'y': '27.94', 'size': '1.9304', 'layer': '94', 'text': 'Attribution Share-Alike 4.0 License'}, {'x': '2.54', 'y': '24.13', 'size': '1.9304', 'layer': '94', 'text': 'https://creativecommons.org/licenses/by-sa/4.0/'}, {'x': '1.27', 'y': '11.43', 'size': '2.54', 'layer': '94', 'text': 'Design by:'}, {'x': '23.114', 'y': '11.176', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DESIGNER'}, {'x': '88.9', 'y': '6.604', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>REV'}]
# text content: DATE:
# text content: SHEET:
# text content: REV:
# text content: TITLE:
# text content: RELEASED UNDER THE CREATIVE COMMONS
# text content: ATTRIBUTION SHARE-ALIKE 4.0 LICENSE
# text content: HTTPS://CREATIVECOMMONS.ORG/LICENSES/BY-SA/4.0/
# text content: DESIGN BY:
# part_name: GND26 part_value:  symbol_name: DGND x: 386.08 y: 226.06 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND15 part_value:  symbol_name: DGND x: 81.28 y: 220.98 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: C7 part_value: 1.0uF symbol_name: CAP x: 50.8 y: 228.6 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C10 part_value: 2.2uF symbol_name: CAP x: 109.22 y: 228.6 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND21 part_value:  symbol_name: DGND x: 109.22 y: 220.98 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND14 part_value:  symbol_name: DGND x: 50.8 y: 220.98 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: U1 part_value:  symbol_name: MCP73831 x: 215.9 y: 243.84 rot: R0 gate: G$1
# Pad Drawn: pin name: VIN pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: STAT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VBAT pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PROG pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VSS pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-7.62', 'y': '5.588', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-7.62', 'y': '-7.62', 'size': '1.778', 'layer': '96', 'text': '>Value'}]
# part_name: GND9 part_value:  symbol_name: DGND x: 228.6 y: 226.06 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND11 part_value:  symbol_name: DGND x: 238.76 y: 226.06 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND12 part_value:  symbol_name: DGND x: 248.92 y: 226.06 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: C6 part_value: 4.7uF symbol_name: CAP x: 248.92 y: 241.3 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: D2 part_value: 1A/23V/620mV symbol_name: DIODE-SCHOTTKY x: 27.94 y: 236.22 rot: R0 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.032', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-2.54', 'y': '-2.032', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: R7 part_value: 10k symbol_name: RESISTOR x: 17.78 y: 233.68 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND13 part_value:  symbol_name: DGND x: 17.78 y: 220.98 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY7 part_value:  symbol_name: VIN x: 48.26 y: 251.46 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND4 part_value:  symbol_name: DGND x: 261.62 y: 226.06 rot: MR0 gate: 1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: D1 part_value: Yellow symbol_name: LED x: 203.2 y: 233.68 rot: R180 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: R3 part_value: 1K symbol_name: RESISTOR x: 195.58 y: 238.76 rot: R270 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: U3 part_value: AP2112K-3.3V symbol_name: V-REG-LDO x: 93.98 y: 231.14 rot: R0 gate: G$1
# here are the texts: [{'x': '-7.62', 'y': '9.144', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-7.62', 'y': '-11.43', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: Q1 part_value: 2.5A/30V symbol_name: MOSFET-PCHANNEL x: 33.02 y: 243.84 rot: R0 gate: G$1
# here are the texts: [{'x': '5.08', 'y': '2.54', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '5.08', 'y': '0', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '-1.27', 'y': '2.54', 'size': '0.8128', 'layer': '93', 'text': 'D'}, {'x': '-1.27', 'y': '-3.556', 'size': '0.8128', 'layer': '93', 'text': 'S'}, {'x': '-5.08', 'y': '-1.27', 'size': '0.8128', 'layer': '93', 'text': 'G'}]
# text content: D
# text content: S
# text content: G
# part_name: R6 part_value: 2.0k symbol_name: RESISTOR x: 238.76 y: 236.22 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY14 part_value:  symbol_name: V_USB x: 388.62 y: 243.84 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY22 part_value:  symbol_name: V_USB x: 17.78 y: 251.46 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY25 part_value:  symbol_name: V_BATT x: 261.62 y: 251.46 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY27 part_value:  symbol_name: V_BATT x: 33.02 y: 251.46 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: C19 part_value: 4.7uF symbol_name: CAP x: 187.96 y: 236.22 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: SUPPLY23 part_value:  symbol_name: V_USB x: 187.96 y: 251.46 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND41 part_value:  symbol_name: DGND x: 187.96 y: 226.06 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY8 part_value:  symbol_name: 3.3V x: 104.14 y: 251.46 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: D4 part_value: BLUE symbol_name: LED x: 226.06 y: 40.64 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: R8 part_value: 330 symbol_name: RESISTOR x: 226.06 y: 27.94 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND37 part_value:  symbol_name: DGND x: 226.06 y: 17.78 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: LOGO2 part_value: OSHW-LOGOMINI symbol_name: OSHW-LOGO x: 243.84 y: 10.16 rot: R0 gate: G$1
# here are the texts: []
# part_name: FD1 part_value: FIDUCIALUFIDUCIAL symbol_name: FIDUCIAL x: 429.26 y: 27.94 rot: R0 gate: G$1
# here are the texts: []
# part_name: FD2 part_value: FIDUCIALUFIDUCIAL symbol_name: FIDUCIAL x: 426.72 y: 25.4 rot: R0 gate: G$1
# here are the texts: []
# part_name: J3 part_value:  symbol_name: I2C_STANDARD x: 271.78 y: 149.86 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-5.08', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-5.08', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-4.572', 'y': '2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SDA'}, {'x': '-4.572', 'y': '0', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'VCC'}, {'x': '-4.572', 'y': '-2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'GND'}, {'x': '-4.572', 'y': '5.08', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SCL'}]
# text content: SDA
# text content: VCC
# text content: GND
# text content: SCL
# part_name: SUPPLY1 part_value:  symbol_name: 3.3V x: 281.94 y: 177.8 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND6 part_value:  symbol_name: DGND x: 281.94 y: 142.24 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: FD3 part_value: FIDUCIALUFIDUCIAL symbol_name: FIDUCIAL x: 429.26 y: 25.4 rot: R0 gate: G$1
# here are the texts: []
# part_name: FD4 part_value: FIDUCIALUFIDUCIAL symbol_name: FIDUCIAL x: 426.72 y: 27.94 rot: R0 gate: G$1
# here are the texts: []
# part_name: U2 part_value:  symbol_name: ATSAMD51J20 x: 119.38 y: 121.92 rot: R0 gate: G$1
# Pad Drawn: pin name: PA00 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA01 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA02 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA03 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA04 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA05 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA06 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA07 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA08 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA09 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA10 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA11 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA12 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA13 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA14 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA15 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA16 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA17 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA18 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA19 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA20 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA21 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA22 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA23 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA24 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA25 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA27 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA30 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PA31 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: PB00 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB01 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB02 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB03 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB04 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB05 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB06 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB07 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB08 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB09 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB13 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB14 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB15 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB16 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB17 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB22 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB23 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB30 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PB31 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VDDIO3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDIO2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDIO1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDIO0 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDCORE pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VSW pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: !RESET pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VDDANA pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-12.7', 'y': '25.4', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT0, SERCOM1_0, TC2_WO0, XIN32'}, {'x': '-12.7', 'y': '22.86', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT1, SERCOM1_1, TC2_WO1, XOUT32'}, {'x': '-12.7', 'y': '20.32', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT2, ADC0_0, DAC_0'}, {'x': '-12.7', 'y': '17.78', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT3, VREFA, ADC0_1, X0/Y0'}, {'x': '-12.7', 'y': '15.24', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT4, VREFB, ADC0_4, AC_0, \nX3/Y3, SERCOM0_0, TC0_WO0'}, {'x': '-12.7', 'y': '12.7', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT5, ADC0_5, AC_1, DAC_1, \nSERCOM0_1, TC0_WO1'}, {'x': '-12.7', 'y': '10.16', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT6, VREFC, ADC0_6, AC_2,\nX4/Y4, SERCOM0_2, TC1_WO0'}, {'x': '-12.7', 'y': '7.62', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT7, ADC0_7, AC_3, X5/Y5,\nSERCOM0_3, TC1_WO1'}, {'x': '-12.7', 'y': '2.54', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'EICNMI, ADC0_8, ADC1_2, X6/Y6,\nSERCOM0_0, SERCOM2_1, TC0_WO0,\nTCC0_WO0, TCC1_WO4'}, {'x': '-12.7', 'y': '0', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT9, ADC0_9, ADC1_3, X7/Y7,\nSERCOM0_1, SERCOM2_0, TC0_WO1,\nTCC0_WO1, TCC1_WO5'}, {'x': '-12.7', 'y': '-2.54', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT10, ADC0_10, X8/Y8, \nSERCOM0_2, SERCOM2_2, TC1_WO0,\nTCC0_WO2, TCC1_WO6'}, {'x': '-12.7', 'y': '-5.08', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT11, ADC0_11, X9/Y9, SERCOM0_3,\nSERCOM2_3, TC1_WO1, TCC0_WO3, \nTCC1_WO7'}, {'x': '-12.7', 'y': '-7.62', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT12, SERCOM2_0, SERCOM4_1, \nTC2_WO0, TCC0_WO6, TCC1_WO2'}, {'x': '-12.7', 'y': '-10.16', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT13, SERCOM2_1, SERCOM4_0, \nTC2_WO1, TCC0_WO7, TCC1_WO3'}, {'x': '-12.7', 'y': '-12.7', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT14, SERCOM2_2, SERCOM4_2, \nTC3_WO0, TCC2_WO0, TCC1_WO2, XIN'}, {'x': '-12.7', 'y': '-15.24', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT15, SERCOM2_3, SERCOM4_3, \nTC3_WO1, TCC2_WO1, TCC1_WO3, XOUT'}, {'x': '-12.7', 'y': '-20.32', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT0, X10/Y10, SERCOM1_0, SERCOM3_1,\nTC2_WO0, TCC1_WO0, TCC0_WO4'}, {'x': '-12.7', 'y': '-22.86', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT1, X11/Y11, SERCOM1_1, SERCOM3_0, \nTC2_WO1, TCC0_WO7, TCC1_WO3'}, {'x': '-12.7', 'y': '-25.4', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT2, X12/Y12, SERCOM1_2, SERCOM3_2, \nTC3_WO0, TCC1_WO2, TCC0_WO6'}, {'x': '-12.7', 'y': '-27.94', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT3, X13/Y13, SERCOM1_3, SECOM3_3, \nTC3_WO1, TCC1_WO3, TCC0_WO7'}, {'x': '-12.7', 'y': '-30.48', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT4, X14/Y14, SERCOM5_2, SERCOM3_2, \nTC7_WO0, TCC1_WO4, TCC0_WO0'}, {'x': '-12.7', 'y': '-33.02', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT5, X15/Y15, SERCOM5_3, SERCOM3_3, \nTC7_WO1, TCC1_WO5, TCC0_WO1'}, {'x': '-12.7', 'y': '-35.56', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT6, X16/Y16, SERCOM3_0, SERCOM5_1, \nTC4_WO0, TCC1_WO6, TCC0_WO2'}, {'x': '-12.7', 'y': '-38.1', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT7, X17/Y17, SERCOM3_1, SERCOM5_0, \nTC4_WO1, TCC1_WO7, TCC0_WO3'}, {'x': '-12.7', 'y': '-43.18', 'size': '0.508', 'layer': '95', 'align': 'center-left', 'text': 'INT8, SERCOM3_2, SERCOM5_2, TC4_WO0, \nTCC2_WO2, USB_DM'}, {'x': '-12.7', 'y': '-45.72', 'size': '0.508', 'layer': '95', 'align': 'center-left' ...
# text content: INT0, SERCOM1_0, TC2_WO0, XIN32
# text content: INT1, SERCOM1_1, TC2_WO1, XOUT32
# text content: INT2, ADC0_0, DAC_0
# text content: INT3, VREFA, ADC0_1, X0/Y0
# text content: INT4, VREFB, ADC0_4, AC_0,
# X3/Y3, SERCOM0_0, TC0_WO0
# text content: INT5, ADC0_5, AC_1, DAC_1,
# SERCOM0_1, TC0_WO1
# text content: INT6, VREFC, ADC0_6, AC_2,
# X4/Y4, SERCOM0_2, TC1_WO0
# text content: INT7, ADC0_7, AC_3, X5/Y5,
# SERCOM0_3, TC1_WO1
# text content: EICNMI, ADC0_8, ADC1_2, X6/Y6,
# SERCOM0_0, SERCOM2_1, TC0_WO0,
# TCC0_WO0, TCC1_WO4
# text content: INT9, ADC0_9, ADC1_3, X7/Y7,
# SERCOM0_1, SERCOM2_0, TC0_WO1,
# TCC0_WO1, TCC1_WO5
# text content: INT10, ADC0_10, X8/Y8,
# SERCOM0_2, SERCOM2_2, TC1_WO0,
# TCC0_WO2, TCC1_WO6
# text content: INT11, ADC0_11, X9/Y9, SERCOM0_3,
# SERCOM2_3, TC1_WO1, TCC0_WO3,
# TCC1_WO7
# text content: INT12, SERCOM2_0, SERCOM4_1,
# TC2_WO0, TCC0_WO6, TCC1_WO2
# text content: INT13, SERCOM2_1, SERCOM4_0,
# TC2_WO1, TCC0_WO7, TCC1_WO3
# text content: INT14, SERCOM2_2, SERCOM4_2,
# TC3_WO0, TCC2_WO0, TCC1_WO2, XIN
# text content: INT15, SERCOM2_3, SERCOM4_3,
# TC3_WO1, TCC2_WO1, TCC1_WO3, XOUT
# text content: INT0, X10/Y10, SERCOM1_0, SERCOM3_1,
# TC2_WO0, TCC1_WO0, TCC0_WO4
# text content: INT1, X11/Y11, SERCOM1_1, SERCOM3_0,
# TC2_WO1, TCC0_WO7, TCC1_WO3
# text content: INT2, X12/Y12, SERCOM1_2, SERCOM3_2,
# TC3_WO0, TCC1_WO2, TCC0_WO6
# text content: INT3, X13/Y13, SERCOM1_3, SECOM3_3,
# TC3_WO1, TCC1_WO3, TCC0_WO7
# text content: INT4, X14/Y14, SERCOM5_2, SERCOM3_2,
# TC7_WO0, TCC1_WO4, TCC0_WO0
# text content: INT5, X15/Y15, SERCOM5_3, SERCOM3_3,
# TC7_WO1, TCC1_WO5, TCC0_WO1
# text content: INT6, X16/Y16, SERCOM3_0, SERCOM5_1,
# TC4_WO0, TCC1_WO6, TCC0_WO2
# text content: INT7, X17/Y17, SERCOM3_1, SERCOM5_0,
# TC4_WO1, TCC1_WO7, TCC0_WO3
# text content: INT8, SERCOM3_2, SERCOM5_2, TC4_WO0,
# TCC2_WO2, USB_DM
# text content: INT9, SERCOM3_3, SERCOM5_3,
#  TC5_WO1, USB_DP
# text content: INT11, X18/Y18
# text content: INT14, X19/Y19, SERCOM7_2, SERCOM1_2,
# TC6_WO0, TCC2_WO0, SWCLK
# text content: INT15, SERCOM7_3, SERCOM1_3,
# TC6_WO1, TCC2_WO1, SWDIO
# text content: INT4, ADC1_6, X21/Y21
# text content: INT5, ADC1_7, X23/Y23
# text content: INT6, ADC1_8, X24/Y24
# text content: INT7, ADC1_9, X25/Y25
# text content: INT8, ADC0_2, ADC1_0, X1/Y1,
# SERCOM4_0, TC4_WO0
# text content: INT9, ADC0_3, ADC1_1, X2/Y2,
# SERCOM4_1, TC4_WO1
# text content: INT10, SERCOM4_2, TC5_WO0,
# TCC0_WO4, TCC1_WO0
# text content: INT11, SERCOM4_3, TC5_WO1,
# TCC0_WO5, TCC1_WO1
# text content: INT12, X27/Y26, SERCOM4_0,
# TC4_WO0, TCC3_WO-, TCC0_WO0
# text content: INT13, X27/Y27, SERCOM4_1,
# TC4_WO1, TCC3_WO1, TCC0_WO1
# text content: INT14, X28/Y28, SERCOM4_2,
# TC5_WO0, TCC4_WO0, TCC0_WO2
# text content: INT15, X29/Y29, SERCOM4_3,
# TC5_WO1, TCC4_WO1, TCC0_WO3
# text content: INT0, SERCOM5_0, TC6_WO0,
# TCC3_WO0, TCC0_WO4
# text content: INT1, SERCOM5_1, TC6_WO1,
# TCC3_WO1, TCC0_WO5
# text content: INT6, SERCOM1_2, SERCOM5_2,
# TC7_WO0, XIN
# text content: INT7, SERCOM1_3, SERCOM5_3,
# TC7_WO1, XOUT
# text content: INT14, SERCOM7_0, SERCOM5_1, TC0_WO0,
# TCC4_WO0, TCC0_WO6, SWO
# text content: INT15, SERCOM7_1, SERCOM5_0,
# TC0_WO1, TCC4_WO1, TCC0_WO7
# text content: INT0, ADC0_12, X30/Y30, SERCOM5_2,
# TC7_WO0
# text content: INT1, ADC0_13, X31/Y31, SECOM5_3,
# TC7_WO1
# text content: INT2, ADC0_14, X20/Y20, SECOM5_0,
# TC6_WO0, TCC2_WO2
# text content: INT3, ADC0_15, X21/Y21, SECOM5_1,
# TC6_WO1
# part_name: SUPPLY2 part_value:  symbol_name: 3.3V x: 91.44 y: 162.56 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: U$1 part_value:  symbol_name: VDDA x: 162.56 y: 162.56 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY3 part_value:  symbol_name: VCC x: 154.94 y: 162.56 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: U$2 part_value:  symbol_name: VDDA x: 81.28 y: 149.86 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: GND2 part_value:  symbol_name: DGND x: 154.94 y: 68.58 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: Y1 part_value: 32.768kHz symbol_name: CRYSTAL x: 17.78 y: 147.32 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.032', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-2.032', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}, {'x': '-2.159', 'y': '-1.143', 'size': '0.8636', 'layer': '93', 'text': '1'}, {'x': '1.524', 'y': '-1.143', 'size': '0.8636', 'layer': '93', 'text': '2'}]
# text content: 1
# text content: 2
# part_name: C1 part_value: 15pF symbol_name: CAP x: 10.16 y: 137.16 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C2 part_value: 15pF symbol_name: CAP x: 25.4 y: 137.16 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C3 part_value: 0.1uF symbol_name: CAP x: 88.9 y: 15.24 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C11 part_value: 0.1uF symbol_name: CAP x: 99.06 y: 15.24 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: L1 part_value: FB - 30Ohm symbol_name: INDUCTOR x: 109.22 y: 22.86 rot: R90 gate: G$1
# here are the texts: [{'x': '1.27', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.27', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: SUPPLY12 part_value:  symbol_name: 3.3V x: 68.58 y: 25.4 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: C12 part_value: 0.1uF symbol_name: CAP x: 119.38 y: 15.24 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND28 part_value:  symbol_name: DGND x: 68.58 y: 5.08 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: C8 part_value: 0.1uF symbol_name: CAP x: 68.58 y: 15.24 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C9 part_value: 0.1uF symbol_name: CAP x: 78.74 y: 15.24 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: SUPPLY13 part_value:  symbol_name: VCC x: 139.7 y: 25.4 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: C13 part_value: 4.7uF symbol_name: CAP x: 139.7 y: 15.24 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C14 part_value: 0.1uF symbol_name: CAP x: 149.86 y: 15.24 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C15 part_value: 10uF symbol_name: CAP x: 129.54 y: 15.24 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: U$3 part_value:  symbol_name: VDDA x: 129.54 y: 25.4 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: R1 part_value: 10k symbol_name: RESISTOR x: 170.18 y: 160.02 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY10 part_value:  symbol_name: 3.3V x: 170.18 y: 167.64 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND8 part_value:  symbol_name: DGND x: 10.16 y: 127.0 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: J6 part_value: AMP FCI 10103594-0001LF symbol_name: USB-5PIN x: 378.46 y: 233.68 rot: R0 gate: J1
# Pad Drawn: pin name: D+ pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D- pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VBUS pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: ID pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SHIELD pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '2.54', 'layer': '94', 'rot': 'R270', 'align': 'center', 'text': 'USB'}, {'x': '-2.54', 'y': '-9.906', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'MR180', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-2.54', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# text content: USB
# part_name: J1 part_value:  symbol_name: CONN_12 x: 378.46 y: 78.74 rot: R180 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 7 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 8 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 9 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 10 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 11 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 12 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J2 part_value:  symbol_name: CONN_16 x: 381.0 y: 73.66 rot: MR180 gate: G$1
# is_mirrored: True rot_angle_rad: 3.141592653589793 rot_angle_deg: 180.0
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 13 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 14 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 15 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 16 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-25.146', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '20.828', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: GND7 part_value:  symbol_name: DGND x: 401.32 y: 81.28 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY4 part_value:  symbol_name: 3.3V x: 403.86 y: 93.98 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY5 part_value:  symbol_name: V_BATT x: 365.76 y: 96.52 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY6 part_value:  symbol_name: V_USB x: 360.68 y: 96.52 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: R2 part_value: 10k symbol_name: RESISTOR x: 73.66 y: 231.14 rot: R180 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: TP1 part_value:  symbol_name: TEST-POINT x: 304.8 y: 101.6 rot: R180 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: TP2 part_value:  symbol_name: TEST-POINT x: 304.8 y: 91.44 rot: R180 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: U4 part_value: 4Mb Flash symbol_name: SPI_FLASH_DUAL/QUAD x: 381.0 y: 139.7 rot: R0 gate: G$1
# Pad Drawn: pin name: !CS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: !WP(D2) pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SO(D1) pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VCC pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: !HOLD(D3) pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SCK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SI(D0) pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-10.16', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-10.16', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: R4 part_value: 10k symbol_name: RESISTOR x: 355.6 y: 154.94 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY9 part_value:  symbol_name: 3.3V x: 355.6 y: 165.1 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY11 part_value:  symbol_name: 3.3V x: 403.86 y: 165.1 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: GND3 part_value:  symbol_name: DGND x: 363.22 y: 132.08 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: LOGO1 part_value:  symbol_name: FOUR_LAYER_WARNING x: 393.7 y: 38.1 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '0', 'size': '1.778', 'layer': '94', 'text': 'THIS IS A FOUR-LAYER BOARD!'}]
# text content: THIS IS A FOUR-LAYER BOARD!
# part_name: LOGO3 part_value:  symbol_name: SFE_LOGO_NAME_FLAME x: 271.78 y: 2.54 rot: R0 gate: G$1
# here are the texts: []
# part_name: LOGO4 part_value:  symbol_name: SFE_LOGO_FLAME x: 304.292 y: 15.24 rot: R0 gate: G$1
# here are the texts: []
# part_name: J4 part_value:  symbol_name: JST_2MM_MALE x: 269.24 y: 238.76 rot: MR90 gate: G$1
# is_mirrored: True rot_angle_rad: 1.5707963267948966 rot_angle_deg: 90.0
# here are the texts: [{'x': '-2.54', 'y': '5.842', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# part_name: R5 part_value: 2.2k symbol_name: RESISTOR x: 289.56 y: 162.56 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R9 part_value: 2.2k symbol_name: RESISTOR x: 304.8 y: 162.56 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: JP1 part_value:  symbol_name: SMT-JUMPER_3_2-NC_TRACE x: 297.18 y: 170.18 rot: R270 gate: G$1
# here are the texts: [{'x': '2.54', 'y': '0.381', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '2.54', 'y': '-0.381', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: SUPPLY15 part_value:  symbol_name: 3.3V x: 297.18 y: 177.8 rot: R0 gate: G$1
# here are the texts: [{'x': '-1.016', 'y': '3.556', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: H1 part_value:  symbol_name: STAND-OFF x: 426.72 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: H2 part_value:  symbol_name: STAND-OFF x: 426.72 y: 33.02 rot: R0 gate: G$1
# here are the texts: []
# part_name: H3 part_value:  symbol_name: STAND-OFF x: 429.26 y: 33.02 rot: R0 gate: G$1
# here are the texts: []
# part_name: H4 part_value:  symbol_name: STAND-OFF x: 429.26 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: U$69 part_value:  symbol_name: LOGO x: 300.228 y: 3.81 rot: R0 gate: G$1
# here are the texts: []
# label: D4 rot: 180
# label: D4 rot: 0
# label: FLASH_SCK rot: 0
# label: FLASH_SCK rot: 180
# label: D- rot: 0
# label: D- rot: 180
# label: D+ rot: 0
# label: D+ rot: 180
# label: FLASH_MOSI rot: 0
# label: FLASH_MOSI rot: 180
# label: XIN32 rot: 180
# label: XIN32 rot: 0
# label: XOUT32 rot: 180
# label: XOUT32 rot: 0
# label: SWDIO rot: 0
# label: SWDIO rot: 180
# label: SWDCLK rot: 0
# label: SWDCLK rot: 180
# label: !RESET rot: 0
# label: !RESET rot: 0
# label: !RESET rot: 0
# label: EN rot: 180
# label: EN rot: 180
# label: D13 rot: 180
# label: D13 rot: 180
# label: D13 rot: 180
# label: D12 rot: 180
# label: D12 rot: 180
# label: D11 rot: 180
# label: D11 rot: 180
# label: D10 rot: 180
# label: D10 rot: 180
# label: D9 rot: 180
# label: D9 rot: 180
# label: D6 rot: 180
# label: D6 rot: 180
# label: D5 rot: 180
# label: D5 rot: 180
# label: SCL rot: 180
# label: SCL rot: 180
# label: SCL rot: 0
# label: SDA rot: 180
# label: SDA rot: 180
# label: SDA rot: 0
# label: A0 rot: 0
# label: A0 rot: 180
# label: A1 rot: 0
# label: A1 rot: 0
# label: A2 rot: 0
# label: A2 rot: 0
# label: A3 rot: 0
# label: A3 rot: 180
# label: A4 rot: 0
# label: A4 rot: 180
# label: A5 rot: 0
# label: A5 rot: 0
# label: SCK rot: 0
# label: SCK rot: 0
# label: MOSI rot: 0
# label: MOSI rot: 0
# label: MISO rot: 0
# label: MISO rot: 0
# label: D0 rot: 0
# label: D0 rot: 180
# label: D1 rot: 0
# label: D1 rot: 180
# label: D7 rot: 180
# label: TXLED rot: 180
# label: TXLED rot: 180
# label: RXLED rot: 0
# label: TXD rot: 0
# label: RXD rot: 0
# label: FLASH_CS rot: 180
# label: FLASH_CS rot: 180
# label: FLASH_MISO rot: 180
# label: FLASH_MISO rot: 180
# plt saved
# /var/folders/tl/q2dlpcnd685cw606gn_pd05h0000gn/T/ipykernel_38471/3723974411.py:1273: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Kept → SAMD51_Thing_Plus.png
# label_filename: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels/SAMD51_Thing_Plus.txt
# label_file:
# label_filename: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels/SAMD51_Thing_Plus.txt
# schematics_raw_dimensions: 278.91999999999996 215.42
# schematics_png_dimensions: 55.78399999999999 43.083999999999996
# Dimensions of schematic: 55.78399999999999 43.083999999999996
# part_name: FRAME1 part_value:  symbol_name: FRAME-LETTER x: 0.0 y: 0.0 rot: R0 gate: G$1
# here are the texts: []
# part_name: FRAME1 part_value:  symbol_name: DOCFIELD x: 147.32 y: 0.0 rot: R0 gate: V
# here are the texts: [{'x': '1.27', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Date:'}, {'x': '12.7', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>LAST_DATE_TIME'}, {'x': '72.39', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Sheet:'}, {'x': '86.36', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>SHEET'}, {'x': '88.9', 'y': '11.43', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'REV:'}, {'x': '1.524', 'y': '17.78', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'TITLE:'}, {'x': '15.494', 'y': '17.78', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DRAWING_NAME'}, {'x': '2.54', 'y': '31.75', 'size': '1.9304', 'layer': '94', 'text': 'Released under the Creative Commons'}, {'x': '2.54', 'y': '27.94', 'size': '1.9304', 'layer': '94', 'text': 'Attribution Share-Alike 4.0 License'}, {'x': '2.54', 'y': '24.13', 'size': '1.9304', 'layer': '94', 'text': 'https://creativecommons.org/licenses/by-sa/4.0/'}, {'x': '1.27', 'y': '11.43', 'size': '2.54', 'layer': '94', 'text': 'Design by:'}, {'x': '23.114', 'y': '11.176', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DESIGNER'}, {'x': '88.9', 'y': '6.604', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>REV'}]
# text content: DATE:
# text content: SHEET:
# text content: REV:
# text content: TITLE:
# text content: RELEASED UNDER THE CREATIVE COMMONS
# text content: ATTRIBUTION SHARE-ALIKE 4.0 LICENSE
# text content: HTTPS://CREATIVECOMMONS.ORG/LICENSES/BY-SA/4.0/
# text content: DESIGN BY:
# Drawing attribute 'LAST_DATE_TIME' for part 'FRAME1'
# Drawing attribute 'SHEET' for part 'FRAME1'
# Drawing attribute 'DRAWING_NAME' for part 'FRAME1'
# Drawing attribute 'DESIGNER' for part 'FRAME1'
# Drawing attribute 'REV' for part 'FRAME1'
# part_name: GND3 part_value:  symbol_name: DGND x: 172.72 y: 63.5 rot: R0 gate: 1
# ...
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-5.08', 'y': '-7.62', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}, {'x': '-5.08', 'y': '8.382', 'size': '1.778', 'layer': '95', 'text': '>NAME'}]
# plt saved
# Kept → SparkFun_adapter-ssop8-v10.png
# label_filename: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels/SparkFun_adapter-ssop8-v10.txt
# label_file:
# label_filename: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels/SparkFun_adapter-ssop8-v10.txt
# schematics_raw_dimensions: 368.59000000000003 227.112
# schematics_png_dimensions: 73.718 45.422399999999996
# Dimensions of schematic: 73.718 45.422399999999996
# part_name: JP3 part_value:  symbol_name: STAND-OFF x: 246.38 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: JP4 part_value:  symbol_name: STAND-OFF x: 246.38 y: 27.94 rot: R0 gate: G$1
# here are the texts: []
# part_name: JP2 part_value:  symbol_name: FIDUCIAL x: 233.68 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: JP6 part_value:  symbol_name: FIDUCIAL x: 236.22 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: R4 part_value: 2.2k symbol_name: RESISTOR x: 152.4 y: 124.46 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R5 part_value: 2.2k symbol_name: RESISTOR x: 167.64 y: 124.46 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: I2C part_value:  symbol_name: SMT-JUMPER_3_2-NC_TRACE x: 160.02 y: 132.08 rot: R270 gate: G$1
# here are the texts: [{'x': '2.54', 'y': '0.381', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '2.54', 'y': '-0.381', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: SUPPLY1 part_value:  symbol_name: 3.3V x: 160.02 y: 144.78 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY4 part_value:  symbol_name: 3.3V x: 60.96 y: 43.18 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: J2 part_value:  symbol_name: I2C_STANDARD x: 71.12 y: 35.56 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: left va: center
# here are the texts: [{'x': '-5.08', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-5.08', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-4.572', 'y': '2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SDA'}, {'x': '-4.572', 'y': '0', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'VCC'}, {'x': '-4.572', 'y': '-2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'GND'}, {'x': '-4.572', 'y': '5.08', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SCL'}]
# text content: SDA
# text content: VCC
# text content: GND
# text content: SCL
# part_name: GND6 part_value:  symbol_name: GND x: 60.96 y: 27.94 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: SUPPLY7 part_value:  symbol_name: 3.3V x: 86.36 y: 43.18 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: J3 part_value: PTH symbol_name: I2C_STANDARD x: 96.52 y: 35.56 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# Pad Drawn: pin name: GND pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: VCC pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: SDA pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: SCL pin_angle_deg_final: 180.0 ha: left va: center
# here are the texts: [{'x': '-5.08', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-5.08', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-4.572', 'y': '2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SDA'}, {'x': '-4.572', 'y': '0', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'VCC'}, {'x': '-4.572', 'y': '-2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'GND'}, {'x': '-4.572', 'y': '5.08', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SCL'}]
# text content: SDA
# text content: VCC
# text content: GND
# text content: SCL
# part_name: GND7 part_value:  symbol_name: GND x: 86.36 y: 27.94 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: FRAME1 part_value:  symbol_name: FRAME-LETTER x: 0.0 y: 0.0 rot: R0 gate: G$1
# here are the texts: []
# part_name: FRAME1 part_value:  symbol_name: DOCFIELD x: 147.32 y: 0.0 rot: R0 gate: V
# here are the texts: [{'x': '1.27', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Date:'}, {'x': '12.7', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>LAST_DATE_TIME'}, {'x': '72.39', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Sheet:'}, {'x': '86.36', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>SHEET'}, {'x': '88.9', 'y': '11.43', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'REV:'}, {'x': '1.524', 'y': '17.78', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'TITLE:'}, {'x': '15.494', 'y': '17.78', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DRAWING_NAME'}, {'x': '2.54', 'y': '31.75', 'size': '1.9304', 'layer': '94', 'text': 'Released under the Creative Commons'}, {'x': '2.54', 'y': '27.94', 'size': '1.9304', 'layer': '94', 'text': 'Attribution Share-Alike 4.0 License'}, {'x': '2.54', 'y': '24.13', 'size': '1.9304', 'layer': '94', 'text': 'https://creativecommons.org/licenses/by-sa/4.0/'}, {'x': '1.27', 'y': '11.43', 'size': '2.54', 'layer': '94', 'text': 'Design by:'}]
# text content: DATE:
# text content: SHEET:
# text content: REV:
# text content: TITLE:
# text content: RELEASED UNDER THE CREATIVE COMMONS
# text content: ATTRIBUTION SHARE-ALIKE 4.0 LICENSE
# text content: HTTPS://CREATIVECOMMONS.ORG/LICENSES/BY-SA/4.0/
# text content: DESIGN BY:
# part_name: U$2 part_value:  symbol_name: SFE_LOGO_NAME_FLAME x: 154.94 y: 38.1 rot: R0 gate: G$1
# here are the texts: []
# part_name: SUPPLY8 part_value:  symbol_name: 3.3V x: 35.56 y: 43.18 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: J4 part_value:  symbol_name: I2C_STANDARD x: 45.72 y: 35.56 rot: MR0 gate: G$1
# is_mirrored: True rot_angle_rad: 0.0 rot_angle_deg: 0.0
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: left va: center
# here are the texts: [{'x': '-5.08', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-5.08', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-4.572', 'y': '2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SDA'}, {'x': '-4.572', 'y': '0', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'VCC'}, {'x': '-4.572', 'y': '-2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'GND'}, {'x': '-4.572', 'y': '5.08', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SCL'}]
# text content: SDA
# text content: VCC
# text content: GND
# text content: SCL
# part_name: GND8 part_value:  symbol_name: GND x: 35.56 y: 27.94 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: LOGO1 part_value:  symbol_name: OSHW-LOGO x: 233.68 y: 45.72 rot: R0 gate: G$1
# here are the texts: []
# part_name: U$1 part_value:  symbol_name: SFE_LOGO_NAME_FLAME x: 154.94 y: 38.1 rot: R0 gate: G$1
# here are the texts: []
# part_name: J5 part_value:  symbol_name: CONN_01 x: 119.38 y: 40.64 rot: R180 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '-4.826', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '-2.54', 'y': '3.048', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: R1 part_value: 10k symbol_name: RESISTOR@1 x: 144.78 y: 124.46 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY2 part_value:  symbol_name: 3.3V x: 144.78 y: 144.78 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: JP1 part_value:  symbol_name: FIDUCIAL x: 236.22 y: 27.94 rot: R0 gate: G$1
# here are the texts: []
# part_name: JP5 part_value:  symbol_name: FIDUCIAL x: 233.68 y: 27.94 rot: R0 gate: G$1
# here are the texts: []
# part_name: JP9 part_value: INT symbol_name: PAD-JUMPER-2-NC_BY_TRACE x: 144.78 y: 137.16 rot: R90 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'text': '>NAME'}, {'x': '-2.54', 'y': '-5.08', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: R3 part_value: 1k symbol_name: RESISTOR x: 58.42 y: 116.84 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY10 part_value:  symbol_name: 3.3V x: 58.42 y: 124.46 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: D1 part_value: RED symbol_name: LED x: 58.42 y: 106.68 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: GND3 part_value:  symbol_name: GND x: 58.42 y: 93.98 rot: R0 gate: 1
# here are the texts: [{'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'text': '>VALUE'}]
# part_name: C1 part_value: 2.2uF symbol_name: CAP x: 86.36 y: 109.22 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C4 part_value: 0.1uF symbol_name: CAP x: 76.2 y: 109.22 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: SUPPLY3 part_value:  symbol_name: 3.3V x: 137.16 y: 124.46 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY5 part_value:  symbol_name: 3.3V x: 96.52 y: 124.46 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY6 part_value:  symbol_name: 3.3V x: 86.36 y: 116.84 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY9 part_value:  symbol_name: 3.3V x: 76.2 y: 116.84 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: GND1 part_value:  symbol_name: DGND x: 76.2 y: 101.6 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND2 part_value:  symbol_name: DGND x: 96.52 y: 93.98 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND4 part_value:  symbol_name: DGND x: 86.36 y: 101.6 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: U2 part_value:  symbol_name: SPARKX_VCNL4040 x: 116.84 y: 111.76 rot: R0 gate: U1
# Pad Drawn: pin name: ANODE pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: CATHODE_LED pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: CATHODE_SEN pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: INT pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SCL pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SDA pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: VDD pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-15.24', 'y': '12.954', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-15.24', 'y': '-18.034', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: LOGO2 part_value:  symbol_name: REVISION x: 148.59 y: 7.112 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '0', 'size': '2.54', 'layer': '94', 'text': 'Revision By:'}]
# text content: REVISION BY:
# label: SCL rot: 180
# label: SCL rot: 180
# label: SCL rot: 180
# label: SCL rot: 0
# label: SDA rot: 180
# label: SDA rot: 180
# label: SDA rot: 180
# label: SDA rot: 0
# label: !INT rot: 180
# label: !INT rot: 0
# plt saved
# Kept → Qwiic Proximity Sensor - VCNL4040.png
# label_filename: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels/Qwiic Proximity Sensor - VCNL4040.txt
# label_file:
# label_filename: /Users/linkaiyuan/文件/PSU/yolo_training_24/dataset/val/labels/Qwiic Proximity Sensor - VCNL4040.txt
# Skipping /Users/linkaiyuan/文件/PSU/products/SparkFun_FTDI_Basic_Breakout_-_3.3V/FTDI Basic-v22-3.3V.sch due to error: not well-formed (invalid token): line 1, column 0
# Skipping /Users/linkaiyuan/文件/PSU/products/SparkFun_MicroMod_Asset_Tracker_Carrier_Board/MicroMod_Asset_Tracker/MicroMod_Asset_Tracker.sch due to error: 'list' object has no attribute 'get'

# %% [markdown]
# # PCB Stat Cal

# %% [markdown]
# ## Stats calculate funs

# %%
import xml.etree.ElementTree as ET
import json
def total_pins(file_path):
    file = process_schematic_file(file_path)
    parts = file.get("parts", {})
    libraries = file.get("IC_library", [])

    # Step 1: Map component name → (library, deviceset, device)
    component_to_dev = {
        comp: {
            "deviceset": data.get("deviceset"),
            "device": data.get("device"),
            "library": data.get("library")
        }
        for comp, data in parts.items()
    }
    # Step 2: Extract device-to-pin mapping from libraries
    device_to_pins = {}
    for lib in libraries:
        lib_name = lib.get("name")
        devicesets = lib.get("devicesets", {}).get("deviceset", [])
        if isinstance(devicesets, dict):
            devicesets = [devicesets]

        for dset in devicesets:
            dset_name = dset.get("name")
            devices = dset.get("devices", {}).get("device", [])
            if isinstance(devices, dict):
                devices = [devices]

            gates = dset.get("gates", {}).get("gate", [])
            if isinstance(gates, dict):
                gates = [gates]

            symbols = lib.get("symbols", {}).get("symbol", [])
            if isinstance(symbols, dict):
                symbols = [symbols]

            # Step 3: Get pin names from symbol used in gates
            pin_names = set()
            
            for gate in gates:
                symbol_name = gate.get("symbol")
                print(f"Gate symbol: {symbol_name}")
                for sym in symbols:
                    if sym.get("name") == symbol_name:
                        pin_data = sym.get("pin", [])
                        if isinstance(pin_data, dict):
                            pin_data = [pin_data]
                        for pin in pin_data:
                            name = pin.get("name")
                            if name:
                                pin_names.add(name)

            for dev in devices:
                device_name = dev.get("name")
                key = (lib_name, dset_name, device_name)
                device_to_pins[key] = pin_names
    # Step 4: Combine component with its pin count
    component_pin_info = []
    for comp_name, info in component_to_dev.items():
        key = (info["library"], info["deviceset"], info["device"])
        pin_names = device_to_pins.get(key, set())
        if pin_names:  # Only keep components with non-zero pins
            component_pin_info.append({
                "Component": comp_name,
                "Library": info["library"],
                "Deviceset": info["deviceset"],
                "Device": info["device"],
                "Pin Count": len(pin_names),
                "Pins": sorted(pin_names)
            })

    # Step 5: Print result
    # for entry in component_pin_info:
    #     print(f"{entry['Component']} ({entry['Device']}): {entry['Pin Count']} pins → {entry['Pins']}")
    total_p = sum(entry['Pin Count'] for entry in component_pin_info)
    return total_p

def parse_eagle_brd_src(file_path, src_file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    file = process_schematic_file(src_file_path)

    # BOARD → PLAIN → DIMENSION or directly bounding box in ELEMENTS or SIGNALS
    drawing = root.find('drawing')
    board = drawing.find('board')
    layers = drawing.find('layers')
    # --- Get Board Dimensions ---
    min_x, min_y, max_x, max_y = float('inf'), float('inf'), float('-inf'), float('-inf')

    for elem in board.findall(".//element"):
        x = float(elem.get('x', 0))
        y = float(elem.get('y', 0))
        min_x = min(min_x, x)
        min_y = min(min_y, y)
        max_x = max(max_x, x)
        max_y = max(max_y, y)

    width = round(max_x - min_x, 2)
    height = round(max_y - min_y, 2)

    # --- Get Number of Layers ---
    
    layercount = 0
    for layer in layers.findall('layer'):
        number = int(layer.get('number', -1))
        active = layer.get('active', 'no')
        if 1 <= number <= 16 and active.lower() == 'yes':
            layercount += 1
    # print(layercount)

    # --- Get Number of Components ---
    elements = board.find('elements')
    num_components = len(elements.findall('element')) if elements is not None else 0


    # print(file['nets'])
    # for net in file['nets']['net']:
    #     print(net)


    # print(type(file["nets"]))
    # print(file["nets"])

    net_dict = file.get("nets", {})
    num_nets = len(net_dict)
    # print("Number of nets:", num_nets)
    # if isinstance(net_list, dict):
    #     net_list = [net_list]

        
    unique_pins = set()

    for net_name, net_data in net_dict.items():
        net_data_list = net_data if isinstance(net_data, list) else [net_data]

        for nd in net_data_list:
            # print(nd)
            pinrefs = nd.get("pinref", [])
            # if isinstance(segments, dict):
            #     segments = [segments]

            # for segment in segments:
            #     pinrefs = segment.get("pinref", [])
                
            if isinstance(pinrefs, dict):
                pinrefs = [pinrefs]
            
            for pinref in pinrefs:
                part = pinref.get("part", "?")
                pin = pinref.get("pin", "?")
                unique_pins.add(f"{part}.{pin}")

    
    a = total_pins(src_file_path)

    return {
        'Width': width,
        'Height': height,
        'Num Layers': layercount,
        'Num Components': num_components,
        'Num Pads': len(unique_pins),
        'Num Nets': num_nets,
        'Num of total pins': a
    }

# Example usage
brd_path = '/Users/linkaiyuan/文件/PSU/products/Arduino_Nano_Every/NANOEveryV3.0.brd'
src_path = '/Users/linkaiyuan/文件/PSU/products/Arduino_Nano_Every/NANOEveryV3.0.sch'
info = parse_eagle_brd_src(brd_path, src_path)
print(info)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 172
#     170 brd_path = '/Users/linkaiyuan/文件/PSU/products/Arduino_Nano_Every/NANOEveryV3.0.brd'
#     171 src_path = '/Users/linkaiyuan/文件/PSU/products/Arduino_Nano_Every/NANOEveryV3.0.sch'
# --> 172 info = parse_eagle_brd_src(brd_path, src_path)
#     173 print(info)
#
# Cell In[2], line 84, in parse_eagle_brd_src(file_path, src_file_path)
#      81 tree = ET.parse(file_path)
#      82 root = tree.getroot()
# ---> 84 file = process_schematic_file(src_file_path)
#      86 # BOARD → PLAIN → DIMENSION or directly bounding box in ELEMENTS or SIGNALS
#      87 drawing = root.find('drawing')
#
# NameError: name 'process_schematic_file' is not defined

# %% [markdown]
# ## Stats Generate and save

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

# Collect all results
folder = "/Users/linkaiyuan/文件/PSU/products"
results = []
file_16_layer = []
bad_file = 0
for brd_file in glob.glob(os.path.join(folder, "**", "*.brd"), recursive=True):
    try:
        sch_file = brd_file.replace(".brd", ".sch")
        if not os.path.exists(sch_file):
            print(f"Missing .sch for {brd_file}")
            continue
        info = parse_eagle_brd_src(brd_file, sch_file)
        if info['Num Layers'] == 4:
            file_16_layer.append(brd_file)
        info['Filename'] = os.path.basename(brd_file)
        results.append(info)
    except Exception as e:
        print(f"Error processing {brd_file}: {e}")
        bad_file+=1
        continue

# Convert to DataFrame and save
df = pd.DataFrame(results)
csv_path = "/Users/linkaiyuan/文件/PSU/eagle_stats.csv"
df.to_csv(csv_path, index=False)
print(f"Saved stats to {csv_path}")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
csv_path = "/Users/linkaiyuan/文件/PSU/eagle_stats.csv"
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip()  # Strip spaces

# List of fields to plot
fields = [
    'Num Components',
    'Num Nets',
    'Num Pads',
    'Num Layers',
    'Num of total pins',
    'Width',
    'Height'
]

# Convert all to numeric (in case of object dtype)
for field in fields:
    df[field] = pd.to_numeric(df[field], errors='coerce')

# Plot and save each field
for field in fields:
    df_sorted = df.sort_values(by=field, ascending=False).reset_index(drop=True)
    
    plt.figure(figsize=(10, 5))
    plt.bar(range(len(df_sorted)), df_sorted[field])
    plt.title(f"{field} per Board")
    plt.xlabel("Board Index")
    plt.ylabel(field)
    plt.tight_layout()

    # Save to PNG
    safe_field_name = field.replace(" ", "_").lower()
    save_path = f"{safe_field_name}_per_board.png"
    plt.savefig(save_path, dpi=300)
    plt.close()
    print(f"Saved plot: {save_path}")

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
csv_path = "/Users/linkaiyuan/文件/PSU/eagle_stats.csv"
df = pd.read_csv(csv_path)
df.columns = df.columns.str.strip()  # Strip spaces

# List of fields to plot
fields = [
    'Num Components',
    'Num Nets',
    'Num Pads',
    'Num Layers',
    'Num of total pins',
    'Width',
    'Height'
]

# Convert all to numeric (in case of object dtype)
for field in fields:
    df[field] = pd.to_numeric(df[field], errors='coerce')

# Plot and save each field as a frequency plot (histogram)
for field in fields:
    plt.figure(figsize=(10, 5))
    
    # Plot frequency (histogram) of each field
    plt.hist(df[field].dropna(), bins=15, color='blue', edgecolor='black', alpha=0.7)
    
    plt.title(f"Frequency Distribution of {field}")
    plt.xlabel(field)
    plt.ylabel("Frequency")
    plt.tight_layout()

    # Save to PNG
    safe_field_name = field.replace(" ", "_").lower()
    save_path = f"{safe_field_name}_frequency.png"
    plt.savefig(save_path, dpi=300)
    plt.close()
    print(f"Saved plot: {save_path}")

# %%
import json
schematic_info = process_schematic_file("/Users/linkaiyuan/文件/PSU/products/Bus_Pirate_-_v3.6a/BusPirate-v3.6a.sch")


output_path = "/Users/linkaiyuan/文件/PSU/test_multi_gate_schematic_info.json"

with open(output_path, "w", encoding="utf-8") as f:
    json.dump(schematic_info, f, ensure_ascii=False, indent=4)

print(f"Saved schematic info to {output_path}")

# %% [markdown]
# # test for multi gate sch generate

# %%
from xml.etree.ElementTree import ParseError
import os
import stat
if __name__ == "__main__":


    root_dir = "/Users/linkaiyuan/文件/PSU/products"
    temp_path = "/Users/linkaiyuan/文件/PSU/template_sch/template.sch"
    # os.makedirs(temp_path, exist_ok=True)
    os.chmod(temp_path, stat.S_IRWXU)
    os.chmod(root_dir, stat.S_IRWXU)
    import shutil
    import glob
    import os
    import json
    import stat

    unique_symbols = set()
    count = 0

    for sch_file_path in glob.glob(os.path.join(root_dir, "**", "*.sch"), recursive=True):
        # if count > 1:
        #     break
        name = os.path.basename(sch_file_path)
        stem = os.path.splitext(name)[0]
        os.chmod(sch_file_path, stat.S_IRWXU)
        try:
            schematic_info = process_schematic_file(sch_file_path)
            for part_name in schematic_info['parts'].items():
                # count += 1
                # if count > 1:
                #     break
                # print(part_name)
                symbol = part_name[1]['instances'][0]['symbol']
                lib = part_name[1]['library']
                if (symbol, lib) in unique_symbols:
                    continue
                unique_symbols.add((symbol, lib))

                new_name = f"{os.path.splitext(name)[0]}_{lib}_{symbol}.sch".replace("/", "slash")
                if ("MGM240P_EFM32GG12B410F1024GL120_EFM32GG12B410F1024GL120_A" in new_name):
                    print("name find:",sch_file_path)
                # dst_path = os.path.join("/Users/linkaiyuan/文件/PSU/test_single_sch", new_name)
                dst_path = os.path.join("/Users/linkaiyuan/文件/PSU/test_multigate", new_name)
                # os.chmod(dst_path, stat.S_IRWXU)
                os.chmod(temp_path, stat.S_IRWXU)
                if os.path.exists(dst_path):
                    os.chmod(dst_path, stat.S_IRWXU)
                shutil.copy(temp_path, dst_path)
                os.chmod(dst_path, stat.S_IRWXU)
                # print(dst_path)

                    
                deviceset = part_name[1]['deviceset']
                device = part_name[1]['device']
                value = part_name[1]['value']
                print(sch_file_path, dst_path, lib, deviceset, device, value)
                merge_schematic_libraries(sch_file_path, dst_path, debug=False)
                add_unit_to_schematic(dst_path,lib, deviceset, device, value)
                print(f"Orgional schematic file: {sch_file_path}")
                print(f"New schematic file: {dst_path}")
                print(f"added unit: {lib}, {deviceset}, {device}, {value}")
    # # device = ""
    # # value = ""
        except AttributeError as e:
            # print(f"Skipping {sch_file_path} due to error: {e}")
            continue
        except ParseError as e:
            # print(f"Skipping {sch_file_path} due to XML parsing error: {e}")
            continue
        except TypeError as e:
            # print(f"Skipping {sch_file_path} due to TypeError: {e}")
            continue

# %% [markdown]
# ## Single Sch to Image Tesing

# %%
import glob
import os
import traceback

save_path = "/Users/linkaiyuan/Downloads/"
sch_file = '/Users/linkaiyuan/文件/PSU/products/SparkFun_Artemis_Development_Kit_with_Camera/ArtemisDevKit.sch'
# sch_file = "/Users/linkaiyuan/文件/PSU/multi_instances/MicroMod_Processor_STM32WB5MMG_stm32wb5mmg_STM32WB5MMG_COMMS.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/SparkFun_Qwiic_Buzzer/SparkFun_Qwiic_Buzzer.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/SparkFun_MicroMod_WiFi_Function_Board_-_DA16200/SparkFun_MicroMod_DA16200_Function.sch"
# sch_file = "/Users/linkaiyuan/文件/PSU/products/WAV_Trigger/wavtrigger_v11.sch"


try:
    # parse schematic and get its full‐sheet bounds
    schematic_info = process_schematic_file(sch_file)
    src_xlim, src_ylim = get_schematic_bounding_box_from_schematic_info(schematic_info)
    print(sch_file)
    # render and save
    png_path = os.path.join(save_path, "version_with_bounding" + os.path.basename(sch_file).replace(".sch", ".png"))
    sizes    = visualize_schematic(sch_file, png_path)
    # sizes   = visualize_schematic_nobounding(sch_file, save_path=png_path)
    px_per_x, px_per_y, _, _, img_w, img_h = sizes


    ic_library = schematic_info.get('IC_library')
    parts_info = schematic_info.get('parts')

    # loop over each part instance
    for part_name, part_data in parts_info.items():
        for instance in part_data.get('instances', []):
            symbol_element = get_symbol_element_of_instance_from_library(
                ic_library, part_name, instance.get('gate', ''), parts_info
            )
            if not symbol_element:
                continue

            # get this symbol’s world‐space bbox
            rot_inst = instance['rot']
            x_inst   = float(instance['x'])
            y_inst   = float(instance['y'])
            (x0, x1), (y0, y1) = get_bounding_box_for_symbol_instance(
                symbol_element, x_inst, y_inst, rot_inst
            )

            # convert to pixels
            w_px  = (x1 - x0) * px_per_x
            h_px  = (y1 - y0) * px_per_y
            cx_px = ((x0 + x1)/2 - src_xlim[0]) * px_per_x
            cy_px = ((y0 + y1)/2 - src_ylim[0]) * px_per_y

            # normalize for YOLO (flip y so origin is top‐left)
            norm_x_center = cx_px / img_w
            norm_y_center = 1.0 - (cy_px / img_h)
            norm_width    = w_px    / img_w
            norm_height   = h_px    / img_h

            # lookup class
            lib          = part_data['library']
            symbol       = instance['symbol']
            base_name    = os.path.splitext(os.path.basename(sch_file))[0]
            key          = f"{base_name}_{lib}_{symbol}"
            if class_map is not None:
                class_number = class_map.get(key, -1)
                if class_number == -1:
                    continue

            label_file += f"{class_number} {norm_x_center:.6f} {norm_y_center:.6f} {norm_width:.6f} {norm_height:.6f}\n"

    # write out labels
    # label_filename = 
    with open(label_filename, "w") as f:
        f.write(label_file)

except Exception as e:
    print(f"Skipping {sch_file} due to error: {e}")
    traceback.print_exc()
# Out:
# /Users/linkaiyuan/文件/PSU/products/SparkFun_Artemis_Development_Kit_with_Camera/ArtemisDevKit.sch
# schematics_raw_dimensions: 461.8 309.4
# schematics_png_dimensions: 92.36 61.879999999999995
# Dimensions of schematic: 92.36 61.879999999999995
# part_name: FRAME1 part_value:  symbol_name: FRAME_LEDGER x: 0.0 y: 0.0 rot: R0 gate: G$1
# here are the texts: []
# part_name: FRAME1 part_value:  symbol_name: DOCFIELD x: 330.2 y: 0.0 rot: R0 gate: G$2
# here are the texts: [{'x': '1.27', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Date:'}, {'x': '12.7', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>LAST_DATE_TIME'}, {'x': '72.39', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'Sheet:'}, {'x': '86.36', 'y': '1.27', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': '>SHEET'}, {'x': '88.9', 'y': '11.43', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'REV:'}, {'x': '1.524', 'y': '17.78', 'size': '2.54', 'layer': '94', 'font': 'vector', 'text': 'TITLE:'}, {'x': '15.494', 'y': '17.78', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DRAWING_NAME'}, {'x': '2.54', 'y': '31.75', 'size': '1.9304', 'layer': '94', 'text': 'Released under the Creative Commons'}, {'x': '2.54', 'y': '27.94', 'size': '1.9304', 'layer': '94', 'text': 'Attribution Share-Alike 4.0 License'}, {'x': '2.54', 'y': '24.13', 'size': '1.9304', 'layer': '94', 'text': 'https://creativecommons.org/licenses/by-sa/4.0/'}, {'x': '1.27', 'y': '11.43', 'size': '2.54', 'layer': '94', 'text': 'Design by:'}, {'x': '23.114', 'y': '11.176', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>DESIGNER'}, {'x': '88.9', 'y': '6.604', 'size': '2.7432', 'layer': '94', 'font': 'vector', 'text': '>REV'}]
# text content: DATE:
# text content: SHEET:
# text content: REV:
# text content: TITLE:
# text content: RELEASED UNDER THE CREATIVE COMMONS
# text content: ATTRIBUTION SHARE-ALIKE 4.0 LICENSE
# text content: HTTPS://CREATIVECOMMONS.ORG/LICENSES/BY-SA/4.0/
# text content: DESIGN BY:
# Drawing attribute 'LAST_DATE_TIME' for part 'FRAME1'
# Drawing attribute 'SHEET' for part 'FRAME1'
# Drawing attribute 'DRAWING_NAME' for part 'FRAME1'
# Drawing attribute 'DESIGNER' for part 'FRAME1'
# Drawing attribute 'REV' for part 'FRAME1'
# part_name: GND11 part_value:  symbol_name: DGND x: 38.1 y: 190.5 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C4 part_value: 0.1uF symbol_name: CAP x: 38.1 y: 203.2 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: R12 part_value: 10k symbol_name: RESISTOR x: 38.1 y: 218.44 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: J1 part_value: USB symbol_name: USB-C-MINIMUM x: 27.94 y: 66.04 rot: R0 gate: J1
# here are the texts: [{'x': '0', 'y': '0', 'size': '2.54', 'layer': '94', 'rot': 'R270', 'align': 'center', 'text': 'USB-C'}, {'x': '-2.54', 'y': '-12.446', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'MR180', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-2.54', 'y': '10.414', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# text content: USB-C
# part_name: R6 part_value: 5.1k symbol_name: RESISTOR x: 48.26 y: 55.88 rot: R90 gate: R1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R7 part_value: 5.1k symbol_name: RESISTOR x: 55.88 y: 55.88 rot: R90 gate: R1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND6 part_value:  symbol_name: DGND x: 48.26 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND7 part_value:  symbol_name: DGND x: 55.88 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND5 part_value:  symbol_name: DGND x: 43.18 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C14 part_value: 0.1uF symbol_name: CAP x: 134.62 y: 38.1 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: R20 part_value: 10k symbol_name: RESISTOR x: 127.0 y: 38.1 rot: R270 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R19 part_value: 5.62k symbol_name: RESISTOR x: 127.0 y: 55.88 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R11 part_value: 10k symbol_name: RESISTOR x: 30.48 y: 218.44 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C5 part_value: 2.2uF symbol_name: CAP x: 17.78 y: 175.26 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND14 part_value:  symbol_name: DGND x: 17.78 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C6 part_value: 0.1uF symbol_name: CAP x: 22.86 y: 175.26 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C7 part_value: 0.1uF symbol_name: CAP x: 27.94 y: 175.26 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND15 part_value:  symbol_name: DGND x: 22.86 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND16 part_value:  symbol_name: DGND x: 27.94 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND17 part_value:  symbol_name: DGND x: 33.02 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C9 part_value: 12pF symbol_name: CAP x: 48.26 y: 152.4 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C8 part_value: 12pF symbol_name: CAP x: 38.1 y: 152.4 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND18 part_value:  symbol_name: DGND x: 38.1 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND20 part_value:  symbol_name: DGND x: 48.26 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: X1 part_value: 16MHz symbol_name: CRYSTAL-GND x: 43.18 y: 160.02 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-2.159', 'y': '-1.143', 'size': '0.8636', 'layer': '93', 'text': '1'}, {'x': '1.524', 'y': '-1.143', 'size': '0.8636', 'layer': '93', 'text': '2'}, {'x': '-1.27', 'y': '-1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'top-right', 'text': '>NAME'}]
# text content: 1
# text content: 2
# part_name: GND19 part_value:  symbol_name: DGND x: 43.18 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: S2 part_value: TGT_RST symbol_name: SWITCH-MOMENTARY-2 x: 45.72 y: 203.2 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-0.508', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: U2 part_value:  symbol_name: ARTEMIS_MODULE x: 254.0 y: 180.34 rot: R0 gate: U1
# here are the texts: [{'x': '-30.48', 'y': '41.148', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-30.48', 'y': '-48.26', 'size': '1.778', 'layer': '96', 'text': '>Value'}]
# part_name: Y1 part_value: 32.768kHz symbol_name: CRYSTAL x: 193.04 y: 175.26 rot: R180 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.032', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-2.032', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}, {'x': '-2.159', 'y': '-1.143', 'size': '0.8636', 'layer': '93', 'text': '1'}, {'x': '1.524', 'y': '-1.143', 'size': '0.8636', 'layer': '93', 'text': '2'}]
# text content: 1
# text content: 2
# part_name: C10 part_value: 15pF symbol_name: CAP x: 187.96 y: 170.18 rot: R180 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C11 part_value: 15pF symbol_name: CAP x: 198.12 y: 170.18 rot: R180 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND12 part_value:  symbol_name: DGND x: 187.96 y: 160.02 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND13 part_value:  symbol_name: DGND x: 198.12 y: 160.02 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: D4 part_value: RED symbol_name: LED x: 144.78 y: 233.68 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: D1 part_value: BLUE symbol_name: LED x: 114.3 y: 233.68 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: D2 part_value: GREEN symbol_name: LED x: 124.46 y: 233.68 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: D3 part_value: Yellow symbol_name: LED x: 134.62 y: 233.68 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: R1 part_value: 330 symbol_name: RESISTOR x: 114.3 y: 243.84 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R2 part_value: 330 symbol_name: RESISTOR x: 124.46 y: 243.84 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R3 part_value: 330 symbol_name: RESISTOR x: 134.62 y: 243.84 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY1 part_value:  symbol_name: 3.3V x: 114.3 y: 254.0 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: R4 part_value: 330 symbol_name: RESISTOR x: 144.78 y: 243.84 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND8 part_value:  symbol_name: DGND x: 144.78 y: 223.52 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R18 part_value: 33 symbol_name: RESISTOR x: 106.68 y: 63.5 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R16 part_value: 33 symbol_name: RESISTOR x: 106.68 y: 73.66 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: D6 part_value:  symbol_name: PRTR5V0U2 x: 86.36 y: 68.58 rot: MR180 gate: D1
# is_mirrored: True rot_angle_rad: 3.141592653589793 rot_angle_deg: 180.0
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: left va: center
# Pad Drawn: pin name: 6 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-7.62', 'y': '7.874', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-7.62', 'y': '-7.874', 'size': '1.778', 'layer': '96', 'align': 'top-left', 'text': '>Value'}]
# part_name: GND24 part_value:  symbol_name: DGND x: 73.66 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C12 part_value: 1.0uF symbol_name: CAP x: 114.3 y: 53.34 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C13 part_value: 0.1uF symbol_name: CAP x: 119.38 y: 53.34 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND25 part_value:  symbol_name: DGND x: 114.3 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND26 part_value:  symbol_name: DGND x: 119.38 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: J3 part_value: CORTEX_JTAG_DEBUG_PTH symbol_name: CORTEX_DEBUG x: 73.66 y: 129.54 rot: R0 gate: J1
# Pad Drawn: pin name: VCC pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND@3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND@5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: KEY pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GNDDTCT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: !RESET pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: NC/TDI pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SWO/TDO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SWDCLK/TCK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SWDIO/TMS pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-12.7', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-12.7', 'y': '-9.906', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: SUPPLY13 part_value:  symbol_name: 3.3V x: 55.88 y: 137.16 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: GND21 part_value:  symbol_name: DGND x: 55.88 y: 119.38 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND27 part_value:  symbol_name: DGND x: 134.62 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND22 part_value:  symbol_name: DGND x: 218.44 y: 132.08 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: D5 part_value: BLUE symbol_name: LED x: 154.94 y: 233.68 rot: R0 gate: G$1
# here are the texts: [{'x': '-3.429', 'y': '-4.572', 'size': '1.778', 'layer': '95', 'font': 'vector', 'rot': 'R90', 'text': '>NAME'}, {'x': '1.905', 'y': '-4.572', 'size': '1.778', 'layer': '96', 'font': 'vector', 'rot': 'R90', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: R5 part_value: 330 symbol_name: RESISTOR x: 154.94 y: 243.84 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND9 part_value:  symbol_name: DGND x: 154.94 y: 223.52 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: E1 part_value: SPH0641LM4H-1 symbol_name: SPH0641LM4H-1_MICROPHONE x: 187.96 y: 38.1 rot: R0 gate: E1
# here are the texts: [{'x': '1.524', 'y': '6.604', 'size': '1.778', 'layer': '95', 'align': 'center', 'text': '>NAME'}, {'x': '2.286', 'y': '-6.604', 'size': '1.778', 'layer': '96', 'align': 'center', 'text': '>VALUE'}, {'x': '-7.112', 'y': '-0.762', 'size': '1.778', 'layer': '94', 'ratio': '15', 'text': 'MIC'}]
# text content: MIC
# part_name: GND31 part_value:  symbol_name: DGND x: 182.88 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND32 part_value:  symbol_name: DGND x: 203.2 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C15 part_value: 1.0uF symbol_name: CAP x: 218.44 y: 38.1 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND33 part_value:  symbol_name: DGND x: 218.44 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: J2 part_value:  symbol_name: CORTEX_DEBUG_MINIMUM x: 236.22 y: 243.84 rot: R0 gate: G$1
# Pad Drawn: pin name: VCC pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: !RESET pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SWO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SWDCLK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SWDIO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-10.16', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-10.16', 'y': '-7.366', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: GND10 part_value:  symbol_name: DGND x: 220.98 y: 236.22 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C1 part_value: 10uF symbol_name: CAP x: 276.86 y: 246.38 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C2 part_value: 1.0uF symbol_name: CAP x: 284.48 y: 246.38 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C3 part_value: 0.1uF symbol_name: CAP x: 292.1 y: 246.38 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: GND2 part_value:  symbol_name: DGND x: 276.86 y: 236.22 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND3 part_value:  symbol_name: DGND x: 284.48 y: 236.22 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND4 part_value:  symbol_name: DGND x: 292.1 y: 236.22 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY9 part_value:  symbol_name: 3.3V x: 38.1 y: 228.6 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY8 part_value:  symbol_name: 3.3V x: 220.98 y: 251.46 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY10 part_value:  symbol_name: 3.3V x: 218.44 y: 220.98 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY2 part_value:  symbol_name: 3.3V x: 276.86 y: 254.0 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY3 part_value:  symbol_name: 3.3V x: 284.48 y: 254.0 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY4 part_value:  symbol_name: 3.3V x: 292.1 y: 254.0 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY18 part_value:  symbol_name: 3.3V x: 182.88 y: 48.26 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY19 part_value:  symbol_name: 3.3V x: 218.44 y: 45.72 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: GND29 part_value:  symbol_name: DGND x: 276.86 y: 30.48 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY14 part_value:  symbol_name: 1.8V x: 271.78 y: 78.74 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: U4 part_value: AP2127K-1.8V symbol_name: V-REG-LDO_NO-BP x: 254.0 y: 38.1 rot: R0 gate: G$1
# here are the texts: [{'x': '-7.62', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-7.62', 'y': '-7.874', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: GND38 part_value:  symbol_name: DGND x: 241.3 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY25 part_value:  symbol_name: 1.8V x: 266.7 y: 45.72 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: GND39 part_value:  symbol_name: DGND x: 266.7 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND37 part_value:  symbol_name: DGND x: 236.22 y: 25.4 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: J7 part_value: CAMERA-HIMAXBOTTOM-CONTACT symbol_name: CAMERA-OV7670-MODULE x: 292.1 y: 55.88 rot: R0 gate: G$1
# Pad Drawn: pin name: SDA pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: AVDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SCL pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TRIG pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: LVLD pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: FVLD pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: INT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: IOVDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: D7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: MCLK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: D5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: PCLK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: D2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-10.16', 'y': '23.114', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-10.16', 'y': '-23.114', 'size': '1.778', 'layer': '96', 'align': 'top-left', 'text': '>Value'}]
# part_name: C18 part_value: 1.0uF symbol_name: CAP x: 236.22 y: 35.56 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C19 part_value: 1.0uF symbol_name: CAP x: 266.7 y: 35.56 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: J6 part_value: QWIIC_RIGHT_ANGLE symbol_name: I2C_STANDARD x: 386.08 y: 200.66 rot: R180 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '-5.08', 'y': '-5.334', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}, {'x': '-5.08', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-4.572', 'y': '2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SDA'}, {'x': '-4.572', 'y': '0', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'VCC'}, {'x': '-4.572', 'y': '-2.54', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'GND'}, {'x': '-4.572', 'y': '5.08', 'size': '1.778', 'layer': '94', 'font': 'vector', 'align': 'center-left', 'text': 'SCL'}]
# text content: SDA
# text content: VCC
# text content: GND
# text content: SCL
# part_name: GND28 part_value:  symbol_name: DGND x: 375.92 y: 190.5 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: R13 part_value: 10k symbol_name: RESISTOR x: 203.2 y: 198.12 rot: R90 gate: G$1
# here are the texts: [{'x': '0', 'y': '1.524', 'size': '1.778', 'layer': '95', 'font': 'vector', 'align': 'bottom-center', 'text': '>NAME'}, {'x': '0', 'y': '-1.524', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY24 part_value:  symbol_name: 3.3V x: 236.22 y: 45.72 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY15 part_value:  symbol_name: 3.3V x: 276.86 y: 78.74 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY16 part_value:  symbol_name: 3.3V x: 373.38 y: 203.2 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: U3 part_value:  symbol_name: LIS2DH12 x: 220.98 y: 68.58 rot: R0 gate: G$1
# Pad Drawn: pin name: VDD_IO pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: GND pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: INT1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: INT2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: RES pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SDA/SDI/SDO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SDO/SA0 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: CS pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SCL/SPC pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-10.16', 'y': '12.954', 'size': '1.778', 'layer': '95', 'text': '>Name'}, {'x': '-10.16', 'y': '-10.414', 'size': '1.778', 'layer': '96', 'align': 'top-left', 'text': '>Value'}]
# part_name: GND36 part_value:  symbol_name: DGND x: 205.74 y: 55.88 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND35 part_value:  symbol_name: DGND x: 195.58 y: 60.96 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND34 part_value:  symbol_name: DGND x: 187.96 y: 60.96 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: C16 part_value: 0.1uF symbol_name: CAP x: 187.96 y: 68.58 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: C17 part_value: 10uF symbol_name: CAP x: 195.58 y: 68.58 rot: R0 gate: G$1
# here are the texts: [{'x': '1.524', 'y': '2.921', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '1.524', 'y': '-2.159', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}]
# part_name: SUPPLY21 part_value:  symbol_name: 3.3V x: 236.22 y: 81.28 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY20 part_value:  symbol_name: 3.3V x: 205.74 y: 81.28 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY23 part_value:  symbol_name: 3.3V x: 195.58 y: 76.2 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY22 part_value:  symbol_name: 3.3V x: 187.96 y: 76.2 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: J4 part_value: SMD symbol_name: CONN_08 x: 355.6 y: 144.78 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-5.08', 'y': '-12.446', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '-5.08', 'y': '13.208', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J8 part_value: PTH symbol_name: CONN_08 x: 378.46 y: 144.78 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-5.08', 'y': '-12.446', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '-5.08', 'y': '13.208', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J12 part_value: PTH symbol_name: CONN_08 x: 401.32 y: 144.78 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '-5.08', 'y': '-12.446', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '-5.08', 'y': '13.208', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: SUPPLY5 part_value:  symbol_name: 1.8V x: 363.22 y: 157.48 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: J14 part_value: PTH symbol_name: CONN_12 x: 378.46 y: 63.5 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J22 part_value: PTH symbol_name: CONN_12 x: 378.46 y: 101.6 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J23 part_value: PTH symbol_name: CONN_12 x: 353.06 y: 99.06 rot: R180 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 7 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 8 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 9 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 10 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 11 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 12 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J24 part_value: PTH symbol_name: CONN_12 x: 353.06 y: 60.96 rot: R180 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 3 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 4 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 5 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 6 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 7 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 8 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 9 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 10 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 11 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: 12 pin_angle_deg_final: 0.0 ha: left va: center
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J25 part_value: PTH symbol_name: CONN_12 x: 401.32 y: 63.5 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J26 part_value: PTH symbol_name: CONN_12 x: 401.32 y: 101.6 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: GND1 part_value:  symbol_name: DGND x: 340.36 y: 43.18 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND23 part_value:  symbol_name: DGND x: 203.2 y: 187.96 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: TGT_BOOT part_value:  symbol_name: SMT-JUMPER_2_NC_TRACE x: 73.66 y: 149.86 rot: R180 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: SUPPLY6 part_value:  symbol_name: 3.3V x: 365.76 y: 160.02 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY17 part_value:  symbol_name: 1.8V x: 386.08 y: 157.48 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY26 part_value:  symbol_name: 3.3V x: 388.62 y: 160.02 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY27 part_value:  symbol_name: 1.8V x: 408.94 y: 157.48 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY28 part_value:  symbol_name: 3.3V x: 411.48 y: 160.02 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: GND30 part_value:  symbol_name: DGND x: 363.22 y: 132.08 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND40 part_value:  symbol_name: DGND x: 386.08 y: 132.08 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: GND41 part_value:  symbol_name: DGND x: 408.94 y: 132.08 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: FD1 part_value:  symbol_name: FIDUCIAL x: 429.26 y: 33.02 rot: R0 gate: G$1
# here are the texts: []
# part_name: FD2 part_value:  symbol_name: FIDUCIAL x: 426.72 y: 33.02 rot: R0 gate: G$1
# here are the texts: []
# part_name: FD3 part_value:  symbol_name: FIDUCIAL x: 426.72 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: FD4 part_value:  symbol_name: FIDUCIAL x: 429.26 y: 30.48 rot: R0 gate: G$1
# here are the texts: []
# part_name: LOGO1 part_value:  symbol_name: OSHW-LOGO x: 411.48 y: 254.0 rot: R0 gate: G$1
# here are the texts: []
# part_name: TGT_SWD_CLK part_value:  symbol_name: SMT-JUMPER_2_NC_TRACE x: 119.38 y: 198.12 rot: R0 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: U5 part_value: 3.3V symbol_name: V-REG-LDO_NO-BP x: 78.74 y: 246.38 rot: R0 gate: G$1
# here are the texts: [{'x': '-7.62', 'y': '7.874', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}, {'x': '-7.62', 'y': '-7.874', 'size': '1.778', 'layer': '96', 'font': 'vector', 'align': 'top-left', 'text': '>VALUE'}]
# part_name: GND42 part_value:  symbol_name: DGND x: 66.04 y: 236.22 rot: R0 gate: 1
# here are the texts: [{'x': '0', 'y': '-0.254', 'size': '1.778', 'layer': '96', 'align': 'top-center', 'text': '>VALUE'}]
# part_name: SUPPLY30 part_value:  symbol_name: 3.3V x: 88.9 y: 254.0 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: SUPPLY29 part_value:  symbol_name: V_USB x: 66.04 y: 254.0 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: U1 part_value:  symbol_name: DAPLINK_MKL26Z x: 88.9 y: 187.96 rot: R0 gate: G$1
# Pad Drawn: pin name: IF_!RESET pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: SW_!RESET!_BTN pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: NRESET_FB_BL pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_D+ pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_D- pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: USB_VBUS pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VREGIN pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VOUT33 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDD pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VDDA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSSA pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSS1 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: VSS2 pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: XTALIN pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: XTALOUT pin_angle_deg_final: 0.0 ha: left va: center
# Pad Drawn: pin name: LED_MSD pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: LED_HID pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: LED_UART pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TGT_SWO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TGT_SWDIO pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TGT_SWCLK pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TGT_NRESET pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: WAKE_NREQ pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: SLEEP_NREQ pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TGT_TX pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: TGT_RX pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: NC1 pin_angle_deg_final: 90.0 ha: left va: center
# Pad Drawn: pin name: NC2 pin_angle_deg_final: 90.0 ha: left va: center
# Pad Drawn: pin name: NC4 pin_angle_deg_final: 90.0 ha: left va: center
# Pad Drawn: pin name: NC5 pin_angle_deg_final: 90.0 ha: left va: center
# Pad Drawn: pin name: NC6 pin_angle_deg_final: 90.0 ha: left va: center
# Pad Drawn: pin name: NC7 pin_angle_deg_final: 90.0 ha: left va: center
# here are the texts: [{'x': '-17.78', 'y': '30.48', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': 'MKL26Z128VFM4'}]
# text content: MKL26Z128VFM4
# part_name: LOGO2 part_value:  symbol_name: SFE_LOGO_NAME_FLAME x: 337.82 y: 241.3 rot: R0 gate: G$1
# here are the texts: []
# part_name: TP1 part_value: INTFC_SWDIO symbol_name: TEST-POINT x: 101.6 y: 144.78 rot: R0 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: TP2 part_value: INTFC_SWDCLK symbol_name: TEST-POINT x: 101.6 y: 142.24 rot: R0 gate: G$1
# here are the texts: [{'x': '-2.54', 'y': '2.54', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>Name'}, {'x': '-2.54', 'y': '-2.54', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>Value'}]
# part_name: SUPPLY7 part_value:  symbol_name: 3.3V x: 17.78 y: 228.6 rot: R0 gate: G$1
# here are the texts: [{'x': '0', 'y': '2.794', 'size': '1.778', 'layer': '96', 'align': 'bottom-center', 'text': '>VALUE'}]
# part_name: J5 part_value:  symbol_name: CONN_12 x: 355.6 y: 101.6 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# part_name: J9 part_value:  symbol_name: CONN_12 x: 355.6 y: 63.5 rot: R0 gate: G$1
# Pad Drawn: pin name: 1 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 2 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 3 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 4 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 5 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 6 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 7 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 8 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 9 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 10 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 11 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# Pad Drawn: pin name: 12 pin_angle_deg_final: 180.0 ha: right va: center
# left 0 or 180 Here
# here are the texts: [{'x': '0', 'y': '-20.066', 'size': '1.778', 'layer': '96', 'font': 'vector', 'text': '>VALUE'}, {'x': '0', 'y': '15.748', 'size': '1.778', 'layer': '95', 'font': 'vector', 'text': '>NAME'}]
# label: LED_MSD rot: 270
# label: LED_HID rot: 270
# label: LED_UART rot: 270
# label: USB_D+_R rot: 0
# label: USB_D+_R rot: 180
# label: USB_D-_R rot: 0
# label: USB_D-_R rot: 180
# label: USB_D+_P rot: 180
# label: USB_D+_P rot: 0
# label: USB_D-_P rot: 180
# label: USB_D-_P rot: 0
# label: INTFC_SWDIO rot: 0
# label: INTFC_NC6 rot: 0
# label: INTFC_NC5 rot: 0
# label: INTFC_SWDCLK rot: 0
# label: !INTFC_RST rot: 0
# label: !INTFC_RST rot: 0
# label: !INTFC_RST rot: 180
# label: !INTFC_RST rot: 180
# label: TGT_TX rot: 0
# label: TGT_TX rot: 180
# label: TGT_RX rot: 0
# label: TGT_RX rot: 180
# label: TGT_SWCLK rot: 0
# label: TGT_SWCLK rot: 180
# label: TGT_SWCLK rot: 0
# label: TGT_SWDIO rot: 0
# label: TGT_SWDIO rot: 180
# label: TGT_SWDIO rot: 0
# label: TGT_SWO rot: 0
# label: TGT_SWO rot: 0
# label: TGT_SWO rot: 0
# label: !TGT_RST rot: 0
# label: !TGT_RST rot: 0
# label: !TGT_RST rot: 180
# label: PDM_DATA rot: 0
# label: PDM_DATA rot: 180
# label: PDM_CLK rot: 0
# label: PDM_CLK rot: 180
# label: SCL rot: 0
# label: SCL rot: 180
# label: SCL rot: 0
# label: SCL rot: 0
# label: SDA rot: 0
# label: SDA rot: 180
# label: SDA rot: 0
# label: SDA rot: 0
# label: CAMERA_D1 rot: 0
# label: CAMERA_D1 rot: 0
# label: CAMERA_D3 rot: 0
# label: CAMERA_D3 rot: 0
# label: CAMERA_D4 rot: 0
# label: CAMERA_D4 rot: 0
# label: CAMERA_D5 rot: 0
# label: CAMERA_D5 rot: 0
# label: CAMERA_D6 rot: 0
# label: CAMERA_D6 rot: 0
# label: CAMERA_D7 rot: 0
# label: CAMERA_D7 rot: 0
# label: CAMERA_VSYNC rot: 0
# label: CAMERA_VSYNC rot: 0
# label: CAMERA_HSYNC rot: 0
# label: CAMERA_HSYNC rot: 0
# label: CAMERA_PCLK rot: 0
# label: CAMERA_PCLK rot: 0
# label: CAMERA_D0 rot: 0
# label: CAMERA_D0 rot: 0
# label: CAMERA_D2 rot: 0
# label: CAMERA_D2 rot: 0
# label: CAMERA_TRIG rot: 180
# label: CAMERA_TRIG rot: 0
# label: CAMERA_INT rot: 180
# label: CAMERA_INT rot: 0
# label: CAMERA_MCLK rot: 0
# label: CAMERA_MCLK rot: 0
# label: D44 rot: 0
# label: D44 rot: 0
# label: D44 rot: 0
# label: D44 rot: 0
# label: D40 rot: 0
# label: D40 rot: 0
# label: D40 rot: 0
# label: D40 rot: 0
# label: D39 rot: 0
# label: D39 rot: 0
# label: D39 rot: 0
# label: D39 rot: 0
# label: D38 rot: 0
# label: D38 rot: 0
# label: D38 rot: 0
# label: D38 rot: 0
# label: D43 rot: 0
# label: D43 rot: 0
# label: D43 rot: 0
# label: D43 rot: 0
# label: D42 rot: 0
# label: D42 rot: 0
# label: D42 rot: 0
# label: D42 rot: 0
# label: D41 rot: 0
# label: D41 rot: 0
# label: D41 rot: 0
# label: D41 rot: 0
# label: D23_LED rot: 0
# label: D23_LED rot: 90
# label: D23_LED rot: 0
# label: D23_LED rot: 0
# label: D23_LED rot: 0
# label: D25 rot: 0
# label: D25 rot: 0
# label: D25 rot: 0
# label: D25 rot: 0
# label: D26 rot: 0
# label: D26 rot: 0
# label: D26 rot: 0
# label: D26 rot: 0
# label: D27 rot: 0
# label: D27 rot: 0
# label: D27 rot: 0
# label: D27 rot: 0
# label: D28 rot: 0
# label: D28 rot: 0
# label: D28 rot: 0
# label: D28 rot: 0
# label: D36 rot: 0
# label: D36 rot: 0
# label: D36 rot: 0
# label: D36 rot: 0
# label: D37 rot: 0
# label: D37 rot: 0
# label: D37 rot: 0
# label: D37 rot: 0
# label: D45 rot: 0
# label: D45 rot: 0
# label: D45 rot: 0
# label: D45 rot: 0
# label: D13 rot: 180
# label: D13 rot: 0
# label: D13 rot: 0
# label: D13 rot: 0
# label: D16 rot: 180
# label: D16 rot: 0
# label: D16 rot: 0
# label: D16 rot: 0
# label: D29 rot: 180
# label: D29 rot: 0
# label: D29 rot: 0
# label: D29 rot: 0
# label: D31 rot: 180
# label: D31 rot: 0
# label: D31 rot: 0
# label: D31 rot: 0
# label: D32 rot: 180
# label: D32 rot: 0
# label: D32 rot: 0
# label: D32 rot: 0
# label: D33 rot: 180
# label: D33 rot: 0
# label: D33 rot: 0
# label: D33 rot: 0
# label: D34 rot: 180
# label: D34 rot: 0
# label: D34 rot: 0
# label: D34 rot: 0
# label: D24 rot: 0
# label: D24 rot: 0
# label: D24 rot: 0
# label: D24 rot: 0
# label: D35 rot: 180
# label: D35 rot: 0
# label: D35 rot: 0
# label: D35 rot: 0
# label: TGT_BOOT rot: 180
# label: TGT_BOOT rot: 180
# label: V_USB rot: 0
# label: V_USB rot: 0
# label: V_USB rot: 90
# label: V_USB rot: 90
# label: V_USB rot: 90
# label: V_USB rot: 180
# /var/folders/tl/q2dlpcnd685cw606gn_pd05h0000gn/T/ipykernel_38471/3723974411.py:1273: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# plt saved
# Skipping /Users/linkaiyuan/文件/PSU/products/SparkFun_Artemis_Development_Kit_with_Camera/ArtemisDevKit.sch due to error: name 'class_map' is not defined
# Traceback (most recent call last):
#   File "/var/folders/tl/q2dlpcnd685cw606gn_pd05h0000gn/T/ipykernel_38471/8854758.py", line 62, in <module>
#     if class_map is not None:
#        ^^^^^^^^^
# NameError: name 'class_map' is not defined

# %%
devicesets
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 devicesets
#
# NameError: name 'devicesets' is not defined

# %% [markdown]
# ## val move to train

# %%
import os
import shutil
import random

# Change this to your actual dataset root
dataset_dir = '/Users/linkaiyuan/文件/PSU/yolo_training_13/dataset'

val_images_dir = os.path.join(dataset_dir, 'val/images')
val_labels_dir = os.path.join(dataset_dir, 'val/labels')

train_images_dir = os.path.join(dataset_dir, 'train/images')
train_labels_dir = os.path.join(dataset_dir, 'train/labels')

# List all images in validation
val_images = [f for f in os.listdir(val_images_dir) if f.endswith(('.jpg', '.png'))]

# Shuffle and select N images to move
random.seed(42)
n_to_move = 200  # change as needed
selected = random.sample(val_images, min(n_to_move, len(val_images)))

for img_file in selected:
    label_file = os.path.splitext(img_file)[0] + '.txt'

    # Full source paths
    src_img = os.path.join(val_images_dir, img_file)
    src_lbl = os.path.join(val_labels_dir, label_file)

    # Full destination paths
    dst_img = os.path.join(train_images_dir, img_file)
    dst_lbl = os.path.join(train_labels_dir, label_file)

    # Move image and label
    shutil.move(src_img, dst_img)
    if os.path.exists(src_lbl):
        shutil.move(src_lbl, dst_lbl)
    else:
        print(f"[WARNING] No label found for {img_file}")
